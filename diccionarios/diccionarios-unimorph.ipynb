# %% [markdown]
# # **Lingüística computacional 1LIN-11 2021-2**
# ### Roberto Zariquiey Biondi, rzariquiey@pucp.edu.pe
# ### Javier Vera Zúñiga, javier.vera@pucv.cl

# %% [markdown]
# ### Diccionarios y unimorph!

# %% [markdown]
# #### DATOS

# %%
## https://github.com/unimorph/ame
## usamos un poco de magia para leer los datos 

import pandas as pd

datos = pd.read_csv('datos/que', sep='\t', header=None)
datos.columns = ['formas','inflexiones','códigos']

# %%
datos = datos[datos['códigos'].str.startswith('V')]

# %%
datos
# Out:
#             formas      inflexiones          códigos
# 256     achalachiy  achalachichunku   V;IMP;POS;3;PL
# 257     achalachiy    achalachichun   V;IMP;POS;3;SG
# 258     achalachiy      achalachina       V.PTCP;FUT
# 259     achalachiy   achalachinchik  V;PRS;1+INCL;PL
# 260     achalachiy      achalachini       V;PRS;1;SG
# ...            ...              ...              ...
# 179743       yuyay      yuyasunchik  V;FUT;1+INCL;PL
# 179744       yuyay        yuyaychik   V;IMP;POS;2;PL
# 179763       yuyay          yuyayku  V;PRS;1+EXCL;PL
# 180001       yuyay            yuyay   V;IMP;POS;2;SG
# 180002       yuyay            yuyay           V;NFIN
#
# [26404 rows x 3 columns]

# %%
lemas = list(datos['formas'])

# %%
codigos = list(datos['códigos'])

# %%
inflexiones = list(datos['inflexiones'])

# %%
print(len(lemas))
# Out:
# 26404

# %% [markdown]
# #### DICCIONARIOS

# %% [markdown]
# Nuestro primer objetivo es construir un diccionario de la forma {lema:lista_inflexiones, ...} donde lista_inflexiones es una lista de todas las inflexiones anotadas para un lema

# %%
## Primero, definimos una lista de lemas únicos

lemas_unicos = []

## recorremos la lista de lemas
for lema in lemas:
    ## solo agregamos si no está en lemas_unicos
    if lema not in lemas_unicos:
        lemas_unicos+=[lema]

# %%
print(len(lemas_unicos))
# Out:
# 644

# %%
## definimos un diccionario vacío

D_lema_inflex = {}

## recorremos la lista de lemas_unicos
for lema in lemas_unicos:
    ## agregamos en cada iteración, una lista vacía :)
    D_lema_inflex[lema]=[]

# %%
D_lema_inflex
# Out:
# {'achalachiy': [],
#  'achalakuy': [],
#  'achalay': [],
#  'achhiy': [],
#  'achikyay': [],
#  'achiy': [],
#  'achkachay': [],
#  'achuray': [],
#  'akay': [],
#  'akllay': [],
#  'aklluy': [],
#  'aklluykachay': [],
#  'akulliy': [],
#  'alawchay': [],
#  'alayrichiy': [],
#  'allay': [],
#  'allichay': [],
#  'allichiy': [],
#  'allinchay': [],
#  'allinyachiy': [],
#  'allinyay': [],
#  'allipanakuy': [],
#  'allipunakuy': [],
#  'allpachay': [],
#  'allpanay': [],
#  'allpayachiy': [],
#  'allpay': [],
#  'allquchakuy': [],
#  'allquchay': [],
#  'allwiy': [],
#  'alqay': [],
#  'amachay': [],
#  'amañay': [],
#  'ama ñiy': [],
#  'amatay': [],
#  'amuyay': [],
#  'añaychay': [],
#  'añaynichiy': [],
#  'anchachay': [],
#  'anchayay': [],
#  'anchaykachay': [],
#  'añikuy': [],
#  'añiy': [],
#  'ankallikuy': [],
#  'anqusay': [],
#  'anschiykachay': [],
#  'anschurichiy': [],
#  'anschuriy': [],
#  'anschuykunakuy': [],
#  'anschuykuy': [],
#  'antachay': [],
#  'apakamuy': [],
#  'apakapuy': [],
#  'apamuy': [],
#  'apatatay': [],
#  'apay': [],
#  'apaykuy': [],
#  'apaysiy': [],
#  'apichakuy': [],
#  'apichay': [],
#  'apuchay': [],
#  'aqhayay': [],
#  'aqtuy': [],
#  'aquchay': [],
#  'araway': [],
#  'arinsay': [],
#  'armakuy': [],
#  'armay': [],
#  'arphayay': [],
#  'arqhipay': [],
#  'ashiy': [],
#  'asipayay': [],
#  'asiy': [],
#  'askhayachiy': [],
#  'askhayay': [],
#  'asllayachiy': [],
#  'asnay': [],
#  'aspiy': [],
#  'astakuy': [],
#  "asut'iy": [],
#  'asuy': [],
#  'asuykuy': [],
#  'atikay': [],
#  'atilchay': [],
#  'atipachikuy': [],
#  'atipanakuy': [],
#  'atiy': [],
#  'awankay': [],
#  'awannay': [],
#  'away': [],
#  'awñiy': [],
#  'awqanakuy': [],
#  'awqay': [],
#  'awsay': [],
#  'aycharay': [],
#  'aykhuy': [],
#  'aylluchakuy': [],
#  'ayllunakuy': [],
#  'aylluy': [],
#  'aymuray': [],
#  'ayniy': [],
#  'ayñiy': [],
#  'aypay': [],
#  'ayphayay': [],
#  'aypuriy': [],
#  'ayqeykuy': [],
#  'ayqichiy': [],
#  'ayqiy': [],
#  'aysay': [],
#  'aysaysiy': [],
#  'ayway': [],
#  'bahay': [],
#  "ch'achuy": [],
#  'chahchay': [],
#  'chahrachay': [],
#  'chahrakuy': [],
#  'chahraysiy': [],
#  'chakachay': [],
#  'chakachikuy': [],
#  'chakannay': [],
#  'chakatay': [],
#  "ch'akayay": [],
#  "ch'akichikuy": [],
#  "ch'akichiy": [],
#  "ch'akiy": [],
#  'chakuy': [],
#  "ch'allay": [],
#  'challpuy': [],
#  'challway': [],
#  'chamqay': [],
#  'chanchay': [],
#  'chaninchay': [],
#  'chanqay': [],
#  'chanqaykukuy': [],
#  'chanqaykuy': [],
#  'chanqiyay': [],
#  'chanrararay': [],
#  "ch'antay": [],
#  'chantay': [],
#  'chapakuy': [],
#  'chapatiyay': [],
#  'chapay': [],
#  "ch'aphchay": [],
#  "ch'aphranay": [],
#  'chapinnay': [],
#  'chapiy': [],
#  'chapukuy': [],
#  'chapuy': [],
#  "ch'aqchuy": [],
#  "ch'aqiy": [],
#  "ch'aqlay": [],
#  "ch'aqway": [],
#  "ch'aranchay": [],
#  'chariy': [],
#  "ch'arkiy": [],
#  "ch'arqayay": [],
#  'chaskiy': [],
#  'chaskiykuy': [],
#  "ch'aspay": [],
#  "ch'atay": [],
#  "ch'away": [],
#  'chaway': [],
#  'chawpichay': [],
#  'chayakamuy': [],
#  'chayamuy': [],
#  'chayanpuy': [],
#  'chayay': [],
#  'chichuyay': [],
#  'chihlluy': [],
#  'chikachay': [],
#  'chikchiy': [],
#  "ch'illchichiy": [],
#  "ch'illmipakuy": [],
#  "ch'illuchay": [],
#  'chimpachiy': [],
#  'chimpay': [],
#  'chinkachiy': [],
#  'chinkakapuy': [],
#  'chinkarpariy': [],
#  'chinkay': [],
#  'chinkaykuy': [],
#  'chinpiy': [],
#  'chinruykachiy': [],
#  "ch'ipchiy": [],
#  "ch'ipihyay": [],
#  "ch'ipuy": [],
#  'chiqachakuy': [],
#  "ch'iqanay": [],
#  'chiqaqchay': [],
#  'chiqchiykachay': [],
#  "ch'iqichiy": [],
#  "ch'iqmichiy": [],
#  'chiqnikuy': [],
#  'chiqniy': [],
#  "ch'iqtay": [],
#  "ch'iquy": [],
#  'chiraray': [],
#  'chiriyachiy': [],
#  'chiriy': [],
#  "ch'irway": [],
#  "ch'isiyay": [],
#  "ch'iwkachiy": [],
#  'chuchuyay': [],
#  'chuhchannay': [],
#  'chuhchuy': [],
#  "ch'uhllay": [],
#  "ch'uhtanay": [],
#  "ch'uhtay": [],
#  'chukullikuy': [],
#  "ch'ullchuy": [],
#  'chulluchiy': [],
#  "ch'ullullulluy": [],
#  'chulluy': [],
#  "ch'umay": [],
#  'chumpiy': [],
#  "ch'unqay": [],
#  'chuqay': [],
#  "ch'uqchuy": [],
#  'churakuy': [],
#  'churay': [],
#  'churichakuy': [],
#  'churiyay': [],
#  'churpuy': [],
#  "ch'usay": [],
#  'chutay': [],
#  "ch'utiy": [],
#  "ch'uyanay": [],
#  "ch'uyanchay": [],
#  "ch'uyayachiy": [],
#  "ch'uychuy": [],
#  "hak'uchay": [],
#  'halay': [],
#  'hallmay': [],
#  'hallpay': [],
#  "hallp'iy": [],
#  'hampiy': [],
#  'hamurpay': [],
#  "hamut'ay": [],
#  'hamuy': [],
#  "hank'ay": [],
#  'hanpuy': [],
#  "hant'arqay": [],
#  "hanuk'ay": [],
#  'hanyay': [],
#  'hapay': [],
#  "hap'iy": [],
#  'haratay': [],
#  'haraway': [],
#  'harawiy': [],
#  'harchiyay': [],
#  "hark'ay": [],
#  'harwiy': [],
#  "hat'alliy": [],
#  "hat'ansillay": [],
#  'hatariy': [],
#  'hatunchay': [],
#  "hawch'ay": [],
#  'hawiy': [],
#  'hawkay': [],
#  'haylliy': [],
#  'haymay': [],
#  'hayratachiy': [],
#  'haytarakuy': [],
#  "hayt'ay": [],
#  'haywariy': [],
#  'hayway': [],
#  'haywaykachay': [],
#  "hephq'ay": [],
#  "hich'ay": [],
#  "hik'ipakuy": [],
#  "hik'iy": [],
#  'hinay': [],
#  "hink'iy": [],
#  "hip'iy": [],
#  "hiq'ipay": [],
#  'huchachakuy': [],
#  "huch'uiyachiy": [],
#  "huch'uiyay": [],
#  'huhllay': [],
#  'huhyay': [],
#  "humint'ay": [],
#  'huñiy': [],
#  "hunp'iy": [],
#  "hunt'achiy": [],
#  "hunt'apuy": [],
#  "hunt'ay": [],
#  'huñuchiy': [],
#  'huñunakuy': [],
#  'huñuy': [],
#  'huñuysiy': [],
#  'hunyay': [],
#  "huq'ariy": [],
#  'huqariy': [],
#  "huq'uchay": [],
#  'hurquy': [],
#  "husk'ay": [],
#  "hut'kuy": [],
#  "hut'uyay": [],
#  'icharay': [],
#  'ichhuy': [],
#  'ichiy': [],
#  'ikmayay': [],
#  'illapay': [],
#  'illay': [],
#  'imanay': [],
#  'iñiy': [],
#  'inqhiykachay': [],
#  'intuy': [],
#  'iqhay': [],
#  'irpay': [],
#  'irqiyay': [],
#  'ischuchay': [],
#  'ishkiy': [],
#  'iskaychay': [],
#  'iskayyay': [],
#  'iskiy': [],
#  'ismay': [],
#  'ismuy': [],
#  'ispapakuy': [],
#  'ispay': [],
#  'kachay': [],
#  'kachuy': [],
#  'kallchay': [],
#  'kallpay': [],
#  'kañay': [],
#  "k'anchay": [],
#  'kanchay': [],
#  'kaniy': [],
#  'kañiy': [],
#  'kapuy': [],
#  'kawsay': [],
#  'kay': [],
#  'khachuy': [],
#  'khallkachikuy': [],
#  'khallkiy': [],
#  'khipuy': [],
#  'khuyay': [],
#  'kichay': [],
#  'kuchuy': [],
#  'kullay': [],
#  'kulliyay': [],
#  "k'umuy": [],
#  'kumuy': [],
#  'kunay': [],
#  'kunununuy': [],
#  'kusikuy': [],
#  'kusiy': [],
#  'kutay': [],
#  'kutichiy': [],
#  'kutipakuy': [],
#  'kutiy': [],
#  'kuyuy': [],
#  'laray': [],
#  'layqay': [],
#  'liyiy': [],
#  'llakiy': [],
#  'llalliy': [],
#  "llamk'ay": [],
#  'llamkay': [],
#  'llamkhay': [],
#  "llamp'uy": [],
#  'llaqway': [],
#  'llasay': [],
#  "llik'iy": [],
#  'llimphiy': [],
#  'lliphiy': [],
#  'lliphlliy': [],
#  'llullay': [],
#  'llulluy': [],
#  'llulmiy': [],
#  'lluqsiy': [],
#  'machay': [],
#  'mallay': [],
#  'malliy': [],
#  'mañay': [],
#  'manchay': [],
#  'maqakuy': [],
#  'maqanakuy': [],
#  'maqay': [],
#  "marq'ay": [],
#  'maskhay': [],
#  'may': [],
#  'mayllakuy': [],
#  'mayllay': [],
#  'mayway': [],
#  'michiy': [],
#  'mikhuy': [],
#  'millay': [],
#  "millp'uy": [],
#  "mink'ay": [],
#  'miray': [],
#  'mitikuy': [],
#  "mitk'ay": [],
#  'mitmay': [],
#  "much'ay": [],
#  'muchuy': [],
#  'munay': [],
#  'musphay': [],
#  'musquchay': [],
#  'musquy': [],
#  'mutkhiy': [],
#  'muyuy': [],
#  'nanay': [],
#  "ñaqch'ay": [],
#  'ñawilliy': [],
#  'ñawinchay': [],
#  'ñawiriy': [],
#  'ñawiy': [],
#  'ñawiykachay': [],
#  'ninay': [],
#  'ninayay': [],
#  "ñit'iy": [],
#  'niy': [],
#  'ñiy': [],
#  'pakay': [],
#  "p'akiy": [],
#  'pallay': [],
#  'pallquy': [],
#  "p'ampachay": [],
#  'pampachay': [],
#  "p'ampay": [],
#  'pantay': [],
#  'paqariy': [],
#  'paqtay': [],
#  'paray': [],
#  'parlay': [],
#  'paskay': [],
#  'paway': [],
#  'phaqsay': [],
#  'phaway': [],
#  'phawaykachay': [],
#  'phiñay': [],
#  'phinkiy': [],
#  'phukuy': [],
#  'phutiy': [],
#  'phuyuy': [],
#  'pichay': [],
#  'pirqay': [],
#  'pirway': [],
#  'pisipay': [],
#  'pisiy': [],
#  "p'itiy": [],
#  'pituy': [],
#  'puchkay': [],
#  'puchqay': [],
#  "p'uchquy": [],
#  'pukaray': [],
#  'pukllay': [],
#  'pukyuy': [],
#  'punkiy': [],
#  'puñuy': [],
#  'puquy': [],
#  'puriy': [],
#  'pusay': [],
#  'qallariy': [],
#  'qallay': [],
#  'qapariy': [],
#  "q'apay": [],
#  "q'apiy": [],
#  "q'aray": [],
#  'qaray': [],
#  'qasay': [],
#  'qatiy': [],
#  'qayay': [],
#  'qhaway': [],
#  'qhinchachay': [],
#  'qhuruy': [],
#  'qichuy': [],
#  'qilliy': [],
#  'qillqaqhawapay': [],
#  'qillqaqhaway': [],
#  'qillqay': [],
#  "q'imikuy": [],
#  "q'imiy": [],
#  'qinchay': [],
#  "q'ipiy": [],
#  'qishyay': [],
#  'qispichiy': [],
#  'qispiy': [],
#  "q'iwiy": [],
#  'qullpay': [],
#  'qunqay': [],
#  'qunuy': [],
#  'qurichiy': [],
#  'quy': [],
#  "rak'iy": [],
#  'rampay': [],
#  'rantikuy': [],
#  'rantiy': [],
#  'rawray': [],
#  "rikch'ay": [],
#  'rikuchiy': [],
#  'rikunakuy': [],
#  'rikuriy': [],
#  'rikuy': [],
#  'rimachiy': [],
#  'rimay': [],
#  'ripuy': [],
#  'riqsiy': [],
#  "rit'iy": [],
#  'riy': [],
#  "ruk'uyay": [],
#  'rumiyay': [],
#  'ruphachiy': [],
#  'ruphay': [],
#  'ruray': [],
#  'ruruy': [],
#  'rutuy': [],
#  'saksay': [],
#  'samay': [],
#  'saphiy': [],
#  'saqiy': [],
#  'saruy': [],
#  "sat'iy": [],
#  'saway': [],
#  'sayariy': [],
#  'sayay': [],
#  "sayk'uy": [],
#  "simp'ay": [],
#  'sinchiyay': [],
#  "sinq'ay": [],
#  'sipiy': [],
#  'siqsiy': [],
#  'siray': [],
#  'siriy': [],
#  'sisay': [],
#  "suk'ay": [],
#  'sukay': [],
#  'sumay': [],
#  'supiy': [],
#  "suq'uy": [],
#  'susuy': [],
#  'sutiy': [],
#  'suway': [],
#  'suyakuy': [],
#  'suyay': [],
#  'suysuy': [],
#  'suyuy': [],
#  'takay': [],
#  'takiy': [],
#  'takuy': [],
#  'tamyay': [],
#  'tanqay': [],
#  "t'antay": [],
#  'tantay': [],
#  'tapuy': [],
#  "t'aqsay": [],
#  'taqtay': [],
#  'taripay': [],
#  'tariy': [],
#  'tarpuy': [],
#  'thantay': [],
#  'thasay': [],
#  'thasnuy': [],
#  'thatkiy': [],
#  'thuñiy': [],
#  'thupay': [],
#  'thuqay': [],
#  "t'ikay": [],
#  "t'ikray": [],
#  'tiksiy': [],
#  "t'impuchiy": [],
#  "t'impuy": [],
#  "t'ipiy": [],
#  'tipiy': [],
#  'tiqsiy': [],
#  "t'ituy": [],
#  'tiyamuy': [],
#  'tiyay': [],
#  'tukuchiy': [],
#  'tukuy': [],
#  'tupay': [],
#  'tupuy': [],
#  "t'urpuy": [],
#  "t'ustuy": [],
#  'tusuy': [],
#  'tutay': [],
#  'tutayay': [],
#  'tuytuy': [],
#  'uhuy': [],
#  'ullpukuy': [],
#  'uniy': [],
#  'unquy': [],
#  'unuyay': [],
#  'upallay': [],
#  'upyay': [],
#  'uray': [],
#  'urmay': [],
#  'usachiy': [],
#  'utqay': [],
#  'utqaychay': [],
#  'uyariy': [],
#  'uyay': [],
#  'uynikuy': [],
#  'uyniy': [],
#  'wachay': [],
#  "wach'iy": [],
#  'wallpay': [],
#  "wamp'uy": [],
#  'wanay': [],
#  'wantuy': [],
#  'wanuy': [],
#  'wañuy': [],
#  'waqachiy': [],
#  'waqay': [],
#  'waqyay': [],
#  'warkuy': [],
#  'waskay': [],
#  'watay': [],
#  'wathiyay': [],
#  'watukuy': [],
#  'watuy': [],
#  'watyay': [],
#  'waylluy': [],
#  'wayrachiy': [],
#  'wayray': [],
#  "wayt'ay": [],
#  'wichay': [],
#  "wichq'ay": [],
#  "wikch'uy": [],
#  'willay': [],
#  'willkachay': [],
#  'willkay': [],
#  'winay': [],
#  'wiñay': [],
#  'yachachiy': [],
#  'yachakuy': [],
#  'yachay': [],
#  'yalliy': [],
#  'yanapay': [],
#  'yanay': [],
#  'yañay': [],
#  'yanuy': [],
#  'yapay': [],
#  'yapuy': [],
#  'yaqullay': [],
#  'yarpay': [],
#  'yarqay': [],
#  'yarquy': [],
#  'yawnay': [],
#  'yaykuy': [],
#  'yupaychay': [],
#  'yuriy': [],
#  'yuyay': []}

# %%
len(D_lema_inflex)
# Out:
# 644

# %%
## ahora resolvemos el problema :) 

## recorremos la lista de lemas (la original). Usamos los índices!

for i in range(len(lemas)):
    ## accedemos al lema de la posición i
    lema = lemas[i]
    ## guardamos en la lista asociada las inflexiones del lema (que están en la lista inflexiones)
    D_lema_inflex[lema]+=[inflexiones[i]]

# %%
D_lema_inflex
# Out:
# {'achalachiy': ['achalachichunku',
#   'achalachichun',
#   'achalachina',
#   'achalachinchik',
#   'achalachini',
#   'achalachinkichik',
#   'achalachinkichik',
#   'achalachinki',
#   'achalachinki',
#   'achalachinku',
#   'achalachinqaku',
#   'achalachinqa',
#   'achalachin',
#   'achalachiq',
#   'achalachirqanchik',
#   'achalachirqaniku',
#   'achalachirqani',
#   'achalachirqankichik',
#   'achalachirqanki',
#   'achalachirqanku',
#   'achalachirqan',
#   'achalachisaqku',
#   'achalachisaq',
#   'achalachispa',
#   'achalachisqanchik',
#   'achalachisqaniku',
#   'achalachisqani',
#   'achalachisqankichik',
#   'achalachisqanki',
#   'achalachisqanku',
#   'achalachisqan',
#   'achalachisqa',
#   'achalachisunchik',
#   'achalachiychik',
#   'achalachiyku',
#   'achalachiy',
#   'achalachiy',
#   'amaachalachichunchu',
#   'amaachalachichunkuchu',
#   'amaachalachiychikchu',
#   'amaachalachiychu'],
#  'achalakuy': ['achalakuchunku',
#   'achalakuchun',
#   'achalakuna',
#   'achalakunchik',
#   'achalakuni',
#   'achalakunkichik',
#   'achalakunkichik',
#   'achalakunki',
#   'achalakunki',
#   'achalakunku',
#   'achalakunqaku',
#   'achalakunqa',
#   'achalakun',
#   'achalakuq',
#   'achalakurqanchik',
#   'achalakurqaniku',
#   'achalakurqani',
#   'achalakurqankichik',
#   'achalakurqanki',
#   'achalakurqanku',
#   'achalakurqan',
#   'achalakusaqku',
#   'achalakusaq',
#   'achalakuspa',
#   'achalakusqanchik',
#   'achalakusqaniku',
#   'achalakusqani',
#   'achalakusqankichik',
#   'achalakusqanki',
#   'achalakusqanku',
#   'achalakusqan',
#   'achalakusqa',
#   'achalakusunchik',
#   'achalakuychik',
#   'achalakuyku',
#   'achalakuy',
#   'achalakuy',
#   'amaachalakuchunchu',
#   'amaachalakuchunkuchu',
#   'amaachalakuychikchu',
#   'amaachalakuychu'],
#  'achalay': ['achalachunku',
#   'achalachun',
#   'achalana',
#   'achalanchik',
#   'achalani',
#   'achalankichik',
#   'achalankichik',
#   'achalanki',
#   'achalanki',
#   'achalanku',
#   'achalanqaku',
#   'achalanqa',
#   'achalan',
#   'achalaq',
#   'achalarqanchik',
#   'achalarqaniku',
#   'achalarqani',
#   'achalarqankichik',
#   'achalarqanki',
#   'achalarqanku',
#   'achalarqan',
#   'achalasaqku',
#   'achalasaq',
#   'achalaspa',
#   'achalasqanchik',
#   'achalasqaniku',
#   'achalasqani',
#   'achalasqankichik',
#   'achalasqanki',
#   'achalasqanku',
#   'achalasqan',
#   'achalasqa',
#   'achalasunchik',
#   'achalaychik',
#   'achalayku',
#   'achalay',
#   'achalay',
#   'amaachalachunchu',
#   'amaachalachunkuchu',
#   'amaachalaychikchu',
#   'amaachalaychu'],
#  'achhiy': ['achhichunku',
#   'achhichun',
#   'achhina',
#   'achhinchik',
#   'achhini',
#   'achhinkichik',
#   'achhinkichik',
#   'achhinki',
#   'achhinki',
#   'achhinku',
#   'achhinqaku',
#   'achhinqa',
#   'achhin',
#   'achhiq',
#   'achhirqanchik',
#   'achhirqaniku',
#   'achhirqani',
#   'achhirqankichik',
#   'achhirqanki',
#   'achhirqanku',
#   'achhirqan',
#   'achhisaqku',
#   'achhisaq',
#   'achhispa',
#   'achhisqanchik',
#   'achhisqaniku',
#   'achhisqani',
#   'achhisqankichik',
#   'achhisqanki',
#   'achhisqanku',
#   'achhisqan',
#   'achhisqa',
#   'achhisunchik',
#   'achhiychik',
#   'achhiyku',
#   'achhiy',
#   'achhiy',
#   'amaachhichunchu',
#   'amaachhichunkuchu',
#   'amaachhiychikchu',
#   'amaachhiychu'],
#  'achikyay': ['achikyachunku',
#   'achikyachun',
#   'achikyana',
#   'achikyanchik',
#   'achikyani',
#   'achikyankichik',
#   'achikyankichik',
#   'achikyanki',
#   'achikyanki',
#   'achikyanku',
#   'achikyanqaku',
#   'achikyanqa',
#   'achikyan',
#   'achikyaq',
#   'achikyarqanchik',
#   'achikyarqaniku',
#   'achikyarqani',
#   'achikyarqankichik',
#   'achikyarqanki',
#   'achikyarqanku',
#   'achikyarqan',
#   'achikyasaqku',
#   'achikyasaq',
#   'achikyaspa',
#   'achikyasqanchik',
#   'achikyasqaniku',
#   'achikyasqani',
#   'achikyasqankichik',
#   'achikyasqanki',
#   'achikyasqanku',
#   'achikyasqan',
#   'achikyasqa',
#   'achikyasunchik',
#   'achikyaychik',
#   'achikyayku',
#   'achikyay',
#   'achikyay',
#   'amaachikyachunchu',
#   'amaachikyachunkuchu',
#   'amaachikyaychikchu',
#   'amaachikyaychu'],
#  'achiy': ['achichunku',
#   'achichun',
#   'achina',
#   'achinchik',
#   'achini',
#   'achinkichik',
#   'achinkichik',
#   'achinki',
#   'achinki',
#   'achinku',
#   'achinqaku',
#   'achinqa',
#   'achin',
#   'achiq',
#   'achirqanchik',
#   'achirqaniku',
#   'achirqani',
#   'achirqankichik',
#   'achirqanki',
#   'achirqanku',
#   'achirqan',
#   'achisaqku',
#   'achisaq',
#   'achispa',
#   'achisqanchik',
#   'achisqaniku',
#   'achisqani',
#   'achisqankichik',
#   'achisqanki',
#   'achisqanku',
#   'achisqan',
#   'achisqa',
#   'achisunchik',
#   'achiychik',
#   'achiyku',
#   'achiy',
#   'achiy',
#   'amaachichunchu',
#   'amaachichunkuchu',
#   'amaachiychikchu',
#   'amaachiychu'],
#  'achkachay': ['achkachachunku',
#   'achkachachun',
#   'achkachana',
#   'achkachanchik',
#   'achkachani',
#   'achkachankichik',
#   'achkachankichik',
#   'achkachanki',
#   'achkachanki',
#   'achkachanku',
#   'achkachanqaku',
#   'achkachanqa',
#   'achkachan',
#   'achkachaq',
#   'achkacharqanchik',
#   'achkacharqaniku',
#   'achkacharqani',
#   'achkacharqankichik',
#   'achkacharqanki',
#   'achkacharqanku',
#   'achkacharqan',
#   'achkachasaqku',
#   'achkachasaq',
#   'achkachaspa',
#   'achkachasqanchik',
#   'achkachasqaniku',
#   'achkachasqani',
#   'achkachasqankichik',
#   'achkachasqanki',
#   'achkachasqanku',
#   'achkachasqan',
#   'achkachasqa',
#   'achkachasunchik',
#   'achkachaychik',
#   'achkachayku',
#   'achkachay',
#   'achkachay',
#   'amaachkachachunchu',
#   'amaachkachachunkuchu',
#   'amaachkachaychikchu',
#   'amaachkachaychu'],
#  'achuray': ['achurachunku',
#   'achurachun',
#   'achurana',
#   'achuranchik',
#   'achurani',
#   'achurankichik',
#   'achurankichik',
#   'achuranki',
#   'achuranki',
#   'achuranku',
#   'achuranqaku',
#   'achuranqa',
#   'achuran',
#   'achuraq',
#   'achurarqanchik',
#   'achurarqaniku',
#   'achurarqani',
#   'achurarqankichik',
#   'achurarqanki',
#   'achurarqanku',
#   'achurarqan',
#   'achurasaqku',
#   'achurasaq',
#   'achuraspa',
#   'achurasqanchik',
#   'achurasqaniku',
#   'achurasqani',
#   'achurasqankichik',
#   'achurasqanki',
#   'achurasqanku',
#   'achurasqan',
#   'achurasqa',
#   'achurasunchik',
#   'achuraychik',
#   'achurayku',
#   'achuray',
#   'achuray',
#   'amaachurachunchu',
#   'amaachurachunkuchu',
#   'amaachuraychikchu',
#   'amaachuraychu'],
#  'akay': ['akachunku',
#   'akachun',
#   'akana',
#   'akanchik',
#   'akani',
#   'akankichik',
#   'akankichik',
#   'akanki',
#   'akanki',
#   'akanku',
#   'akanqaku',
#   'akanqa',
#   'akan',
#   'akaq',
#   'akarqanchik',
#   'akarqaniku',
#   'akarqani',
#   'akarqankichik',
#   'akarqanki',
#   'akarqanku',
#   'akarqan',
#   'akasaqku',
#   'akasaq',
#   'akaspa',
#   'akasqanchik',
#   'akasqaniku',
#   'akasqani',
#   'akasqankichik',
#   'akasqanki',
#   'akasqanku',
#   'akasqan',
#   'akasqa',
#   'akasunchik',
#   'akaychik',
#   'akayku',
#   'akay',
#   'akay',
#   'amaakachunchu',
#   'amaakachunkuchu',
#   'amaakaychikchu',
#   'amaakaychu'],
#  'akllay': ['akllachunku',
#   'akllachun',
#   'akllana',
#   'akllanchik',
#   'akllani',
#   'akllankichik',
#   'akllankichik',
#   'akllanki',
#   'akllanki',
#   'akllanku',
#   'akllanqaku',
#   'akllanqa',
#   'akllan',
#   'akllaq',
#   'akllarqanchik',
#   'akllarqaniku',
#   'akllarqani',
#   'akllarqankichik',
#   'akllarqanki',
#   'akllarqanku',
#   'akllarqan',
#   'akllasaqku',
#   'akllasaq',
#   'akllaspa',
#   'akllasqanchik',
#   'akllasqaniku',
#   'akllasqani',
#   'akllasqankichik',
#   'akllasqanki',
#   'akllasqanku',
#   'akllasqan',
#   'akllasqa',
#   'akllasunchik',
#   'akllaychik',
#   'akllayku',
#   'akllay',
#   'akllay',
#   'amaakllachunchu',
#   'amaakllachunkuchu',
#   'amaakllaychikchu',
#   'amaakllaychu'],
#  'aklluy': ['aklluchunku',
#   'aklluchun',
#   'aklluna',
#   'akllunchik',
#   'aklluni',
#   'akllunkichik',
#   'akllunkichik',
#   'akllunki',
#   'akllunki',
#   'akllunku',
#   'akllunqaku',
#   'akllunqa',
#   'akllun',
#   'aklluq',
#   'akllurqanchik',
#   'akllurqaniku',
#   'akllurqani',
#   'akllurqankichik',
#   'akllurqanki',
#   'akllurqanku',
#   'akllurqan',
#   'akllusaqku',
#   'akllusaq',
#   'aklluspa',
#   'akllusqanchik',
#   'akllusqaniku',
#   'akllusqani',
#   'akllusqankichik',
#   'akllusqanki',
#   'akllusqanku',
#   'akllusqan',
#   'akllusqa',
#   'akllusunchik',
#   'aklluychik',
#   'aklluyku',
#   'aklluy',
#   'aklluy',
#   'amaaklluchunchu',
#   'amaaklluchunkuchu',
#   'amaaklluychikchu',
#   'amaaklluychu'],
#  'aklluykachay': ['aklluykachachunku',
#   'aklluykachachun',
#   'aklluykachana',
#   'aklluykachanchik',
#   'aklluykachani',
#   'aklluykachankichik',
#   'aklluykachankichik',
#   'aklluykachanki',
#   'aklluykachanki',
#   'aklluykachanku',
#   'aklluykachanqaku',
#   'aklluykachanqa',
#   'aklluykachan',
#   'aklluykachaq',
#   'aklluykacharqanchik',
#   'aklluykacharqaniku',
#   'aklluykacharqani',
#   'aklluykacharqankichik',
#   'aklluykacharqanki',
#   'aklluykacharqanku',
#   'aklluykacharqan',
#   'aklluykachasaqku',
#   'aklluykachasaq',
#   'aklluykachaspa',
#   'aklluykachasqanchik',
#   'aklluykachasqaniku',
#   'aklluykachasqani',
#   'aklluykachasqankichik',
#   'aklluykachasqanki',
#   'aklluykachasqanku',
#   'aklluykachasqan',
#   'aklluykachasqa',
#   'aklluykachasunchik',
#   'aklluykachaychik',
#   'aklluykachayku',
#   'aklluykachay',
#   'aklluykachay',
#   'amaaklluykachachunchu',
#   'amaaklluykachachunkuchu',
#   'amaaklluykachaychikchu',
#   'amaaklluykachaychu'],
#  'akulliy': ['akullichunku',
#   'akullichun',
#   'akullina',
#   'akullinchik',
#   'akullini',
#   'akullinkichik',
#   'akullinkichik',
#   'akullinki',
#   'akullinki',
#   'akullinku',
#   'akullinqaku',
#   'akullinqa',
#   'akullin',
#   'akulliq',
#   'akullirqanchik',
#   'akullirqaniku',
#   'akullirqani',
#   'akullirqankichik',
#   'akullirqanki',
#   'akullirqanku',
#   'akullirqan',
#   'akullisaqku',
#   'akullisaq',
#   'akullispa',
#   'akullisqanchik',
#   'akullisqaniku',
#   'akullisqani',
#   'akullisqankichik',
#   'akullisqanki',
#   'akullisqanku',
#   'akullisqan',
#   'akullisqa',
#   'akullisunchik',
#   'akulliychik',
#   'akulliyku',
#   'akulliy',
#   'akulliy',
#   'amaakullichunchu',
#   'amaakullichunkuchu',
#   'amaakulliychikchu',
#   'amaakulliychu'],
#  'alawchay': ['alawchachunku',
#   'alawchachun',
#   'alawchana',
#   'alawchanchik',
#   'alawchani',
#   'alawchankichik',
#   'alawchankichik',
#   'alawchanki',
#   'alawchanki',
#   'alawchanku',
#   'alawchanqaku',
#   'alawchanqa',
#   'alawchan',
#   'alawchaq',
#   'alawcharqanchik',
#   'alawcharqaniku',
#   'alawcharqani',
#   'alawcharqankichik',
#   'alawcharqanki',
#   'alawcharqanku',
#   'alawcharqan',
#   'alawchasaqku',
#   'alawchasaq',
#   'alawchaspa',
#   'alawchasqanchik',
#   'alawchasqaniku',
#   'alawchasqani',
#   'alawchasqankichik',
#   'alawchasqanki',
#   'alawchasqanku',
#   'alawchasqan',
#   'alawchasqa',
#   'alawchasunchik',
#   'alawchaychik',
#   'alawchayku',
#   'alawchay',
#   'alawchay',
#   'amaalawchachunchu',
#   'amaalawchachunkuchu',
#   'amaalawchaychikchu',
#   'amaalawchaychu'],
#  'alayrichiy': ['alayrichichunku',
#   'alayrichichun',
#   'alayrichina',
#   'alayrichinchik',
#   'alayrichini',
#   'alayrichinkichik',
#   'alayrichinkichik',
#   'alayrichinki',
#   'alayrichinki',
#   'alayrichinku',
#   'alayrichinqaku',
#   'alayrichinqa',
#   'alayrichin',
#   'alayrichiq',
#   'alayrichirqanchik',
#   'alayrichirqaniku',
#   'alayrichirqani',
#   'alayrichirqankichik',
#   'alayrichirqanki',
#   'alayrichirqanku',
#   'alayrichirqan',
#   'alayrichisaqku',
#   'alayrichisaq',
#   'alayrichispa',
#   'alayrichisqanchik',
#   'alayrichisqaniku',
#   'alayrichisqani',
#   'alayrichisqankichik',
#   'alayrichisqanki',
#   'alayrichisqanku',
#   'alayrichisqan',
#   'alayrichisqa',
#   'alayrichisunchik',
#   'alayrichiychik',
#   'alayrichiyku',
#   'alayrichiy',
#   'alayrichiy',
#   'amaalayrichichunchu',
#   'amaalayrichichunkuchu',
#   'amaalayrichiychikchu',
#   'amaalayrichiychu'],
#  'allay': ['allachunku',
#   'allachun',
#   'allana',
#   'allanchik',
#   'allani',
#   'allankichik',
#   'allankichik',
#   'allanki',
#   'allanki',
#   'allanku',
#   'allanqaku',
#   'allanqa',
#   'allan',
#   'allaq',
#   'allarqanchik',
#   'allarqaniku',
#   'allarqani',
#   'allarqankichik',
#   'allarqanki',
#   'allarqanku',
#   'allarqan',
#   'allasaqku',
#   'allasaq',
#   'allaspa',
#   'allasqanchik',
#   'allasqaniku',
#   'allasqani',
#   'allasqankichik',
#   'allasqanki',
#   'allasqanku',
#   'allasqan',
#   'allasqa',
#   'allasunchik',
#   'allaychik',
#   'allayku',
#   'allay',
#   'allay',
#   'amaallachunchu',
#   'amaallachunkuchu',
#   'amaallaychikchu',
#   'amaallaychu'],
#  'allichay': ['allichachunku',
#   'allichachun',
#   'allichana',
#   'allichanchik',
#   'allichani',
#   'allichankichik',
#   'allichankichik',
#   'allichanki',
#   'allichanki',
#   'allichanku',
#   'allichanqaku',
#   'allichanqa',
#   'allichan',
#   'allichaq',
#   'allicharqanchik',
#   'allicharqaniku',
#   'allicharqani',
#   'allicharqankichik',
#   'allicharqanki',
#   'allicharqanku',
#   'allicharqan',
#   'allichasaqku',
#   'allichasaq',
#   'allichaspa',
#   'allichasqanchik',
#   'allichasqaniku',
#   'allichasqani',
#   'allichasqankichik',
#   'allichasqanki',
#   'allichasqanku',
#   'allichasqan',
#   'allichasqa',
#   'allichasunchik',
#   'allichaychik',
#   'allichayku',
#   'allichay',
#   'allichay',
#   'amaallichachunchu',
#   'amaallichachunkuchu',
#   'amaallichaychikchu',
#   'amaallichaychu'],
#  'allichiy': ['allichichunku',
#   'allichichun',
#   'allichina',
#   'allichinchik',
#   'allichini',
#   'allichinkichik',
#   'allichinkichik',
#   'allichinki',
#   'allichinki',
#   'allichinku',
#   'allichinqaku',
#   'allichinqa',
#   'allichin',
#   'allichiq',
#   'allichirqanchik',
#   'allichirqaniku',
#   'allichirqani',
#   'allichirqankichik',
#   'allichirqanki',
#   'allichirqanku',
#   'allichirqan',
#   'allichisaqku',
#   'allichisaq',
#   'allichispa',
#   'allichisqanchik',
#   'allichisqaniku',
#   'allichisqani',
#   'allichisqankichik',
#   'allichisqanki',
#   'allichisqanku',
#   'allichisqan',
#   'allichisqa',
#   'allichisunchik',
#   'allichiychik',
#   'allichiyku',
#   'allichiy',
#   'allichiy',
#   'amaallichichunchu',
#   'amaallichichunkuchu',
#   'amaallichiychikchu',
#   'amaallichiychu'],
#  'allinchay': ['allinchachunku',
#   'allinchachun',
#   'allinchana',
#   'allinchanchik',
#   'allinchani',
#   'allinchankichik',
#   'allinchankichik',
#   'allinchanki',
#   'allinchanki',
#   'allinchanku',
#   'allinchanqaku',
#   'allinchanqa',
#   'allinchan',
#   'allinchaq',
#   'allincharqanchik',
#   'allincharqaniku',
#   'allincharqani',
#   'allincharqankichik',
#   'allincharqanki',
#   'allincharqanku',
#   'allincharqan',
#   'allinchasaqku',
#   'allinchasaq',
#   'allinchaspa',
#   'allinchasqanchik',
#   'allinchasqaniku',
#   'allinchasqani',
#   'allinchasqankichik',
#   'allinchasqanki',
#   'allinchasqanku',
#   'allinchasqan',
#   'allinchasqa',
#   'allinchasunchik',
#   'allinchaychik',
#   'allinchayku',
#   'allinchay',
#   'allinchay',
#   'amaallinchachunchu',
#   'amaallinchachunkuchu',
#   'amaallinchaychikchu',
#   'amaallinchaychu'],
#  'allinyachiy': ['allinyachichunku',
#   'allinyachichun',
#   'allinyachina',
#   'allinyachinchik',
#   'allinyachini',
#   'allinyachinkichik',
#   'allinyachinkichik',
#   'allinyachinki',
#   'allinyachinki',
#   'allinyachinku',
#   'allinyachinqaku',
#   'allinyachinqa',
#   'allinyachin',
#   'allinyachiq',
#   'allinyachirqanchik',
#   'allinyachirqaniku',
#   'allinyachirqani',
#   'allinyachirqankichik',
#   'allinyachirqanki',
#   'allinyachirqanku',
#   'allinyachirqan',
#   'allinyachisaqku',
#   'allinyachisaq',
#   'allinyachispa',
#   'allinyachisqanchik',
#   'allinyachisqaniku',
#   'allinyachisqani',
#   'allinyachisqankichik',
#   'allinyachisqanki',
#   'allinyachisqanku',
#   'allinyachisqan',
#   'allinyachisqa',
#   'allinyachisunchik',
#   'allinyachiychik',
#   'allinyachiyku',
#   'allinyachiy',
#   'allinyachiy',
#   'amaallinyachichunchu',
#   'amaallinyachichunkuchu',
#   'amaallinyachiychikchu',
#   'amaallinyachiychu'],
#  'allinyay': ['allinyachunku',
#   'allinyachun',
#   'allinyana',
#   'allinyanchik',
#   'allinyani',
#   'allinyankichik',
#   'allinyankichik',
#   'allinyanki',
#   'allinyanki',
#   'allinyanku',
#   'allinyanqaku',
#   'allinyanqa',
#   'allinyan',
#   'allinyaq',
#   'allinyarqanchik',
#   'allinyarqaniku',
#   'allinyarqani',
#   'allinyarqankichik',
#   'allinyarqanki',
#   'allinyarqanku',
#   'allinyarqan',
#   'allinyasaqku',
#   'allinyasaq',
#   'allinyaspa',
#   'allinyasqanchik',
#   'allinyasqaniku',
#   'allinyasqani',
#   'allinyasqankichik',
#   'allinyasqanki',
#   'allinyasqanku',
#   'allinyasqan',
#   'allinyasqa',
#   'allinyasunchik',
#   'allinyaychik',
#   'allinyayku',
#   'allinyay',
#   'allinyay',
#   'amaallinyachunchu',
#   'amaallinyachunkuchu',
#   'amaallinyaychikchu',
#   'amaallinyaychu'],
#  'allipanakuy': ['allipanakuchunku',
#   'allipanakuchun',
#   'allipanakuna',
#   'allipanakunchik',
#   'allipanakuni',
#   'allipanakunkichik',
#   'allipanakunkichik',
#   'allipanakunki',
#   'allipanakunki',
#   'allipanakunku',
#   'allipanakunqaku',
#   'allipanakunqa',
#   'allipanakun',
#   'allipanakuq',
#   'allipanakurqanchik',
#   'allipanakurqaniku',
#   'allipanakurqani',
#   'allipanakurqankichik',
#   'allipanakurqanki',
#   'allipanakurqanku',
#   'allipanakurqan',
#   'allipanakusaqku',
#   'allipanakusaq',
#   'allipanakuspa',
#   'allipanakusqanchik',
#   'allipanakusqaniku',
#   'allipanakusqani',
#   'allipanakusqankichik',
#   'allipanakusqanki',
#   'allipanakusqanku',
#   'allipanakusqan',
#   'allipanakusqa',
#   'allipanakusunchik',
#   'allipanakuychik',
#   'allipanakuyku',
#   'allipanakuy',
#   'allipanakuy',
#   'amaallipanakuchunchu',
#   'amaallipanakuchunkuchu',
#   'amaallipanakuychikchu',
#   'amaallipanakuychu'],
#  'allipunakuy': ['allipunakuchunku',
#   'allipunakuchun',
#   'allipunakuna',
#   'allipunakunchik',
#   'allipunakuni',
#   'allipunakunkichik',
#   'allipunakunkichik',
#   'allipunakunki',
#   'allipunakunki',
#   'allipunakunku',
#   'allipunakunqaku',
#   'allipunakunqa',
#   'allipunakun',
#   'allipunakuq',
#   'allipunakurqanchik',
#   'allipunakurqaniku',
#   'allipunakurqani',
#   'allipunakurqankichik',
#   'allipunakurqanki',
#   'allipunakurqanku',
#   'allipunakurqan',
#   'allipunakusaqku',
#   'allipunakusaq',
#   'allipunakuspa',
#   'allipunakusqanchik',
#   'allipunakusqaniku',
#   'allipunakusqani',
#   'allipunakusqankichik',
#   'allipunakusqanki',
#   'allipunakusqanku',
#   'allipunakusqan',
#   'allipunakusqa',
#   'allipunakusunchik',
#   'allipunakuychik',
#   'allipunakuyku',
#   'allipunakuy',
#   'allipunakuy',
#   'amaallipunakuchunchu',
#   'amaallipunakuchunkuchu',
#   'amaallipunakuychikchu',
#   'amaallipunakuychu'],
#  'allpachay': ['allpachachunku',
#   'allpachachun',
#   'allpachana',
#   'allpachanchik',
#   'allpachani',
#   'allpachankichik',
#   'allpachankichik',
#   'allpachanki',
#   'allpachanki',
#   'allpachanku',
#   'allpachanqaku',
#   'allpachanqa',
#   'allpachan',
#   'allpachaq',
#   'allpacharqanchik',
#   'allpacharqaniku',
#   'allpacharqani',
#   'allpacharqankichik',
#   'allpacharqanki',
#   'allpacharqanku',
#   'allpacharqan',
#   'allpachasaqku',
#   'allpachasaq',
#   'allpachaspa',
#   'allpachasqanchik',
#   'allpachasqaniku',
#   'allpachasqani',
#   'allpachasqankichik',
#   'allpachasqanki',
#   'allpachasqanku',
#   'allpachasqan',
#   'allpachasqa',
#   'allpachasunchik',
#   'allpachaychik',
#   'allpachayku',
#   'allpachay',
#   'allpachay',
#   'amaallpachachunchu',
#   'amaallpachachunkuchu',
#   'amaallpachaychikchu',
#   'amaallpachaychu'],
#  'allpanay': ['allpanachunku',
#   'allpanachun',
#   'allpanana',
#   'allpananchik',
#   'allpanani',
#   'allpanankichik',
#   'allpanankichik',
#   'allpananki',
#   'allpananki',
#   'allpananku',
#   'allpananqaku',
#   'allpananqa',
#   'allpanan',
#   'allpanaq',
#   'allpanarqanchik',
#   'allpanarqaniku',
#   'allpanarqani',
#   'allpanarqankichik',
#   'allpanarqanki',
#   'allpanarqanku',
#   'allpanarqan',
#   'allpanasaqku',
#   'allpanasaq',
#   'allpanaspa',
#   'allpanasqanchik',
#   'allpanasqaniku',
#   'allpanasqani',
#   'allpanasqankichik',
#   'allpanasqanki',
#   'allpanasqanku',
#   'allpanasqan',
#   'allpanasqa',
#   'allpanasunchik',
#   'allpanaychik',
#   'allpanayku',
#   'allpanay',
#   'allpanay',
#   'amaallpanachunchu',
#   'amaallpanachunkuchu',
#   'amaallpanaychikchu',
#   'amaallpanaychu'],
#  'allpayachiy': ['allpayachichunku',
#   'allpayachichun',
#   'allpayachina',
#   'allpayachinchik',
#   'allpayachini',
#   'allpayachinkichik',
#   'allpayachinkichik',
#   'allpayachinki',
#   'allpayachinki',
#   'allpayachinku',
#   'allpayachinqaku',
#   'allpayachinqa',
#   'allpayachin',
#   'allpayachiq',
#   'allpayachirqanchik',
#   'allpayachirqaniku',
#   'allpayachirqani',
#   'allpayachirqankichik',
#   'allpayachirqanki',
#   'allpayachirqanku',
#   'allpayachirqan',
#   'allpayachisaqku',
#   'allpayachisaq',
#   'allpayachispa',
#   'allpayachisqanchik',
#   'allpayachisqaniku',
#   'allpayachisqani',
#   'allpayachisqankichik',
#   'allpayachisqanki',
#   'allpayachisqanku',
#   'allpayachisqan',
#   'allpayachisqa',
#   'allpayachisunchik',
#   'allpayachiychik',
#   'allpayachiyku',
#   'allpayachiy',
#   'allpayachiy',
#   'amaallpayachichunchu',
#   'amaallpayachichunkuchu',
#   'amaallpayachiychikchu',
#   'amaallpayachiychu'],
#  'allpay': ['allpachunku',
#   'allpachun',
#   'allpana',
#   'allpanchik',
#   'allpani',
#   'allpankichik',
#   'allpankichik',
#   'allpanki',
#   'allpanki',
#   'allpanku',
#   'allpanqaku',
#   'allpanqa',
#   'allpan',
#   'allpaq',
#   'allparqanchik',
#   'allparqaniku',
#   'allparqani',
#   'allparqankichik',
#   'allparqanki',
#   'allparqanku',
#   'allparqan',
#   'allpasaqku',
#   'allpasaq',
#   'allpaspa',
#   'allpasqanchik',
#   'allpasqaniku',
#   'allpasqani',
#   'allpasqankichik',
#   'allpasqanki',
#   'allpasqanku',
#   'allpasqan',
#   'allpasqa',
#   'allpasunchik',
#   'allpaychik',
#   'allpayku',
#   'allpay',
#   'allpay',
#   'amaallpachunchu',
#   'amaallpachunkuchu',
#   'amaallpaychikchu',
#   'amaallpaychu'],
#  'allquchakuy': ['allquchakuchunku',
#   'allquchakuchun',
#   'allquchakuna',
#   'allquchakunchik',
#   'allquchakuni',
#   'allquchakunkichik',
#   'allquchakunkichik',
#   'allquchakunki',
#   'allquchakunki',
#   'allquchakunku',
#   'allquchakunqaku',
#   'allquchakunqa',
#   'allquchakun',
#   'allquchakuq',
#   'allquchakurqanchik',
#   'allquchakurqaniku',
#   'allquchakurqani',
#   'allquchakurqankichik',
#   'allquchakurqanki',
#   'allquchakurqanku',
#   'allquchakurqan',
#   'allquchakusaqku',
#   'allquchakusaq',
#   'allquchakuspa',
#   'allquchakusqanchik',
#   'allquchakusqaniku',
#   'allquchakusqani',
#   'allquchakusqankichik',
#   'allquchakusqanki',
#   'allquchakusqanku',
#   'allquchakusqan',
#   'allquchakusqa',
#   'allquchakusunchik',
#   'allquchakuychik',
#   'allquchakuyku',
#   'allquchakuy',
#   'allquchakuy',
#   'amaallquchakuchunchu',
#   'amaallquchakuchunkuchu',
#   'amaallquchakuychikchu',
#   'amaallquchakuychu'],
#  'allquchay': ['allquchachunku',
#   'allquchachun',
#   'allquchana',
#   'allquchanchik',
#   'allquchani',
#   'allquchankichik',
#   'allquchankichik',
#   'allquchanki',
#   'allquchanki',
#   'allquchanku',
#   'allquchanqaku',
#   'allquchanqa',
#   'allquchan',
#   'allquchaq',
#   'allqucharqanchik',
#   'allqucharqaniku',
#   'allqucharqani',
#   'allqucharqankichik',
#   'allqucharqanki',
#   'allqucharqanku',
#   'allqucharqan',
#   'allquchasaqku',
#   'allquchasaq',
#   'allquchaspa',
#   'allquchasqanchik',
#   'allquchasqaniku',
#   'allquchasqani',
#   'allquchasqankichik',
#   'allquchasqanki',
#   'allquchasqanku',
#   'allquchasqan',
#   'allquchasqa',
#   'allquchasunchik',
#   'allquchaychik',
#   'allquchayku',
#   'allquchay',
#   'allquchay',
#   'amaallquchachunchu',
#   'amaallquchachunkuchu',
#   'amaallquchaychikchu',
#   'amaallquchaychu'],
#  'allwiy': ['allwichunku',
#   'allwichun',
#   'allwina',
#   'allwinchik',
#   'allwini',
#   'allwinkichik',
#   'allwinkichik',
#   'allwinki',
#   'allwinki',
#   'allwinku',
#   'allwinqaku',
#   'allwinqa',
#   'allwin',
#   'allwiq',
#   'allwirqanchik',
#   'allwirqaniku',
#   'allwirqani',
#   'allwirqankichik',
#   'allwirqanki',
#   'allwirqanku',
#   'allwirqan',
#   'allwisaqku',
#   'allwisaq',
#   'allwispa',
#   'allwisqanchik',
#   'allwisqaniku',
#   'allwisqani',
#   'allwisqankichik',
#   'allwisqanki',
#   'allwisqanku',
#   'allwisqan',
#   'allwisqa',
#   'allwisunchik',
#   'allwiychik',
#   'allwiyku',
#   'allwiy',
#   'allwiy',
#   'amaallwichunchu',
#   'amaallwichunkuchu',
#   'amaallwiychikchu',
#   'amaallwiychu'],
#  'alqay': ['alqachunku',
#   'alqachun',
#   'alqana',
#   'alqanchik',
#   'alqani',
#   'alqankichik',
#   'alqankichik',
#   'alqanki',
#   'alqanki',
#   'alqanku',
#   'alqanqaku',
#   'alqanqa',
#   'alqan',
#   'alqaq',
#   'alqarqanchik',
#   'alqarqaniku',
#   'alqarqani',
#   'alqarqankichik',
#   'alqarqanki',
#   'alqarqanku',
#   'alqarqan',
#   'alqasaqku',
#   'alqasaq',
#   'alqaspa',
#   'alqasqanchik',
#   'alqasqaniku',
#   'alqasqani',
#   'alqasqankichik',
#   'alqasqanki',
#   'alqasqanku',
#   'alqasqan',
#   'alqasqa',
#   'alqasunchik',
#   'alqaychik',
#   'alqayku',
#   'alqay',
#   'alqay',
#   'amaalqachunchu',
#   'amaalqachunkuchu',
#   'amaalqaychikchu',
#   'amaalqaychu'],
#  'amachay': ['amaamachachunchu',
#   'amaamachachunkuchu',
#   'amaamachaychikchu',
#   'amaamachaychu',
#   'amachachunku',
#   'amachachun',
#   'amachana',
#   'amachanchik',
#   'amachani',
#   'amachankichik',
#   'amachankichik',
#   'amachanki',
#   'amachanki',
#   'amachanku',
#   'amachanqaku',
#   'amachanqa',
#   'amachan',
#   'amachaq',
#   'amacharqanchik',
#   'amacharqaniku',
#   'amacharqani',
#   'amacharqankichik',
#   'amacharqanki',
#   'amacharqanku',
#   'amacharqan',
#   'amachasaqku',
#   'amachasaq',
#   'amachaspa',
#   'amachasqanchik',
#   'amachasqaniku',
#   'amachasqani',
#   'amachasqankichik',
#   'amachasqanki',
#   'amachasqanku',
#   'amachasqan',
#   'amachasqa',
#   'amachasunchik',
#   'amachaychik',
#   'amachayku',
#   'amachay',
#   'amachay'],
#  'amañay': ['amaamañachunchu',
#   'amaamañachunkuchu',
#   'amaamañaychikchu',
#   'amaamañaychu',
#   'amañachunku',
#   'amañachun',
#   'amañana',
#   'amañanchik',
#   'amañani',
#   'amañankichik',
#   'amañankichik',
#   'amañanki',
#   'amañanki',
#   'amañanku',
#   'amañanqaku',
#   'amañanqa',
#   'amañan',
#   'amañaq',
#   'amañarqanchik',
#   'amañarqaniku',
#   'amañarqani',
#   'amañarqankichik',
#   'amañarqanki',
#   'amañarqanku',
#   'amañarqan',
#   'amañasaqku',
#   'amañasaq',
#   'amañaspa',
#   'amañasqanchik',
#   'amañasqaniku',
#   'amañasqani',
#   'amañasqankichik',
#   'amañasqanki',
#   'amañasqanku',
#   'amañasqan',
#   'amañasqa',
#   'amañasunchik',
#   'amañaychik',
#   'amañayku',
#   'amañay',
#   'amañay'],
#  'ama ñiy': ['amaama ñichunchu',
#   'amaama ñichunkuchu',
#   'amaama ñiychikchu',
#   'amaama ñiychu',
#   'ama ñichunku',
#   'ama ñichun',
#   'ama ñina',
#   'ama ñinchik',
#   'ama ñini',
#   'ama ñinkichik',
#   'ama ñinkichik',
#   'ama ñinki',
#   'ama ñinki',
#   'ama ñinku',
#   'ama ñinqaku',
#   'ama ñinqa',
#   'ama ñin',
#   'ama ñiq',
#   'ama ñirqanchik',
#   'ama ñirqaniku',
#   'ama ñirqani',
#   'ama ñirqankichik',
#   'ama ñirqanki',
#   'ama ñirqanku',
#   'ama ñirqan',
#   'ama ñisaqku',
#   'ama ñisaq',
#   'ama ñispa',
#   'ama ñisqanchik',
#   'ama ñisqaniku',
#   'ama ñisqani',
#   'ama ñisqankichik',
#   'ama ñisqanki',
#   'ama ñisqanku',
#   'ama ñisqan',
#   'ama ñisqa',
#   'ama ñisunchik',
#   'ama ñiychik',
#   'ama ñiyku',
#   'ama ñiy',
#   'ama ñiy'],
#  'amatay': ['amaamatachunchu',
#   'amaamatachunkuchu',
#   'amaamataychikchu',
#   'amaamataychu',
#   'amatachunku',
#   'amatachun',
#   'amatana',
#   'amatanchik',
#   'amatani',
#   'amatankichik',
#   'amatankichik',
#   'amatanki',
#   'amatanki',
#   'amatanku',
#   'amatanqaku',
#   'amatanqa',
#   'amatan',
#   'amataq',
#   'amatarqanchik',
#   'amatarqaniku',
#   'amatarqani',
#   'amatarqankichik',
#   'amatarqanki',
#   'amatarqanku',
#   'amatarqan',
#   'amatasaqku',
#   'amatasaq',
#   'amataspa',
#   'amatasqanchik',
#   'amatasqaniku',
#   'amatasqani',
#   'amatasqankichik',
#   'amatasqanki',
#   'amatasqanku',
#   'amatasqan',
#   'amatasqa',
#   'amatasunchik',
#   'amataychik',
#   'amatayku',
#   'amatay',
#   'amatay'],
#  'amuyay': ['amaamuyachunchu',
#   'amaamuyachunkuchu',
#   'amaamuyaychikchu',
#   'amaamuyaychu',
#   'amuyachunku',
#   'amuyachun',
#   'amuyana',
#   'amuyanchik',
#   'amuyani',
#   'amuyankichik',
#   'amuyankichik',
#   'amuyanki',
#   'amuyanki',
#   'amuyanku',
#   'amuyanqaku',
#   'amuyanqa',
#   'amuyan',
#   'amuyaq',
#   'amuyarqanchik',
#   'amuyarqaniku',
#   'amuyarqani',
#   'amuyarqankichik',
#   'amuyarqanki',
#   'amuyarqanku',
#   'amuyarqan',
#   'amuyasaqku',
#   'amuyasaq',
#   'amuyaspa',
#   'amuyasqanchik',
#   'amuyasqaniku',
#   'amuyasqani',
#   'amuyasqankichik',
#   'amuyasqanki',
#   'amuyasqanku',
#   'amuyasqan',
#   'amuyasqa',
#   'amuyasunchik',
#   'amuyaychik',
#   'amuyayku',
#   'amuyay',
#   'amuyay'],
#  'añaychay': ['amaañaychachunchu',
#   'amaañaychachunkuchu',
#   'amaañaychaychikchu',
#   'amaañaychaychu',
#   'añaychachunku',
#   'añaychachun',
#   'añaychana',
#   'añaychanchik',
#   'añaychani',
#   'añaychankichik',
#   'añaychankichik',
#   'añaychanki',
#   'añaychanki',
#   'añaychanku',
#   'añaychanqaku',
#   'añaychanqa',
#   'añaychan',
#   'añaychaq',
#   'añaycharqanchik',
#   'añaycharqaniku',
#   'añaycharqani',
#   'añaycharqankichik',
#   'añaycharqanki',
#   'añaycharqanku',
#   'añaycharqan',
#   'añaychasaqku',
#   'añaychasaq',
#   'añaychaspa',
#   'añaychasqanchik',
#   'añaychasqaniku',
#   'añaychasqani',
#   'añaychasqankichik',
#   'añaychasqanki',
#   'añaychasqanku',
#   'añaychasqan',
#   'añaychasqa',
#   'añaychasunchik',
#   'añaychaychik',
#   'añaychayku',
#   'añaychay',
#   'añaychay'],
#  'añaynichiy': ['amaañaynichichunchu',
#   'amaañaynichichunkuchu',
#   'amaañaynichiychikchu',
#   'amaañaynichiychu',
#   'añaynichichunku',
#   'añaynichichun',
#   'añaynichina',
#   'añaynichinchik',
#   'añaynichini',
#   'añaynichinkichik',
#   'añaynichinkichik',
#   'añaynichinki',
#   'añaynichinki',
#   'añaynichinku',
#   'añaynichinqaku',
#   'añaynichinqa',
#   'añaynichin',
#   'añaynichiq',
#   'añaynichirqanchik',
#   'añaynichirqaniku',
#   'añaynichirqani',
#   'añaynichirqankichik',
#   'añaynichirqanki',
#   'añaynichirqanku',
#   'añaynichirqan',
#   'añaynichisaqku',
#   'añaynichisaq',
#   'añaynichispa',
#   'añaynichisqanchik',
#   'añaynichisqaniku',
#   'añaynichisqani',
#   'añaynichisqankichik',
#   'añaynichisqanki',
#   'añaynichisqanku',
#   'añaynichisqan',
#   'añaynichisqa',
#   'añaynichisunchik',
#   'añaynichiychik',
#   'añaynichiyku',
#   'añaynichiy',
#   'añaynichiy'],
#  'anchachay': ['amaanchachachunchu',
#   'amaanchachachunkuchu',
#   'amaanchachaychikchu',
#   'amaanchachaychu',
#   'anchachachunku',
#   'anchachachun',
#   'anchachana',
#   'anchachanchik',
#   'anchachani',
#   'anchachankichik',
#   'anchachankichik',
#   'anchachanki',
#   'anchachanki',
#   'anchachanku',
#   'anchachanqaku',
#   'anchachanqa',
#   'anchachan',
#   'anchachaq',
#   'anchacharqanchik',
#   'anchacharqaniku',
#   'anchacharqani',
#   'anchacharqankichik',
#   'anchacharqanki',
#   'anchacharqanku',
#   'anchacharqan',
#   'anchachasaqku',
#   'anchachasaq',
#   'anchachaspa',
#   'anchachasqanchik',
#   'anchachasqaniku',
#   'anchachasqani',
#   'anchachasqankichik',
#   'anchachasqanki',
#   'anchachasqanku',
#   'anchachasqan',
#   'anchachasqa',
#   'anchachasunchik',
#   'anchachaychik',
#   'anchachayku',
#   'anchachay',
#   'anchachay'],
#  'anchayay': ['amaanchayachunchu',
#   'amaanchayachunkuchu',
#   'amaanchayaychikchu',
#   'amaanchayaychu',
#   'anchayachunku',
#   'anchayachun',
#   'anchayana',
#   'anchayanchik',
#   'anchayani',
#   'anchayankichik',
#   'anchayankichik',
#   'anchayanki',
#   'anchayanki',
#   'anchayanku',
#   'anchayanqaku',
#   'anchayanqa',
#   'anchayan',
#   'anchayaq',
#   'anchayarqanchik',
#   'anchayarqaniku',
#   'anchayarqani',
#   'anchayarqankichik',
#   'anchayarqanki',
#   'anchayarqanku',
#   'anchayarqan',
#   'anchayasaqku',
#   'anchayasaq',
#   'anchayaspa',
#   'anchayasqanchik',
#   'anchayasqaniku',
#   'anchayasqani',
#   'anchayasqankichik',
#   'anchayasqanki',
#   'anchayasqanku',
#   'anchayasqan',
#   'anchayasqa',
#   'anchayasunchik',
#   'anchayaychik',
#   'anchayayku',
#   'anchayay',
#   'anchayay'],
#  'anchaykachay': ['amaanchaykachachunchu',
#   'amaanchaykachachunkuchu',
#   'amaanchaykachaychikchu',
#   'amaanchaykachaychu',
#   'anchaykachachunku',
#   'anchaykachachun',
#   'anchaykachana',
#   'anchaykachanchik',
#   'anchaykachani',
#   'anchaykachankichik',
#   'anchaykachankichik',
#   'anchaykachanki',
#   'anchaykachanki',
#   'anchaykachanku',
#   'anchaykachanqaku',
#   'anchaykachanqa',
#   'anchaykachan',
#   'anchaykachaq',
#   'anchaykacharqanchik',
#   'anchaykacharqaniku',
#   'anchaykacharqani',
#   'anchaykacharqankichik',
#   'anchaykacharqanki',
#   'anchaykacharqanku',
#   'anchaykacharqan',
#   'anchaykachasaqku',
#   'anchaykachasaq',
#   'anchaykachaspa',
#   'anchaykachasqanchik',
#   'anchaykachasqaniku',
#   'anchaykachasqani',
#   'anchaykachasqankichik',
#   'anchaykachasqanki',
#   'anchaykachasqanku',
#   'anchaykachasqan',
#   'anchaykachasqa',
#   'anchaykachasunchik',
#   'anchaykachaychik',
#   'anchaykachayku',
#   'anchaykachay',
#   'anchaykachay'],
#  'añikuy': ['amaañikuchunchu',
#   'amaañikuchunkuchu',
#   'amaañikuychikchu',
#   'amaañikuychu',
#   'añikuchunku',
#   'añikuchun',
#   'añikuna',
#   'añikunchik',
#   'añikuni',
#   'añikunkichik',
#   'añikunkichik',
#   'añikunki',
#   'añikunki',
#   'añikunku',
#   'añikunqaku',
#   'añikunqa',
#   'añikun',
#   'añikuq',
#   'añikurqanchik',
#   'añikurqaniku',
#   'añikurqani',
#   'añikurqankichik',
#   'añikurqanki',
#   'añikurqanku',
#   'añikurqan',
#   'añikusaqku',
#   'añikusaq',
#   'añikuspa',
#   'añikusqanchik',
#   'añikusqaniku',
#   'añikusqani',
#   'añikusqankichik',
#   'añikusqanki',
#   'añikusqanku',
#   'añikusqan',
#   'añikusqa',
#   'añikusunchik',
#   'añikuychik',
#   'añikuyku',
#   'añikuy',
#   'añikuy'],
#  'añiy': ['amaañichunchu',
#   'amaañichunkuchu',
#   'amaañiychikchu',
#   'amaañiychu',
#   'añichunku',
#   'añichun',
#   'añina',
#   'añinchik',
#   'añini',
#   'añinkichik',
#   'añinkichik',
#   'añinki',
#   'añinki',
#   'añinku',
#   'añinqaku',
#   'añinqa',
#   'añin',
#   'añiq',
#   'añirqanchik',
#   'añirqaniku',
#   'añirqani',
#   'añirqankichik',
#   'añirqanki',
#   'añirqanku',
#   'añirqan',
#   'añisaqku',
#   'añisaq',
#   'añispa',
#   'añisqanchik',
#   'añisqaniku',
#   'añisqani',
#   'añisqankichik',
#   'añisqanki',
#   'añisqanku',
#   'añisqan',
#   'añisqa',
#   'añisunchik',
#   'añiychik',
#   'añiyku',
#   'añiy',
#   'añiy'],
#  'ankallikuy': ['amaankallikuchunchu',
#   'amaankallikuchunkuchu',
#   'amaankallikuychikchu',
#   'amaankallikuychu',
#   'ankallikuchunku',
#   'ankallikuchun',
#   'ankallikuna',
#   'ankallikunchik',
#   'ankallikuni',
#   'ankallikunkichik',
#   'ankallikunkichik',
#   'ankallikunki',
#   'ankallikunki',
#   'ankallikunku',
#   'ankallikunqaku',
#   'ankallikunqa',
#   'ankallikun',
#   'ankallikuq',
#   'ankallikurqanchik',
#   'ankallikurqaniku',
#   'ankallikurqani',
#   'ankallikurqankichik',
#   'ankallikurqanki',
#   'ankallikurqanku',
#   'ankallikurqan',
#   'ankallikusaqku',
#   'ankallikusaq',
#   'ankallikuspa',
#   'ankallikusqanchik',
#   'ankallikusqaniku',
#   'ankallikusqani',
#   'ankallikusqankichik',
#   'ankallikusqanki',
#   'ankallikusqanku',
#   'ankallikusqan',
#   'ankallikusqa',
#   'ankallikusunchik',
#   'ankallikuychik',
#   'ankallikuyku',
#   'ankallikuy',
#   'ankallikuy'],
#  'anqusay': ['amaanqusachunchu',
#   'amaanqusachunkuchu',
#   'amaanqusaychikchu',
#   'amaanqusaychu',
#   'anqusachunku',
#   'anqusachun',
#   'anqusana',
#   'anqusanchik',
#   'anqusani',
#   'anqusankichik',
#   'anqusankichik',
#   'anqusanki',
#   'anqusanki',
#   'anqusanku',
#   'anqusanqaku',
#   'anqusanqa',
#   'anqusan',
#   'anqusaq',
#   'anqusarqanchik',
#   'anqusarqaniku',
#   'anqusarqani',
#   'anqusarqankichik',
#   'anqusarqanki',
#   'anqusarqanku',
#   'anqusarqan',
#   'anqusasaqku',
#   'anqusasaq',
#   'anqusaspa',
#   'anqusasqanchik',
#   'anqusasqaniku',
#   'anqusasqani',
#   'anqusasqankichik',
#   'anqusasqanki',
#   'anqusasqanku',
#   'anqusasqan',
#   'anqusasqa',
#   'anqusasunchik',
#   'anqusaychik',
#   'anqusayku',
#   'anqusay',
#   'anqusay'],
#  'anschiykachay': ['amaanschiykachachunchu',
#   'amaanschiykachachunkuchu',
#   'amaanschiykachaychikchu',
#   'amaanschiykachaychu',
#   'anschiykachachunku',
#   'anschiykachachun',
#   'anschiykachana',
#   'anschiykachanchik',
#   'anschiykachani',
#   'anschiykachankichik',
#   'anschiykachankichik',
#   'anschiykachanki',
#   'anschiykachanki',
#   'anschiykachanku',
#   'anschiykachanqaku',
#   'anschiykachanqa',
#   'anschiykachan',
#   'anschiykachaq',
#   'anschiykacharqanchik',
#   'anschiykacharqaniku',
#   'anschiykacharqani',
#   'anschiykacharqankichik',
#   'anschiykacharqanki',
#   'anschiykacharqanku',
#   'anschiykacharqan',
#   'anschiykachasaqku',
#   'anschiykachasaq',
#   'anschiykachaspa',
#   'anschiykachasqanchik',
#   'anschiykachasqaniku',
#   'anschiykachasqani',
#   'anschiykachasqankichik',
#   'anschiykachasqanki',
#   'anschiykachasqanku',
#   'anschiykachasqan',
#   'anschiykachasqa',
#   'anschiykachasunchik',
#   'anschiykachaychik',
#   'anschiykachayku',
#   'anschiykachay',
#   'anschiykachay'],
#  'anschurichiy': ['amaanschurichichunchu',
#   'amaanschurichichunkuchu',
#   'amaanschurichiychikchu',
#   'amaanschurichiychu',
#   'anschurichichunku',
#   'anschurichichun',
#   'anschurichina',
#   'anschurichinchik',
#   'anschurichini',
#   'anschurichinkichik',
#   'anschurichinkichik',
#   'anschurichinki',
#   'anschurichinki',
#   'anschurichinku',
#   'anschurichinqaku',
#   'anschurichinqa',
#   'anschurichin',
#   'anschurichiq',
#   'anschurichirqanchik',
#   'anschurichirqaniku',
#   'anschurichirqani',
#   'anschurichirqankichik',
#   'anschurichirqanki',
#   'anschurichirqanku',
#   'anschurichirqan',
#   'anschurichisaqku',
#   'anschurichisaq',
#   'anschurichispa',
#   'anschurichisqanchik',
#   'anschurichisqaniku',
#   'anschurichisqani',
#   'anschurichisqankichik',
#   'anschurichisqanki',
#   'anschurichisqanku',
#   'anschurichisqan',
#   'anschurichisqa',
#   'anschurichisunchik',
#   'anschurichiychik',
#   'anschurichiyku',
#   'anschurichiy',
#   'anschurichiy'],
#  'anschuriy': ['amaanschurichunchu',
#   'amaanschurichunkuchu',
#   'amaanschuriychikchu',
#   'amaanschuriychu',
#   'anschurichunku',
#   'anschurichun',
#   'anschurina',
#   'anschurinchik',
#   'anschurini',
#   'anschurinkichik',
#   'anschurinkichik',
#   'anschurinki',
#   'anschurinki',
#   'anschurinku',
#   'anschurinqaku',
#   'anschurinqa',
#   'anschurin',
#   'anschuriq',
#   'anschurirqanchik',
#   'anschurirqaniku',
#   'anschurirqani',
#   'anschurirqankichik',
#   'anschurirqanki',
#   'anschurirqanku',
#   'anschurirqan',
#   'anschurisaqku',
#   'anschurisaq',
#   'anschurispa',
#   'anschurisqanchik',
#   'anschurisqaniku',
#   'anschurisqani',
#   'anschurisqankichik',
#   'anschurisqanki',
#   'anschurisqanku',
#   'anschurisqan',
#   'anschurisqa',
#   'anschurisunchik',
#   'anschuriychik',
#   'anschuriyku',
#   'anschuriy',
#   'anschuriy'],
#  'anschuykunakuy': ['amaanschuykunakuchunchu',
#   'amaanschuykunakuchunkuchu',
#   'amaanschuykunakuychikchu',
#   'amaanschuykunakuychu',
#   'anschuykunakuchunku',
#   'anschuykunakuchun',
#   'anschuykunakuna',
#   'anschuykunakunchik',
#   'anschuykunakuni',
#   'anschuykunakunkichik',
#   'anschuykunakunkichik',
#   'anschuykunakunki',
#   'anschuykunakunki',
#   'anschuykunakunku',
#   'anschuykunakunqaku',
#   'anschuykunakunqa',
#   'anschuykunakun',
#   'anschuykunakuq',
#   'anschuykunakurqanchik',
#   'anschuykunakurqaniku',
#   'anschuykunakurqani',
#   'anschuykunakurqankichik',
#   'anschuykunakurqanki',
#   'anschuykunakurqanku',
#   'anschuykunakurqan',
#   'anschuykunakusaqku',
#   'anschuykunakusaq',
#   'anschuykunakuspa',
#   'anschuykunakusqanchik',
#   'anschuykunakusqaniku',
#   'anschuykunakusqani',
#   'anschuykunakusqankichik',
#   'anschuykunakusqanki',
#   'anschuykunakusqanku',
#   'anschuykunakusqan',
#   'anschuykunakusqa',
#   'anschuykunakusunchik',
#   'anschuykunakuychik',
#   'anschuykunakuyku',
#   'anschuykunakuy',
#   'anschuykunakuy'],
#  'anschuykuy': ['amaanschuykuchunchu',
#   'amaanschuykuchunkuchu',
#   'amaanschuykuychikchu',
#   'amaanschuykuychu',
#   'anschuykuchunku',
#   'anschuykuchun',
#   'anschuykuna',
#   'anschuykunchik',
#   'anschuykuni',
#   'anschuykunkichik',
#   'anschuykunkichik',
#   'anschuykunki',
#   'anschuykunki',
#   'anschuykunku',
#   'anschuykunqaku',
#   'anschuykunqa',
#   'anschuykun',
#   'anschuykuq',
#   'anschuykurqanchik',
#   'anschuykurqaniku',
#   'anschuykurqani',
#   'anschuykurqankichik',
#   'anschuykurqanki',
#   'anschuykurqanku',
#   'anschuykurqan',
#   'anschuykusaqku',
#   'anschuykusaq',
#   'anschuykuspa',
#   'anschuykusqanchik',
#   'anschuykusqaniku',
#   'anschuykusqani',
#   'anschuykusqankichik',
#   'anschuykusqanki',
#   'anschuykusqanku',
#   'anschuykusqan',
#   'anschuykusqa',
#   'anschuykusunchik',
#   'anschuykuychik',
#   'anschuykuyku',
#   'anschuykuy',
#   'anschuykuy'],
#  'antachay': ['amaantachachunchu',
#   'amaantachachunkuchu',
#   'amaantachaychikchu',
#   'amaantachaychu',
#   'antachachunku',
#   'antachachun',
#   'antachana',
#   'antachanchik',
#   'antachani',
#   'antachankichik',
#   'antachankichik',
#   'antachanki',
#   'antachanki',
#   'antachanku',
#   'antachanqaku',
#   'antachanqa',
#   'antachan',
#   'antachaq',
#   'antacharqanchik',
#   'antacharqaniku',
#   'antacharqani',
#   'antacharqankichik',
#   'antacharqanki',
#   'antacharqanku',
#   'antacharqan',
#   'antachasaqku',
#   'antachasaq',
#   'antachaspa',
#   'antachasqanchik',
#   'antachasqaniku',
#   'antachasqani',
#   'antachasqankichik',
#   'antachasqanki',
#   'antachasqanku',
#   'antachasqan',
#   'antachasqa',
#   'antachasunchik',
#   'antachaychik',
#   'antachayku',
#   'antachay',
#   'antachay'],
#  'apakamuy': ['amaapakamuchunchu',
#   'amaapakamuchunkuchu',
#   'amaapakamuychikchu',
#   'amaapakamuychu',
#   'apakamuchunku',
#   'apakamuchun',
#   'apakamuna',
#   'apakamunchik',
#   'apakamuni',
#   'apakamunkichik',
#   'apakamunkichik',
#   'apakamunki',
#   'apakamunki',
#   'apakamunku',
#   'apakamunqaku',
#   'apakamunqa',
#   'apakamun',
#   'apakamuq',
#   'apakamurqanchik',
#   'apakamurqaniku',
#   'apakamurqani',
#   'apakamurqankichik',
#   'apakamurqanki',
#   'apakamurqanku',
#   'apakamurqan',
#   'apakamusaqku',
#   'apakamusaq',
#   'apakamuspa',
#   'apakamusqanchik',
#   'apakamusqaniku',
#   'apakamusqani',
#   'apakamusqankichik',
#   'apakamusqanki',
#   'apakamusqanku',
#   'apakamusqan',
#   'apakamusqa',
#   'apakamusunchik',
#   'apakamuychik',
#   'apakamuyku',
#   'apakamuy',
#   'apakamuy'],
#  'apakapuy': ['amaapakapuchunchu',
#   'amaapakapuchunkuchu',
#   'amaapakapuychikchu',
#   'amaapakapuychu',
#   'apakapuchunku',
#   'apakapuchun',
#   'apakapuna',
#   'apakapunchik',
#   'apakapuni',
#   'apakapunkichik',
#   'apakapunkichik',
#   'apakapunki',
#   'apakapunki',
#   'apakapunku',
#   'apakapunqaku',
#   'apakapunqa',
#   'apakapun',
#   'apakapuq',
#   'apakapurqanchik',
#   'apakapurqaniku',
#   'apakapurqani',
#   'apakapurqankichik',
#   'apakapurqanki',
#   'apakapurqanku',
#   'apakapurqan',
#   'apakapusaqku',
#   'apakapusaq',
#   'apakapuspa',
#   'apakapusqanchik',
#   'apakapusqaniku',
#   'apakapusqani',
#   'apakapusqankichik',
#   'apakapusqanki',
#   'apakapusqanku',
#   'apakapusqan',
#   'apakapusqa',
#   'apakapusunchik',
#   'apakapuychik',
#   'apakapuyku',
#   'apakapuy',
#   'apakapuy'],
#  'apamuy': ['amaapamuchunchu',
#   'amaapamuchunkuchu',
#   'amaapamuychikchu',
#   'amaapamuychu',
#   'apamuchunku',
#   'apamuchun',
#   'apamuna',
#   'apamunchik',
#   'apamuni',
#   'apamunkichik',
#   'apamunkichik',
#   'apamunki',
#   'apamunki',
#   'apamunku',
#   'apamunqaku',
#   'apamunqa',
#   'apamun',
#   'apamuq',
#   'apamurqanchik',
#   'apamurqaniku',
#   'apamurqani',
#   'apamurqankichik',
#   'apamurqanki',
#   'apamurqanku',
#   'apamurqan',
#   'apamusaqku',
#   'apamusaq',
#   'apamuspa',
#   'apamusqanchik',
#   'apamusqaniku',
#   'apamusqani',
#   'apamusqankichik',
#   'apamusqanki',
#   'apamusqanku',
#   'apamusqan',
#   'apamusqa',
#   'apamusunchik',
#   'apamuychik',
#   'apamuyku',
#   'apamuy',
#   'apamuy'],
#  'apatatay': ['amaapatatachunchu',
#   'amaapatatachunkuchu',
#   'amaapatataychikchu',
#   'amaapatataychu',
#   'apatatachunku',
#   'apatatachun',
#   'apatatana',
#   'apatatanchik',
#   'apatatani',
#   'apatatankichik',
#   'apatatankichik',
#   'apatatanki',
#   'apatatanki',
#   'apatatanku',
#   'apatatanqaku',
#   'apatatanqa',
#   'apatatan',
#   'apatataq',
#   'apatatarqanchik',
#   'apatatarqaniku',
#   'apatatarqani',
#   'apatatarqankichik',
#   'apatatarqanki',
#   'apatatarqanku',
#   'apatatarqan',
#   'apatatasaqku',
#   'apatatasaq',
#   'apatataspa',
#   'apatatasqanchik',
#   'apatatasqaniku',
#   'apatatasqani',
#   'apatatasqankichik',
#   'apatatasqanki',
#   'apatatasqanku',
#   'apatatasqan',
#   'apatatasqa',
#   'apatatasunchik',
#   'apatataychik',
#   'apatatayku',
#   'apatatay',
#   'apatatay'],
#  'apay': ['amaapachunchu',
#   'amaapachunkuchu',
#   'amaapaychikchu',
#   'amaapaychu',
#   'apachunku',
#   'apachun',
#   'apana',
#   'apanchik',
#   'apani',
#   'apankichik',
#   'apankichik',
#   'apanki',
#   'apanki',
#   'apanku',
#   'apanqaku',
#   'apanqa',
#   'apan',
#   'apaq',
#   'aparqanchik',
#   'aparqaniku',
#   'aparqani',
#   'aparqankichik',
#   'aparqanki',
#   'aparqanku',
#   'aparqan',
#   'apasaqku',
#   'apasaq',
#   'apaspa',
#   'apasqanchik',
#   'apasqaniku',
#   'apasqani',
#   'apasqankichik',
#   'apasqanki',
#   'apasqanku',
#   'apasqan',
#   'apasqa',
#   'apasunchik',
#   'apaychik',
#   'apayku',
#   'apay',
#   'apay'],
#  'apaykuy': ['amaapaykuchunchu',
#   'amaapaykuchunkuchu',
#   'amaapaykuychikchu',
#   'amaapaykuychu',
#   'apaykuchunku',
#   'apaykuchun',
#   'apaykuna',
#   'apaykunchik',
#   'apaykuni',
#   'apaykunkichik',
#   'apaykunkichik',
#   'apaykunki',
#   'apaykunki',
#   'apaykunku',
#   'apaykunqaku',
#   'apaykunqa',
#   'apaykun',
#   'apaykuq',
#   'apaykurqanchik',
#   'apaykurqaniku',
#   'apaykurqani',
#   'apaykurqankichik',
#   'apaykurqanki',
#   'apaykurqanku',
#   'apaykurqan',
#   'apaykusaqku',
#   'apaykusaq',
#   'apaykuspa',
#   'apaykusqanchik',
#   'apaykusqaniku',
#   'apaykusqani',
#   'apaykusqankichik',
#   'apaykusqanki',
#   'apaykusqanku',
#   'apaykusqan',
#   'apaykusqa',
#   'apaykusunchik',
#   'apaykuychik',
#   'apaykuyku',
#   'apaykuy',
#   'apaykuy'],
#  'apaysiy': ['amaapaysichunchu',
#   'amaapaysichunkuchu',
#   'amaapaysiychikchu',
#   'amaapaysiychu',
#   'apaysichunku',
#   'apaysichun',
#   'apaysina',
#   'apaysinchik',
#   'apaysini',
#   'apaysinkichik',
#   'apaysinkichik',
#   'apaysinki',
#   'apaysinki',
#   'apaysinku',
#   'apaysinqaku',
#   'apaysinqa',
#   'apaysin',
#   'apaysiq',
#   'apaysirqanchik',
#   'apaysirqaniku',
#   'apaysirqani',
#   'apaysirqankichik',
#   'apaysirqanki',
#   'apaysirqanku',
#   'apaysirqan',
#   'apaysisaqku',
#   'apaysisaq',
#   'apaysispa',
#   'apaysisqanchik',
#   'apaysisqaniku',
#   'apaysisqani',
#   'apaysisqankichik',
#   'apaysisqanki',
#   'apaysisqanku',
#   'apaysisqan',
#   'apaysisqa',
#   'apaysisunchik',
#   'apaysiychik',
#   'apaysiyku',
#   'apaysiy',
#   'apaysiy'],
#  'apichakuy': ['amaapichakuchunchu',
#   'amaapichakuchunkuchu',
#   'amaapichakuychikchu',
#   'amaapichakuychu',
#   'apichakuchunku',
#   'apichakuchun',
#   'apichakuna',
#   'apichakunchik',
#   'apichakuni',
#   'apichakunkichik',
#   'apichakunkichik',
#   'apichakunki',
#   'apichakunki',
#   'apichakunku',
#   'apichakunqaku',
#   'apichakunqa',
#   'apichakun',
#   'apichakuq',
#   'apichakurqanchik',
#   'apichakurqaniku',
#   'apichakurqani',
#   'apichakurqankichik',
#   'apichakurqanki',
#   'apichakurqanku',
#   'apichakurqan',
#   'apichakusaqku',
#   'apichakusaq',
#   'apichakuspa',
#   'apichakusqanchik',
#   'apichakusqaniku',
#   'apichakusqani',
#   'apichakusqankichik',
#   'apichakusqanki',
#   'apichakusqanku',
#   'apichakusqan',
#   'apichakusqa',
#   'apichakusunchik',
#   'apichakuychik',
#   'apichakuyku',
#   'apichakuy',
#   'apichakuy'],
#  'apichay': ['amaapichachunchu',
#   'amaapichachunkuchu',
#   'amaapichaychikchu',
#   'amaapichaychu',
#   'apichachunku',
#   'apichachun',
#   'apichana',
#   'apichanchik',
#   'apichani',
#   'apichankichik',
#   'apichankichik',
#   'apichanki',
#   'apichanki',
#   'apichanku',
#   'apichanqaku',
#   'apichanqa',
#   'apichan',
#   'apichaq',
#   'apicharqanchik',
#   'apicharqaniku',
#   'apicharqani',
#   'apicharqankichik',
#   'apicharqanki',
#   'apicharqanku',
#   'apicharqan',
#   'apichasaqku',
#   'apichasaq',
#   'apichaspa',
#   'apichasqanchik',
#   'apichasqaniku',
#   'apichasqani',
#   'apichasqankichik',
#   'apichasqanki',
#   'apichasqanku',
#   'apichasqan',
#   'apichasqa',
#   'apichasunchik',
#   'apichaychik',
#   'apichayku',
#   'apichay',
#   'apichay'],
#  'apuchay': ['amaapuchachunchu',
#   'amaapuchachunkuchu',
#   'amaapuchaychikchu',
#   'amaapuchaychu',
#   'apuchachunku',
#   'apuchachun',
#   'apuchana',
#   'apuchanchik',
#   'apuchani',
#   'apuchankichik',
#   'apuchankichik',
#   'apuchanki',
#   'apuchanki',
#   'apuchanku',
#   'apuchanqaku',
#   'apuchanqa',
#   'apuchan',
#   'apuchaq',
#   'apucharqanchik',
#   'apucharqaniku',
#   'apucharqani',
#   'apucharqankichik',
#   'apucharqanki',
#   'apucharqanku',
#   'apucharqan',
#   'apuchasaqku',
#   'apuchasaq',
#   'apuchaspa',
#   'apuchasqanchik',
#   'apuchasqaniku',
#   'apuchasqani',
#   'apuchasqankichik',
#   'apuchasqanki',
#   'apuchasqanku',
#   'apuchasqan',
#   'apuchasqa',
#   'apuchasunchik',
#   'apuchaychik',
#   'apuchayku',
#   'apuchay',
#   'apuchay'],
#  'aqhayay': ['amaaqhayachunchu',
#   'amaaqhayachunkuchu',
#   'amaaqhayaychikchu',
#   'amaaqhayaychu',
#   'aqhayachunku',
#   'aqhayachun',
#   'aqhayana',
#   'aqhayanchik',
#   'aqhayani',
#   'aqhayankichik',
#   'aqhayankichik',
#   'aqhayanki',
#   'aqhayanki',
#   'aqhayanku',
#   'aqhayanqaku',
#   'aqhayanqa',
#   'aqhayan',
#   'aqhayaq',
#   'aqhayarqanchik',
#   'aqhayarqaniku',
#   'aqhayarqani',
#   'aqhayarqankichik',
#   'aqhayarqanki',
#   'aqhayarqanku',
#   'aqhayarqan',
#   'aqhayasaqku',
#   'aqhayasaq',
#   'aqhayaspa',
#   'aqhayasqanchik',
#   'aqhayasqaniku',
#   'aqhayasqani',
#   'aqhayasqankichik',
#   'aqhayasqanki',
#   'aqhayasqanku',
#   'aqhayasqan',
#   'aqhayasqa',
#   'aqhayasunchik',
#   'aqhayaychik',
#   'aqhayayku',
#   'aqhayay',
#   'aqhayay'],
#  'aqtuy': ['amaaqtuchunchu',
#   'amaaqtuchunkuchu',
#   'amaaqtuychikchu',
#   'amaaqtuychu',
#   'aqtuchunku',
#   'aqtuchun',
#   'aqtuna',
#   'aqtunchik',
#   'aqtuni',
#   'aqtunkichik',
#   'aqtunkichik',
#   'aqtunki',
#   'aqtunki',
#   'aqtunku',
#   'aqtunqaku',
#   'aqtunqa',
#   'aqtun',
#   'aqtuq',
#   'aqturqanchik',
#   'aqturqaniku',
#   'aqturqani',
#   'aqturqankichik',
#   'aqturqanki',
#   'aqturqanku',
#   'aqturqan',
#   'aqtusaqku',
#   'aqtusaq',
#   'aqtuspa',
#   'aqtusqanchik',
#   'aqtusqaniku',
#   'aqtusqani',
#   'aqtusqankichik',
#   'aqtusqanki',
#   'aqtusqanku',
#   'aqtusqan',
#   'aqtusqa',
#   'aqtusunchik',
#   'aqtuychik',
#   'aqtuyku',
#   'aqtuy',
#   'aqtuy'],
# ...
#   'willasqanku',
#   'willasqan',
#   'willasqa',
#   'willasunchik',
#   'willaychik',
#   'willayku',
#   'willay',
#   'willay'],
#  'willkachay': ['amawillkachachunchu',
#   'amawillkachachunkuchu',
#   'amawillkachaychikchu',
#   'amawillkachaychu',
#   'willkachachunku',
#   'willkachachun',
#   'willkachana',
#   'willkachanchik',
#   'willkachani',
#   'willkachankichik',
#   'willkachankichik',
#   'willkachanki',
#   'willkachanki',
#   'willkachanku',
#   'willkachanqaku',
#   'willkachanqa',
#   'willkachan',
#   'willkachaq',
#   'willkacharqanchik',
#   'willkacharqaniku',
#   'willkacharqani',
#   'willkacharqankichik',
#   'willkacharqanki',
#   'willkacharqanku',
#   'willkacharqan',
#   'willkachasaqku',
#   'willkachasaq',
#   'willkachaspa',
#   'willkachasqanchik',
#   'willkachasqaniku',
#   'willkachasqani',
#   'willkachasqankichik',
#   'willkachasqanki',
#   'willkachasqanku',
#   'willkachasqan',
#   'willkachasqa',
#   'willkachasunchik',
#   'willkachaychik',
#   'willkachayku',
#   'willkachay',
#   'willkachay'],
#  'willkay': ['amawillkachunchu',
#   'amawillkachunkuchu',
#   'amawillkaychikchu',
#   'amawillkaychu',
#   'willkachunku',
#   'willkachun',
#   'willkana',
#   'willkanchik',
#   'willkani',
#   'willkankichik',
#   'willkankichik',
#   'willkanki',
#   'willkanki',
#   'willkanku',
#   'willkanqaku',
#   'willkanqa',
#   'willkan',
#   'willkaq',
#   'willkarqanchik',
#   'willkarqaniku',
#   'willkarqani',
#   'willkarqankichik',
#   'willkarqanki',
#   'willkarqanku',
#   'willkarqan',
#   'willkasaqku',
#   'willkasaq',
#   'willkaspa',
#   'willkasqanchik',
#   'willkasqaniku',
#   'willkasqani',
#   'willkasqankichik',
#   'willkasqanki',
#   'willkasqanku',
#   'willkasqan',
#   'willkasqa',
#   'willkasunchik',
#   'willkaychik',
#   'willkayku',
#   'willkay',
#   'willkay'],
#  'winay': ['amawinachunchu',
#   'amawinachunkuchu',
#   'amawinaychikchu',
#   'amawinaychu',
#   'winachunku',
#   'winachun',
#   'winana',
#   'winanchik',
#   'winani',
#   'winankichik',
#   'winankichik',
#   'winanki',
#   'winanki',
#   'winanku',
#   'winanqaku',
#   'winanqa',
#   'winan',
#   'winaq',
#   'winarqanchik',
#   'winarqaniku',
#   'winarqani',
#   'winarqankichik',
#   'winarqanki',
#   'winarqanku',
#   'winarqan',
#   'winasaqku',
#   'winasaq',
#   'winaspa',
#   'winasqanchik',
#   'winasqaniku',
#   'winasqani',
#   'winasqankichik',
#   'winasqanki',
#   'winasqanku',
#   'winasqan',
#   'winasqa',
#   'winasunchik',
#   'winaychik',
#   'winayku',
#   'winay',
#   'winay'],
#  'wiñay': ['amawiñachunchu',
#   'amawiñachunkuchu',
#   'amawiñaychikchu',
#   'amawiñaychu',
#   'wiñachunku',
#   'wiñachun',
#   'wiñana',
#   'wiñanchik',
#   'wiñani',
#   'wiñankichik',
#   'wiñankichik',
#   'wiñanki',
#   'wiñanki',
#   'wiñanku',
#   'wiñanqaku',
#   'wiñanqa',
#   'wiñan',
#   'wiñaq',
#   'wiñarqanchik',
#   'wiñarqaniku',
#   'wiñarqani',
#   'wiñarqankichik',
#   'wiñarqanki',
#   'wiñarqanku',
#   'wiñarqan',
#   'wiñasaqku',
#   'wiñasaq',
#   'wiñaspa',
#   'wiñasqanchik',
#   'wiñasqaniku',
#   'wiñasqani',
#   'wiñasqankichik',
#   'wiñasqanki',
#   'wiñasqanku',
#   'wiñasqan',
#   'wiñasqa',
#   'wiñasunchik',
#   'wiñaychik',
#   'wiñayku',
#   'wiñay',
#   'wiñay'],
#  'yachachiy': ['amayachachichunchu',
#   'amayachachichunkuchu',
#   'amayachachiychikchu',
#   'amayachachiychu',
#   'yachachichunku',
#   'yachachichun',
#   'yachachina',
#   'yachachinchik',
#   'yachachini',
#   'yachachinkichik',
#   'yachachinkichik',
#   'yachachinki',
#   'yachachinki',
#   'yachachinku',
#   'yachachinqaku',
#   'yachachinqa',
#   'yachachin',
#   'yachachiq',
#   'yachachirqanchik',
#   'yachachirqaniku',
#   'yachachirqani',
#   'yachachirqankichik',
#   'yachachirqanki',
#   'yachachirqanku',
#   'yachachirqan',
#   'yachachisaqku',
#   'yachachisaq',
#   'yachachispa',
#   'yachachisqanchik',
#   'yachachisqaniku',
#   'yachachisqani',
#   'yachachisqankichik',
#   'yachachisqanki',
#   'yachachisqanku',
#   'yachachisqan',
#   'yachachisqa',
#   'yachachisunchik',
#   'yachachiychik',
#   'yachachiyku',
#   'yachachiy',
#   'yachachiy'],
#  'yachakuy': ['amayachakuchunchu',
#   'amayachakuchunkuchu',
#   'amayachakuychikchu',
#   'amayachakuychu',
#   'yachakuchunku',
#   'yachakuchun',
#   'yachakuna',
#   'yachakunchik',
#   'yachakuni',
#   'yachakunkichik',
#   'yachakunkichik',
#   'yachakunki',
#   'yachakunki',
#   'yachakunku',
#   'yachakunqaku',
#   'yachakunqa',
#   'yachakun',
#   'yachakuq',
#   'yachakurqanchik',
#   'yachakurqaniku',
#   'yachakurqani',
#   'yachakurqankichik',
#   'yachakurqanki',
#   'yachakurqanku',
#   'yachakurqan',
#   'yachakusaqku',
#   'yachakusaq',
#   'yachakuspa',
#   'yachakusqanchik',
#   'yachakusqaniku',
#   'yachakusqani',
#   'yachakusqankichik',
#   'yachakusqanki',
#   'yachakusqanku',
#   'yachakusqan',
#   'yachakusqa',
#   'yachakusunchik',
#   'yachakuychik',
#   'yachakuyku',
#   'yachakuy',
#   'yachakuy'],
#  'yachay': ['amayachachunchu',
#   'amayachachunkuchu',
#   'amayachaychikchu',
#   'amayachaychu',
#   'yachachunku',
#   'yachachun',
#   'yachana',
#   'yachanchik',
#   'yachani',
#   'yachankichik',
#   'yachankichik',
#   'yachanki',
#   'yachanki',
#   'yachanku',
#   'yachanqaku',
#   'yachanqa',
#   'yachan',
#   'yachaq',
#   'yacharqanchik',
#   'yacharqaniku',
#   'yacharqani',
#   'yacharqankichik',
#   'yacharqanki',
#   'yacharqanku',
#   'yacharqan',
#   'yachasaqku',
#   'yachasaq',
#   'yachaspa',
#   'yachasqanchik',
#   'yachasqaniku',
#   'yachasqani',
#   'yachasqankichik',
#   'yachasqanki',
#   'yachasqanku',
#   'yachasqan',
#   'yachasqa',
#   'yachasunchik',
#   'yachaychik',
#   'yachayku',
#   'yachay',
#   'yachay'],
#  'yalliy': ['amayallichunchu',
#   'amayallichunkuchu',
#   'amayalliychikchu',
#   'amayalliychu',
#   'yallichunku',
#   'yallichun',
#   'yallina',
#   'yallinchik',
#   'yallini',
#   'yallinkichik',
#   'yallinkichik',
#   'yallinki',
#   'yallinki',
#   'yallinku',
#   'yallinqaku',
#   'yallinqa',
#   'yallin',
#   'yalliq',
#   'yallirqanchik',
#   'yallirqaniku',
#   'yallirqani',
#   'yallirqankichik',
#   'yallirqanki',
#   'yallirqanku',
#   'yallirqan',
#   'yallisaqku',
#   'yallisaq',
#   'yallispa',
#   'yallisqanchik',
#   'yallisqaniku',
#   'yallisqani',
#   'yallisqankichik',
#   'yallisqanki',
#   'yallisqanku',
#   'yallisqan',
#   'yallisqa',
#   'yallisunchik',
#   'yalliychik',
#   'yalliyku',
#   'yalliy',
#   'yalliy'],
#  'yanapay': ['amayanapachunchu',
#   'amayanapachunkuchu',
#   'amayanapaychikchu',
#   'amayanapaychu',
#   'yanapachunku',
#   'yanapachun',
#   'yanapana',
#   'yanapanchik',
#   'yanapani',
#   'yanapankichik',
#   'yanapankichik',
#   'yanapanki',
#   'yanapanki',
#   'yanapanku',
#   'yanapanqaku',
#   'yanapanqa',
#   'yanapan',
#   'yanapaq',
#   'yanaparqanchik',
#   'yanaparqaniku',
#   'yanaparqani',
#   'yanaparqankichik',
#   'yanaparqanki',
#   'yanaparqanku',
#   'yanaparqan',
#   'yanapasaqku',
#   'yanapasaq',
#   'yanapaspa',
#   'yanapasqanchik',
#   'yanapasqaniku',
#   'yanapasqani',
#   'yanapasqankichik',
#   'yanapasqanki',
#   'yanapasqanku',
#   'yanapasqan',
#   'yanapasqa',
#   'yanapasunchik',
#   'yanapaychik',
#   'yanapayku',
#   'yanapay',
#   'yanapay'],
#  'yanay': ['amayanachunchu',
#   'amayanachunkuchu',
#   'amayanaychikchu',
#   'amayanaychu',
#   'yanachunku',
#   'yanachun',
#   'yanana',
#   'yananchik',
#   'yanani',
#   'yanankichik',
#   'yanankichik',
#   'yananki',
#   'yananki',
#   'yananku',
#   'yananqaku',
#   'yananqa',
#   'yanan',
#   'yanaq',
#   'yanarqanchik',
#   'yanarqaniku',
#   'yanarqani',
#   'yanarqankichik',
#   'yanarqanki',
#   'yanarqanku',
#   'yanarqan',
#   'yanasaqku',
#   'yanasaq',
#   'yanaspa',
#   'yanasqanchik',
#   'yanasqaniku',
#   'yanasqani',
#   'yanasqankichik',
#   'yanasqanki',
#   'yanasqanku',
#   'yanasqan',
#   'yanasqa',
#   'yanasunchik',
#   'yanaychik',
#   'yanayku',
#   'yanay',
#   'yanay'],
#  'yañay': ['amayañachunchu',
#   'amayañachunkuchu',
#   'amayañaychikchu',
#   'amayañaychu',
#   'yañachunku',
#   'yañachun',
#   'yañana',
#   'yañanchik',
#   'yañani',
#   'yañankichik',
#   'yañankichik',
#   'yañanki',
#   'yañanki',
#   'yañanku',
#   'yañanqaku',
#   'yañanqa',
#   'yañan',
#   'yañaq',
#   'yañarqanchik',
#   'yañarqaniku',
#   'yañarqani',
#   'yañarqankichik',
#   'yañarqanki',
#   'yañarqanku',
#   'yañarqan',
#   'yañasaqku',
#   'yañasaq',
#   'yañaspa',
#   'yañasqanchik',
#   'yañasqaniku',
#   'yañasqani',
#   'yañasqankichik',
#   'yañasqanki',
#   'yañasqanku',
#   'yañasqan',
#   'yañasqa',
#   'yañasunchik',
#   'yañaychik',
#   'yañayku',
#   'yañay',
#   'yañay'],
#  'yanuy': ['amayanuchunchu',
#   'amayanuchunkuchu',
#   'amayanuychikchu',
#   'amayanuychu',
#   'yanuchunku',
#   'yanuchun',
#   'yanuna',
#   'yanunchik',
#   'yanuni',
#   'yanunkichik',
#   'yanunkichik',
#   'yanunki',
#   'yanunki',
#   'yanunku',
#   'yanunqaku',
#   'yanunqa',
#   'yanun',
#   'yanuq',
#   'yanurqanchik',
#   'yanurqaniku',
#   'yanurqani',
#   'yanurqankichik',
#   'yanurqanki',
#   'yanurqanku',
#   'yanurqan',
#   'yanusaqku',
#   'yanusaq',
#   'yanuspa',
#   'yanusqanchik',
#   'yanusqaniku',
#   'yanusqani',
#   'yanusqankichik',
#   'yanusqanki',
#   'yanusqanku',
#   'yanusqan',
#   'yanusqa',
#   'yanusunchik',
#   'yanuychik',
#   'yanuyku',
#   'yanuy',
#   'yanuy'],
#  'yapay': ['amayapachunchu',
#   'amayapachunkuchu',
#   'amayapaychikchu',
#   'amayapaychu',
#   'yapachunku',
#   'yapachun',
#   'yapana',
#   'yapanchik',
#   'yapani',
#   'yapankichik',
#   'yapankichik',
#   'yapanki',
#   'yapanki',
#   'yapanku',
#   'yapanqaku',
#   'yapanqa',
#   'yapan',
#   'yapaq',
#   'yaparqanchik',
#   'yaparqaniku',
#   'yaparqani',
#   'yaparqankichik',
#   'yaparqanki',
#   'yaparqanku',
#   'yaparqan',
#   'yapasaqku',
#   'yapasaq',
#   'yapaspa',
#   'yapasqanchik',
#   'yapasqaniku',
#   'yapasqani',
#   'yapasqankichik',
#   'yapasqanki',
#   'yapasqanku',
#   'yapasqan',
#   'yapasqa',
#   'yapasunchik',
#   'yapaychik',
#   'yapayku',
#   'yapay',
#   'yapay'],
#  'yapuy': ['amayapuchunchu',
#   'amayapuchunkuchu',
#   'amayapuychikchu',
#   'amayapuychu',
#   'yapuchunku',
#   'yapuchun',
#   'yapuna',
#   'yapunchik',
#   'yapuni',
#   'yapunkichik',
#   'yapunkichik',
#   'yapunki',
#   'yapunki',
#   'yapunku',
#   'yapunqaku',
#   'yapunqa',
#   'yapun',
#   'yapuq',
#   'yapurqanchik',
#   'yapurqaniku',
#   'yapurqani',
#   'yapurqankichik',
#   'yapurqanki',
#   'yapurqanku',
#   'yapurqan',
#   'yapusaqku',
#   'yapusaq',
#   'yapuspa',
#   'yapusqanchik',
#   'yapusqaniku',
#   'yapusqani',
#   'yapusqankichik',
#   'yapusqanki',
#   'yapusqanku',
#   'yapusqan',
#   'yapusqa',
#   'yapusunchik',
#   'yapuychik',
#   'yapuyku',
#   'yapuy',
#   'yapuy'],
#  'yaqullay': ['amayaqullachunchu',
#   'amayaqullachunkuchu',
#   'amayaqullaychikchu',
#   'amayaqullaychu',
#   'yaqullachunku',
#   'yaqullachun',
#   'yaqullana',
#   'yaqullanchik',
#   'yaqullani',
#   'yaqullankichik',
#   'yaqullankichik',
#   'yaqullanki',
#   'yaqullanki',
#   'yaqullanku',
#   'yaqullanqaku',
#   'yaqullanqa',
#   'yaqullan',
#   'yaqullaq',
#   'yaqullarqanchik',
#   'yaqullarqaniku',
#   'yaqullarqani',
#   'yaqullarqankichik',
#   'yaqullarqanki',
#   'yaqullarqanku',
#   'yaqullarqan',
#   'yaqullasaqku',
#   'yaqullasaq',
#   'yaqullaspa',
#   'yaqullasqanchik',
#   'yaqullasqaniku',
#   'yaqullasqani',
#   'yaqullasqankichik',
#   'yaqullasqanki',
#   'yaqullasqanku',
#   'yaqullasqan',
#   'yaqullasqa',
#   'yaqullasunchik',
#   'yaqullaychik',
#   'yaqullayku',
#   'yaqullay',
#   'yaqullay'],
#  'yarpay': ['amayarpachunchu',
#   'amayarpachunkuchu',
#   'amayarpaychikchu',
#   'amayarpaychu',
#   'yarpachunku',
#   'yarpachun',
#   'yarpana',
#   'yarpanchik',
#   'yarpani',
#   'yarpankichik',
#   'yarpankichik',
#   'yarpanki',
#   'yarpanki',
#   'yarpanku',
#   'yarpanqaku',
#   'yarpanqa',
#   'yarpan',
#   'yarpaq',
#   'yarparqanchik',
#   'yarparqaniku',
#   'yarparqani',
#   'yarparqankichik',
#   'yarparqanki',
#   'yarparqanku',
#   'yarparqan',
#   'yarpasaqku',
#   'yarpasaq',
#   'yarpaspa',
#   'yarpasqanchik',
#   'yarpasqaniku',
#   'yarpasqani',
#   'yarpasqankichik',
#   'yarpasqanki',
#   'yarpasqanku',
#   'yarpasqan',
#   'yarpasqa',
#   'yarpasunchik',
#   'yarpaychik',
#   'yarpayku',
#   'yarpay',
#   'yarpay'],
#  'yarqay': ['amayarqachunchu',
#   'amayarqachunkuchu',
#   'amayarqaychikchu',
#   'amayarqaychu',
#   'yarqachunku',
#   'yarqachun',
#   'yarqana',
#   'yarqanchik',
#   'yarqani',
#   'yarqankichik',
#   'yarqankichik',
#   'yarqanki',
#   'yarqanki',
#   'yarqanku',
#   'yarqanqaku',
#   'yarqanqa',
#   'yarqan',
#   'yarqaq',
#   'yarqarqanchik',
#   'yarqarqaniku',
#   'yarqarqani',
#   'yarqarqankichik',
#   'yarqarqanki',
#   'yarqarqanku',
#   'yarqarqan',
#   'yarqasaqku',
#   'yarqasaq',
#   'yarqaspa',
#   'yarqasqanchik',
#   'yarqasqaniku',
#   'yarqasqani',
#   'yarqasqankichik',
#   'yarqasqanki',
#   'yarqasqanku',
#   'yarqasqan',
#   'yarqasqa',
#   'yarqasunchik',
#   'yarqaychik',
#   'yarqayku',
#   'yarqay',
#   'yarqay'],
#  'yarquy': ['amayarquchunchu',
#   'amayarquchunkuchu',
#   'amayarquychikchu',
#   'amayarquychu',
#   'yarquchunku',
#   'yarquchun',
#   'yarquna',
#   'yarqunchik',
#   'yarquni',
#   'yarqunkichik',
#   'yarqunkichik',
#   'yarqunki',
#   'yarqunki',
#   'yarqunku',
#   'yarqunqaku',
#   'yarqunqa',
#   'yarqun',
#   'yarquq',
#   'yarqurqanchik',
#   'yarqurqaniku',
#   'yarqurqani',
#   'yarqurqankichik',
#   'yarqurqanki',
#   'yarqurqanku',
#   'yarqurqan',
#   'yarqusaqku',
#   'yarqusaq',
#   'yarquspa',
#   'yarqusqanchik',
#   'yarqusqaniku',
#   'yarqusqani',
#   'yarqusqankichik',
#   'yarqusqanki',
#   'yarqusqanku',
#   'yarqusqan',
#   'yarqusqa',
#   'yarqusunchik',
#   'yarquychik',
#   'yarquyku',
#   'yarquy',
#   'yarquy'],
#  'yawnay': ['amayawnachunchu',
#   'amayawnachunkuchu',
#   'amayawnaychikchu',
#   'amayawnaychu',
#   'yawnachunku',
#   'yawnachun',
#   'yawnana',
#   'yawnanchik',
#   'yawnani',
#   'yawnankichik',
#   'yawnankichik',
#   'yawnanki',
#   'yawnanki',
#   'yawnanku',
#   'yawnanqaku',
#   'yawnanqa',
#   'yawnan',
#   'yawnaq',
#   'yawnarqanchik',
#   'yawnarqaniku',
#   'yawnarqani',
#   'yawnarqankichik',
#   'yawnarqanki',
#   'yawnarqanku',
#   'yawnarqan',
#   'yawnasaqku',
#   'yawnasaq',
#   'yawnaspa',
#   'yawnasqanchik',
#   'yawnasqaniku',
#   'yawnasqani',
#   'yawnasqankichik',
#   'yawnasqanki',
#   'yawnasqanku',
#   'yawnasqan',
#   'yawnasqa',
#   'yawnasunchik',
#   'yawnaychik',
#   'yawnayku',
#   'yawnay',
#   'yawnay'],
#  'yaykuy': ['amayaykuchunchu',
#   'amayaykuchunkuchu',
#   'amayaykuychikchu',
#   'amayaykuychu',
#   'yaykuchunku',
#   'yaykuchun',
#   'yaykuna',
#   'yaykunchik',
#   'yaykuni',
#   'yaykunkichik',
#   'yaykunkichik',
#   'yaykunki',
#   'yaykunki',
#   'yaykunku',
#   'yaykunqaku',
#   'yaykunqa',
#   'yaykun',
#   'yaykuq',
#   'yaykurqanchik',
#   'yaykurqaniku',
#   'yaykurqani',
#   'yaykurqankichik',
#   'yaykurqanki',
#   'yaykurqanku',
#   'yaykurqan',
#   'yaykusaqku',
#   'yaykusaq',
#   'yaykuspa',
#   'yaykusqanchik',
#   'yaykusqaniku',
#   'yaykusqani',
#   'yaykusqankichik',
#   'yaykusqanki',
#   'yaykusqanku',
#   'yaykusqan',
#   'yaykusqa',
#   'yaykusunchik',
#   'yaykuychik',
#   'yaykuyku',
#   'yaykuy',
#   'yaykuy'],
#  'yupaychay': ['amayupaychachunchu',
#   'amayupaychachunkuchu',
#   'amayupaychaychikchu',
#   'amayupaychaychu',
#   'yupaychachunku',
#   'yupaychachun',
#   'yupaychana',
#   'yupaychanchik',
#   'yupaychani',
#   'yupaychankichik',
#   'yupaychankichik',
#   'yupaychanki',
#   'yupaychanki',
#   'yupaychanku',
#   'yupaychanqaku',
#   'yupaychanqa',
#   'yupaychan',
#   'yupaychaq',
#   'yupaycharqanchik',
#   'yupaycharqaniku',
#   'yupaycharqani',
#   'yupaycharqankichik',
#   'yupaycharqanki',
#   'yupaycharqanku',
#   'yupaycharqan',
#   'yupaychasaqku',
#   'yupaychasaq',
#   'yupaychaspa',
#   'yupaychasqanchik',
#   'yupaychasqaniku',
#   'yupaychasqani',
#   'yupaychasqankichik',
#   'yupaychasqanki',
#   'yupaychasqanku',
#   'yupaychasqan',
#   'yupaychasqa',
#   'yupaychasunchik',
#   'yupaychaychik',
#   'yupaychayku',
#   'yupaychay',
#   'yupaychay'],
#  'yuriy': ['amayurichunchu',
#   'amayurichunkuchu',
#   'amayuriychikchu',
#   'amayuriychu',
#   'yurichunku',
#   'yurichun',
#   'yurina',
#   'yurinchik',
#   'yurini',
#   'yurinkichik',
#   'yurinkichik',
#   'yurinki',
#   'yurinki',
#   'yurinku',
#   'yurinqaku',
#   'yurinqa',
#   'yurin',
#   'yuriq',
#   'yurirqanchik',
#   'yurirqaniku',
#   'yurirqani',
#   'yurirqankichik',
#   'yurirqanki',
#   'yurirqanku',
#   'yurirqan',
#   'yurisaqku',
#   'yurisaq',
#   'yurispa',
#   'yurisqanchik',
#   'yurisqaniku',
#   'yurisqani',
#   'yurisqankichik',
#   'yurisqanki',
#   'yurisqanku',
#   'yurisqan',
#   'yurisqa',
#   'yurisunchik',
#   'yuriychik',
#   'yuriyku',
#   'yuriy',
#   'yuriy'],
#  'yuyay': ['amayuyachunchu',
#   'amayuyachunkuchu',
#   'amayuyaychikchu',
#   'amayuyaychu',
#   'yuyachunku',
#   'yuyachun',
#   'yuyana',
#   'yuyanchik',
#   'yuyani',
#   'yuyankichik',
#   'yuyankichik',
#   'yuyanki',
#   'yuyanki',
#   'yuyanku',
#   'yuyanqaku',
#   'yuyanqa',
#   'yuyan',
#   'yuyaq',
#   'yuyarqanchik',
#   'yuyarqaniku',
#   'yuyarqani',
#   'yuyarqankichik',
#   'yuyarqanki',
#   'yuyarqanku',
#   'yuyarqan',
#   'yuyasaqku',
#   'yuyasaq',
#   'yuyaspa',
#   'yuyasqanchik',
#   'yuyasqaniku',
#   'yuyasqani',
#   'yuyasqankichik',
#   'yuyasqanki',
#   'yuyasqanku',
#   'yuyasqan',
#   'yuyasqa',
#   'yuyasunchik',
#   'yuyaychik',
#   'yuyayku',
#   'yuyay',
#   'yuyay']}

# %% [markdown]
# El segundo objetivo, que queda para ustedes, es una modificación del diccionario D_lema_inflex. En vez de asociar una lista a cada lema, asocie un diccionario. Este diccionario será de la forma {inflexión:código,...}. Tendremos entonces un diccionario de diccionarios :)

# %%
######################### código de ustedes!!! ############################

# %% [markdown]
# En un tercer ejercicio, buscamos crear un diccionario de la forma {codigo:lista_inflexiones, ...} donde lista_inflexiones es una lista de todas las inflexiones anotadas para ese código

# %%
## Primero, definimos una lista de códigos únicos

codigos_unicos = []

## recorremos la lista de lemas
for codigo in codigos:
    ## solo agregamos si no está en lemas_unicos
    if codigo not in codigos_unicos:
        codigos_unicos+=[codigo]

# %%
print(len(codigos_unicos))
# Out:
# 41

# %%
codigos_unicos[:5]
# Out:
# ['V;IMP;POS;3;PL',
#  'V;IMP;POS;3;SG',
#  'V.PTCP;FUT',
#  'V;PRS;1+INCL;PL',
#  'V;PRS;1;SG']

# %%
## definimos un diccionario vacío

D_codigo_inflex = {}

## recorremos la lista codigos_unicos
for codigo in codigos_unicos:
    ## agregamos en cada iteración, una lista vacía :)
    D_codigo_inflex[codigo]=[]

# %%
D_codigo_inflex
# Out:
# {'V;IMP;POS;3;PL': [],
#  'V;IMP;POS;3;SG': [],
#  'V.PTCP;FUT': [],
#  'V;PRS;1+INCL;PL': [],
#  'V;PRS;1;SG': [],
#  'V;FUT;2;PL': [],
#  'V;PRS;2;PL': [],
#  'V;FUT;2;SG': [],
#  'V;PRS;2;SG': [],
#  'V;PRS;3;PL': [],
#  'V;FUT;3;PL': [],
#  'V;FUT;3;SG': [],
#  'V;PRS;3;SG': [],
#  'V;NFIN;AGT': [],
#  'V;PST;FH;1+INCL;PL': [],
#  'V;PST;FH;1+EXCL;PL': [],
#  'V;PST;FH;1;SG': [],
#  'V;PST;FH;2;PL': [],
#  'V;PST;FH;2;SG': [],
#  'V;PST;FH;3;PL': [],
#  'V;PST;FH;3;SG': [],
#  'V;FUT;1+EXCL;PL': [],
#  'V;FUT;1;SG': [],
#  'V.PTCP;PRS': [],
#  'V;PST;NFH;1+INCL;PL': [],
#  'V;PST;NFH;1+EXCL;PL': [],
#  'V;PST;NFH;1;SG': [],
#  'V;PST;NFH;2;PL': [],
#  'V;PST;NFH;2;SG': [],
#  'V;PST;NFH;3;PL': [],
#  'V;PST;NFH;3;SG': [],
#  'V.PTCP;PST': [],
#  'V;FUT;1+INCL;PL': [],
#  'V;IMP;POS;2;PL': [],
#  'V;PRS;1+EXCL;PL': [],
#  'V;IMP;POS;2;SG': [],
#  'V;NFIN': [],
#  'V;IMP;NEG;3;SG': [],
#  'V;IMP;NEG;3;PL': [],
#  'V;IMP;NEG;2;PL': [],
#  'V;IMP;NEG;2;SG': []}

# %% [markdown]
# Un ejercicio: en el diccionario D_codigo_inflex, guarde en la lista correspondiente a cada key (código) todas las inflexiones asociadas a ese key

# %% [markdown]
# Otra manera de ver los datos! Usemos la siguiente lista de diccionarios :)

# %%
lista_diccionarios = list(datos.to_dict('index').values())

# %%
lista_diccionarios[:5]
# Out:
# [{'formas': 'achalachiy',
#   'inflexiones': 'achalachichunku',
#   'códigos': 'V;IMP;POS;3;PL'},
#  {'formas': 'achalachiy',
#   'inflexiones': 'achalachichun',
#   'códigos': 'V;IMP;POS;3;SG'},
#  {'formas': 'achalachiy',
#   'inflexiones': 'achalachina',
#   'códigos': 'V.PTCP;FUT'},
#  {'formas': 'achalachiy',
#   'inflexiones': 'achalachinchik',
#   'códigos': 'V;PRS;1+INCL;PL'},
#  {'formas': 'achalachiy',
#   'inflexiones': 'achalachini',
#   'códigos': 'V;PRS;1;SG'}]

# %% [markdown]
# Noten que cada elemento de esta lista es un diccionario

# %%
lista_diccionarios[0]
# Out:
# {'formas': 'achalachiy',
#  'inflexiones': 'achalachichunku',
#  'códigos': 'V;IMP;POS;3;PL'}

# %%
## Ejercicio! Filtre la lista anterior para los códigos en la siguiente lista

codigos_red = ['V;PRS;1;SG','V;PRS;2;SG','V;PRS;1;PL','V;PRS;2;PL']

# %%
lista_filtrada = []

for D in lista_diccionarios:
    ## :)

# %%
## a partir de esta lista, construya otro diccionario, D_lema, con la siguiente forma
## {lema:{'SG':{'1':inflexion_1_SG,'2':inflexion_2_SG},'PL':{...},...}, 
## donde inflexion_1_SG es la inflexión asociada a 'V;PRS;1;SG'

# %%
## ¿qué podemos hacer con este diccionario?
