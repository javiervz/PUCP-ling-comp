# %% [markdown]
# ## Universal dependencies en **Kakataibo!**

# %%
#!pip install conllu

# %% [markdown]
# ## Leemos todos los archivos conllu de la carpeta archivos-conllu

# %%
import glob as glob

conllu_archivos = glob.glob('archivos-conllu/*.conllu')

# %%
conllu_archivos
# Out:
# ['archivos-conllu\\1005(1)-sabina.conllu',
#  'archivos-conllu\\1005(6)-sabina.conllu',
#  'archivos-conllu\\174-mariana.conllu',
#  'archivos-conllu\\175(1)-mariana.conllu',
#  'archivos-conllu\\175(2)-mariana.conllu',
#  'archivos-conllu\\178-mariana.conllu',
#  'archivos-conllu\\180-mariana.conllu',
#  'archivos-conllu\\189a-mariana.conllu',
#  'archivos-conllu\\199-mariana.conllu',
#  'archivos-conllu\\200-mariana.conllu',
#  'archivos-conllu\\201-luisa.conllu',
#  'archivos-conllu\\202-luisa.conllu',
#  'archivos-conllu\\203-mariana.conllu',
#  'archivos-conllu\\204-rosa.conllu',
#  'archivos-conllu\\206-luisa.conllu',
#  'archivos-conllu\\209-rosa.conllu',
#  'archivos-conllu\\210-luisa.conllu',
#  'archivos-conllu\\211-mariana.conllu',
#  'archivos-conllu\\214-rosa.conllu',
#  'archivos-conllu\\222a-mariana.conllu',
#  'archivos-conllu\\222b-mariana.conllu',
#  'archivos-conllu\\225-mariana.conllu',
#  'archivos-conllu\\226-mariana.conllu',
#  'archivos-conllu\\227-rosa.conllu',
#  'archivos-conllu\\228-rosa.conllu',
#  'archivos-conllu\\232-mariana.conllu',
#  'archivos-conllu\\233-luisa.conllu',
#  'archivos-conllu\\234-luisa.conllu',
#  'archivos-conllu\\241-rosa.conllu',
#  'archivos-conllu\\243-luisa.conllu',
#  'archivos-conllu\\247-rosa.conllu',
#  'archivos-conllu\\248-sabina.conllu',
#  'archivos-conllu\\255-rosa.conllu',
#  'archivos-conllu\\263(1)-rosa.conllu',
#  'archivos-conllu\\264(1)-luisa.conllu',
#  'archivos-conllu\\264(2)-luisa.conllu',
#  'archivos-conllu\\265(2)-luisa.conllu',
#  'archivos-conllu\\270a-rosa.conllu',
#  'archivos-conllu\\271a-luisa.conllu',
#  'archivos-conllu\\285-rosa.conllu',
#  'archivos-conllu\\286(3)-luisa.conllu',
#  'archivos-conllu\\299-luisa.conllu',
#  'archivos-conllu\\301-luisa.conllu',
#  'archivos-conllu\\302-luisa.conllu',
#  'archivos-conllu\\310-luisa.conllu',
#  'archivos-conllu\\315-claudia.conllu',
#  'archivos-conllu\\316-claudia.conllu',
#  'archivos-conllu\\318-rosa.conllu',
#  'archivos-conllu\\319-claudia.conllu',
#  'archivos-conllu\\320-claudia.conllu',
#  'archivos-conllu\\330-claudia.conllu',
#  'archivos-conllu\\331-claudia.conllu',
#  'archivos-conllu\\332-claudia.conllu',
#  'archivos-conllu\\333-mariana.conllu',
#  'archivos-conllu\\334-claudia.conllu',
#  'archivos-conllu\\335-mariana.conllu',
#  'archivos-conllu\\337-claudia.conllu',
#  'archivos-conllu\\338-claudia.conllu',
#  'archivos-conllu\\339-claudia.conllu',
#  'archivos-conllu\\340-claudia.conllu',
#  'archivos-conllu\\341-rosa.conllu',
#  'archivos-conllu\\343-sabina.conllu',
#  'archivos-conllu\\348 -sabina.conllu',
#  'archivos-conllu\\357-sabina.conllu',
#  'archivos-conllu\\361-sabina.conllu',
#  'archivos-conllu\\363-rosa.conllu',
#  'archivos-conllu\\366-sabina.conllu',
#  'archivos-conllu\\369-sabina.conllu',
#  'archivos-conllu\\370-luisa.conllu',
#  'archivos-conllu\\379 -sabina.conllu',
#  'archivos-conllu\\388-sabina.conllu',
#  'archivos-conllu\\389-sabina.conllu',
#  'archivos-conllu\\390-sabina.conllu',
#  'archivos-conllu\\391-sabina.conllu',
#  'archivos-conllu\\393-sabina.conllu',
#  'archivos-conllu\\395-sabina.conllu',
#  'archivos-conllu\\397-sabina.conllu',
#  'archivos-conllu\\401-sabina.conllu',
#  'archivos-conllu\\405-claudia.conllu',
#  'archivos-conllu\\407-rosa.conllu',
#  'archivos-conllu\\408-sabina.conllu',
#  'archivos-conllu\\460-mariana.conllu',
#  'archivos-conllu\\471-claudia.conllu',
#  'archivos-conllu\\476-luisa.conllu',
#  'archivos-conllu\\490-rosa.conllu',
#  'archivos-conllu\\508-rosa.conllu',
#  'archivos-conllu\\509-claudia.conllu',
#  'archivos-conllu\\515-rosa.conllu',
#  'archivos-conllu\\517-claudia.conllu',
#  'archivos-conllu\\518-claudia.conllu',
#  'archivos-conllu\\7-mariana.conllu',
#  'archivos-conllu\\799-claudia.conllu',
#  'archivos-conllu\\976-mariana.conllu',
#  'archivos-conllu\\977a-sabina.conllu',
#  'archivos-conllu\\977b-sabina.conllu',
#  'archivos-conllu\\ximena-615.conllu',
#  'archivos-conllu\\ximena-672.conllu',
#  'archivos-conllu\\ximena-708.conllu',
#  'archivos-conllu\\ximena-719.conllu',
#  'archivos-conllu\\ximena-775.conllu',
#  'archivos-conllu\\ximena-854.conllu',
#  'archivos-conllu\\ximena-881.conllu',
#  'archivos-conllu\\ximena-882.conllu',
#  'archivos-conllu\\ximena-884.conllu',
#  'archivos-conllu\\ximena-916.conllu',
#  'archivos-conllu\\ximena-947.conllu',
#  'archivos-conllu\\ximena-967.conllu']

# %%
kakataibo = []

# %%
from conllu import parse

for file in conllu_archivos:
    try:
        data_k = open('archivos-conllu/'+file.split('\\')[1] , "r", encoding="utf-8")
        print(data_k)
        data = data_k.read()
        kakataibo += parse(data)
        print(data_k,data)
    except Exception as inst:
        print(file)
        pass
# Out:
# <_io.TextIOWrapper name='archivos-conllu/1005(1)-sabina.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/1005(1)-sabina.conllu' mode='r' encoding='utf-8'> # sent_id = 1005(1)-sabina
# 1	patron	_	NOUN	_	_	6	obl	_	boss
# 2	=bëtan	_	PART	_	_	1	case	_	=COM
# 3	ka	_	PART	_	_	6	aux:sgen	_	NAR
# 4	=a	_	PART	_	_	6	nsubj	_	:3
# 5	balata	_	NOUN	_	_	6	obj	_	rubber.latex
# 6	a-akë-x-ín	_	VERB	_	_	0	root	_	do-REM.PST-3-PROX
# 7	.	_	PUNCT	_	_	6	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/1005(6)-sabina.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/1005(6)-sabina.conllu' mode='r' encoding='utf-8'> # sent_id = 1005(6)-sabina
# 1	maru-kin	_	VERB	_	_	3	advcl	_	sell-s/a>a:se
# 2	no-n	_	ADJ	_	_	3	nsubj:free	_	non.indigenous-erg
# 3	buan-akë-x-ín	_	VERB	_	_	0	root	_	take-rem.pas-3-non.prox
# 4	.	_	PUNCT	_	_	3	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/174-mariana.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/174-mariana.conllu' mode='r' encoding='utf-8'> # sent_id = 174-mariana
# 1	Juan	_	PROPN	_	_	7	nsubj	_	Juan
# 2	ka	_	PART	_	_	7	nsubj	_	NAR:3
# 3	=mënë	_	PART	_	_	7	nsubj	_	=MIR
# 4	mi	_	PRON	_	_	6	nmod	_	2SG
# 5	=n	_	PART	_	_	4	case	_	=GEN
# 6	kuriki	_	NOUN	_	_	7	aux:sgen	_	money:ABS
# 7	mëkama-iéé	_	VERB	_	_	0	root	_	steal-3.accusatory
# 8	.	_	PUNCT	_	_	7	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/175(1)-mariana.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/175(1)-mariana.conllu' mode='r' encoding='utf-8'> # sent_id = 175-mariana
# 1	Nukën	_	PRON	_	_	2	nmod	_	1pl:gen
# 2	chaiti	_	NOUN	_	_	6	nsubj:free	_	ancestor:abs
# 3	ka	_	PART	_	_	6	aux:sgen	_	nar
# 4	=is	_	PART	_	_	6	aux:ev	_	=rep
# 5	=a	_	PART	_	_	6	nsubj	_	=3
# 6	tsó-akë-x-a	_	VERB	_	_	0	root	_	live-rem.pst-3-non.prox
# 7	norte	_	NOUN	_	_	6	obl	_	North
# 8	=nu	_	PART	_	_	7	case	_	=loc
# 9	.	_	PUNCT	_	_	6	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/175(2)-mariana.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/175(2)-mariana.conllu' mode='r' encoding='utf-8'> # sent_id = 175(2)-mariana
# 1	Norte	_	NOUN	_	_	16	obl	_	North
# 2	=nu	_	PART	_	_	1	case	_	=loc
# 3	tsó-xun	_	VERB	_	_	16	advcl	_	live-S/A>A:SE
# 4	ka	_	PART	_	_	16	aux:sgen	_	NAR
# 5	=is	_	PART	_	_	16	aux:ev	_	=REP
# 6	=a	_	PART	_	_	16	nsubj	_	=3
# 7	nukën	_	PRON	_	_	8	nmod	_	1pl.gen
# 8	chaiti-baë	_	NOUN	_	_	16	nsubj:free	_	ancestor-COL
# 9	=n	_	PART	_	_	8	case	_	=ERG
# 10	uni	_	NOUN	_	_	16	obl	_	people
# 11	=ñu	_	PART	_	_	10	case	_	=PROP
# 12	=ma	_	PART	_	_	10	nmod	_	=NEG
# 13	no	_	ADJ	_	_	16	obl	_	foreign
# 14	=ñu	_	PART	_	_	13	case	_	=PROP
# 15	=ma	_	PART	_	_	13	nmod	_	=NEG
# 16	'a-akë-x-a	_	VERB	_	_	0	root	_	do-REM.PST-3-NON.PROX
# 17	.	_	PUNCT	_	_	16	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/178-mariana.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/178-mariana.conllu' mode='r' encoding='utf-8'> # sent_id = 178-mariana
# 1	Nukën	_	PRON	_	_	2	nmod	_	1PL.GEN
# 2	chaiti	_	NOUN	_	_	7	nsubj:free	_	ancestor
# 3	=n	_	PART	_	_	2	case	_	=ERG
# 4	ka	_	PART	_	_	7	aux:sgen	_	NAR:3
# 5	=a	_	PART	_	_	7	nsubj	_	_
# 6	bana	_	NOUN	_	_	7	obl	_	tale:ABS
# 7	ñui-xun-kian	_	VERB	_	_	0	root	_	say-BEN-REM.PST.HAB.3
# 8	.	_	PUNCT	_	_	7	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/180-mariana.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/180-mariana.conllu' mode='r' encoding='utf-8'> # sent_id = 180-mariana
# 1	'Ë	_	PRON	_	_	4	nsubj	_	1SG:P
# 2	ka	_	PART	_	_	4	aux:sgen	_	NAR
# 3	'atsa	_	NOUN	_	_	4	obl	_	manioc:ABS
# 4	'inan	_	VERB	_	_	0	root	_	give:IMP
# 5	.	_	PUNCT	_	_	4	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/189a-mariana.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/189a-mariana.conllu' mode='r' encoding='utf-8'> # sent_id = 189a-mariana
# 1	Nukën	_	PRON	_	_	2	nmod	_	1PL.GEN
# 2	chaiti	_	NOUN	_	_	9	nsubj:free	_	ancestor
# 3	=n	_	PART	_	_	2	case	_	=ERG
# 4	ka	_	PART	_	_	9	aux:gen	_	NAR
# 5	=is	_	PART	_	_	9	aux:ev	_	=REP
# 6	=a	_	PART	_	_	9	nsubj	_	=3
# 7	'ó	_	NOUN	_	_	8	nmod	_	tapir
# 8	nami	_	NOUN	_	_	9	obl	_	meat:ABS
# 9	pi-akë-x-a	_	VERB	_	_	0	root	_	eat-REM.PST-3-NON.PROX
# 10	.	_	PUNCT	_	_	9	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/199-mariana.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/199-mariana.conllu' mode='r' encoding='utf-8'> # sent_id = 199-mariana
# # text = Achushi uni chaxkë =bëtan ka =na 'ë =n xubu' a-ti 'ain .
# 1	Achushi	_	NUM	_	_	2	nummod	_	one
# 2	uni	_	NOUN	_	_	10	obl	_	man
# 3	chaxkë	_	ADJ	_	_	2	amod	_	big
# 4	=bëtan	_	PART	_	_	3	case	_	=COM:A
# 5	ka	_	PART	_	_	10	aux:sgen	_	NAR
# 6	=na	_	PART	_	_	10	nsubj	_	=1SG
# 7	'ë	_	PRON	_	_	10	nsubj:free	_	1SG
# 8	=n	_	PART	_	_	7	case	_	=GEN
# 9	xubu'	_	NOUN	_	_	10	obl	_	house:ABS
# 10	a-ti	_	VERB	_	_	0	root	_	do-NMLZ
# 11	'ain	_	AUX	_	_	10	aux	_	be:1/2
# 12	.	_	PUNCT	_	_	10	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/200-mariana.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/200-mariana.conllu' mode='r' encoding='utf-8'> # sent_id = 200-mariana
# 1	Uni	_	NOUN	_	_	9	nsubj:free	_	man
# 2	=n	_	PART	_	_	1	case	_	=ERG
# 3	ka	_	PART	_	_	9	aux:sgen	_	NAR:3
# 4	=a	_	PART	_	_	9	nsubj	_	_
# 5	baka	_	NOUN	_	_	9	obl	_	river
# 6	=nu	_	PART	_	_	5	case	_	=LOC
# 7	=xun	_	PART	_	_	1	case	_	=PA.A
# 8	chaxu	_	NOUN	_	_	9	obj	_	deer:ABS
# 9	'a-a-x-a	_	VERB	_	_	0	root	_	kill-PFV-3-NON.PROX
# 10	.	_	PUNCT	_	_	9	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/201-luisa.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/201-luisa.conllu' mode='r' encoding='utf-8'> # sent_id = 201-luisa
# 1	Xanu-xun	xanu	NOUN	_	_	5	adv	_	woman
# 2	ka		_	PART	_	_	5	aux:sgen	_	_
# 3	=a		ka	PART	_	_	5	nsubj:bound	_	nar:3
# 4	‘atapa		‘atapa	NOUN	_	_	5	obj	_	chicken:abs
# 5	‘a-a-x-a	‘a	VERB	_	_	0	root	_	kill-pfv-3-non.prox
# 6	.		_	PUNCT	_	_	5	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/202-luisa.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/202-luisa.conllu' mode='r' encoding='utf-8'> # sent_id = 202-luisa
# 1	Uni	uni	NOUN	_	_	9	nsubj:free	_	man
# 2	achushi	achushi	DET	_	_	1	xmod	_	one
# 3	=n	n	PART	_	_	1	case	_	=ergative
# 4	=pain	pain	PART	_	_	9	adv	_	=first
# 5	ka	_	PART	_	_	9	aux:sgen	_	_
# 6	=a	ka	PART	_	_	9	nsubj:bound	_	nar:3
# 7	ënë	ënë	DET	_	_	8	det	_	this
# 8	‘ó	‘ó	NOUN	_	_	9	obj	_	tapir:abs
# 9	‘a-a-x-a	‘a	VERB	_	_	0	root	_	kill-pfv-3-non.prox
# 10	.	_	PUNCT	_	_	9	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/203-mariana.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/203-mariana.conllu' mode='r' encoding='utf-8'> # sent_id = 203-mariana
# 1	Munu	_	ADV	_	_	5	advmod	_	slowly
# 2	=ishi	_	PART	_	_	1	advmod	_	=only
# 3	ka	_	PART	_	_	5	aux:sgen	_	NAR
# 4	=mina	_	PART	_	_	5	nsubj	_	=2
# 5	pi-ti	_	VERB	_	_	0	root	_	eat-NOMLZ
# 6	'ain	_	AUX	_	_	5	aux	_	be:1/2
# 7	.	_	PUNCT	_	_	6	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/204-rosa.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/204-rosa.conllu' mode='r' encoding='utf-8'> # sent_id = 204-rosa
# 1	Roberto	Roberto=n	PROPN	_	_	8	nsubj:free	_	Roberto
# 2	=nën	n	PART	_	_	1	case	_	Ergative
# 3	ka	ka	PART	_	_	8	aux:sgen	_	narrative
# 4	=a	a	PART	_	_	8	nsubj:bound	_	3
# 5	ënë	ënë	DET	_	_	7	det	_	this
# 6	‘ó	'o	NOUN	_	_	7	nmod	_	tapir
# 7	name	nami	NOUN	_	_	8	obj	_	meat:abs
# 8	pipania	pi-pan-i-a	VERB	_	_	0	root	_	eat-first-IPFV-NOM.PROX
# 9	.	_	PUNCT	_	_	8	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/206-luisa.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/206-luisa.conllu' mode='r' encoding='utf-8'> # sent_id = 206-luisa
# 1	Achushi	achushi	DET	_	_	3	nummod	_	one
# 2	=ishi	ishi	PART	_	_	1	advmod	_	=only
# 3	ñu	ñu	NOUN	_	_	7	obj	_	thing:abs
# 4	ka	_	PART	_	_	7	aux:sgen	_	_
# 5	=a	ka	PART	_	_	7	nsubj:bound	_	nar:3
# 6	‘ë	‘ë	PRON	_	_	7	obj	_	1sg:p
# 7	‘inan	'inan	VERB	_	_	0	root	_	give:imp
# 8	.	_	PUNCT	_	_	7	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/209-rosa.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/209-rosa.conllu' mode='r' encoding='utf-8'> # sent_id = 209-rosa
# 1	Uni	uni	NOUN	_	_	10	obl	_	man
# 2	chaxkë´	chaxkë´	ADJ	_	_	1	amod	_	big
# 3	achushi	achushi	NUM	_	_	1	nummod	_	one
# 4	=bëtan	bëtan	PART	_	_	1	case	_	comitative:A
# 5	ka	ka	PART	_	_	10	aux:sgen	_	narrative
# 6	=na	na	PART	_	_	10	nsubj:bound	_	1sg
# 7	'ë	'ë	PRON	_	_	9	nmod	_	1sg
# 8	=n	n	PART	_	_	7	case	_	genitive
# 9	xubu	xubu	NOUN	_	_	10	obj	_	house:ABS
# 10	'ati	'a-ti	VERB	_	_	0	root	_	do-nomlz
# 11	'ain	'ain	AUX	_	_	10	aux	_	be:1/2
# 12	.	_	PUNCT	_	_	10	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/210-luisa.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/210-luisa.conllu' mode='r' encoding='utf-8'> # sent_id = 210-luisa
# 1	Imëishi	imëishi	ADV	_	_	6	advmod	_	tomorrow
# 2	ka	ka	PART	_	_	6	aux:sgen	_	narrative
# 3	=na	na	PART	_	_	6	nsubj:bound	_	=1sg
# 4	Aguaytia	Aguaytia	NOUN	_	_	6	obl	_	Aguaytia
# 5	=nu	nu	PART	_	_	4	case	_	=directional
# 6	kwan-ti	kwanti	VERB	_	_	0	root	_	go-nomlz
# 7	‘ain	‘i	AUX	_	_	6	aux	_	be:1/2
# 8	.	_	PUNCT	_	_	6	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/211-mariana.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/211-mariana.conllu' mode='r' encoding='utf-8'> # sent_id = 211-mariana
# 1	Aguaytia	_	PRON	_	_	6	obl	_	Aguaytía
# 2	=nu	_	PART	_	_	1	case	_	=DIR
# 3	ka	_	PART	_	_	6	aux:sgen	_	NAR
# 4	=na	_	PART	_	_	6	nsubj	_	=1SG
# 5	imëshi	_	NOUN	_	_	6	advmod	_	tomorrow
# 6	kwan-ti	_	VERB	_	_	0	root	_	go-NOMLZ
# 7	ain	_	AUX	_	_	6	aux	_	be:1/2
# 8	.	_	PUNCT	_	_	6	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/214-rosa.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/214-rosa.conllu' mode='r' encoding='utf-8'> # sent_id = 214-rosa
# 1	uni	uni	NOUN	_	_	10	nsubj:free	_	man
# 2	=n	n	PART	_	_	1	case	_	ergative
# 3	ka	ka	PART	_	_	10	aux:sgen	_	narrative
# 4	=a	a	PART	_	_	10	nsubj	_	3
# 5	baka	baka	NOUN	_	_	10	obl	_	river
# 6	=nu	nu	PART	_	_	5	case	_	locative
# 7	=xun	xun	PART	_	_	1	case	_	Participant agreement.Agent
# 8	=bi	bi	PART	_	_	5	advmod	_	=same
# 9	chaxu	chaxu	NOUN	_	_	10	obj	_	deer:abs
# 10	'aaxa	'a-a-x-a	VERB	_	_	0	root	_	kill-pfv-3-non.prox
# 11	.	_	PUNCT	_	_	10	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/222a-mariana.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/222a-mariana.conllu' mode='r' encoding='utf-8'> # sent_id = 222a-mariana
# 1	Roberto	_	PROPN	_	_	5	nsubj:free	_	Roberto
# 2	ka	_	PART	_	_	5	aux:sgen	_	NAR
# 3	=a	_	PART	_	_	5	nsubj	_	_
# 4	më-uxu	_	NOUN	_	_	5	nmod	_	hand-white
# 5	'ikën	_	VERB	_	_	0	root	_	be:3
# 6	.	_	PUNCT	_	_	5	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/222b-mariana.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/222b-mariana.conllu' mode='r' encoding='utf-8'> # sent_id = 222b-mariana
# 1	Roberto	_	PROPN	_	_	7	nsubj:free	_	Roberto
# 2	ka	_	PART	_	_	7	aux:sgen	_	NAR:3
# 3	=a	_	PART	_	_	7	nsubj	_	_
# 4	mëkën	_	NOUN	_	_	7	obl	_	hand
# 5	=nu	_	PART	_	_	4	case	_	=LOC
# 6	më-uxu	_	NOUN	_	_	7	nmod	_	hand-white
# 7	'ikën	_	VERB	_	_	0	root	_	be:3
# 8	.	_	PUNCT	_	_	7	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/225-mariana.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/225-mariana.conllu' mode='r' encoding='utf-8'> # sent_id = 225-mariana
# 1	Ta-tani-katsi	_	VERB	_	_	2	parataxis	_	foot-tie-pretending
# 2	ki-xun	_	_	VERB	_	3	advcl	_	say:INTR-S/A>A:SE
# 3	rakan-bian-a-n	_	VERB	_	_	0	root	_	lay.down-going:TRAN-PFV-1/2
# 4	.	_	PUNCT	_	_	3	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/226-mariana.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/226-mariana.conllu' mode='r' encoding='utf-8'> # sent_id = 226-mariana
# 1	Tënka-këbë	_	VERB	_	_	8	advcl	_	cut-when:DS/A/P:INTR
# 2	ka	_	PART	_	_	8	aux:sgen	_	NAR
# 3	=is	_	PART	_	_	8	aux:ev	_	REP
# 4	=a	_	PART	_	_	8	nsubj	_	3
# 5	uni	_	NOUN	_	_	8	nsubj:free	_	person:ABS
# 6	ëëëëëë	_	INTJ	_	_	8	parataxis	_	ëëëëë
# 7	ki-i	_	VERB	_	_	8	advcl	_	say:INTR-S/A>S:SE
# 8	bë-man-mët-akë-xín	_	VERB	_	_	0	root	_	eyes-touch-REFL-REM.PST-3-PROX
# 9	.	_	PUNCT	_	_	8	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/227-rosa.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/227-rosa.conllu' mode='r' encoding='utf-8'> # sent_id = 227-rosa
# 1	Parunuti	parunuti	NOUN	_	_	6	nsubj:free	_	earring
# 2	a	a	DET	_	_	1	det	_	that
# 3	=x	x	PART	_	_	1	case	_	=s.
# 4	ka	ka	PART	_	_	6	aux:sgen	_	narrative
# 5	=a	a	PART	_	_	6	nsubj:bound	_	3
# 6	pabëntamëti	pa-bëntan-mët-ti	VERB	_	_	0	root	_	ear-hang-REFL-NOMLZ
# 7	'ikën	'ikën	AUX	_	_	6	aux	_	be:3
# 8	.	_	PUNCT	_	_	6	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/228-rosa.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/228-rosa.conllu' mode='r' encoding='utf-8'> # sent_id = 228-rosa
# 1	Parunuti	parunuti	NOUN	_	_	8	nsubj:free	_	earring
# 2	a	a	DET	_	_	1	det	_	that
# 3	=x	x	PART	_	_	1	case	_	=s.
# 4	ka	ka	PART	_	_	8	aux:sgen	_	narrative
# 5	=a	a	PART	_	_	8	nsubj:bound	_	3
# 6	pabí	pabí	NOUN	_	_	8	obl	_	ear
# 7	=nu	nu	PART	_	_	6	case	_	locative
# 8	bëntamëti	bëntan-mët-ti	VERB	_	_	0	root	_	hang-REFL-NOMLZ
# 9	'ikën	'ikën	AUX	_	_	8	aux	_	be:3
# 10	.	_	PUNCT	_	_	8	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/232-mariana.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/232-mariana.conllu' mode='r' encoding='utf-8'> # sent_id = 232-mariana
# 1	Ë	_	PRON	_	_	7	nsubj:free	_	1SG
# 2	=x	_	PART	_	_	1	case	_	=S
# 3	ka	_	PART	_	_	7	aux:sgen	_	NAR
# 4	=na	_	PART	_	_	7	nsubj	_	=1SG
# 5	xubu	_	NOUN	_	_	7	obl	_	house
# 6	=nu	_	PART	_	_	5	case	_	=LOC
# 7	atsin-i-n	_	VERB	_	_	0	root	_	enter-IPFV-1/2
# 8	.	_	PUNCT	_	_	7	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/233-luisa.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/233-luisa.conllu' mode='r' encoding='utf-8'> # sent_id = 233-luisa
# 1	Ë	ë	PRON	_	_	8	nsubj:free	_	1sg
# 2	=n	n	PART	_	_	1	case	_	=a
# 3	ka	ka	PART	_	_	8	aux:sgen	_	narrative
# 4	=na	na	PART	_	_	8	nsubj:bound	_	=1sg
# 5	xubu	xubu	NOUN	_	_	8	obl	_	house
# 6	=nu	nu	PART	_	_	5	case	_	=locative
# 7	i	i	NOUN	_	_	8	obj	_	wood:abs
# 8	atsin-mi-i-n	atsin	VERB	_	_	0	root	_	enter-caus-ipfv-1/2
# 9	.	_	PUNCT	_	_	8	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/234-luisa.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/234-luisa.conllu' mode='r' encoding='utf-8'> # sent_id = 234-luisa
# 1	‘Ë	‘ë	PRON	_	_	7	nsubj:free	_	1sg
# 2	=x	x	PART	_	_	1	case	_	=s
# 3	ka	ka	PART	_	_	7	aux:sgen	_	narrative
# 4	=na	na	PART	_	_	7	nsubj:bound	_	=1sg
# 5	kini	kini	NOUN	_	_	7	obl	_	hole
# 6	=nu	nu	PART	_	_	5	case	_	=locative
# 7	më-atsin-mët-i-n	atsin	VERB	_	_	0	root	_	hand-enter-refl-ipfv-1/2
# 8	.	_	PUNCT	_	_	7	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/241-rosa.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/241-rosa.conllu' mode='r' encoding='utf-8'> # sent_id = 241-rosa
# 1	Uinbirës	uinbirës	PRON	_	_	7	nsubj:free	_	anyone
# 2	ka	ka	PART	_	_	7	aux:sgen	_	narrative
# 3	=a	a	PART	_	_	7	nsubj:bound	_	3
# 4	'ë	'ë	PRON	_	_	6	nmod	_	1
# 5	=n	n	PART	_	_	4	case	_	genetive
# 6	piti	piti	NOUN	_	_	7	obj	_	food:ABS
# 7	piti	pi-ti	VERB	_	_	0	root	_	eat-NOMLZ
# 8	'ikën	'ikën	AUX	_	_	7	aux	_	be:3
# 9	.	_	PUNCT	_	_	7	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/243-luisa.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/243-luisa.conllu' mode='r' encoding='utf-8'> # sent_id = 243-luisa
# 1	Uinbi	uinbi	PRON	_	_	7	nsubj:free	_	nobody:a
# 2	ka	_	PART	_	_	7	aux:sgen	_	_
# 3	=a	ka	PART	_	_	7	nsubj:bound	_	nar:3
# 4	‘ë	‘ë	PRON	_	_	6	nmod	_	1sg
# 5	=n	n	PART	_	_	4	case	_	=genitive
# 6	piti	piti	NOUN	_	_	7	obj	_	food:abs
# 7	pi-ti	piti	VERB	_	_	0	root	_	eat-nomlz
# 8	=ma	ma	PART	_	_	7	neg	_	=negative
# 9	‘ikën	‘i	AUX	_	_	7	aux	_	be:3
# 10	.	_	PUNCT	_	_	7	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/247-rosa.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/247-rosa.conllu' mode='r' encoding='utf-8'> # sent_id = 247-rosa
# 1	Tanu	tanu	NOUN	_	_	2	obj	_	palm.grub:ABS
# 2	rërëkanux	rërëka-nux	VERB	_	_	3	advcl	_	spill-S/A>S:POE
# 3	tsóbuakëxa	tsót-but-akë-x-a	VERB	_	_	0	root	_	live-down:INTR-REM.PST-3-NON-PROX
# 4	bai	bai	NOUN	_	_	3	obl	_	path
# 5	‘ipasu	'ipasu	ADP	_	_	4	case	_	at.side.of
# 6	.	_	PUNCT	_	_	3	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/248-sabina.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/248-sabina.conllu' mode='r' encoding='utf-8'> # sent_id = 248-sabina
# 1	y	_	CCONJ	_	_	8	conj	8:conj	and
# 2	a	_	SCONJ	_	_	3	det	3:det	that
# 3	kaibu	_	NOUN	_	_	_	_	_	relative:ABS
# 4	=ribi	_	PART	_	_	3	advmod	3:advmod	=also
# 5	abat-a	_	NOUN	_	_	3	advmod	3:advmod	escape-NOMLZ
# 6	ka	_	PART	_	_	8	aux:sgen	8:aux:sgen	NAR
# 7	=a	_	PART	_	_	8	nsubj	8:nsubj	:3
# 8	ikën	_	VERB	_	_	0	root	0:root	be:3
# 9	bëtsi	_	NOUN	_	_	8	advmod	8:advmod	other
# 10	Palcaso	_	PROPN	_	_	11	nmod	11:nmod	Palcaso river
# 11	rëbúmi	_	ADP	_	_	8	advmod	8:advmod	beyond
# 12	.	_	PUNCT	_	_	8	punct	8:punct	_
#
# <_io.TextIOWrapper name='archivos-conllu/255-rosa.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/255-rosa.conllu' mode='r' encoding='utf-8'> # sent_id = 255-rosa
# 1	Comodiezaños	como diez años	ADV	_	_	2	advmod	_	like.ten.years
# 2	aish	aish	VERB	_	_	7	advcl	_	be:S/A>S
# 3	ka	ka	PART	_	_	7	aux:sgen	_	narrative
# 4	=na	=na	PART	_	_	7	nsubj:bound	_	1sg
# 5	'ë	'ë	PRON	_	_	_	_	_	1sg
# 6	=x	x	PART	_	_	5	case	_	=s
# 7	tsókën	tsót-akë-n	VERB	_	_	0	root	_	live-REM.PST-1/2
# 8	SantaRosa	Santa Rosa	NOUN	_	_	7	obl	_	Santa.Rosa.village
# 9	tsipúmi	 tsipumi	ADP	_	_	8	case	_	below
# 10	.	_	PUNCT	_	_	7	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/263(1)-rosa.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/263(1)-rosa.conllu' mode='r' encoding='utf-8'> # sent_id = 263(1)-rosa
# 1	Nukën	nukën	PRON	_	_	2	nmod	_	1pl.gen
# 2	'ibu	'ibu	NOUN	_	_	9	nsubj:free	_	owner:abs
# 3	ka	ka	PART	_	_	9	aux:sgen	_	narrative
# 4	=is	is	PART	_	_	9	aux:evid	_	reportative
# 5	=a	a	PART	_	_	9	nsubj:bound	_	3
# 6	nai	nai	NOUN	_	_	9	obl	_	sky
# 7	=nu	nu	PART	_	_	6	case	_	locative
# 8	=ax	ax	PART	_	_	2	case	_	PA.s
# 9	uakëxa	u-akë-x-a	VERB	_	_	0	root	_	come-REM.PST-3-NON.PROX
# 10	.	_	PUNCT	_	_	9	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/264(1)-luisa.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/264(1)-luisa.conllu' mode='r' encoding='utf-8'> # sent_id = 264(1)-luisa
# 1	Achushi	achushi	ADJ	_	_	2	nummod	_	one
# 2	kini	kini	NOUN	_	_	_	_	_	hole
# 3	=ñu	ñu	PART	_	_	2	case	_	=propietive
# 4	ka	_	PART	_	_	10	aux:sgen	_	_
# 5	=a	ka	PART	_	_	10	nsubj:bound	_	nar:3
# 6	mi	mi	PRON	_	_	8	nmod	_	2sg
# 7	=n	n	PART	_	_	6	case	_	=genitive
# 8	xo	_	NOUN	_	_	9	amod	_	_
# 9	rabé̈okë	xo vrabé̈okë	NOUN	_	_	_	_	_	pants
# 10	‘ikën	‘i	VERB	_	_	0	root	_	be:3
# 11	.	_	PUNCT	_	_	10	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/264(2)-luisa.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/264(2)-luisa.conllu' mode='r' encoding='utf-8'> # sent_id = 264(2)-luisa
# 1	Mi	mi	PRON	_	_	3	nmod	_	2sg
# 2	=n	n	PART	_	_	1	case	_	=genitive
# 3	nunti	nunti	NOUN	_	_	6	nsubj:free	_	canoe:abs
# 4	ka	_	PART	_	_	6	aux:sgen	_	_
# 5	=a	ka	PART	_	_	6	nsubj:bound	_	nar:3
# 6	kini-i-ín	kini	VERB	_	_	0	root	_	become.hole-ipfv-prox_
# 7	.	_	PUNCT	_	_	6	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/265(2)-luisa.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/265(2)-luisa.conllu' mode='r' encoding='utf-8'> # sent_id = 265(2)-luisa
# 1	Mi	mi	PRON	_	_	3	nmod	_	2sg
# 2	=n	n	PART	_	_	1	case	_	=genitive
# 3	naë	naë	NOUN	_	_	6	nsubj:free	_	garden:abs
# 4	ka	_	PART	_	_	6	aux:sgen	_	_
# 5	=a	ka	PART	_	_	6	nsubj:bound	_	nar:3
# 6	matat-i-ín	matat	VERB	_	_	0	root	_	become.hill-ipfv-prox
# 7	.	_	PUNCT	_	_	6	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/270a-rosa.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/270a-rosa.conllu' mode='r' encoding='utf-8'> # sent_id = 270a-rosa
# 1	Bari	bari	NOUN	_	_	7	nsubj:free	_	sun
# 2	=n	n	PART	_	_	1	case	_	ergative
# 3	ka	ka	PART	_	_	7	aux:sgen	_	narrative
# 4	=a	a	PART	_	_	7	nsubj:bound	_	3
# 5	a	a	DET	_	_	6	det	_	that
# 6	këntí	këntí	NOUN	_	_	7	obj	_	pot:abs
# 7	ichútmiaxa	ichút-mi-a-x-a	VERB	_	_	0	root	_	be.bright-CAUS-PFV-3-NON.PROX
# 8	.	_	PUNCT	_	_	7	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/271a-luisa.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/271a-luisa.conllu' mode='r' encoding='utf-8'> # sent_id = 271a-luisa
# 1	Mi	mi	PRON	_	_	3	nmod	_	2sg
# 2	=n	n	PART	_	_	1	case	_	=genitive
# 3	linterna	linterna	NOUN	_	_	6	nsubj:free	_	torch:abs
# 4	ka	ka	PART	_	_	6	aux:sgen	_	narrative
# 5	=mina	mina	PART	_	_	6	nsubj:bound	_	=2
# 6	tirit-o-a-n	tirit	VERB	_	_	0	root	_	become.shining-fact-pfv-2
# 7	.	_	PUNCT	_	_	6	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/285-rosa.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/285-rosa.conllu' mode='r' encoding='utf-8'> # sent_id = 285-rosa
# 1	A	a	DET	_	_	2	det	_	that
# 2	uni	uni	NOUN	_	_	9	nsubj:free	_	man
# 3	=n	n	PART	_	_	2	case	_	ergative
# 4	ka	ka	PART	_	_	9	aux:sgen	_	narrative
# 5	=a	a	PART	_	_	9	nsubj:bound	_	3
# 6	uri	uri	ADV	_	_	9	advmod	_	far
# 7	achushi	achushi	NUM	_	_	8	nummod	_	one
# 8	xaë	xaë	NOUN	_	_	9	obj	_	turtle:abs
# 9	mëraxa	mëra-a-x-a	VERB	_	_	0	root	_	find-PFV-3-NON.PROX
# 10	.	_	PUNCT	_	_	9	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/286(3)-luisa.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/286(3)-luisa.conllu' mode='r' encoding='utf-8'> # sent_id = 286(3)-luisa
# 1	A	a	DET	_	_	2	det	_	that
# 2	xubu	xubu	NOUN	_	_	7	obl	_	house
# 3	=nu	nu	PART	_	_	2	case	_	=locative
# 4	ka	ka	PART	_	_	7	aux:sgen	_	narrative
# 5	=na	na	PART	_	_	7	nsubj:bound	_	=1sg
# 6	imé̈	imé̈	ADV	_	_	7	advmod	_	at.night
# 7	kwan-ti	kwanti	VERB	_	_	0	root	_	go-nomlz
# 8	‘ain	‘i	AUX	_	_	7	aux	_	be:1/2
# 9	.	_	PUNCT	_	_	7	punct	_	_
#
# <_io.TextIOWrapper name='archivos-conllu/299-luisa.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/299-luisa.conllu' mode='r' encoding='utf-8'> # sent_id = 299-luisa
# 1	‘Ë	‘Ë	PRON	_	_	3	nmod	_	1sg
# 2	=n	n	PART	_	_	1	case	_	=genitive
# 3	xubu	xubu	NOUN	_	_	5	nsubj	_	house:abs
# 4	‘aisama	‘aisama	ADJ	_	_	5	amod	_	bad
# 5	‘i-këbëtan	‘i	VERB	_	_	_	_	_	be-ds/a/p:se:tran
# 6	ka	ka	PART	_	_	12	aux:sgen	_	narrative
# 7	=na	na	PART	_	_	12	nsubj:bound	_	=1sg
# 8	bëtsi	bëtsi	ADJ	_	_	9	amod	_	other
# 9	xubu	xubu	NOUN	_	_	12	obj	_	house:abs
# 10	‘ë	‘ë	PRON	_	_	12	nsubj:free	_	1sg
# 11	=n	n	PART	_	_	10	case	_	=a
# 12	‘a-akë-n	‘a	VERB	_	_	0	root	_	do-rem.pst-1/2
# 13	.	_	PUNCT	_	_	12	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/301-luisa.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/301-luisa.conllu' mode='r' encoding='utf-8'> # sent_id = 301-luisa
# 1	Kënë	kënë	NOUN	_	_	2	nsubj	_	wall:abs
# 2	xaiki-këbë	xaibi	VERB	_	_	6	advcl	_	shake-ds/a/p:se:intr
# 3	ka	_	PART	_	_	6	aux:sgen	_	_
# 4	=a	ka	PART	_	_	6	nsubj:bound	_	nar:3
# 5	xubu	xubu	NOUN	_	_	6	nsubj:free	_	house:abs
# 6	nipakët-a-x-a	nipakët	VERB	_	_	0	root	_	fall.down-ipfv-non.prox
# 7	.	_	PUNCT	_	_	6	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/302-luisa.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/302-luisa.conllu' mode='r' encoding='utf-8'> # sent_id = 302-luisa
# 1	Emilionë	Emilionë	NOUN	_	_	4	nsubj	_	Emilio
# 2	=n	n	PART	_	_	1	case	_	=ergative
# 3	kënë	kënë	NOUN	_	_	4	obj	_	wall:abs
# 4	xaika-këx	xaika	VERB	_	_	8	advcl	_	shake:tran-p>s:pe:tran
# 5	ka	_	PART	_	_	8	aux:sgen	_	_
# 6	=a	ka	PART	_	_	8	nsubj:bound	_	nar:3
# 7	xubu	xubu	NOUN	_	_	8	nsubj:free	_	house:abs
# 8	nipakët-a-x-a	nipakët	VERB	_	_	0	root	_	fall.down-ipfv-3-non.prox
# 9	.	_	PUNCT	_	_	8	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/310-luisa.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/310-luisa.conllu' mode='r' encoding='utf-8'> # sent_id = 310-luisa
# 1	‘Ë	‘ë	PRON	_	_	3	nmod	_	1sg
# 2	=n	n	PART	_	_	1	case	_	=genitive
# 3	xubu	xubu	NOUN	_	_	8	obl	_	house
# 4	=nu	nu	PART	_	_	3	case	_	=locative
# 5	ka	ka	PART	_	_	8	aux:sgen	_	narrative
# 6	=na	na	PART	_	_	8	nsubj:bound	_	=1sg
# 7	‘aisama	‘aisama	ADJ	_	_	8	amod	_	bad
# 8	‘ain	‘i	VERB	_	_	0	root	_	be:1/2
# 9	.	_	PUNCT	_	_	8	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/315-claudia.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/315-claudia.conllu' mode='r' encoding='utf-8'> # sent_id = 315-claudia
# 1	Xanu	Xanu	_	NOUN	_	6	nsubj:free	_	_
# 2	 =n	 =n	_	PART	_	1	case	_	_
# 3	ka	ka	_	AUX	_	6	aux:sgen	_	_
# 4	=is	=is	_	AUX	_	6	aux:evid	_	_
# 5	=a	=a	_	DET	_	6	nsubj:bound	_	_
# 6	buankian	buankian	_	VERB	_	0	root	_	_
# 7	ain	ain	_	DET	_	8	nmod	_	_
# 8	bënë	bënë	_	NOUN	_	6	obj	_	_
# 9	“	“	_	PUNCT	_	6	punct	_	_
# 10	unirá	unirá	_	NOUN	_	11	nsubj:free	_	_
# 11	ka	ka	_	AUX	_	6	parataxis	_	_
# 12	”	”	_	PUNCT	_	6	punct	_	_
# 13	.	.	_	PUNCT	_	6	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/316-claudia.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/316-claudia.conllu' mode='r' encoding='utf-8'> # sent_id = 316-claudia
# 1	“	_	PUNCT	_	_	15	punct	_	_
# 2	Min	_	DET	_	_	3	nmod	_	_
# 3	bënë	_	NOUN	_	_	4	obj	_	_
# 4	‘atankëxun	_	ADV	_	_	10	advcl	_	_
# 5	ka	_	AUX	_	_	10	aux:sgen	_	_
# 6	‘ëribi	_	NOUN	_	_	10	obj	_	_
# 7	min	_	DET	_	_	8	nmod	_	_
# 8	maëxratsukun	_	NOUN	_	_	10	obl	_	_
# 9	‘ë	_	PRON	_	_	10	obj	_	_
# 10	‘a	_	VERB	_	_	15	parataxis	_	_
# 11	”	_	PUNCT	_	_	15	punct	_	_
# 12	ka	_	AUX	_	_	15	aux:sgen	_	_
# 13	=is	_	AUX	_	_	15	aux:ev	_	_
# 14	=a	_	DET	_	_	15	nsubj:bound	_	_
# 15	kakëshín	_	VERB	_	_	0	root	_	_
# 16	.	_	PUNCT	_	_	15	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/318-rosa.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/318-rosa.conllu' mode='r' encoding='utf-8'> # sent_id = 318-rosa
# 1	Anuxun	anu-xun	ADV	_	_	11	advmod	_	there-S/A>A:SE
# 2	nukën	nukën	PRON	_	_	3	nmod	_	1pl.gen
# 3	bake	bakë	NOUN	_	_	11	obj	_	son:abs
# 4	bëchikë	bëchikë	NOUN	_	_	3	compound	_	son:abs
# 5	nukën	nukën	PRON	_	_	6	nmod	_	1pl.gen
# 6	ini	ini	NOUN	_	_	11	obj	_	daughter:abs
# 7	bëchikë	bëchikë	NOUN	_	_	6	compound	_	daughter:abs
# 8	'óina	'ó-ina	NOUN	_	_	10	obj	_	tapir-GENE:ABS
# 9	chunena	chuna-ina	NOUN	_	_	10	obj	_	monkey.species-GENE:ABS
# 10	pitankëxun	pi-tankëxun	VERB	_	_	11	advcl	_	eat-S/A>A:PE
# 11	kaniotin	kaniot-i-n	VERB	_	_	0	root	_	raise-IPFV-1/2
# 12	.	_	PUNCT	_	_	11	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/319-claudia.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/319-claudia.conllu' mode='r' encoding='utf-8'> # sent_id = 319-claudia
# 1	Usa	_	ADV	_	_	6	advmod	_	_
# 2	=bi	_	PART	_	_	6	aux:sgen	_	_
# 3	ka	_	AUX	_	_	_	_	_	_
# 4	‘isenaka	_	NOUN	_	_	6	nsubj:bound	_	_
# 5	=n	_	PART	_	_	4	case	_	_
# 6	rataxtamainun	_	VERB	_	_	0	root	_	_
# 7	chëkiai	_	ADV	_	_	_	_	_	_
# 8	.	_	PUNCT	_	_	6	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/320-claudia.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/320-claudia.conllu' mode='r' encoding='utf-8'> # sent_id = 320-claudia
# 1	Usai	_	ADV	_	_	5	advmod	_	_
# 2	ka	_	AUX	_	_	5	aux:sgen	_	_
# 3	=a	_	PART	_	_	5	nsubj:bound	_	_
# 4	ëo	_	ADJ	_	_	_	_	_	_
# 5	kamëokëxa	_	VERB	_	_	0	root	_	_
# 6	nu	_	PRON	_	_	8	nmod	_	_
# 7	=n	_	PART	_	_	6	case	_	_
# 8	‘anibu	_	NOUN	_	_	5	obj	_	_
# 9	nukën	_	PRON	_	_	10	nmod	_	_
# 10	chaitibaë	_	NOUN	_	_	5	nmod	_	_
# 11	=n	_	PART	_	_	10	case	_	_
# 12	nukën	_	PRON	_	_	13	nmod	_	_
# 13	xutabaë	_	NOUN	_	_	5	nmod	_	_
# 14	=n	_	PART	_	_	13	case	_	_
# 15	.	_	PUNCT	_	_	5	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/330-claudia.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/330-claudia.conllu' mode='r' encoding='utf-8'> # sent_id = 330-claudia
# 1	‘Ë	_	NOUN	_	_	11	nsubj:free	_	_
# 2	=n	_	PART	_	_	1	case	_	_
# 3	ka	_	AUX	_	_	10	aux:sgen	_	_
# 4	=na	_	PART	_	_	10	nsubj:bound	_	_
# 5	ënë	_	PRON	_	_	8	det	_	_
# 6	an	_	PART	_	_	8	compound	_	_
# 7	taë	_	PART	_	_	8	compound	_	_
# 8	tëbiskati	_	NOUN	_	_	_	_	_	_
# 9	bu	_	VERB	_	_	0	root	_	_
# 10	=a	_	DET	_	_	_	_	_	_
# 11	=n	_	PART	_	_	_	_	_	_
# 12	.	_	PUNCT	_	_	9	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/331-claudia.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/331-claudia.conllu' mode='r' encoding='utf-8'> # sent_id = 331-claudia
# 1	An	_	PART	_	_	3	compound	_	_
# 2	taë	_	PART	_	_	3	compound	_	_
# 3	tëbiskati	_	NOUN	_	_	7	nsubj:free	_	_
# 4	ka	_	AUX	_	_	7	aux:sgen	_	_
# 5	=n	_	PART	_	_	7	nsubj	_	_
# 6	‘aisama	_	ADJ	_	_	7	amod	_	_
# 7	‘ikën	_	VERB	_	_	0	root	_	_
# 8	.	_	PUNCT	_	_	7	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/332-claudia.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/332-claudia.conllu' mode='r' encoding='utf-8'> # sent_id = 332-claudia
# 1	Tsatsa	_	NOUN	_	_	4	obj	_	_
# 2	ënë	_	PRON	_	_	1	det	_	_
# 3	ka	_	AUX	_	_	4	aux:sgen	_	_
# 4	bëruan	_	VERB	_	_	0	root	_	_
# 5	!	_	PUNCT	_	_	4	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/333-mariana.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/333-mariana.conllu' mode='r' encoding='utf-8'> # sent_id = 333-mariana
# 1	atian	_	ADV	_	_	11	discourse	_	then
# 2	casi	_	ADV	_	_	3	advmod	_	almost
# 3	kamabi	_	DET	_	_	4	nummod	_	every
# 4	nëtë	_	NOUN	_	_	11	advmod	_	day
# 5	=n	_	PART	_	_	4	case	_	=temp
# 6	ka	_	PART	_	_	11	aux:sgen	_	nar
# 7	=is	_	PART	_	_	11	aux:evi	_	=rep
# 8	=a	_	PART	_	_	11	nsubj:bound	_	=3
# 9	a	_	DET	_	_	10	det	_	that
# 10	uni	_	NOUN	_	_	11	nsubj	_	person:abs
# 11	kwan-akë-x-ín	_	VERB	_	_	0	root	_	go-rem.pst-3-prox
# 12	.	_	PUNCT	_	_	11	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/334-claudia.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/334-claudia.conllu' mode='r' encoding='utf-8'> # sent_id = 334-claudia
# 1	Upí	_	ADJ	_	_	2	amod	_	_
# 2	ñu	_	NOUN	_	_	5	obj	_	_
# 3	ka	_	AUX	_	_	5	aux:sgen	_	_
# 4	=na	_	PART	_	_	5	nsubj:bound	_	_
# 5	kwëënin	_	VERB	_	_	0	root	_	_
# 6	.	_	PUNCT	_	_	5	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/335-mariana.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/335-mariana.conllu' mode='r' encoding='utf-8'> # sent_id = 335-mariana
# 1	ka	_	PART	_	_	11	aux:sgen	11:aux:sgen	nar
# 2	=nanuna	_	PART	_	_	11	nsubj:bound	11:nsubj:bound	=1pl
# 3	toxama	_	NOUN	_	_	5	obj	5:obj	tree.sp.
# 4	upí	_	ADJ	_	_	3	amod	3:amod	beautiful:abs
# 5	bits-tankëxun	_	VERB	_	_	11	advcl	11:advcl	pick.up-s/a>a:pe
# 6	taish	_	NOUN	_	_	8	obj	8:obj	tree.sp.
# 7	a	_	DET	_	_	6	det	6:det	3sg:p
# 8	bits-tankëxun	_	VERB	_	_	11	advcl	11:advcl	buy-s/a>a:pe
# 9	ka	_	PART	_	_	11	aux:sgen	11:aux:sgen	nar
# 10	=nanuna	_	PART	_	_	11	nsubj:bound	11:nsubj:bound	=1pl
# 11	‘aru-i-n	_	VERB	_	_	0	root	0:root	cook-ipfv-½
# 12	.	_	PUNCT	_	_	11	punct	11:punct	_
# <_io.TextIOWrapper name='archivos-conllu/337-claudia.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/337-claudia.conllu' mode='r' encoding='utf-8'> # sent_id = 337-claudia
# 1	Ka	_	PRON	_	_	5	nsubj:free	_	_
# 2	=n	_	PART	_	_	1	nsubj	_	_
# 3	‘itsa	_	ADJ	_	_	4	nummod	_	_
# 4	ñu	_	NOUN	_	_	_	_	_	_
# 5	xarákë	_	VERB	_	_	4	appos	_	_
# 6	.	_	PUNCT	_	_	5	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/338-claudia.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/338-claudia.conllu' mode='r' encoding='utf-8'> # sent_id = 338-claudia
# 1	Ësaokin	_	ADV	_	_	5	advcl	_	_
# 2	mane	_	NOUN	_	_	5	nsubj	_	_
# 3	‘itsa	_	ADJ	_	_	2	nummod	_	_
# 4	toinkë	_	VERB	_	_	2	appos	_	_
# 5	‘ixunmabi	_	VERB	_	_	0	root	_	_
# 6	.	_	PUNCT	_	_	5	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/339-claudia.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/339-claudia.conllu' mode='r' encoding='utf-8'> # sent_id = 339-claudia
# 1	Pui	_	NOUN	_	_	3	obl	_	_
# 2	=n	_	PART	_	_	1	case	_	_
# 3	‘axankëbë	_	VERB	_	_	9	advcl	_	_
# 4	ka	_	AUX	_	_	9	aux:sgen	_	_
# 5	=is	_	AUX	_	_	9	aux:evid	_	_
# 6	=a	_	DET	_	_	9	nsubj:bound	_	_
# 7	a	_	DET	_	_	_	_	_	_
# 8	kaxu	_	ADV	_	_	7	case	_	_
# 9	kwankëxa	_	VERB	_	_	0	root	_	_
# 10	uni	_	NOUN	_	_	_	_	_	_
# 11	achushi	_	ADJ	_	_	10	nummod	_	_
# 12	.	_	PUNCT	_	_	_	_	_	_
#
# <_io.TextIOWrapper name='archivos-conllu/340-claudia.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/340-claudia.conllu' mode='r' encoding='utf-8'> # sent_id = 340-claudia
# 1	Achushi	_	ADJ	_	_	2	nmod	_	_
# 2	uni	_	NOUN	_	_	11	nsubj:free	_	_
# 3	=n	_	PART	_	_	2	case	_	_
# 4	ka	_	AUX	_	_	11	aux:sgen	_	_
# 5	=is	_	AUX	_	_	11	aux:evid	_	_
# 6	=a	_	DET	_	_	11	nsubj:bound	_	_
# 7	kamabi	_	ADJ	_	_	8	nummod	_	_
# 8	nëtë	_	NOUN	_	_	11	obl	_	_
# 9	=n	_	PART	_	_	8	case	_	_
# 10	tanu	_	NOUN	_	_	11	obj	_	_
# 11	buankëxa	_	VERB	_	_	_	_	_	_
# 12	.	_	PUNCT	_	_	11	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/341-rosa.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/341-rosa.conllu' mode='r' encoding='utf-8'> # sent_id = 341-rosa
# 1	Kana	kana	NOUN	_	_	2	nmod	_	macaw
# 2	rani	rani	NOUN	_	_	10	obj	_	feather:abs
# 3	xon	xon	NOUN	_	_	4	nmod	_	red.macaw
# 4	rani	rani	NOUN	_	_	10	obj	_	feather:abs
# 5	ka	ka	PART	_	_	10	aux:sgen	_	narrative
# 6	=nanuna	nanuna	PART	_	_	10	nsubj:bound	_	=1pl
# 7	ain	ain	PRON	_	_	8	nmod	_	his
# 8	tsipu	tsipun	NOUN	_	_	10	obl	_	end
# 9	=nu	nu	PART	_	_	8	case	_	locative
# 10	bëtanitin	bëtanit-i-n	VERB	_	_	0	root	_	tie-IPFV-1/2
# 11	.	_	PUNCT	_	_	10	punct	_	_
#
# <_io.TextIOWrapper name='archivos-conllu/343-sabina.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/343-sabina.conllu' mode='r' encoding='utf-8'> # sent_id = 343-sabina
# 1	nukën	_	DET	_	_	2	nmod	2:nmod	1PL.GEN
# 2	papa	_	NOUN	_	_	4	nmod	4:nmod	father
# 3	=n	_	PART	_	_	2	case	2:case	=GEN
# 4	bana	_	NOUN	_	_	7	nsubj	7:nsubj	tale:ABS
# 5	=ishi	_	PART	_	_	4	advmod	4:advmod	=only
# 6	a-i	_	VERB	_	_	7	advcl	7:advcl	do-S/A>S:SE
# 7	tsót-i-n	_	VERB	_	_	12	parataxis	12:parataxis	live-IPFV-1/2
# 8	a	_	PRON	_	_	12	obj	12:obj	that
# 9	=ishi	_	PART	_	_	8	advmod	8:advmod	=only
# 10	ka	_	PART	_	_	12	aux:sgen	12:aux:sgen	NAR
# 11	=na	_	PART	_	_	12	nsubj	12:nsubj	=1SG
# 12	ka-i-n	_	VERB	_	_	0	root	0:root	say-IPFV-1/2
# 13	.	_	PUNCT	_	_	12	punct	12:punct	_
# <_io.TextIOWrapper name='archivos-conllu/348 -sabina.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/348 -sabina.conllu' mode='r' encoding='utf-8'> # sent_id = 348-sabina
# 1	rët-tankëxun	_	VERB	_	_	8	advcl	_	kill-S/A:A:PE
# 2	ka	_	PART	_	_	8	aux:sgen	_	NAR
# 3	=is	_	PART	_	_	8	aux:ev	_	=REP
# 4	=a	_	PART	_	_	8	nsubj	_	=3
# 5	xanu	_	NOUN	_	_	8	nsubj:free	_	woman
# 6	=n	_	PART	_	_	5	case	_	=ERG
# 7	chaxu	_	NOUN	_	_	8	obj	_	deer:ABS
# 8	rakan-akë-x-in	_	VERB	_	_	0	root	_	lay.down-REM.PST-3-PROX
# 9	.	_	PUNCT	_	_	8	punct	_	_
#
# <_io.TextIOWrapper name='archivos-conllu/357-sabina.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/357-sabina.conllu' mode='r' encoding='utf-8'> # sent_id = 357-sabina
# 1	ka	_	NOUN	_	_	2	aux:sgen	_	NAR
# 2	xui	_	VERB	_	_	10	parataxis	_	grill:IMP
# 3	ka-xun	_	VERB	_	_	10	advcl	_	say-S/A>A:SE
# 4	ka	_	PART	_	_	10	aux:sgen	_	NAR
# 5	=is	_	PART	_	_	10	aux:ev	_	=REP
# 6	=a	_	PART	_	_	10	nsubj	_	=3
# 7	charu	_	NOUN	_	_	10	obj	_	crab:ABS
# 8	ain	_	PRON	_	_	9	nmod	_	3SG:GEN
# 9	xanu	_	NOUN	_	_	10	iobj	_	woman:ABS
# 10	inan-akë-x-a	_	VERB	_	_	0	root	_	give-REM.PST-3-NON.PROX
# 11	.	_	PUNCT	_	_	10	punct	_	_
#
# <_io.TextIOWrapper name='archivos-conllu/361-sabina.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/361-sabina.conllu' mode='r' encoding='utf-8'> # sent_id = 361-sabina
# 1	a-kin	_	VERB	_	_	5	advcl	_	do-S/A>A:SE
# 2	=ma	_	PART	_	_	1	advmod	_	=NEG
# 3	ka	_	PART	_	_	5	aux:sgen	_	NAR
# 4	=nanuna	_	PART	_	_	5	nsubj	_	=1PL
# 5	a-i-n	_	VERB	_	_	0	root	_	do-IPFV-1/1
# 6	atsa	_	NOUN	_	_	5	obl	_	manioc
# 7	=këñun	_	PART	_	_	6	case	_	=COMP:P
# 8	xëki	_	NOUN	_	_	5	obj	_	corn:ABS
# 9	.	_	PUNCT	_	_	5	punct	_	_
#
# <_io.TextIOWrapper name='archivos-conllu/363-rosa.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/363-rosa.conllu' mode='r' encoding='utf-8'> # sent_id = 363-rosa
# 1	Ain	ain	PRON	_	_	2	nmod	_	3sg:gen
# 2	monument	monumento	NOUN	_	_	8	nsubj:free	_	statue
# 3	=sapi	sapi	PART	_	_	8	aux:dub	_	dubitative
# 4	ka	ka	PART	_	_	8	aux:sgen	_	narrative
# 5	=a	a	PART	_	_	8	nsubj:bound	_	3
# 6	Pucallpa	Pucallpa	NOUN	_	_	8	obl	_	Pucallpa
# 7	=nu	nu	PART	_	_	6	case	_	locative
# 8	'ikën	'ikën	VERB	_	_	0	root	_	be:3
# 9	.	_	PUNCT	_	_	8	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/366-sabina.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/366-sabina.conllu' mode='r' encoding='utf-8'> # sent_id = 366-sabina
# 1	cha	_	ADJ	_	_	2	amod	_	big
# 2	bai	_	NOUN	_	_	5	obj	_	path:ABS
# 3	ka	_	PART	_	_	5	aux:sgen	_	NAR
# 4	=a	_	PART	_	_	5	nsubj	_	=3
# 5	a-akë-x-a	_	VERB	_	_	0	root	_	do-REM.PST-3
# 6	desde	_	ADP	_	_	7	case	_	from
# 7	Tingo	_	PROPN	_	_	8	compound	_	Tingo
# 8	María	_	PROPN	_	_	5	obl	_	María
# 9	anu-xun	_	ADV	_	_	5	advmod	_	there-PA.A
# 10	hasta	_	ADP	_	_	11	case	_	until
# 11	Pucallpa	_	PROPN	_	_	5	obl	_	Pucallpa
# 12	=nu	_	PART	_	_	11	case	_	=LOC
# 13	.	_	PUNCT	_	_	5	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/369-sabina.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/369-sabina.conllu' mode='r' encoding='utf-8'> # sent_id = 369-sabina
# 1	hotel	_	NOUN	_	_	8	obl	_	hotel
# 2	=miki	_	PART	_	_	1	case	_	=IMPR.DIR
# 3	ka	_	PART	_	_	8	aux:sgen	_	NAR
# 4	=a	_	PART	_	_	8	nsubj	_	:3
# 5	e	_	PRON	_	_	7	nmod	_	1SG
# 6	=n	_	PART	_	_	5	case	_	=GEN
# 7	xukën	_	NOUN	_	_	8	nsubj:free	_	brother:ABS
# 8	u-i-a	_	VERB	_	_	0	root	_	come-IPFV-NON.PROX
# 9	.	_	PUNCT	_	_	8	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/370-luisa.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/370-luisa.conllu' mode='r' encoding='utf-8'> # sent_id = 370-luisa
# 1	Hotel	hotel	NOUN	_	_	8	obl	_	hotel
# 2	=uki	u(ki)	PART	_	_	1	case	_	=indirect direction
# 3	ka	_	PART	_	_	8	aux:sgen	_	_
# 4	=a	ka	PART	_	_	8	nsubj:bound	_	nar:3
# 5	‘ë	‘ë	PRON	_	_	7	nmod	_	1sg
# 6	=n	n	PART	_	_	5	case	_	=genitive
# 7	xukën	xukën	NOUN	_	_	8	nsubj:free	_	brother:abs
# 8	u-i-a	u	VERB	_	_	0	root	_	come-ipvf-non.prox
# 9	.	_	PUNCT	_	_	8	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/379 -sabina.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/379 -sabina.conllu' mode='r' encoding='utf-8'> # sent_id = 379-sabina
# 1	xubu	_	NOUN	_	_	5	obj	_	houses
# 2	=kama	_	PART	_	_	1	nmod	_	=PL:ABS
# 3	ka	_	PART	_	_	5	aux:sgen	_	NAR
# 4	=a	_	PART	_	_	5	nsubj	_	:3
# 5	is-akë-x-a	_	VERB	_	_	0	root	_	see-REM.PST-3-NON.PROX
# 6	.	_	PUNCT	_	_	5	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/388-sabina.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/388-sabina.conllu' mode='r' encoding='utf-8'> # sent_id = 388-sabina
# 1	nukën	_	PRON	_	_	2	nmod	_	our
# 2	papaokë	_	NOUN	_	_	10	nsubj:free	_	ancestor
# 3	=kama	_	PART	_	_	2	nummod	_	=PL
# 4	ka	_	PART	_	_	10	aux:sgen	_	NAR
# 5	=a	_	PART	_	_	10	nsubj	_	:3
# 6	uni	_	NOUN	_	_	7	amod	_	man
# 7	chaxkë	_	ADJ	_	_	10	nmod	_	big
# 8	siná	_	ADJ	_	_	9	amod	_	brave
# 9	uni	_	NOUN	_	_	10	nmod	_	man
# 10	i-akë-x-a	_	VERB	_	_	0	root	_	be-REM.PST-3-NON.PROX
# 11	.	_	PUNCT	_	_	10	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/389-sabina.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/389-sabina.conllu' mode='r' encoding='utf-8'> # sent_id = 389-sabina
# 1	anu	_	ADV	_	_	4	advmod	_	heroes
# 2	ka	_	PART	_	_	4	aux	_	NAR
# 3	=a	_	PART	_	_	4	nsubj	_	:3
# 4	i-akë-x-a	_	VERB	_	_	0	root	_	be-REM.PST-3-NON.PROX
# 5	a	_	SCONJ	_	_	6	det	_	that
# 6	uni	_	NOUN	_	_	4	nsubj:free	_	person
# 7	=kama	_	PART	_	_	6	nmod	_	=PL
# 8	ë	_	PRON	_	_	10	nmod	_	1SG
# 9	=n	_	PART	_	_	8	case	_	=GEN
# 10	papaokë	_	NOUN	_	_	6	appos	_	ancestor
# 11	.	_	PUNCT	_	_	4	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/390-sabina.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/390-sabina.conllu' mode='r' encoding='utf-8'> # sent_id = 390-sabina
# 1	después	_	ADV	_	_	5	advmod	_	after
# 2	ka	_	PART	_	_	5	aux:sgen	_	NAR
# 3	=nanuna	_	PART	_	_	5	nsubj	_	=PL
# 4	bëtsi	_	NOUN	_	_	5	obj	_	other:ABS
# 5	a-ti	_	VERB	_	_	0	root	_	do-NOMLZ
# 6	ain	_	AUX	_	_	5	aux	_	be:1/2
# 7	bëtsi	_	DET	_	_	8	amod	_	other
# 8	historia	_	NOUN	_	_	5	obj	_	story:ABS
# 9	bëtsi	_	DET	_	_	10	amod	_	other
# 10	bana	_	NOUN	_	_	8	appos	_	tale:ABS
# 11	.	_	PUNCT	_	_	5	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/391-sabina.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/391-sabina.conllu' mode='r' encoding='utf-8'> # sent_id = 391-sabina
# 1	a-tankëxun	_	VERB	_	_	8	advcl	8:advcl	do-S/A>A:PE
# 2	ka	_	PART	_	_	8	aux:sgen	8:aux:sgen	NAR
# 3	=na	_	PART	_	_	8	nsubj	8:nsubj	=1SG
# 4	itsa	_	DET	_	_	5	nummod	5:nummod	a.lot
# 5	katsin	_	NOUN	_	_	8	obj	8:obj	banana.sp:ABS
# 6	itsa	_	DET	_	_	7	nummod	7:nummod	a.lot
# 7	xinkun	_	NOUN	_	_	5	appos	5:appos	banana.sp:ABS
# 8	a-ti	_	VERB	_	_	0	root	0:root	do-NOMLZ
# 9	ain	_	AUX	_	_	8	aux	8:aux	be:1/2
# 10	.	_	PUNCT	_	_	8	punct	8:punct	_
# <_io.TextIOWrapper name='archivos-conllu/393-sabina.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/393-sabina.conllu' mode='r' encoding='utf-8'> # sent_id = 393-sabina
# 1	ainbi	_	CCONJ	_	_	11	advcl	_	but:DS/A/P
# 2	ka	_	PART	_	_	11	aux:sgen	_	NAR
# 3	=a	_	PART	_	_	11	nsubj	_	:3
# 4	bëná	_	ADJ	_	_	5	amod	_	young
# 5	uni	_	NOUN	_	_	11	nsubj:free	_	person
# 6	=n	_	PART	_	_	5	case	_	=ERG
# 7	pia	_	NOUN	_	_	8	nmod	_	arrow:ABS
# 8	toin-ti	_	NOUN	_	_	11	obj	_	grab-NOMLZ
# 9	kanti	_	NOUN	_	_	10	nmod	_	bow
# 10	toin-ti	_	NOUN	_	_	8	appos	_	hold-NOMLZ
# 11	rabin-i-a	_	VERB	_	_	0	root	_	feel.embarrased-IPFV-NON.PROX
# 12	.	_	PUNCT	_	_	11	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/395-sabina.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/395-sabina.conllu' mode='r' encoding='utf-8'> # sent_id = 395-sabina
# 1	upit-o-kin	_	ADJ	_	_	3	advcl	_	good-FACT-S/A>A:SE
# 2	nui-xun	_	_	NOUN	_	3	advcl	_	love-S/A>A:SE
# 3	nits-kin-kin	_	VERB	_	_	0	root	_	walk-APPL-HAB:REM.PST:3
# 4	.	_	PUNCT	_	_	3	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/397-sabina.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/397-sabina.conllu' mode='r' encoding='utf-8'> # sent_id = 397-sabina
# 1	a	_	PRON	_	_	8	obl	_	that
# 2	=kupí	_	PART	_	_	1	case	_	-REAS
# 3	ka	_	PART	_	_	8	aux:sgen	_	NAR
# 4	=a	_	PART	_	_	8	nsubj	_	:3
# 5	nu	_	PRON	_	_	7	nmod	_	we
# 6	=n	_	PART	_	_	5	case	_	=GEN
# 7	me	_	NOUN	_	_	8	nsubj:free	_	land:ABS
# 8	chukúma	_	ADJ	_	_	9	amod	_	small
# 9	ikën	_	VERB	_	_	0	root	_	be:3
# 10	.	_	PUNCT	_	_	9	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/401-sabina.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/401-sabina.conllu' mode='r' encoding='utf-8'> # sent_id = 401-sabina
# 1	Emilio	_	NOUN	_	_	9	nsubj	_	Emilio:abs
# 2	ka	_	PART	_	_	9	aux:spgen	_	nar:3
# 3	=a	_	PART	_	_	9	nsubj	_	_
# 4	mas	_	ADV	_	_	6	goeswith	_	more
# 5	xuá	_	ADJ	_	_	9	cop	_	fat
# 6	ki	_	CCONJ	_	_	7	case	_	than
# 7	Roberto	_	NOUN	_	_	9	obl	_	Roberto
# 8	=ma	_	PART	_	_	9	advmod	_	=neg
# 9	‘ikën	_	VERB	_	_	0	root	_	be:3
# 10	.	_	PUNCT	_	_	9	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/405-claudia.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/405-claudia.conllu' mode='r' encoding='utf-8'> # sent_id = 405-claudia
# 1	Bëxuñurá	_	NOUN	_	_	2	nsubj	_	_
# 2	‘ikë	_	VERB	_	_	14	advcl	_	_
# 3	=bi	_	ADV	_	_	2	advmod	_	_
# 4	ka	_	AUX	_	_	14	aux:sgen	_	_
# 5	=is	_	AUX	_	_	14	aux:evid	_	_
# 6	=a	_	DET	_	_	14	nsubj:bound	_	_
# 7	xanu	_	NOUN	_	_	14	nsubj:free	_	_
# 8	=n	_	PART	_	_	7	case	_	_
# 9	ain	_	AUX	_	_	10	nmod	_	_
# 10	bënë	_	NOUN	_	_	13	obj	_	_
# 11	‘akë	_	VERB	_	_	13	obl	_	_
# 12	=sa	_	PART	_	_	11	case	_	_
# 13	okin	_	ADV	_	_	14	advcl	_	_
# 14	maso	_	VERB	_	_	0	root	_	_
# 15	=ma	_	ADV	_	_	14	advmod	_	_
# 16	‘ikën	_	VERB	_	_	14	aux	_	_
# 17	.	_	PUNCT	_	_	14	punct	_	_
#
# <_io.TextIOWrapper name='archivos-conllu/407-rosa.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/407-rosa.conllu' mode='r' encoding='utf-8'> # sent_id = 407-rosa
# 1	Chuna	chuna	NOUN	_	_	8	nsubj:free	_	spider.monkey
# 2	unitín	uni-tín	NOUN	_	_	1	nmod	_	man-same.size
# 3	a	a	PRON	_	_	1	appos	_	3sg
# 4	=n	n	PART	_	_	3	case	_	=A
# 5	ka	ka	PART	_	_	8	aux:sgen	_	narrative
# 6	=a	a	PART	_	_	8	nsubj:bound	_	3
# 7	'ë	'ë	PRON	_	_	8	obj	_	1sg:P
# 8	ratuaxa	ratu-a-x-a	VERB	_	_	0	root	_	scare-PFV-3-NON.PROX
# 9	.	_	PUNCT	_	_	8	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/408-sabina.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/408-sabina.conllu' mode='r' encoding='utf-8'> # sent_id = 408-sabina
# 1	uni-tín	_	ADJ	_	_	2	nmod	2:nmod	man-same.size
# 2	chuna	_	NOUN	_	_	8	nsubj:free	8:nsubj:free	spider.monkey
# 3	a	_	PRON	_	_	2	det	2:det	3SG
# 4	=n	_	PART	_	_	2	case	2:case	=A
# 5	ka	_	PART	_	_	8	aux:sgen	8:aux:sgen	NAR
# 6	=a	_	PART	_	_	8	nsubj	8:nsubj	:3
# 7	ë	_	PRON	_	_	8	obj	8:obj	1SG:P
# 8	ratu-a-x-a	_	VERB	_	_	0	root	0:root	scare-PFV-3-NON.PROX
# 9	.	_	PUNCT	_	_	8	punct	8:punct	_
# <_io.TextIOWrapper name='archivos-conllu/460-mariana.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/460-mariana.conllu' mode='r' encoding='utf-8'> # sent_id = 460-mariana
# 1	paën-xun	_	VERB	_	_	7	advcl	_	get.drunk-s/a>a
# 2	ka	_	PART	_	_	7	aux:sgen	_	nar
# 3	=na	_	PART	_	_	7	nsubj:bound	_	1sg
# 4	‘ë	_	PRON	_	_	7	nsubj:free	_	1sg
# 5	=n	_	PART	_	_	4	case	_	a
# 6	‘atsa	_	NOUN	_	_	7	nsubj:free	_	manioc:abs
# 7	kwëën-i-n	_	VERB	_	_	0	root	_	want-ipfv-½
# 8	.	_	PUNCT	_	_	7	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/471-claudia.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/471-claudia.conllu' mode='r' encoding='utf-8'> # sent_id = 471-claudia
# 1	“	_	PUNCT	_	_	17	punct	_	_
# 2	Anun	_	PRON	_	_	3	nmod	_	_
# 3	ma	_	NOUN	_	_	12	obj	_	_
# 4	shi	_	VERB	_	_	17	parataxis	_	_
# 5	ki	_	PRON	_	_	3	nmod	_	_
# 6	nun	_	ADV	_	_	4	advcl	_	_
# 7	ka	_	AUX	_	_	12	aux:sgen	_	_
# 8	‘ë	_	PRON	_	_	9	nmod	_	_
# 9	nanë	_	NOUN	_	_	12	obj	_	_
# 10	itsirá	_	NOUN	_	_	12	obj	_	_
# 11	‘ë	_	PRON	_	_	10	nmod	_	_
# 12	nipáxun	_	VERB	_	_	17	parataxis	_	_
# 13	”	_	PUNCT	_	_	17	punct	_	_
# 14	ka	_	AUX	_	_	17	aux:sgen	_	_
# 15	=is	_	AUX	_	_	17	aux:ev	_	_
# 16	=a	_	DET	_	_	17	nsubj:bound	_	_
# 17	kakëshín	_	VERB	_	_	0	root	_	_
# 18	.	_	PUNCT	_	_	17	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/476-luisa.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/476-luisa.conllu' mode='r' encoding='utf-8'> # sent_id = 476-luisa
# 1	Bëru-ax	bëru	VERB	_	_	11	advcl	_	stay-s/a>s
# 2	ka	_	PART	_	_	11	aux:sgen	_	stay-ds:pe
# 3	=is	_	PART	_	_	11	aux:evi	_	_
# 4	=a	kaisa	PART	_	_	11	nsubj:bound	_	nar=rep=3
# 5	bëru-an	bëru	VERB	_	_	11	advcl	_	_
# 6	ka	_	PART	_	_	11	aux:sgen	_	_
# 7	=is	_	PART	_	_	11	aux:evi	_	_
# 8	=a	kaisa	PART	_	_	11	nsubj:bound	_	nar=rep=3
# 9	ukairi	_	NOUN	_	_	11	obj	_	ladder
# 10	a	_	DET	_	_	9	appos	_	that:p
# 11	tënka-pat-akë-x-ín	_	VERB	_	_	0	root	_	cut.making.noise-down:tran-rem.pst-3-prox
# 12	u-but-kin	u	VERB	_	_	11	advcl	_	come-down:intr-s/a>a:se
# 13	is	_	PART	_	_	11	aux:evi	_	_
# 14	=a	isa	PART	_	_	11	nsubj:bound	_	rep=3
# 15	rët-uku-but-an	rët	VERB	_	_	11	advcl	_	cut-iter:one.direction-down:intr-ds/a/p:pe
# 16	.	_	PUNCT	_	_	11	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/490-rosa.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/490-rosa.conllu' mode='r' encoding='utf-8'> # sent_id = 490-rosa
# 1	'Aishbi	'aishbi	VERB	_	_	5	advmod	_	but:S/A>A
# 2	ka	ka	PART	_	_	5	aux:sgen	_	narrative
# 3	=is	is	PART	_	_	5	aux:evid	_	reportative
# 4	=a	a	PART	_	_	5	nsubj:bound	_	3
# 5	'iakëxa	'i-akë-x-a	VERB	_	_	0	root	_	be-REM.PST-3-NON.PROX
# 6	a	a	DET	_	_	7	det	_	that
# 7	uni	uni	NOUN	_	_	5	nsubj:free	_	person
# 8	chumíbukë	chumin-but-kë	ADJ	_	_	7	amod	_	thin-advance.process-NOMLZ:ABS
# 9	bamati	bama	VERB	_	_	5	advmod	_	die
# 10	ura	ura	ADV	_	_	9	advmod	_	far
# 11	=ma	ma	ADV	_	_	10	advmod	_	negative
# 12	.	_	PUNCT	_	_	5	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/508-rosa.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/508-rosa.conllu' mode='r' encoding='utf-8'> # sent_id = 508-rosa
# 1	kwainkin	kwain-kin	VERB	_	_	13	advcl	_	move.over-S/A>A:SE=only
# 2	=shi	ishi	PART	_	_	1	advmod	_	=only
# 3	ka	ka	PART	_	_	13	aux:sgen	_	narrative
# 4	=is	is	PART	_	_	13	aux:evid	_	reportative
# 5	=a	a	PART	_	_	13	nsubj:bound	_	3
# 6	ain	ain	PRON	_	_	7	nmod	_	3sg:gen
# 7	tita	tita	NOUN	_	_	13	obj	_	mother
# 8	ñuxanrá	ñuxan-rá	NOUN	_	_	7	amod	_	old.woman-DIM:ABS
# 9	ain	ain	PRON	_	_	10	nmod	_	3sg:gen
# 10	maë	maë	NOUN	_	_	11	obj	_	house:abs
# 11	matsunkubuinia	matsun-uku-buin-ia=bi	VERB	_	_	13	advcl	_	sweep-ITER-passing:TRA-S/A>P:SE
# 12	=bi	bi	PART	_	_	11	advmod	_	=same
# 13	rëakëxa	rët-akë-x-a	VERB	_	_	0	root	_	beat-REM.PST-3-NON.PROX
# 14	.	_	PUNCT	_	_	13	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/509-claudia.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/509-claudia.conllu' mode='r' encoding='utf-8'> # sent_id = 509-claudia
# 1	Chaxu	_	NOUN	_	_	_	_	_	_
# 2	an	_	DET	_	_	1	det	_	_
# 3	=n	_	PART	_	_	1	case	_	_
# 4	churukukwainkin	_	NOUN	_	_	12	nsubj	_	_
# 5	ka	_	AUX	_	_	12	aux:sgen	_	_
# 6	=is	_	AUX	_	_	12	aux:evid	_	_
# 7	=a	_	DET	_	_	12	nsubj:bound	_	_
# 8	xanu	_	NOUN	_	_	12	obj	_	_
# 9	xënirá	_	ADJ	_	_	8	amod	_	_
# 10	chaxu	_	NOUN	_	_	12	nsubj:free	_	_
# 11	=n	_	PART	_	_	10	case	_	_
# 12	makwëxakëshín	_	VERB	_	_	0	root	_	_
# 13	.	_	PUNCT	_	_	12	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/515-rosa.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/515-rosa.conllu' mode='r' encoding='utf-8'> # sent_id = 515-rosa
# 1	Ë	Ë	ADV	_	_	8	obl	_	here
# 2	=nu	nu	PART	_	_	1	case	_	locative
# 3	achushi	achushi	NUM	_	_	7	nummod	_	one
# 4	bëráma	bëráma	ADJ	_	_	7	amod	_	old
# 5	nu	nu	PRON	_	_	7	amod	_	1pl
# 6	=n	n	PART	_	_	5	case	_	genitive
# 7	‘anibu	‘anibu	NOUN	_	_	8	nsubj:free	_	ancestor:abs
# 8	‘ia	'i-a	NOUN	_	_	11	ccomp	_	be-NOMLZ
# 9	ka	ka	PART	_	_	11	aux:sgen	_	narrative
# 10	=na	na	PART	_	_	11	nsubj:bound	_	=1sg
# 11	ñuikasin	ñui-kas-i-n	VERB	_	_	0	root	_	tell-DES-IPFV-1/2
# 12	.	_	PUNCT	_	_	11	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/517-claudia.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/517-claudia.conllu' mode='r' encoding='utf-8'> # sent_id = 517-claudia
# 1	‘Ë	_	PRON	_	_	8	nmod	_	_
# 2	=n	_	PART	_	_	1	case	_	_
# 3	ka	_	AUX	_	_	8	aux:sgen	_	_
# 4	=na	_	PART	_	_	8	nsubj:bound	_	_
# 5	a	_	DET	_	_	7	nsubj:bound	_	_
# 6	bana	_	NOUN	_	_	7	nsubj	_	_
# 7	ñuiti	_	VERB	_	_	0	root	_	_
# 8	kwëëni	_	ADV	_	_	7	advcl	_	_
# 9	=ma	_	PART	_	_	8	advmod	_	_
# 10	.	_	PUNCT	_	_	7	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/518-claudia.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/518-claudia.conllu' mode='r' encoding='utf-8'> # sent_id = 518-claudia
# 1	Ë	_	PRON	_	_	7	nmod	_	_
# 2	=n	_	PART	_	_	1	case	_	_
# 3	ka	_	AUX	_	_	7	aux:sgen	_	_
# 4	=na	_	PART	_	_	7	nsubj:bound	_	_
# 5	a	_	DET	_	_	7	nsubj:bound	_	_
# 6	bana	_	NOUN	_	_	7	nsubj	_	_
# 7	ñuiti	_	VERB	_	_	0	root	_	_
# 8	‘ain	_	AUX	_	_	7	aux:sgen	_	_
# 9	.	_	PUNCT	_	_	7	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/7-mariana.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/7-mariana.conllu' mode='r' encoding='utf-8'> # sent_id = 7-mariana
# 1	atian	_	ADV	_	_	11	discourse	_	then
# 2	casi	_	ADV	_	_	3	advmod	_	almost
# 3	kamabi	_	DET	_	_	4	nummod	_	every
# 4	nëtë	_	NOUN	_	_	11	advmod	_	day
# 5	=n	_	PART	_	_	4	case	_	=temp
# 6	ka	_	PART	_	_	11	aux:sgen	_	nar
# 7	=is	_	PART	_	_	11	aux:evi	_	=rep
# 8	=a	_	PART	_	_	11	nsubj:bound	_	=3
# 9	a	_	DET	_	_	10	det	_	that
# 10	uni	_	NOUN	_	_	11	nsubj	_	person:abs
# 11	kwan-akë-x-ín	_	VERB	_	_	0	root	_	go-rem.pst-3-prox
# 12	.	_	PUNCT	_	_	11	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/799-claudia.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/799-claudia.conllu' mode='r' encoding='utf-8'> # sent_id = 799-claudia
# 1	‘Itankëxun	_	ADV	_	_	5	advcl	_	_
# 2	ka	_	AUX	_	_	5	aux:sgen	_	_
# 3	=is	_	AUX	_	_	5	aux:evid	_	_
# 4	=a	_	DET	_	_	5	nsubj:bound	_	_
# 5	kakëxa	_	VERB	_	_	0	root	_	_
# 6	ain	_	AUX	_	_	7	nmod	_	_
# 7	tita	_	NOUN	_	_	5	obj	_	_
# 8	ñuxanrá	_	ADJ	_	_	7	amod	_	_
# 9	“	_	PUNCT	_	_	5	punct	_	_
# 10	tita	_	NOUN	_	_	23	discourse	_	_
# 11	=n	_	PART	_	_	10	case	_	_
# 12	,	_	PUNCT	_	_	_	_	_	_
# 13	anu	_	DET	_	_	16	obj	_	_
# 14	uni	_	NOUN	_	_	16	advmod	_	_
# 15	xëni	_	ADJ	_	_	14	amod	_	_
# 16	‘ati	_	VERB	_	_	21	ccomp	_	_
# 17	ë	_	PRON	_	_	20	nmod	_	_
# 18	=n	_	PART	_	_	17	case	_	_
# 19	kupë	_	NOUN	_	_	_	_	_	_
# 20	atsa	_	PART	_	_	19	compound	_	_
# 21	bitstanmainun	_	VERB	_	_	23	advcl	_	_
# 22	ka	_	AUX	_	_	23	aux:sgen	_	_
# 23	bëruan	_	VERB	_	_	5	parataxis	_	_
# 24	,	_	PUNCT	_	_	5	punct	_	_
# 25	tita	_	NOUN	_	_	23	discourse	_	_
# 26	=n	_	PART	_	_	25	case	_	_
# 27	”	_	PUNCT	_	_	5	punct	_	_
# 28	.	_	PUNCT	_	_	5	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/976-mariana.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/976-mariana.conllu' mode='r' encoding='utf-8'> # sent_id = 976-mariana
# 1	Nüken	_	_	PRON	_	2	nmod	_	1PL.GEN
# 2	chaiti	_	_	NOUN	_	6	nsubj	_	ancestor:ABS
# 3	ka	_	_	PART	_	6	aux:sgen	_	=NAR
# 4	=is	_	_	PART	_	6	aux:ev	_	=REP
# 5	=a	_	_	PART	_	6	nsubj	_	=3
# 6	tsót-akë-x-a	_	VERB	_	_	0	root	_	live-REM.PST-3-NON.PROX
# 7	rima	_	_	PROPN	_	6	obl	_	Lima
# 8	kaxu	_	_	ADV	_	7	case	_	behind
# 9	norte	_	_	NOUN	_	6	obl	_	North
# 10	=nu	_	_	PART	_	9	case	_	=LOC
# 11	.	_	_	PUNCT	_	6	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/977a-sabina.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/977a-sabina.conllu' mode='r' encoding='utf-8'> # sent_id = 977a-sabina
# 1	xëa-kë	_	NOUN	_	_	6	nsubj:free	6:nsubj:free	drink-NOMLZ
# 2	a	_	DET	_	_	1	det	1:det	that
# 3	=x	_	PART	_	_	1	case	1:case	=S
# 4	ka	_	PART	_	_	6	aux:sgen	6:aux:sgen	NAR
# 5	=a	_	PART	_	_	6	nsubj	6:nsubj	:3
# 6	ikën	_	VERB	_	_	0	root	0:root	be:3
# 7	shipibo	_	PROPN	_	_	8	nmod	8:nmod	Shipibo
# 8	bana	_	NOUN	_	_	6	nmod	6:nmod	word:ABS
# 9	.	_	PUNCT	_	_	6	punct	6:punct	_
# <_io.TextIOWrapper name='archivos-conllu/977b-sabina.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/977b-sabina.conllu' mode='r' encoding='utf-8'> # sent_id = 977b-sabina
# 1	nu	_	PRON	_	_	3	nmod	3:nmod	1PL
# 2	=n	_	PART	_	_	1	case	1:case	=GEN
# 3	bana	_	NOUN	_	_	6	nmod	6:nmod	word:ABS
# 4	ka	_	PART	_	_	6	aux:sgen	6:aux:sgen	NAR
# 5	=a	_	PART	_	_	6	nsubj	6:nsubj	:3
# 6	iken	_	VERB	_	_	0	root	0:root	be:3
# 7	kwáxka-kë	_	NOUN	_	_	6	nsubj:free	6:nsubj:free	drink-NOMLZ
# 8	.	_	PUNCT	_	_	6	punct	6:punct	_
# <_io.TextIOWrapper name='archivos-conllu/ximena-615.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/ximena-615.conllu' mode='r' encoding='utf-8'> # sent_id = 615-ximena
# 1	ui	_	PRON	_	_	7	nsubj:free	_	_
# 2	n	_	PART	_	_	1	case	_	_
# 3	ka	_	PART	_	_	7	aux:sgen	_	_
# 4	ra	_	AUX	_	_	7	aux:int	_	_
# 5	a	_	DET	_	_	7	nsubj	_	_
# 6	carretera	_	NOUN	_	_	7	obj	_	_
# 7	aakëxa	_	VERB	_	_	0	root	_	_
# <_io.TextIOWrapper name='archivos-conllu/ximena-672.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/ximena-672.conllu' mode='r' encoding='utf-8'> # sent_id = 672-ximena
# 1	‘ë	_	PRON	_	_	7	nsubj:free	_	_
# 2	x 	_	PART	_	_	1	case	_	_
# 3	ka	_	PART	_	_	7	aux:sgen	_	_
# 4	na 	_	DET	_	_	7	nsubj	_	_
# 5	munui	_	NOUN	_	_	7	advcl	_	_
# 6	ishi 	_	ADV	_	_	5	advmod	_	_
# 7	kwanin	_	VERB	_	_	0	root	_	_
# <_io.TextIOWrapper name='archivos-conllu/ximena-708.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/ximena-708.conllu' mode='r' encoding='utf-8'> # sent_id = 708-ximena
# 1	‘inu	_	NOUN	_	_	6	nsubj:free	_	_
# 2	=n	_	PART	_	_	1	case	_	_
# 3	=bu 	_	PART	_	_	1	nummod	_	_
# 4	ka	_	PART	_	_	6	aux:sgen	_	_
# 5	:a	_	AUX	_	_	6	nsubj	_	_
# 6	'aaxa	_	VERB	_	_	0	root	_	_
# 7	.	_	PUNCT	_	_	6	punct	_	_
#
# <_io.TextIOWrapper name='archivos-conllu/ximena-719.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/ximena-719.conllu' mode='r' encoding='utf-8'> # sent_id = 719-ximena
# 1	Juan 	_	NOUN 	_	_	6	nsubj:free	_	_
# 2	ka	_	PART	_	_	6	aux:sgen	_	_
# 3	a 	_	DET	_	_	6	nsubj	_	_
# 4	chuna	_	NOUN	_	_	6	nmod	_	_
# 5	sa 	_	PART	_	_	4	case	_	_
# 6	‘ikën	_	VERB	_	_	0	root	_	_
# 7	.	_	PUNCT	_	_	6	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/ximena-775.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/ximena-775.conllu' mode='r' encoding='utf-8'> # sent_id = 775-ximena
# 1	chupa 	_	NOUN	_	_	2	obj	_	_
# 2	maru-kin	_	VERB	_	_	8	advcl	_	_
# 3	bi 	_	ADV	_	_	2	advmod	_	_
# 4	ka	_	PART	_	_	8	aux:sgen	_	_
# 5	na 	_	DET	_	_	8	nsubj	_	_
# 6	‘ë	_	PRON	_	_	8	nsubj:free	_	_
# 7	n 	_	PART	_	_	6	case	_	_
# 8	iëtan-a-n	_	VERB	_	_	0	root	_	_
# 9	.	_	PUNCT	_	_	8	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/ximena-854.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/ximena-854.conllu' mode='r' encoding='utf-8'> # sent_id = 854-ximena
# 1	María	_	NOUN	_	_	3	nsubj:free	_	_
# 2	=n 	_	PART	_	_	1	case	_	_
# 3	‘aru-kë	_	VERB	_	_	7	ccomp	_	_
# 4	=sa 	_	PART	_	_	3	case	_	_
# 5	ka	_	AUX	_	_	7	aux:sgen	_	_
# 6	=na 	_	PART	_	_	7	nsubj	_	_
# 7	sinan-i-n	_	VERB	_	_	0	root	_	_
# <_io.TextIOWrapper name='archivos-conllu/ximena-881.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/ximena-881.conllu' mode='r' encoding='utf-8'> # sent_id = 881-ximena
# 1	a	_	PRON	_	_	7	nsubj:free	_	_
# 2	=kama	_	DET	_	_	1	nummod	_	_
# 3	=n 	_	PART	_	_	1	case	_	_
# 4	ka 	_	AUX	_	_	7	aux:sgen	_	_
# 5	=a	_	DET_	_	_	7	nsubj	_	_
# 6	‘atsa 	_	NOUN	_	_	7	obj	_	_
# 7	pi-kan-i-n	_	VERB	_	_	0	root	_	_
# 8	.	_	PUNCT	_	_	7	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/ximena-882.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/ximena-882.conllu' mode='r' encoding='utf-8'> # sent_id = 882-ximena
# 1	a	_	_	PRON	_	7	nsubj:free	_	_
# 2	=kama	_	_	DET	_	1	nummod	_	_
# 3	=n	_	_	PART	_	1	case	_	_
# 4	ka	_	_	PART	_	7	aux:sgen	_	_
# 5	:a	_	_	DET	_	7	nsubj	_	_
# 6	‘atsa	_	_	NOUN	_	7	obj	_	_
# 7	pi-kan-i-n	_	_	VERB	_	0	root	_	_
#
#
# <_io.TextIOWrapper name='archivos-conllu/ximena-884.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/ximena-884.conllu' mode='r' encoding='utf-8'> # sent_id = 884-ximena
# 1	Juan	_	_	NOUN	_	6	case	_	_
# 2	ka	_	_	PART	_	7	aux:sgen	_	_
# 3	:a	_	_	DET	_	7	nsubj	_	_
# 4	ni	_	_	NOUN	_	7	obl	_	_
# 5	=nu	_	_	PART	_	4	case	_	_
# 6	=ax	_	_	PART	_	7	nsubj	_	_
# 7	‘ux-a-x-a	_	_	VERB	_	0	root	_	_
# <_io.TextIOWrapper name='archivos-conllu/ximena-916.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/ximena-916.conllu' mode='r' encoding='utf-8'> # sent_id = 916-ximena
# 1	kashi	_	_	NOUN	_	8	nsubj	8:nsubj	_
# 2	a	_	_	DET	_	1	det	1:det	_
# 3	=x	_	_	PART	_	1	case	1:case	_
# 4	ka	_	_	PART	_	8	aux:sgen	8:aux:sgen	_
# 5	=a	_	_	DET	_	8	nsubj	8:nsubj	_
# 6	i	_	_	NOUN	_	8	obl	8:obl	_
# 7	=nu	_	_	PART	_	6	case	6:case	_
# 8	pani-a-x-a	_	_	VERB	_	0	root	0:root	_
# <_io.TextIOWrapper name='archivos-conllu/ximena-947.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/ximena-947.conllu' mode='r' encoding='utf-8'> # sent_id = 947-ximena
# 1	Emilio	_	_	NOUN	_	6	nsubj:free	_	_
# 2	=n	_	_	PART	_	1	case	_	_
# 3	ka	_	_	PART	_	6	aux:sgen	_	_
# 4	=a	_	_	DET	_	6	nsubj	_	_
# 5	Wilton	_	_	NOUN	_	6	obj	_	_
# 6	bana-anan-xun-a-x-a	_	_	VERB	_	0	root	_	_
# <_io.TextIOWrapper name='archivos-conllu/ximena-967.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/ximena-967.conllu' mode='r' encoding='utf-8'> # sent_id = 967-ximena
# 1	xanu	_	_	NOUN	_	5	nsubj:free	_	_
# 2	rabé̈	_	_	DET	_	1	nummod	_	_
# 3	ka	_	_	PART	_	5	aux:sgen	_	_
# 4	:a	_	_	DET	_	5	nsubj	_	_
# 5	‘ikut-kan-anan-i-a	_	_	VERB	_	0	root	_	_

# %%
len(kakataibo)
# Out:
# 107

# %%
## lista de objetos TokenList

kakataibo
# Out:
# [TokenList<patron, =bëtan, ka, =a, balata, a-akë-x-ín, .>,
#  TokenList<maru-kin, no-n, buan-akë-x-ín, .>,
#  TokenList<Juan, ka, =mënë, mi, =n, kuriki, mëkama-iéé, .>,
#  TokenList<Nukën, chaiti, ka, =is, =a, tsó-akë-x-a, norte, =nu, .>,
#  TokenList<Norte, =nu, tsó-xun, ka, =is, =a, nukën, chaiti-baë, =n, uni, =ñu, =ma, no, =ñu, =ma, 'a-akë-x-a, .>,
#  TokenList<Nukën, chaiti, =n, ka, =a, bana, ñui-xun-kian, .>,
#  TokenList<'Ë, ka, 'atsa, 'inan, .>,
#  TokenList<Nukën, chaiti, =n, ka, =is, =a, 'ó, nami, pi-akë-x-a, .>,
#  TokenList<Achushi, uni, chaxkë, =bëtan, ka, =na, 'ë, =n, xubu', a-ti, 'ain, .>,
#  TokenList<Uni, =n, ka, =a, baka, =nu, =xun, chaxu, 'a-a-x-a, .>,
#  TokenList<Xanu-xun, ka, =a, ‘atapa, ‘a-a-x-a, .>,
#  TokenList<Uni, achushi, =n, =pain, ka, =a, ënë, ‘ó, ‘a-a-x-a, .>,
#  TokenList<Munu, =ishi, ka, =mina, pi-ti, 'ain, .>,
#  TokenList<Roberto, =nën, ka, =a, ënë, ‘ó, name, pipania, .>,
#  TokenList<Achushi, =ishi, ñu, ka, =a, ‘ë, ‘inan, .>,
#  TokenList<Uni, chaxkë´, achushi, =bëtan, ka, =na, 'ë, =n, xubu, 'ati, 'ain, .>,
#  TokenList<Imëishi, ka, =na, Aguaytia, =nu, kwan-ti, ‘ain, .>,
#  TokenList<Aguaytia, =nu, ka, =na, imëshi, kwan-ti, ain, .>,
#  TokenList<uni, =n, ka, =a, baka, =nu, =xun, =bi, chaxu, 'aaxa, .>,
#  TokenList<Roberto, ka, =a, më-uxu, 'ikën, .>,
#  TokenList<Roberto, ka, =a, mëkën, =nu, më-uxu, 'ikën, .>,
#  TokenList<Ta-tani-katsi, ki-xun, rakan-bian-a-n, .>,
#  TokenList<Tënka-këbë, ka, =is, =a, uni, ëëëëëë, ki-i, bë-man-mët-akë-xín, .>,
#  TokenList<Parunuti, a, =x, ka, =a, pabëntamëti, 'ikën, .>,
#  TokenList<Parunuti, a, =x, ka, =a, pabí, =nu, bëntamëti, 'ikën, .>,
#  TokenList<Ë, =x, ka, =na, xubu, =nu, atsin-i-n, .>,
#  TokenList<Ë, =n, ka, =na, xubu, =nu, i, atsin-mi-i-n, .>,
#  TokenList<‘Ë, =x, ka, =na, kini, =nu, më-atsin-mët-i-n, .>,
#  TokenList<Uinbirës, ka, =a, 'ë, =n, piti, piti, 'ikën, .>,
#  TokenList<Uinbi, ka, =a, ‘ë, =n, piti, pi-ti, =ma, ‘ikën, .>,
#  TokenList<Tanu, rërëkanux, tsóbuakëxa, bai, ‘ipasu, .>,
#  TokenList<y, a, kaibu, =ribi, abat-a, ka, =a, ikën, bëtsi, Palcaso, rëbúmi, .>,
#  TokenList<Comodiezaños, aish, ka, =na, 'ë, =x, tsókën, SantaRosa, tsipúmi, .>,
#  TokenList<Nukën, 'ibu, ka, =is, =a, nai, =nu, =ax, uakëxa, .>,
#  TokenList<Achushi, kini, =ñu, ka, =a, mi, =n, xo, rabé̈okë, ‘ikën, .>,
#  TokenList<Mi, =n, nunti, ka, =a, kini-i-ín, .>,
#  TokenList<Mi, =n, naë, ka, =a, matat-i-ín, .>,
#  TokenList<Bari, =n, ka, =a, a, këntí, ichútmiaxa, .>,
#  TokenList<Mi, =n, linterna, ka, =mina, tirit-o-a-n, .>,
#  TokenList<A, uni, =n, ka, =a, uri, achushi, xaë, mëraxa, .>,
#  TokenList<A, xubu, =nu, ka, =na, imé̈, kwan-ti, ‘ain, .>,
#  TokenList<‘Ë, =n, xubu, ‘aisama, ‘i-këbëtan, ka, =na, bëtsi, xubu, ‘ë, =n, ‘a-akë-n, .>,
#  TokenList<Kënë, xaiki-këbë, ka, =a, xubu, nipakët-a-x-a, .>,
#  TokenList<Emilionë, =n, kënë, xaika-këx, ka, =a, xubu, nipakët-a-x-a, .>,
#  TokenList<‘Ë, =n, xubu, =nu, ka, =na, ‘aisama, ‘ain, .>,
#  TokenList<Xanu,  =n, ka, =is, =a, buankian, ain, bënë, “, unirá, ka, ”, .>,
#  TokenList<“, Min, bënë, ‘atankëxun, ka, ‘ëribi, min, maëxratsukun, ‘ë, ‘a, ”, ka, =is, =a, kakëshín, .>,
#  TokenList<Anuxun, nukën, bake, bëchikë, nukën, ini, bëchikë, 'óina, chunena, pitankëxun, kaniotin, .>,
#  TokenList<Usa, =bi, ka, ‘isenaka, =n, rataxtamainun, chëkiai, .>,
#  TokenList<Usai, ka, =a, ëo, kamëokëxa, nu, =n, ‘anibu, nukën, chaitibaë, =n, nukën, xutabaë, =n, .>,
#  TokenList<‘Ë, =n, ka, =na, ënë, an, taë, tëbiskati, bu, =a, =n, .>,
#  TokenList<An, taë, tëbiskati, ka, =n, ‘aisama, ‘ikën, .>,
#  TokenList<Tsatsa, ënë, ka, bëruan, !>,
#  TokenList<atian, casi, kamabi, nëtë, =n, ka, =is, =a, a, uni, kwan-akë-x-ín, .>,
#  TokenList<Upí, ñu, ka, =na, kwëënin, .>,
#  TokenList<ka, =nanuna, toxama, upí, bits-tankëxun, taish, a, bits-tankëxun, ka, =nanuna, ‘aru-i-n, .>,
#  TokenList<Ka, =n, ‘itsa, ñu, xarákë, .>,
#  TokenList<Ësaokin, mane, ‘itsa, toinkë, ‘ixunmabi, .>,
#  TokenList<Pui, =n, ‘axankëbë, ka, =is, =a, a, kaxu, kwankëxa, uni, achushi, .>,
#  TokenList<Achushi, uni, =n, ka, =is, =a, kamabi, nëtë, =n, tanu, buankëxa, .>,
#  TokenList<Kana, rani, xon, rani, ka, =nanuna, ain, tsipu, =nu, bëtanitin, .>,
#  TokenList<nukën, papa, =n, bana, =ishi, a-i, tsót-i-n, a, =ishi, ka, =na, ka-i-n, .>,
#  TokenList<rët-tankëxun, ka, =is, =a, xanu, =n, chaxu, rakan-akë-x-in, .>,
#  TokenList<ka, xui, ka-xun, ka, =is, =a, charu, ain, xanu, inan-akë-x-a, .>,
#  TokenList<a-kin, =ma, ka, =nanuna, a-i-n, atsa, =këñun, xëki, .>,
#  TokenList<Ain, monument, =sapi, ka, =a, Pucallpa, =nu, 'ikën, .>,
#  TokenList<cha, bai, ka, =a, a-akë-x-a, desde, Tingo, María, anu-xun, hasta, Pucallpa, =nu, .>,
#  TokenList<hotel, =miki, ka, =a, e, =n, xukën, u-i-a, .>,
#  TokenList<Hotel, =uki, ka, =a, ‘ë, =n, xukën, u-i-a, .>,
#  TokenList<xubu, =kama, ka, =a, is-akë-x-a, .>,
#  TokenList<nukën, papaokë, =kama, ka, =a, uni, chaxkë, siná, uni, i-akë-x-a, .>,
#  TokenList<anu, ka, =a, i-akë-x-a, a, uni, =kama, ë, =n, papaokë, .>,
#  TokenList<después, ka, =nanuna, bëtsi, a-ti, ain, bëtsi, historia, bëtsi, bana, .>,
#  TokenList<a-tankëxun, ka, =na, itsa, katsin, itsa, xinkun, a-ti, ain, .>,
#  TokenList<ainbi, ka, =a, bëná, uni, =n, pia, toin-ti, kanti, toin-ti, rabin-i-a, .>,
#  TokenList<upit-o-kin, nui-xun, nits-kin-kin, .>,
#  TokenList<a, =kupí, ka, =a, nu, =n, me, chukúma, ikën, .>,
#  TokenList<Emilio, ka, =a, mas, xuá, ki, Roberto, =ma, ‘ikën, .>,
#  TokenList<Bëxuñurá, ‘ikë, =bi, ka, =is, =a, xanu, =n, ain, bënë, ‘akë, =sa, okin, maso, =ma, ‘ikën, .>,
#  TokenList<Chuna, unitín, a, =n, ka, =a, 'ë, ratuaxa, .>,
#  TokenList<uni-tín, chuna, a, =n, ka, =a, ë, ratu-a-x-a, .>,
#  TokenList<paën-xun, ka, =na, ‘ë, =n, ‘atsa, kwëën-i-n, .>,
#  TokenList<“, Anun, ma, shi, ki, nun, ka, ‘ë, nanë, itsirá, ‘ë, nipáxun, ”, ka, =is, =a, kakëshín, .>,
#  TokenList<Bëru-ax, ka, =is, =a, bëru-an, ka, =is, =a, ukairi, a, tënka-pat-akë-x-ín, u-but-kin, is, =a, rët-uku-but-an, .>,
#  TokenList<'Aishbi, ka, =is, =a, 'iakëxa, a, uni, chumíbukë, bamati, ura, =ma, .>,
#  TokenList<kwainkin, =shi, ka, =is, =a, ain, tita, ñuxanrá, ain, maë, matsunkubuinia, =bi, rëakëxa, .>,
#  TokenList<Chaxu, an, =n, churukukwainkin, ka, =is, =a, xanu, xënirá, chaxu, =n, makwëxakëshín, .>,
#  TokenList<Ë, =nu, achushi, bëráma, nu, =n, ‘anibu, ‘ia, ka, =na, ñuikasin, .>,
#  TokenList<‘Ë, =n, ka, =na, a, bana, ñuiti, kwëëni, =ma, .>,
#  TokenList<Ë, =n, ka, =na, a, bana, ñuiti, ‘ain, .>,
#  TokenList<atian, casi, kamabi, nëtë, =n, ka, =is, =a, a, uni, kwan-akë-x-ín, .>,
#  TokenList<‘Itankëxun, ka, =is, =a, kakëxa, ain, tita, ñuxanrá, “, tita, =n, ,, anu, uni, xëni, ‘ati, ë, =n, kupë, atsa, bitstanmainun, ka, bëruan, ,, tita, =n, ”, .>,
#  TokenList<Nüken, chaiti, ka, =is, =a, tsót-akë-x-a, rima, kaxu, norte, =nu, .>,
#  TokenList<xëa-kë, a, =x, ka, =a, ikën, shipibo, bana, .>,
#  TokenList<nu, =n, bana, ka, =a, iken, kwáxka-kë, .>,
#  TokenList<ui, n, ka, ra, a, carretera, aakëxa>,
#  TokenList<‘ë, x , ka, na , munui, ishi , kwanin>,
#  TokenList<‘inu, =n, =bu , ka, :a, 'aaxa, .>,
#  TokenList<Juan , ka, a , chuna, sa , ‘ikën, .>,
#  TokenList<chupa , maru-kin, bi , ka, na , ‘ë, n , iëtan-a-n, .>,
#  TokenList<María, =n , ‘aru-kë, =sa , ka, =na , sinan-i-n>,
#  TokenList<a, =kama, =n , ka , =a, ‘atsa , pi-kan-i-n, .>,
#  TokenList<a, =kama, =n, ka, :a, ‘atsa, pi-kan-i-n>,
#  TokenList<Juan, ka, :a, ni, =nu, =ax, ‘ux-a-x-a>,
#  TokenList<kashi, a, =x, ka, =a, i, =nu, pani-a-x-a>,
#  TokenList<Emilio, =n, ka, =a, Wilton, bana-anan-xun-a-x-a>,
#  TokenList<xanu, rabé̈, ka, :a, ‘ikut-kan-anan-i-a>]

# %%
with open("treebank-kakataibo.conllu", "w", encoding='utf-8') as f:
    for token_list in kakataibo:
        # Your custom work and changes here
        serialized = token_list.serialize()
        f.write(serialized)
        f.write('\n\n')

# %%
from conllu import parse_incr

data_file = open("treebank-kakataibo.conllu", "r", encoding="utf-8")
for tokenlist in parse_incr(data_file):
    print(tokenlist)
# Out:
# TokenList<patron, =bëtan, ka, =a, balata, a-akë-x-ín, .>
# TokenList<maru-kin, no-n, buan-akë-x-ín, .>
# TokenList<Juan, ka, =mënë, mi, =n, kuriki, mëkama-iéé, .>
# TokenList<Nukën, chaiti, ka, =is, =a, tsó-akë-x-a, norte, =nu, .>
# TokenList<Norte, =nu, tsó-xun, ka, =is, =a, nukën, chaiti-baë, =n, uni, =ñu, =ma, no, =ñu, =ma, 'a-akë-x-a, .>
# TokenList<Nukën, chaiti, =n, ka, =a, bana, ñui-xun-kian, .>
# TokenList<'Ë, ka, 'atsa, 'inan, .>
# TokenList<Nukën, chaiti, =n, ka, =is, =a, 'ó, nami, pi-akë-x-a, .>
# TokenList<Achushi, uni, chaxkë, =bëtan, ka, =na, 'ë, =n, xubu', a-ti, 'ain, .>
# TokenList<Uni, =n, ka, =a, baka, =nu, =xun, chaxu, 'a-a-x-a, .>
# TokenList<Xanu-xun, ka, =a, ‘atapa, ‘a-a-x-a, .>
# TokenList<Uni, achushi, =n, =pain, ka, =a, ënë, ‘ó, ‘a-a-x-a, .>
# TokenList<Munu, =ishi, ka, =mina, pi-ti, 'ain, .>
# TokenList<Roberto, =nën, ka, =a, ënë, ‘ó, name, pipania, .>
# TokenList<Achushi, =ishi, ñu, ka, =a, ‘ë, ‘inan, .>
# TokenList<Uni, chaxkë´, achushi, =bëtan, ka, =na, 'ë, =n, xubu, 'ati, 'ain, .>
# TokenList<Imëishi, ka, =na, Aguaytia, =nu, kwan-ti, ‘ain, .>
# TokenList<Aguaytia, =nu, ka, =na, imëshi, kwan-ti, ain, .>
# TokenList<uni, =n, ka, =a, baka, =nu, =xun, =bi, chaxu, 'aaxa, .>
# TokenList<Roberto, ka, =a, më-uxu, 'ikën, .>
# TokenList<Roberto, ka, =a, mëkën, =nu, më-uxu, 'ikën, .>
# TokenList<Ta-tani-katsi, ki-xun, rakan-bian-a-n, .>
# TokenList<Tënka-këbë, ka, =is, =a, uni, ëëëëëë, ki-i, bë-man-mët-akë-xín, .>
# TokenList<Parunuti, a, =x, ka, =a, pabëntamëti, 'ikën, .>
# TokenList<Parunuti, a, =x, ka, =a, pabí, =nu, bëntamëti, 'ikën, .>
# TokenList<Ë, =x, ka, =na, xubu, =nu, atsin-i-n, .>
# TokenList<Ë, =n, ka, =na, xubu, =nu, i, atsin-mi-i-n, .>
# TokenList<‘Ë, =x, ka, =na, kini, =nu, më-atsin-mët-i-n, .>
# TokenList<Uinbirës, ka, =a, 'ë, =n, piti, piti, 'ikën, .>
# TokenList<Uinbi, ka, =a, ‘ë, =n, piti, pi-ti, =ma, ‘ikën, .>
# TokenList<Tanu, rërëkanux, tsóbuakëxa, bai, ‘ipasu, .>
# TokenList<y, a, kaibu, =ribi, abat-a, ka, =a, ikën, bëtsi, Palcaso, rëbúmi, .>
# TokenList<Comodiezaños, aish, ka, =na, 'ë, =x, tsókën, SantaRosa, tsipúmi, .>
# TokenList<Nukën, 'ibu, ka, =is, =a, nai, =nu, =ax, uakëxa, .>
# TokenList<Achushi, kini, =ñu, ka, =a, mi, =n, xo, rabé̈okë, ‘ikën, .>
# TokenList<Mi, =n, nunti, ka, =a, kini-i-ín, .>
# TokenList<Mi, =n, naë, ka, =a, matat-i-ín, .>
# TokenList<Bari, =n, ka, =a, a, këntí, ichútmiaxa, .>
# TokenList<Mi, =n, linterna, ka, =mina, tirit-o-a-n, .>
# TokenList<A, uni, =n, ka, =a, uri, achushi, xaë, mëraxa, .>
# TokenList<A, xubu, =nu, ka, =na, imé̈, kwan-ti, ‘ain, .>
# TokenList<‘Ë, =n, xubu, ‘aisama, ‘i-këbëtan, ka, =na, bëtsi, xubu, ‘ë, =n, ‘a-akë-n, .>
# TokenList<Kënë, xaiki-këbë, ka, =a, xubu, nipakët-a-x-a, .>
# TokenList<Emilionë, =n, kënë, xaika-këx, ka, =a, xubu, nipakët-a-x-a, .>
# TokenList<‘Ë, =n, xubu, =nu, ka, =na, ‘aisama, ‘ain, .>
# TokenList<Xanu,  =n, ka, =is, =a, buankian, ain, bënë, “, unirá, ka, ”, .>
# TokenList<“, Min, bënë, ‘atankëxun, ka, ‘ëribi, min, maëxratsukun, ‘ë, ‘a, ”, ka, =is, =a, kakëshín, .>
# TokenList<Anuxun, nukën, bake, bëchikë, nukën, ini, bëchikë, 'óina, chunena, pitankëxun, kaniotin, .>
# TokenList<Usa, =bi, ka, ‘isenaka, =n, rataxtamainun, chëkiai, .>
# TokenList<Usai, ka, =a, ëo, kamëokëxa, nu, =n, ‘anibu, nukën, chaitibaë, =n, nukën, xutabaë, =n, .>
# TokenList<‘Ë, =n, ka, =na, ënë, an, taë, tëbiskati, bu, =a, =n, .>
# TokenList<An, taë, tëbiskati, ka, =n, ‘aisama, ‘ikën, .>
# TokenList<Tsatsa, ënë, ka, bëruan, !>
# TokenList<atian, casi, kamabi, nëtë, =n, ka, =is, =a, a, uni, kwan-akë-x-ín, .>
# TokenList<Upí, ñu, ka, =na, kwëënin, .>
# TokenList<ka, =nanuna, toxama, upí, bits-tankëxun, taish, a, bits-tankëxun, ka, =nanuna, ‘aru-i-n, .>
# TokenList<Ka, =n, ‘itsa, ñu, xarákë, .>
# TokenList<Ësaokin, mane, ‘itsa, toinkë, ‘ixunmabi, .>
# TokenList<Pui, =n, ‘axankëbë, ka, =is, =a, a, kaxu, kwankëxa, uni, achushi, .>
# TokenList<Achushi, uni, =n, ka, =is, =a, kamabi, nëtë, =n, tanu, buankëxa, .>
# TokenList<Kana, rani, xon, rani, ka, =nanuna, ain, tsipu, =nu, bëtanitin, .>
# TokenList<nukën, papa, =n, bana, =ishi, a-i, tsót-i-n, a, =ishi, ka, =na, ka-i-n, .>
# TokenList<rët-tankëxun, ka, =is, =a, xanu, =n, chaxu, rakan-akë-x-in, .>
# TokenList<ka, xui, ka-xun, ka, =is, =a, charu, ain, xanu, inan-akë-x-a, .>
# TokenList<a-kin, =ma, ka, =nanuna, a-i-n, atsa, =këñun, xëki, .>
# TokenList<Ain, monument, =sapi, ka, =a, Pucallpa, =nu, 'ikën, .>
# TokenList<cha, bai, ka, =a, a-akë-x-a, desde, Tingo, María, anu-xun, hasta, Pucallpa, =nu, .>
# TokenList<hotel, =miki, ka, =a, e, =n, xukën, u-i-a, .>
# TokenList<Hotel, =uki, ka, =a, ‘ë, =n, xukën, u-i-a, .>
# TokenList<xubu, =kama, ka, =a, is-akë-x-a, .>
# TokenList<nukën, papaokë, =kama, ka, =a, uni, chaxkë, siná, uni, i-akë-x-a, .>
# TokenList<anu, ka, =a, i-akë-x-a, a, uni, =kama, ë, =n, papaokë, .>
# TokenList<después, ka, =nanuna, bëtsi, a-ti, ain, bëtsi, historia, bëtsi, bana, .>
# TokenList<a-tankëxun, ka, =na, itsa, katsin, itsa, xinkun, a-ti, ain, .>
# TokenList<ainbi, ka, =a, bëná, uni, =n, pia, toin-ti, kanti, toin-ti, rabin-i-a, .>
# TokenList<upit-o-kin, nui-xun, nits-kin-kin, .>
# TokenList<a, =kupí, ka, =a, nu, =n, me, chukúma, ikën, .>
# TokenList<Emilio, ka, =a, mas, xuá, ki, Roberto, =ma, ‘ikën, .>
# TokenList<Bëxuñurá, ‘ikë, =bi, ka, =is, =a, xanu, =n, ain, bënë, ‘akë, =sa, okin, maso, =ma, ‘ikën, .>
# TokenList<Chuna, unitín, a, =n, ka, =a, 'ë, ratuaxa, .>
# TokenList<uni-tín, chuna, a, =n, ka, =a, ë, ratu-a-x-a, .>
# TokenList<paën-xun, ka, =na, ‘ë, =n, ‘atsa, kwëën-i-n, .>
# TokenList<“, Anun, ma, shi, ki, nun, ka, ‘ë, nanë, itsirá, ‘ë, nipáxun, ”, ka, =is, =a, kakëshín, .>
# TokenList<Bëru-ax, ka, =is, =a, bëru-an, ka, =is, =a, ukairi, a, tënka-pat-akë-x-ín, u-but-kin, is, =a, rët-uku-but-an, .>
# TokenList<'Aishbi, ka, =is, =a, 'iakëxa, a, uni, chumíbukë, bamati, ura, =ma, .>
# TokenList<kwainkin, =shi, ka, =is, =a, ain, tita, ñuxanrá, ain, maë, matsunkubuinia, =bi, rëakëxa, .>
# TokenList<Chaxu, an, =n, churukukwainkin, ka, =is, =a, xanu, xënirá, chaxu, =n, makwëxakëshín, .>
# TokenList<Ë, =nu, achushi, bëráma, nu, =n, ‘anibu, ‘ia, ka, =na, ñuikasin, .>
# TokenList<‘Ë, =n, ka, =na, a, bana, ñuiti, kwëëni, =ma, .>
# TokenList<Ë, =n, ka, =na, a, bana, ñuiti, ‘ain, .>
# TokenList<atian, casi, kamabi, nëtë, =n, ka, =is, =a, a, uni, kwan-akë-x-ín, .>
# TokenList<‘Itankëxun, ka, =is, =a, kakëxa, ain, tita, ñuxanrá, “, tita, =n, ,, anu, uni, xëni, ‘ati, ë, =n, kupë, atsa, bitstanmainun, ka, bëruan, ,, tita, =n, ”, .>
# TokenList<Nüken, chaiti, ka, =is, =a, tsót-akë-x-a, rima, kaxu, norte, =nu, .>
# TokenList<xëa-kë, a, =x, ka, =a, ikën, shipibo, bana, .>
# TokenList<nu, =n, bana, ka, =a, iken, kwáxka-kë, .>
# TokenList<ui, n, ka, ra, a, carretera, aakëxa>
# TokenList<‘ë, x , ka, na , munui, ishi , kwanin>
# TokenList<‘inu, =n, =bu , ka, :a, 'aaxa, .>
# TokenList<Juan , ka, a , chuna, sa , ‘ikën, .>
# TokenList<chupa , maru-kin, bi , ka, na , ‘ë, n , iëtan-a-n, .>
# TokenList<María, =n , ‘aru-kë, =sa , ka, =na , sinan-i-n>
# TokenList<a, =kama, =n , ka , =a, ‘atsa , pi-kan-i-n, .>
# TokenList<a, =kama, =n, ka, :a, ‘atsa, pi-kan-i-n>
# TokenList<Juan, ka, :a, ni, =nu, =ax, ‘ux-a-x-a>
# TokenList<kashi, a, =x, ka, =a, i, =nu, pani-a-x-a>
# TokenList<Emilio, =n, ka, =a, Wilton, bana-anan-xun-a-x-a>
# TokenList<xanu, rabé̈, ka, :a, ‘ikut-kan-anan-i-a>

# %% [markdown]
# ## Ejercicios con el corpus :)

# %% [markdown]
# Para una **oración**, identifique todos los **tokens** y los **types**.

# %%
## función que calcula la frecuencia de types para una oración

## INPUT: lista de diccionarios
## OUTPUT: diccionario type:frecuencia del type
def frecuencia_types(sent):
    
    ## tokens
    puntuacion = ['.',',']
    tokens = []
    for d in sent:
        form = d['form']
        if form not in puntuacion:
            tokens+=[form.lower()]
            
    ## types
    types = []
    for palabra in tokens:
        if palabra not in types:
            types+=[palabra]
            
    D_type_frec = {}
    
    ## diccionario de frecuencia, con ceros al principio
    for word_type in types:
        D_type_frec[word_type]=0
    ## recorremos la lista tokens buscando los types, y cuando aparecen sumamos 1
    for token in tokens:
        D_type_frec[token]+=1
        
    return D_type_frec

# %%
frecuencia_types(kakataibo[6])
# Out:
# {"'ë": 1, 'ka': 1, "'atsa": 1, "'inan": 1}

# %%
from collections import Counter

## función que usa la librería collections

## INPUT: lista de diccionarios
## OUTPUT: diccionario type:frecuencia del type
def frecuencia_types_counter(sent):
    
    ## tokens
    puntuacion = ['.',',']
    tokens = []
    for d in sent:
        form = d['form']
        if form not in puntuacion:
            tokens+=[form.lower()]
            
    D_type_frec = dict(Counter(tokens))
        
    return D_type_frec

# %%
frecuencia_types_counter(kakataibo[12])
# Out:
# {'aguaytia': 1,
#  '=nu': 1,
#  'ka': 1,
#  '=na': 1,
#  'imëshi': 1,
#  'kwan-ti': 1,
#  'ain': 1}

# %%
## INPUT: lista de diccionarios
## INPUT: entero k -> número de types más frecuentes
## OUTPUT: diccionario type:frecuencia del type
def types_mas_frecuentes(sent,k):
    
    ## tokens
    puntuacion = ['.',',']
    tokens = []
    for d in sent:
        form = d['form']
        if form not in puntuacion:
            tokens+=[form.lower()]
            
    D_type_frec = Counter(tokens)
        
    return D_type_frec.most_common(k)

# %%
types_mas_frecuentes(kakataibo[0],4)
# Out:
# [('patron', 1), ('=bëtan', 1), ('ka', 1), ('=a', 1)]

# %%
## ¿Cómo podemos generalizar esto para todo el mini-corpus?

lista_diccionarios_corpus = []

for sentence in kakataibo:
    for d in sentence:
        lista_diccionarios_corpus+=[d]

# %%
dict_frec_types = frecuencia_types(lista_diccionarios_corpus)

# %%
dict_frec_types
# Out:
# {'patron': 1,
#  '=bëtan': 3,
#  'ka': 115,
#  '=a': 71,
#  'balata': 1,
#  'a-akë-x-ín': 1,
#  'maru-kin': 2,
#  'no-n': 2,
#  'buan-akë-x-ín': 2,
#  'juan': 1,
#  '=mënë': 1,
#  'mi': 5,
#  '=n': 61,
#  'kuriki': 1,
#  'mëkama-iéé': 1,
#  'nukën': 16,
#  'chaiti': 7,
#  '=is': 28,
#  'tsó-akë-x-a': 1,
#  'norte': 4,
#  '=nu': 21,
#  'tsó-xun': 1,
#  'chaiti-baë': 1,
#  'uni': 20,
#  '=ñu': 3,
#  '=ma': 10,
#  'no': 1,
#  "'a-akë-x-a": 1,
#  'bana': 7,
#  'ñui-xun-kian': 1,
#  "'ë": 6,
#  "'atsa": 1,
#  "'inan": 1,
#  "'ó": 2,
#  'nami': 2,
#  'pi-akë-x-a': 2,
#  'achushi': 10,
#  'chaxkë': 2,
#  '=na': 23,
#  "xubu'": 1,
#  'a-ti': 3,
#  "'ain": 3,
#  'baka': 2,
#  '=xun': 2,
#  'chaxu': 5,
#  "'a-a-x-a": 1,
#  'munu': 1,
#  '=ishi': 4,
#  '=mina': 2,
#  'pi-ti': 4,
#  'aguaytia': 2,
#  'imëshi': 1,
#  'kwan-ti': 3,
#  'ain': 12,
#  'roberto': 6,
#  'më-uxu': 2,
#  "'ikën": 6,
#  'mëkën': 1,
#  'ta-tani-katsi': 1,
#  'ki-xun': 1,
#  'rakan-bian-a-n': 1,
#  'tënka-këbë': 1,
#  'ëëëëëë': 1,
#  'ki-i': 1,
#  'bë-man-mët-akë-xín': 1,
#  'ë': 8,
#  '=x': 8,
#  'xubu': 10,
#  'atsin-i-n': 1,
#  'y': 1,
#  'a': 21,
#  'kaibu': 1,
#  '=ribi': 1,
#  'abat-a': 1,
#  'ikën': 3,
#  'bëtsi': 5,
#  'palcaso': 1,
#  'rëbúmi': 1,
#  'papa': 1,
#  'a-i': 1,
#  'tsót-i-n': 1,
#  'ka-i-n': 1,
#  'xanu': 6,
#  ' =n': 2,
#  'buankian': 2,
#  'bënë': 4,
#  '“': 7,
#  'unirá': 2,
#  '”': 7,
#  'min': 4,
#  '‘atankëxun': 2,
#  '‘ëribi': 2,
#  'maëxratsukun': 2,
#  '‘ë': 6,
#  '‘a': 2,
#  'kakëshín': 4,
#  'usa': 1,
#  '=bi': 4,
#  '‘isenaka': 1,
#  'rataxtamainun': 1,
#  'chëkiai': 1,
#  'usai': 1,
#  'ëo': 1,
#  'kamëokëxa': 1,
#  'nu': 5,
#  '‘anibu': 3,
#  'chaitibaë': 1,
#  'xutabaë': 1,
#  '‘ë': 14,
#  'ënë': 5,
#  'an': 3,
#  'taë': 2,
#  'tëbiskati': 2,
#  'bu': 1,
#  '‘aisama': 3,
#  '‘ikën': 7,
#  'tsatsa': 1,
#  'bëruan': 2,
#  '!': 1,
#  'atian': 2,
#  'casi': 2,
#  'kamabi': 3,
#  'nëtë': 3,
#  'kwan-akë-x-ín': 2,
#  'upí': 3,
#  'ñu': 3,
#  'kwëënin': 1,
#  '=nanuna': 7,
#  'toxama': 2,
#  'bits-tankëxun': 4,
#  'taish': 2,
#  '‘aru-i-n': 2,
#  '‘itsa': 2,
#  'xarákë': 1,
#  'ësaokin': 1,
#  'mane': 1,
#  'toinkë': 1,
#  '‘ixunmabi': 1,
#  'pui': 1,
#  '‘axankëbë': 1,
#  'kaxu': 2,
#  'kwankëxa': 1,
#  'tanu': 3,
#  'buankëxa': 1,
#  'rët-tankëxun': 1,
#  'rakan-akë-x-in': 1,
#  'xui': 1,
#  'ka-xun': 1,
#  'charu': 1,
#  'inan-akë-x-a': 1,
#  'a-kin': 1,
#  'a-i-n': 1,
#  'atsa': 2,
#  '=këñun': 1,
#  'xëki': 1,
#  'cha': 1,
#  'bai': 3,
#  'a-akë-x-a': 1,
#  'desde': 1,
#  'tingo': 1,
#  'maría': 1,
#  'anu-xun': 1,
#  'hasta': 1,
#  'pucallpa': 2,
#  'hotel': 3,
#  '=miki': 1,
#  'e': 1,
#  'xukën': 3,
#  'u-i-a': 3,
#  '=kama': 4,
#  'is-akë-x-a': 1,
#  'papaokë': 3,
#  'siná': 2,
#  'i-akë-x-a': 2,
#  'anu': 2,
#  'después': 1,
#  'historia': 1,
#  'a-tankëxun': 1,
#  'itsa': 2,
#  'katsin': 1,
#  'xinkun': 1,
#  'ainbi': 1,
#  'bëná': 1,
#  'pia': 1,
#  'toin-ti': 2,
#  'kanti': 1,
#  'rabin-i-a': 1,
#  'upit-o-kin': 1,
#  'nui-xun': 1,
#  'nits-kin-kin': 1,
#  '=kupí': 1,
#  'me': 1,
#  'chukúma': 1,
#  'emilio': 2,
#  'mas': 2,
#  'xuá': 2,
#  'ki': 4,
#  'bëxuñurá': 1,
#  '‘ikë': 1,
#  'bënë': 1,
#  '‘akë': 1,
#  '=sa': 1,
#  'okin': 1,
#  'maso': 1,
#  'uni-tín': 1,
#  'chuna': 2,
#  'ratu-a-x-a': 1,
#  'paën-xun': 2,
#  '‘atsa': 2,
#  'kwëën-i-n': 2,
#  'anun': 2,
#  'ma': 2,
#  'shi': 2,
#  'nun': 2,
#  'nanë': 2,
#  'itsirá': 2,
#  'nipáxun': 2,
#  'churukukwainkin': 1,
#  'xënirá': 1,
#  'makwëxakëshín': 1,
#  'ñuiti': 2,
#  'kwëëni': 1,
#  '‘ain': 4,
#  '‘itankëxun': 1,
#  'kakëxa': 1,
#  'tita': 4,
#  'ñuxanrá': 2,
#  'xëni': 1,
#  '‘ati': 1,
#  'kupë': 1,
#  'bitstanmainun': 1,
#  'ënu': 1,
#  'tsót-a': 1,
#  'sino': 1,
#  'tsót-akë-x-a': 2,
#  'rima': 1,
#  'xëa-kë': 1,
#  'shipibo': 1,
#  'iken': 1,
#  'kwáxka-kë': 1,
#  'xanu-xun': 1,
#  '‘atapa': 1,
#  '‘a-a-x-a': 2,
#  '=pain': 1,
#  '‘ó': 3,
#  '‘inan': 1,
#  'imëishi': 1,
#  'i': 1,
#  'atsin-mi-i-n': 1,
#  'kini': 2,
#  'më-atsin-mët-i-n': 1,
#  'uinbi': 1,
#  'piti': 3,
#  'xo': 1,
#  'rabé̈okë': 1,
#  'nunti': 1,
#  'kini-i-ín': 1,
#  'naë': 1,
#  'matat-i-ín': 1,
#  'linterna': 1,
#  'tirit-o-a-n': 1,
#  'imé̈': 1,
#  '‘i-këbëtan': 1,
#  '‘a-akë-n': 1,
#  'kënë': 2,
#  'xaiki-këbë': 1,
#  'nipakët-a-x-a': 2,
#  'emilionë': 1,
#  'xaika-këx': 1,
#  '=uki': 2,
#  'rakwët-i-n': 2,
#  '‘inu': 2,
#  'rabanan': 2,
#  '=nën': 2,
#  'name': 2,
#  'pipania': 2,
#  'chaxkë´': 1,
#  "'ati": 1,
#  "'aaxa": 1,
#  'parunuti': 2,
#  'pabëntamëti': 1,
#  'pabí': 1,
#  'bëntamëti': 1,
#  'uinbirës': 1,
#  'rërëkanux': 2,
#  'tsóbuakëxa': 2,
#  '‘ipasu': 2,
#  'comodiezaños': 1,
#  'aish': 1,
#  'tsókën': 1,
#  'santarosa': 1,
#  'tsipúmi': 1,
#  "'ibu": 1,
#  'nai': 1,
#  '=ax': 1,
#  'uakëxa': 1,
#  'bari': 1,
#  'këntí': 1,
#  'ichútmiaxa': 1,
#  'uri': 1,
#  'xaë': 1,
#  'mëraxa': 1,
#  'anuxun': 1,
#  'bake': 1,
#  'bëchikë': 2,
#  'ini': 1,
#  "'óina": 1,
#  'chunena': 1,
#  'pitankëxun': 1,
#  'kaniotin': 1,
#  'kana': 1,
#  'rani': 2,
#  'xon': 1,
#  'tsipu': 1,
#  'bëtanitin': 1,
#  'monument': 1,
#  '=sapi': 1,
#  'unitín': 1,
#  'ratuaxa': 1,
#  "'aishbi": 1,
#  "'iakëxa": 1,
#  'chumíbukë': 1,
#  'bamati': 1,
#  'ura': 1,
#  'kwainkin': 1,
#  '=shi': 1,
#  'maë': 1,
#  'matsunkubuinia': 1,
#  'rëakëxa': 1,
#  'bëráma': 2,
#  '‘ia': 2,
#  'ñuikasin': 2,
#  'bëru-ax': 1,
#  'bëru-an': 1,
#  'ukairi': 1,
#  'tënka-pat-akë-x-ín': 1,
#  'u-but-kin': 1,
#  'is': 1,
#  'rët-uku-but-an': 1,
#  'chaxké': 1,
#  '‘i-akë-x-a': 1}

# %%
num_types = len(dict_frec_types)

# %%
num_types
# Out:
# 341

# %%
num_tokens = sum(dict_frec_types.values())

# %%
num_tokens
# Out:
# 1006

# %%
types_frec = types_mas_frecuentes(lista_diccionarios_corpus,len(lista_diccionarios_corpus))

# %%
types_frec
# Out:
# [('ka', 115),
#  ('=a', 71),
#  ('=n', 61),
#  ('=is', 28),
#  ('=na', 23),
#  ('=nu', 21),
#  ('a', 21),
#  ('uni', 20),
#  ('nukën', 16),
#  ('‘ë', 14),
#  ('ain', 12),
#  ('=ma', 10),
#  ('achushi', 10),
#  ('xubu', 10),
#  ('ë', 8),
#  ('=x', 8),
#  ('chaiti', 7),
#  ('bana', 7),
#  ('“', 7),
#  ('”', 7),
#  ('‘ikën', 7),
#  ('=nanuna', 7),
#  ("'ë", 6),
#  ('roberto', 6),
#  ("'ikën", 6),
#  ('xanu', 6),
#  ('‘ë', 6),
#  ('mi', 5),
#  ('chaxu', 5),
#  ('bëtsi', 5),
#  ('nu', 5),
#  ('ënë', 5),
#  ('norte', 4),
#  ('=ishi', 4),
#  ('pi-ti', 4),
#  ('bënë', 4),
#  ('min', 4),
#  ('kakëshín', 4),
#  ('=bi', 4),
#  ('bits-tankëxun', 4),
#  ('=kama', 4),
#  ('ki', 4),
#  ('‘ain', 4),
#  ('tita', 4),
#  ('=bëtan', 3),
#  ('=ñu', 3),
#  ('a-ti', 3),
#  ("'ain", 3),
#  ('kwan-ti', 3),
#  ('ikën', 3),
#  ('‘anibu', 3),
#  ('an', 3),
#  ('‘aisama', 3),
#  ('kamabi', 3),
#  ('nëtë', 3),
#  ('upí', 3),
#  ('ñu', 3),
#  ('tanu', 3),
#  ('bai', 3),
#  ('hotel', 3),
#  ('xukën', 3),
#  ('u-i-a', 3),
#  ('papaokë', 3),
#  ('‘ó', 3),
#  ('piti', 3),
#  ('maru-kin', 2),
#  ('no-n', 2),
#  ('buan-akë-x-ín', 2),
#  ("'ó", 2),
#  ('nami', 2),
#  ('pi-akë-x-a', 2),
#  ('chaxkë', 2),
#  ('baka', 2),
#  ('=xun', 2),
#  ('=mina', 2),
#  ('aguaytia', 2),
#  ('më-uxu', 2),
#  (' =n', 2),
#  ('buankian', 2),
#  ('unirá', 2),
#  ('‘atankëxun', 2),
#  ('‘ëribi', 2),
#  ('maëxratsukun', 2),
#  ('‘a', 2),
#  ('taë', 2),
#  ('tëbiskati', 2),
#  ('bëruan', 2),
#  ('atian', 2),
#  ('casi', 2),
#  ('kwan-akë-x-ín', 2),
#  ('toxama', 2),
#  ('taish', 2),
#  ('‘aru-i-n', 2),
#  ('‘itsa', 2),
#  ('kaxu', 2),
#  ('atsa', 2),
#  ('pucallpa', 2),
#  ('siná', 2),
#  ('i-akë-x-a', 2),
#  ('anu', 2),
#  ('itsa', 2),
#  ('toin-ti', 2),
#  ('emilio', 2),
#  ('mas', 2),
#  ('xuá', 2),
#  ('chuna', 2),
#  ('paën-xun', 2),
#  ('‘atsa', 2),
#  ('kwëën-i-n', 2),
#  ('anun', 2),
#  ('ma', 2),
#  ('shi', 2),
#  ('nun', 2),
#  ('nanë', 2),
#  ('itsirá', 2),
#  ('nipáxun', 2),
#  ('ñuiti', 2),
#  ('ñuxanrá', 2),
#  ('tsót-akë-x-a', 2),
#  ('‘a-a-x-a', 2),
#  ('kini', 2),
#  ('kënë', 2),
#  ('nipakët-a-x-a', 2),
#  ('=uki', 2),
#  ('rakwët-i-n', 2),
#  ('‘inu', 2),
#  ('rabanan', 2),
#  ('=nën', 2),
#  ('name', 2),
#  ('pipania', 2),
#  ('parunuti', 2),
#  ('rërëkanux', 2),
#  ('tsóbuakëxa', 2),
#  ('‘ipasu', 2),
#  ('bëchikë', 2),
#  ('rani', 2),
#  ('bëráma', 2),
#  ('‘ia', 2),
#  ('ñuikasin', 2),
#  ('patron', 1),
#  ('balata', 1),
#  ('a-akë-x-ín', 1),
#  ('juan', 1),
#  ('=mënë', 1),
#  ('kuriki', 1),
#  ('mëkama-iéé', 1),
#  ('tsó-akë-x-a', 1),
#  ('tsó-xun', 1),
#  ('chaiti-baë', 1),
#  ('no', 1),
#  ("'a-akë-x-a", 1),
#  ('ñui-xun-kian', 1),
#  ("'atsa", 1),
#  ("'inan", 1),
#  ("xubu'", 1),
#  ("'a-a-x-a", 1),
#  ('munu', 1),
#  ('imëshi', 1),
#  ('mëkën', 1),
#  ('ta-tani-katsi', 1),
#  ('ki-xun', 1),
#  ('rakan-bian-a-n', 1),
#  ('tënka-këbë', 1),
#  ('ëëëëëë', 1),
#  ('ki-i', 1),
#  ('bë-man-mët-akë-xín', 1),
#  ('atsin-i-n', 1),
#  ('y', 1),
#  ('kaibu', 1),
#  ('=ribi', 1),
#  ('abat-a', 1),
#  ('palcaso', 1),
#  ('rëbúmi', 1),
#  ('papa', 1),
#  ('a-i', 1),
#  ('tsót-i-n', 1),
#  ('ka-i-n', 1),
#  ('usa', 1),
#  ('‘isenaka', 1),
#  ('rataxtamainun', 1),
#  ('chëkiai', 1),
#  ('usai', 1),
#  ('ëo', 1),
#  ('kamëokëxa', 1),
#  ('chaitibaë', 1),
#  ('xutabaë', 1),
#  ('bu', 1),
#  ('tsatsa', 1),
#  ('!', 1),
#  ('kwëënin', 1),
#  ('xarákë', 1),
#  ('ësaokin', 1),
#  ('mane', 1),
#  ('toinkë', 1),
#  ('‘ixunmabi', 1),
#  ('pui', 1),
#  ('‘axankëbë', 1),
#  ('kwankëxa', 1),
#  ('buankëxa', 1),
#  ('rët-tankëxun', 1),
#  ('rakan-akë-x-in', 1),
#  ('xui', 1),
#  ('ka-xun', 1),
#  ('charu', 1),
#  ('inan-akë-x-a', 1),
#  ('a-kin', 1),
#  ('a-i-n', 1),
#  ('=këñun', 1),
#  ('xëki', 1),
#  ('cha', 1),
#  ('a-akë-x-a', 1),
#  ('desde', 1),
#  ('tingo', 1),
#  ('maría', 1),
#  ('anu-xun', 1),
#  ('hasta', 1),
#  ('=miki', 1),
#  ('e', 1),
#  ('is-akë-x-a', 1),
#  ('después', 1),
#  ('historia', 1),
#  ('a-tankëxun', 1),
#  ('katsin', 1),
#  ('xinkun', 1),
#  ('ainbi', 1),
#  ('bëná', 1),
#  ('pia', 1),
#  ('kanti', 1),
#  ('rabin-i-a', 1),
#  ('upit-o-kin', 1),
#  ('nui-xun', 1),
#  ('nits-kin-kin', 1),
#  ('=kupí', 1),
#  ('me', 1),
#  ('chukúma', 1),
#  ('bëxuñurá', 1),
#  ('‘ikë', 1),
#  ('bënë', 1),
#  ('‘akë', 1),
#  ('=sa', 1),
#  ('okin', 1),
#  ('maso', 1),
#  ('uni-tín', 1),
#  ('ratu-a-x-a', 1),
#  ('churukukwainkin', 1),
#  ('xënirá', 1),
#  ('makwëxakëshín', 1),
#  ('kwëëni', 1),
#  ('‘itankëxun', 1),
#  ('kakëxa', 1),
#  ('xëni', 1),
#  ('‘ati', 1),
#  ('kupë', 1),
#  ('bitstanmainun', 1),
#  ('ënu', 1),
#  ('tsót-a', 1),
#  ('sino', 1),
#  ('rima', 1),
#  ('xëa-kë', 1),
#  ('shipibo', 1),
#  ('iken', 1),
#  ('kwáxka-kë', 1),
#  ('xanu-xun', 1),
#  ('‘atapa', 1),
#  ('=pain', 1),
#  ('‘inan', 1),
#  ('imëishi', 1),
#  ('i', 1),
#  ('atsin-mi-i-n', 1),
#  ('më-atsin-mët-i-n', 1),
#  ('uinbi', 1),
#  ('xo', 1),
#  ('rabé̈okë', 1),
#  ('nunti', 1),
#  ('kini-i-ín', 1),
#  ('naë', 1),
#  ('matat-i-ín', 1),
#  ('linterna', 1),
#  ('tirit-o-a-n', 1),
#  ('imé̈', 1),
#  ('‘i-këbëtan', 1),
#  ('‘a-akë-n', 1),
#  ('xaiki-këbë', 1),
#  ('emilionë', 1),
#  ('xaika-këx', 1),
#  ('chaxkë´', 1),
#  ("'ati", 1),
#  ("'aaxa", 1),
#  ('pabëntamëti', 1),
#  ('pabí', 1),
#  ('bëntamëti', 1),
#  ('uinbirës', 1),
#  ('comodiezaños', 1),
#  ('aish', 1),
#  ('tsókën', 1),
#  ('santarosa', 1),
#  ('tsipúmi', 1),
#  ("'ibu", 1),
#  ('nai', 1),
#  ('=ax', 1),
#  ('uakëxa', 1),
#  ('bari', 1),
#  ('këntí', 1),
#  ('ichútmiaxa', 1),
#  ('uri', 1),
#  ('xaë', 1),
#  ('mëraxa', 1),
#  ('anuxun', 1),
#  ('bake', 1),
#  ('ini', 1),
#  ("'óina", 1),
#  ('chunena', 1),
#  ('pitankëxun', 1),
#  ('kaniotin', 1),
#  ('kana', 1),
#  ('xon', 1),
#  ('tsipu', 1),
#  ('bëtanitin', 1),
#  ('monument', 1),
#  ('=sapi', 1),
#  ('unitín', 1),
#  ('ratuaxa', 1),
#  ("'aishbi", 1),
#  ("'iakëxa", 1),
#  ('chumíbukë', 1),
#  ('bamati', 1),
#  ('ura', 1),
#  ('kwainkin', 1),
#  ('=shi', 1),
#  ('maë', 1),
#  ('matsunkubuinia', 1),
#  ('rëakëxa', 1),
#  ('bëru-ax', 1),
#  ('bëru-an', 1),
#  ('ukairi', 1),
#  ('tënka-pat-akë-x-ín', 1),
#  ('u-but-kin', 1),
#  ('is', 1),
#  ('rët-uku-but-an', 1),
#  ('chaxké', 1),
#  ('‘i-akë-x-a', 1)]

# %%
X = list(range(len(types_frec)))
Y = []

for item in types_frec:
    Y += [item[1]]

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(dpi=800)

plt.title('Ránking de frecuencias corpus Kakataibo',fontsize=12)

ax.plot(X,Y,marker='o',color='gold',markersize=3,markeredgewidth=0.5,markeredgecolor='k',alpha=0.75,linewidth=1,fillstyle='full')

for i in range(3):
    ax.annotate(types_frec[i][0], (X[i], Y[i]), fontsize=7)
    
#plt.grid(False)
#plt.legend(loc='best',fontsize=7)
plt.xlabel(r'ránking (frecuencia decreciente)',fontsize=10)
plt.ylabel(r'frecuencia de types',fontsize=10)
plt.rcParams.update({'font.size': 10})
plt.savefig('K.jpg', format='jpg', transparent=True, bbox_inches='tight',dpi=800)
plt.show()

# %% [markdown]
# Calcule para cada type la cantidad $-\log (p_t)$, donde $p_t$ es la frecuencia normalizada del type $t$ ¿Qué puede observar?

# %%
dict_probabilidades = {}

for key in dict_frec_types:
    dict_probabilidades[key]=dict_frec_types[key]/num_tokens

# %%
import math

# %%
dict_sorpresa = {}

for key in dict_frec_types:
    dict_sorpresa[key]=-math.log(dict_probabilidades[key])

# %%
types = [item[0] for item in types_frec]

# %%
entropia_kakataibo = 0

for key in types:
    entropia_kakataibo += dict_probabilidades[key]*dict_sorpresa[key]

# %%
X = []
Y = []

for key in types:
    X += [dict_probabilidades[key]]
    Y += [dict_sorpresa[key]]
    print(key,dict_frec_types[key],dict_probabilidades[key],dict_sorpresa[key])
# Out:
# ka 115 0.1143141153081511 2.1688052222964345
# =a 71 0.0705765407554672 2.651057473618369
# =n 61 0.06063618290258449 2.8028634864863733
# =is 28 0.027833001988071572 3.5815328404844804
# =na 23 0.02286282306163022 3.778243134730535
# =nu 21 0.020874751491053677 3.8692149129362616
# a 21 0.020874751491053677 3.8692149129362616
# uni 20 0.019880715705765408 3.9180050771056933
# nukën 16 0.015904572564612324 4.141148628419903
# ‘ë 14 0.013916500994035786 4.274680021044426
# ain 12 0.011928429423459244 4.428830700871684
# =ma 10 0.009940357852882704 4.611152257665639
# achushi 10 0.009940357852882704 4.611152257665639
# xubu 10 0.009940357852882704 4.611152257665639
# ë 8 0.007952286282306162 4.8342958089798485
# =x 8 0.007952286282306162 4.8342958089798485
# chaiti 7 0.006958250497017893 4.967827201604371
# bana 7 0.006958250497017893 4.967827201604371
# “ 7 0.006958250497017893 4.967827201604371
# ” 7 0.006958250497017893 4.967827201604371
# ‘ikën 7 0.006958250497017893 4.967827201604371
# =nanuna 7 0.006958250497017893 4.967827201604371
# 'ë 6 0.005964214711729622 5.121977881431629
# roberto 6 0.005964214711729622 5.121977881431629
# 'ikën 6 0.005964214711729622 5.121977881431629
# xanu 6 0.005964214711729622 5.121977881431629
# ‘ë 6 0.005964214711729622 5.121977881431629
# mi 5 0.004970178926441352 5.304299438225584
# chaxu 5 0.004970178926441352 5.304299438225584
# bëtsi 5 0.004970178926441352 5.304299438225584
# nu 5 0.004970178926441352 5.304299438225584
# ënë 5 0.004970178926441352 5.304299438225584
# norte 4 0.003976143141153081 5.527442989539794
# =ishi 4 0.003976143141153081 5.527442989539794
# pi-ti 4 0.003976143141153081 5.527442989539794
# bënë 4 0.003976143141153081 5.527442989539794
# min 4 0.003976143141153081 5.527442989539794
# kakëshín 4 0.003976143141153081 5.527442989539794
# =bi 4 0.003976143141153081 5.527442989539794
# bits-tankëxun 4 0.003976143141153081 5.527442989539794
# =kama 4 0.003976143141153081 5.527442989539794
# ki 4 0.003976143141153081 5.527442989539794
# ‘ain 4 0.003976143141153081 5.527442989539794
# tita 4 0.003976143141153081 5.527442989539794
# =bëtan 3 0.002982107355864811 5.815125061991575
# =ñu 3 0.002982107355864811 5.815125061991575
# a-ti 3 0.002982107355864811 5.815125061991575
# 'ain 3 0.002982107355864811 5.815125061991575
# kwan-ti 3 0.002982107355864811 5.815125061991575
# ikën 3 0.002982107355864811 5.815125061991575
# ‘anibu 3 0.002982107355864811 5.815125061991575
# an 3 0.002982107355864811 5.815125061991575
# ‘aisama 3 0.002982107355864811 5.815125061991575
# kamabi 3 0.002982107355864811 5.815125061991575
# nëtë 3 0.002982107355864811 5.815125061991575
# upí 3 0.002982107355864811 5.815125061991575
# ñu 3 0.002982107355864811 5.815125061991575
# tanu 3 0.002982107355864811 5.815125061991575
# bai 3 0.002982107355864811 5.815125061991575
# hotel 3 0.002982107355864811 5.815125061991575
# xukën 3 0.002982107355864811 5.815125061991575
# u-i-a 3 0.002982107355864811 5.815125061991575
# papaokë 3 0.002982107355864811 5.815125061991575
# ‘ó 3 0.002982107355864811 5.815125061991575
# piti 3 0.002982107355864811 5.815125061991575
# maru-kin 2 0.0019880715705765406 6.220590170099739
# no-n 2 0.0019880715705765406 6.220590170099739
# buan-akë-x-ín 2 0.0019880715705765406 6.220590170099739
# 'ó 2 0.0019880715705765406 6.220590170099739
# nami 2 0.0019880715705765406 6.220590170099739
# pi-akë-x-a 2 0.0019880715705765406 6.220590170099739
# chaxkë 2 0.0019880715705765406 6.220590170099739
# baka 2 0.0019880715705765406 6.220590170099739
# =xun 2 0.0019880715705765406 6.220590170099739
# =mina 2 0.0019880715705765406 6.220590170099739
# aguaytia 2 0.0019880715705765406 6.220590170099739
# më-uxu 2 0.0019880715705765406 6.220590170099739
#  =n 2 0.0019880715705765406 6.220590170099739
# buankian 2 0.0019880715705765406 6.220590170099739
# unirá 2 0.0019880715705765406 6.220590170099739
# ‘atankëxun 2 0.0019880715705765406 6.220590170099739
# ‘ëribi 2 0.0019880715705765406 6.220590170099739
# maëxratsukun 2 0.0019880715705765406 6.220590170099739
# ‘a 2 0.0019880715705765406 6.220590170099739
# taë 2 0.0019880715705765406 6.220590170099739
# tëbiskati 2 0.0019880715705765406 6.220590170099739
# bëruan 2 0.0019880715705765406 6.220590170099739
# atian 2 0.0019880715705765406 6.220590170099739
# casi 2 0.0019880715705765406 6.220590170099739
# kwan-akë-x-ín 2 0.0019880715705765406 6.220590170099739
# toxama 2 0.0019880715705765406 6.220590170099739
# taish 2 0.0019880715705765406 6.220590170099739
# ‘aru-i-n 2 0.0019880715705765406 6.220590170099739
# ‘itsa 2 0.0019880715705765406 6.220590170099739
# kaxu 2 0.0019880715705765406 6.220590170099739
# atsa 2 0.0019880715705765406 6.220590170099739
# pucallpa 2 0.0019880715705765406 6.220590170099739
# siná 2 0.0019880715705765406 6.220590170099739
# i-akë-x-a 2 0.0019880715705765406 6.220590170099739
# anu 2 0.0019880715705765406 6.220590170099739
# itsa 2 0.0019880715705765406 6.220590170099739
# toin-ti 2 0.0019880715705765406 6.220590170099739
# emilio 2 0.0019880715705765406 6.220590170099739
# mas 2 0.0019880715705765406 6.220590170099739
# xuá 2 0.0019880715705765406 6.220590170099739
# chuna 2 0.0019880715705765406 6.220590170099739
# paën-xun 2 0.0019880715705765406 6.220590170099739
# ‘atsa 2 0.0019880715705765406 6.220590170099739
# kwëën-i-n 2 0.0019880715705765406 6.220590170099739
# anun 2 0.0019880715705765406 6.220590170099739
# ma 2 0.0019880715705765406 6.220590170099739
# shi 2 0.0019880715705765406 6.220590170099739
# nun 2 0.0019880715705765406 6.220590170099739
# nanë 2 0.0019880715705765406 6.220590170099739
# itsirá 2 0.0019880715705765406 6.220590170099739
# nipáxun 2 0.0019880715705765406 6.220590170099739
# ñuiti 2 0.0019880715705765406 6.220590170099739
# ñuxanrá 2 0.0019880715705765406 6.220590170099739
# tsót-akë-x-a 2 0.0019880715705765406 6.220590170099739
# ‘a-a-x-a 2 0.0019880715705765406 6.220590170099739
# kini 2 0.0019880715705765406 6.220590170099739
# kënë 2 0.0019880715705765406 6.220590170099739
# nipakët-a-x-a 2 0.0019880715705765406 6.220590170099739
# =uki 2 0.0019880715705765406 6.220590170099739
# rakwët-i-n 2 0.0019880715705765406 6.220590170099739
# ‘inu 2 0.0019880715705765406 6.220590170099739
# rabanan 2 0.0019880715705765406 6.220590170099739
# =nën 2 0.0019880715705765406 6.220590170099739
# name 2 0.0019880715705765406 6.220590170099739
# pipania 2 0.0019880715705765406 6.220590170099739
# parunuti 2 0.0019880715705765406 6.220590170099739
# rërëkanux 2 0.0019880715705765406 6.220590170099739
# tsóbuakëxa 2 0.0019880715705765406 6.220590170099739
# ‘ipasu 2 0.0019880715705765406 6.220590170099739
# bëchikë 2 0.0019880715705765406 6.220590170099739
# rani 2 0.0019880715705765406 6.220590170099739
# bëráma 2 0.0019880715705765406 6.220590170099739
# ‘ia 2 0.0019880715705765406 6.220590170099739
# ñuikasin 2 0.0019880715705765406 6.220590170099739
# patron 1 0.0009940357852882703 6.913737350659685
# balata 1 0.0009940357852882703 6.913737350659685
# a-akë-x-ín 1 0.0009940357852882703 6.913737350659685
# juan 1 0.0009940357852882703 6.913737350659685
# =mënë 1 0.0009940357852882703 6.913737350659685
# kuriki 1 0.0009940357852882703 6.913737350659685
# mëkama-iéé 1 0.0009940357852882703 6.913737350659685
# tsó-akë-x-a 1 0.0009940357852882703 6.913737350659685
# tsó-xun 1 0.0009940357852882703 6.913737350659685
# chaiti-baë 1 0.0009940357852882703 6.913737350659685
# no 1 0.0009940357852882703 6.913737350659685
# 'a-akë-x-a 1 0.0009940357852882703 6.913737350659685
# ñui-xun-kian 1 0.0009940357852882703 6.913737350659685
# 'atsa 1 0.0009940357852882703 6.913737350659685
# 'inan 1 0.0009940357852882703 6.913737350659685
# xubu' 1 0.0009940357852882703 6.913737350659685
# 'a-a-x-a 1 0.0009940357852882703 6.913737350659685
# munu 1 0.0009940357852882703 6.913737350659685
# imëshi 1 0.0009940357852882703 6.913737350659685
# mëkën 1 0.0009940357852882703 6.913737350659685
# ta-tani-katsi 1 0.0009940357852882703 6.913737350659685
# ki-xun 1 0.0009940357852882703 6.913737350659685
# rakan-bian-a-n 1 0.0009940357852882703 6.913737350659685
# tënka-këbë 1 0.0009940357852882703 6.913737350659685
# ëëëëëë 1 0.0009940357852882703 6.913737350659685
# ki-i 1 0.0009940357852882703 6.913737350659685
# bë-man-mët-akë-xín 1 0.0009940357852882703 6.913737350659685
# atsin-i-n 1 0.0009940357852882703 6.913737350659685
# y 1 0.0009940357852882703 6.913737350659685
# kaibu 1 0.0009940357852882703 6.913737350659685
# =ribi 1 0.0009940357852882703 6.913737350659685
# abat-a 1 0.0009940357852882703 6.913737350659685
# palcaso 1 0.0009940357852882703 6.913737350659685
# rëbúmi 1 0.0009940357852882703 6.913737350659685
# papa 1 0.0009940357852882703 6.913737350659685
# a-i 1 0.0009940357852882703 6.913737350659685
# tsót-i-n 1 0.0009940357852882703 6.913737350659685
# ka-i-n 1 0.0009940357852882703 6.913737350659685
# usa 1 0.0009940357852882703 6.913737350659685
# ‘isenaka 1 0.0009940357852882703 6.913737350659685
# rataxtamainun 1 0.0009940357852882703 6.913737350659685
# chëkiai 1 0.0009940357852882703 6.913737350659685
# usai 1 0.0009940357852882703 6.913737350659685
# ëo 1 0.0009940357852882703 6.913737350659685
# kamëokëxa 1 0.0009940357852882703 6.913737350659685
# chaitibaë 1 0.0009940357852882703 6.913737350659685
# xutabaë 1 0.0009940357852882703 6.913737350659685
# bu 1 0.0009940357852882703 6.913737350659685
# tsatsa 1 0.0009940357852882703 6.913737350659685
# ! 1 0.0009940357852882703 6.913737350659685
# kwëënin 1 0.0009940357852882703 6.913737350659685
# xarákë 1 0.0009940357852882703 6.913737350659685
# ësaokin 1 0.0009940357852882703 6.913737350659685
# mane 1 0.0009940357852882703 6.913737350659685
# toinkë 1 0.0009940357852882703 6.913737350659685
# ‘ixunmabi 1 0.0009940357852882703 6.913737350659685
# pui 1 0.0009940357852882703 6.913737350659685
# ‘axankëbë 1 0.0009940357852882703 6.913737350659685
# kwankëxa 1 0.0009940357852882703 6.913737350659685
# buankëxa 1 0.0009940357852882703 6.913737350659685
# rët-tankëxun 1 0.0009940357852882703 6.913737350659685
# rakan-akë-x-in 1 0.0009940357852882703 6.913737350659685
# xui 1 0.0009940357852882703 6.913737350659685
# ka-xun 1 0.0009940357852882703 6.913737350659685
# charu 1 0.0009940357852882703 6.913737350659685
# inan-akë-x-a 1 0.0009940357852882703 6.913737350659685
# a-kin 1 0.0009940357852882703 6.913737350659685
# a-i-n 1 0.0009940357852882703 6.913737350659685
# =këñun 1 0.0009940357852882703 6.913737350659685
# xëki 1 0.0009940357852882703 6.913737350659685
# cha 1 0.0009940357852882703 6.913737350659685
# a-akë-x-a 1 0.0009940357852882703 6.913737350659685
# desde 1 0.0009940357852882703 6.913737350659685
# tingo 1 0.0009940357852882703 6.913737350659685
# maría 1 0.0009940357852882703 6.913737350659685
# anu-xun 1 0.0009940357852882703 6.913737350659685
# hasta 1 0.0009940357852882703 6.913737350659685
# =miki 1 0.0009940357852882703 6.913737350659685
# e 1 0.0009940357852882703 6.913737350659685
# is-akë-x-a 1 0.0009940357852882703 6.913737350659685
# después 1 0.0009940357852882703 6.913737350659685
# historia 1 0.0009940357852882703 6.913737350659685
# a-tankëxun 1 0.0009940357852882703 6.913737350659685
# katsin 1 0.0009940357852882703 6.913737350659685
# xinkun 1 0.0009940357852882703 6.913737350659685
# ainbi 1 0.0009940357852882703 6.913737350659685
# bëná 1 0.0009940357852882703 6.913737350659685
# pia 1 0.0009940357852882703 6.913737350659685
# kanti 1 0.0009940357852882703 6.913737350659685
# rabin-i-a 1 0.0009940357852882703 6.913737350659685
# upit-o-kin 1 0.0009940357852882703 6.913737350659685
# nui-xun 1 0.0009940357852882703 6.913737350659685
# nits-kin-kin 1 0.0009940357852882703 6.913737350659685
# =kupí 1 0.0009940357852882703 6.913737350659685
# me 1 0.0009940357852882703 6.913737350659685
# chukúma 1 0.0009940357852882703 6.913737350659685
# bëxuñurá 1 0.0009940357852882703 6.913737350659685
# ‘ikë 1 0.0009940357852882703 6.913737350659685
# bënë 1 0.0009940357852882703 6.913737350659685
# ‘akë 1 0.0009940357852882703 6.913737350659685
# =sa 1 0.0009940357852882703 6.913737350659685
# okin 1 0.0009940357852882703 6.913737350659685
# maso 1 0.0009940357852882703 6.913737350659685
# uni-tín 1 0.0009940357852882703 6.913737350659685
# ratu-a-x-a 1 0.0009940357852882703 6.913737350659685
# churukukwainkin 1 0.0009940357852882703 6.913737350659685
# xënirá 1 0.0009940357852882703 6.913737350659685
# makwëxakëshín 1 0.0009940357852882703 6.913737350659685
# kwëëni 1 0.0009940357852882703 6.913737350659685
# ‘itankëxun 1 0.0009940357852882703 6.913737350659685
# kakëxa 1 0.0009940357852882703 6.913737350659685
# xëni 1 0.0009940357852882703 6.913737350659685
# ‘ati 1 0.0009940357852882703 6.913737350659685
# kupë 1 0.0009940357852882703 6.913737350659685
# bitstanmainun 1 0.0009940357852882703 6.913737350659685
# ënu 1 0.0009940357852882703 6.913737350659685
# tsót-a 1 0.0009940357852882703 6.913737350659685
# sino 1 0.0009940357852882703 6.913737350659685
# rima 1 0.0009940357852882703 6.913737350659685
# xëa-kë 1 0.0009940357852882703 6.913737350659685
# shipibo 1 0.0009940357852882703 6.913737350659685
# iken 1 0.0009940357852882703 6.913737350659685
# kwáxka-kë 1 0.0009940357852882703 6.913737350659685
# xanu-xun 1 0.0009940357852882703 6.913737350659685
# ‘atapa 1 0.0009940357852882703 6.913737350659685
# =pain 1 0.0009940357852882703 6.913737350659685
# ‘inan 1 0.0009940357852882703 6.913737350659685
# imëishi 1 0.0009940357852882703 6.913737350659685
# i 1 0.0009940357852882703 6.913737350659685
# atsin-mi-i-n 1 0.0009940357852882703 6.913737350659685
# më-atsin-mët-i-n 1 0.0009940357852882703 6.913737350659685
# uinbi 1 0.0009940357852882703 6.913737350659685
# xo 1 0.0009940357852882703 6.913737350659685
# rabé̈okë 1 0.0009940357852882703 6.913737350659685
# nunti 1 0.0009940357852882703 6.913737350659685
# kini-i-ín 1 0.0009940357852882703 6.913737350659685
# naë 1 0.0009940357852882703 6.913737350659685
# matat-i-ín 1 0.0009940357852882703 6.913737350659685
# linterna 1 0.0009940357852882703 6.913737350659685
# tirit-o-a-n 1 0.0009940357852882703 6.913737350659685
# imé̈ 1 0.0009940357852882703 6.913737350659685
# ‘i-këbëtan 1 0.0009940357852882703 6.913737350659685
# ‘a-akë-n 1 0.0009940357852882703 6.913737350659685
# xaiki-këbë 1 0.0009940357852882703 6.913737350659685
# emilionë 1 0.0009940357852882703 6.913737350659685
# xaika-këx 1 0.0009940357852882703 6.913737350659685
# chaxkë´ 1 0.0009940357852882703 6.913737350659685
# 'ati 1 0.0009940357852882703 6.913737350659685
# 'aaxa 1 0.0009940357852882703 6.913737350659685
# pabëntamëti 1 0.0009940357852882703 6.913737350659685
# pabí 1 0.0009940357852882703 6.913737350659685
# bëntamëti 1 0.0009940357852882703 6.913737350659685
# uinbirës 1 0.0009940357852882703 6.913737350659685
# comodiezaños 1 0.0009940357852882703 6.913737350659685
# aish 1 0.0009940357852882703 6.913737350659685
# tsókën 1 0.0009940357852882703 6.913737350659685
# santarosa 1 0.0009940357852882703 6.913737350659685
# tsipúmi 1 0.0009940357852882703 6.913737350659685
# 'ibu 1 0.0009940357852882703 6.913737350659685
# nai 1 0.0009940357852882703 6.913737350659685
# =ax 1 0.0009940357852882703 6.913737350659685
# uakëxa 1 0.0009940357852882703 6.913737350659685
# bari 1 0.0009940357852882703 6.913737350659685
# këntí 1 0.0009940357852882703 6.913737350659685
# ichútmiaxa 1 0.0009940357852882703 6.913737350659685
# uri 1 0.0009940357852882703 6.913737350659685
# xaë 1 0.0009940357852882703 6.913737350659685
# mëraxa 1 0.0009940357852882703 6.913737350659685
# anuxun 1 0.0009940357852882703 6.913737350659685
# bake 1 0.0009940357852882703 6.913737350659685
# ini 1 0.0009940357852882703 6.913737350659685
# 'óina 1 0.0009940357852882703 6.913737350659685
# chunena 1 0.0009940357852882703 6.913737350659685
# pitankëxun 1 0.0009940357852882703 6.913737350659685
# kaniotin 1 0.0009940357852882703 6.913737350659685
# kana 1 0.0009940357852882703 6.913737350659685
# xon 1 0.0009940357852882703 6.913737350659685
# tsipu 1 0.0009940357852882703 6.913737350659685
# bëtanitin 1 0.0009940357852882703 6.913737350659685
# monument 1 0.0009940357852882703 6.913737350659685
# =sapi 1 0.0009940357852882703 6.913737350659685
# unitín 1 0.0009940357852882703 6.913737350659685
# ratuaxa 1 0.0009940357852882703 6.913737350659685
# 'aishbi 1 0.0009940357852882703 6.913737350659685
# 'iakëxa 1 0.0009940357852882703 6.913737350659685
# chumíbukë 1 0.0009940357852882703 6.913737350659685
# bamati 1 0.0009940357852882703 6.913737350659685
# ura 1 0.0009940357852882703 6.913737350659685
# kwainkin 1 0.0009940357852882703 6.913737350659685
# =shi 1 0.0009940357852882703 6.913737350659685
# maë 1 0.0009940357852882703 6.913737350659685
# matsunkubuinia 1 0.0009940357852882703 6.913737350659685
# rëakëxa 1 0.0009940357852882703 6.913737350659685
# bëru-ax 1 0.0009940357852882703 6.913737350659685
# bëru-an 1 0.0009940357852882703 6.913737350659685
# ukairi 1 0.0009940357852882703 6.913737350659685
# tënka-pat-akë-x-ín 1 0.0009940357852882703 6.913737350659685
# u-but-kin 1 0.0009940357852882703 6.913737350659685
# is 1 0.0009940357852882703 6.913737350659685
# rët-uku-but-an 1 0.0009940357852882703 6.913737350659685
# chaxké 1 0.0009940357852882703 6.913737350659685
# ‘i-akë-x-a 1 0.0009940357852882703 6.913737350659685

# %%
fig, ax = plt.subplots(dpi=800)

plt.title('Probabilidad versus sorpresa corpus Kakataibo',fontsize=12)

ax.plot(X,Y,marker='D',color='fuchsia',markersize=3,markeredgewidth=0.5,markeredgecolor='k',alpha=0.75,linewidth=1,fillstyle='full')
    
#plt.grid(False)
#plt.legend(loc='best',fontsize=7)
plt.xlabel(r'probabilidad',fontsize=10)
plt.ylabel(r'sorpresa',fontsize=10)
plt.rcParams.update({'font.size': 10})
plt.savefig('PvsS.jpg', format='jpg', transparent=True, bbox_inches='tight',dpi=800)
plt.show()

# %%
entropia_kakataibo
# Out:
# 4.846325206854226

# %% [markdown]
# Construya un **diccionario {frecuencia:lista de types con esa frecuencia}** para cada frecuencia del corpus.

# %%
len(dict_frec_types)
# Out:
# 341

# %%
sum(dict_frec_types.values())
# Out:
# 1006

# %%
frecuencias = list(set(dict_frec_types.values()))

# %%
frecuencias
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 10, 12, 14, 16, 20, 21, 23, 28, 61, 71, 115]

# %%
D_frecuencias_lista = {}

for f in frecuencias:
    D_frecuencias_lista[f]=[]

# %%
for palabra in dict_frec_types.keys():
    frec = dict_frec_types[palabra]
    D_frecuencias_lista[frec]+=[palabra]

# %%
D_frecuencias_lista[3]
# Out:
# ['=bëtan',
#  '=ñu',
#  'a-ti',
#  "'ain",
#  'kwan-ti',
#  'ikën',
#  '‘anibu',
#  'an',
#  '‘aisama',
#  'kamabi',
#  'nëtë',
#  'upí',
#  'ñu',
#  'tanu',
#  'bai',
#  'hotel',
#  'xukën',
#  'u-i-a',
#  'papaokë',
#  '‘ó',
#  'piti']

# %% [markdown]
# Construya un **diccionario {frecuencia:número de veces que aparece esa frecuencia}** para cada frecuencia del corpus.

# %%
D_frec_numero = {}

for key in D_frecuencias_lista.keys():
    D_frec_numero[key]=len(D_frecuencias_lista[key])

# %%
D_frec_numero
# Out:
# {1: 202,
#  2: 74,
#  3: 21,
#  4: 12,
#  5: 5,
#  6: 5,
#  7: 6,
#  8: 2,
#  10: 3,
#  12: 1,
#  14: 1,
#  16: 1,
#  20: 1,
#  21: 2,
#  23: 1,
#  28: 1,
#  61: 1,
#  71: 1,
#  115: 1}

# %%
X = list(D_frec_numero.keys())
Y = list(D_frec_numero.values())

# %%
sum(X)
# Out:
# 427

# %%
fig, ax = plt.subplots(dpi=800)

plt.title('Frecuencia de aparición vs. número de types corpus Kakataibo',fontsize=9)
ax.plot(X,Y,marker='o',color='gold',markersize=3,markeredgewidth=0.5,markeredgecolor='k',alpha=0.75,linewidth=1,fillstyle='full')

#plt.grid(False)
#plt.legend(loc='best',fontsize=7)
plt.xlabel(r'frecuencia',fontsize=10)
plt.ylabel(r'número de types',fontsize=10)
plt.rcParams.update({'font.size': 10})
plt.savefig('frec_num.jpg', format='jpg', transparent=True, bbox_inches='tight',dpi=800)
plt.show()

# %% [markdown]
# Suponga que el número de tokens es $n$. Si las palabras sucesivas están numeradas desde la palabra 1, luego 2, hasta la palabra $n$, la **distancia** entre dos palabras en posiciones $i$ y $j$ se define como $|i-j|$.

# %% [markdown]
# Para una oración, calcule las distancias entre **cada token** y la **raiz (head)**. Identifique primero la posición de **head**.

# %%
oracion = kakataibo[6]

# %%
oracion
# Out:
# TokenList<'Ë, ka, 'atsa, 'inan, .>

# %%
token = oracion[2]

# %%
token
# Out:
# {'id': 3,
#  'form': "'atsa",
#  'lemma': '_',
#  'upos': 'NOUN',
#  'xpos': None,
#  'feats': None,
#  'head': 4,
#  'deprel': 'obl',
#  'deps': None,
#  'misc': {'manioc:ABS': ''}}

# %%
def head_oracion(oracion):
    
    for token in oracion:
        if token['head']==0 or token['head']==None:
            head_id = token['id']
            
    return head_id

# %%
head_id = head_oracion(oracion)

# %%
import numpy as np

distancias_head = []

for token in oracion:
    distancia = np.abs(token['id']-head_id)
    distancias_head+=[distancia]

# %%
distancias_head
# Out:
# [3, 2, 1, 0, 1]

# %%
import numpy as np

def distancias_head(oracion):
    
    head_id = head_oracion(oracion)
    distancias_head = []

    for token in oracion:
        distancia = np.abs(token['id']-head_id)
        distancias_head+=[distancia]
    return np.mean(distancias_head),np.max(distancias_head)

# %%
distancias_head(oracion)
# Out:
# (1.4, 3)

# %%
for token in oracion:
    print(token['form'],token['id'],token['head'])
# Out:
# 'Ë 1 4
# ka 2 4
# 'atsa 3 4
# 'inan 4 0
# . 5 4

# %%
import numpy as np
largos = []

for d in kakataibo[0]:
    largos += [np.abs(d['id']-d['head'])]

# %%
np.mean(largos)
# Out:
# 2.7142857142857144

# %% [markdown]
# Calcule el **largo de dependencias** **promedio**, **máximo** y **mínimo**.

# %% [markdown]
# [Paper :)](liu-dependencies-2017.pdf)

# %% [markdown]
# [otro paper :)](W19-7911.pdf)

# %% [markdown]
# Desordene **aleatoriamente las dependencias de las oraciones.** Use

# %%
import random

A = [1,2,3]

A_random = random.sample(A,len(A))

# %%
A_random
# Out:
# [1, 2, 3]

# %% [markdown]
# Cree 100 versiones aleatorias de las dependencias de una oración. Guárdelas en una lista.
