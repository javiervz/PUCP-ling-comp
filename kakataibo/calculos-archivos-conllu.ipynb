# %% [markdown]
# ## Universal dependencies en **Kakataibo!**

# %%
#!pip install conllu

# %% [markdown]
# ## Leemos todos los archivos conllu de la carpeta archivos-conllu

# %%
import glob as glob

conllu_archivos = glob.glob('archivos-conllu/*.conllu')

# %%
conllu_archivos
# Out:
# ['archivos-conllu\\1005(1) - Sabina (v).conllu',
#  'archivos-conllu\\1005(6) - Sabina -- ud-sabina-3.conllu',
#  'archivos-conllu\\174-ud-annotatrix-corpus.conllu',
#  'archivos-conllu\\175-1-ud-annotatrix-corpus.conllu',
#  'archivos-conllu\\175-2-ud-annotatrix-corpus.conllu',
#  'archivos-conllu\\178-ud-annotatrix-corpus.conllu',
#  'archivos-conllu\\180-ud-annotatrix-corpus.conllu',
#  'archivos-conllu\\189-a-ud-annotatrix-corpus.conllu',
#  'archivos-conllu\\189a-ud-annotatrix-corpus.conllu',
#  'archivos-conllu\\199-ud-annotatrix-corpus.conllu',
#  'archivos-conllu\\200-ud-annotatrix-corpus.conllu',
#  'archivos-conllu\\203-ud-annotatrix-corpus.conllu',
#  'archivos-conllu\\211-ud-annotatrix-corpus.conllu',
#  'archivos-conllu\\222a-ud-annotatrix-corpus.conllu',
#  'archivos-conllu\\222b-ud-annotatrix-corpus.conllu',
#  'archivos-conllu\\225-ud-annotatrix-corpus.conllu',
#  'archivos-conllu\\226-ud-annotatrix-corpus.conllu',
#  'archivos-conllu\\232-ud-annotatrix-corpus.conllu',
#  'archivos-conllu\\248 - 343 - Sabina (v).conllu',
#  'archivos-conllu\\315.conllu',
#  'archivos-conllu\\316.conllu',
#  'archivos-conllu\\319.conllu',
#  'archivos-conllu\\320.conllu',
#  'archivos-conllu\\330.conllu',
#  'archivos-conllu\\331.conllu',
#  'archivos-conllu\\332.conllu',
#  'archivos-conllu\\333-ud-annotatrix-corpus.conllu',
#  'archivos-conllu\\334.conllu',
#  'archivos-conllu\\335-ud-annotatrix-corpus.conllu',
#  'archivos-conllu\\337.conllu',
#  'archivos-conllu\\338.conllu',
#  'archivos-conllu\\339.conllu',
#  'archivos-conllu\\340.conllu',
#  'archivos-conllu\\348 - Sabina (v).conllu',
#  'archivos-conllu\\357 - Sabina (v).conllu',
#  'archivos-conllu\\361 - Sabina (v).conllu',
#  'archivos-conllu\\366 - Sabina (v).conllu',
#  'archivos-conllu\\369 - Sabina (v).conllu',
#  'archivos-conllu\\379 - Sabina (v).conllu',
#  'archivos-conllu\\388 - Sabina (v)--ud-sabina-2.conllu',
#  'archivos-conllu\\389 - Sabina (v).conllu',
#  'archivos-conllu\\390 - Sabina (v).conllu',
#  'archivos-conllu\\391 - Sabina (v).conllu',
#  'archivos-conllu\\393 - Sabina (v).conllu',
#  'archivos-conllu\\395 - Sabina (v).conllu',
#  'archivos-conllu\\397 - Sabina (v).conllu',
#  'archivos-conllu\\401 - Sabina (v)--ud-sabina-1.conllu',
#  'archivos-conllu\\405.conllu',
#  'archivos-conllu\\408 - Sabina (v).conllu',
#  'archivos-conllu\\460-ud-annotatrix-corpus.conllu',
#  'archivos-conllu\\471.conllu',
#  'archivos-conllu\\509.conllu',
#  'archivos-conllu\\517.conllu',
#  'archivos-conllu\\518.conllu',
#  'archivos-conllu\\799.conllu',
#  'archivos-conllu\\976-ud-annotatrix-corpus.conllu',
#  'archivos-conllu\\977a - Sabina (v).conllu',
#  'archivos-conllu\\977b - Sabina (v).conllu',
#  'archivos-conllu\\s201.conllu',
#  'archivos-conllu\\s202.conllu',
#  'archivos-conllu\\s206.conllu',
#  'archivos-conllu\\s210.conllu',
#  'archivos-conllu\\s233.conllu',
#  'archivos-conllu\\s234.conllu',
#  'archivos-conllu\\s243.conllu',
#  'archivos-conllu\\s264(1).conllu',
#  'archivos-conllu\\s264(2).conllu',
#  'archivos-conllu\\s265(2).conllu',
#  'archivos-conllu\\s271(a).conllu',
#  'archivos-conllu\\s286(3).conllu',
#  'archivos-conllu\\s299.conllu',
#  'archivos-conllu\\s301.conllu',
#  'archivos-conllu\\s302.conllu',
#  'archivos-conllu\\s310.conllu',
#  'archivos-conllu\\s370.conllu',
#  'archivos-conllu\\s445.conllu',
#  'archivos-conllu\\ud-annotatrix-(204)-Rosa Gonzales.conllu',
#  'archivos-conllu\\ud-annotatrix-(209)-Rosa Gonzales.conllu',
#  'archivos-conllu\\ud-annotatrix-(214)-Rosa Gonzales.conllu',
#  'archivos-conllu\\ud-annotatrix-(227)-Rosa Gonzales.conllu',
#  'archivos-conllu\\ud-annotatrix-(228)-Rosa Gonzales.conllu',
#  'archivos-conllu\\ud-annotatrix-(241)-Rosa Gonzales.conllu',
#  'archivos-conllu\\ud-annotatrix-(247)-Rosa Gonzales.conllu',
#  'archivos-conllu\\ud-annotatrix-(255)-Rosa Gonzales.conllu',
#  'archivos-conllu\\ud-annotatrix-(263)-Rosa Gonzales.conllu',
#  'archivos-conllu\\ud-annotatrix-(270)-Rosa Gonzales.conllu',
#  'archivos-conllu\\ud-annotatrix-(285)-Rosa Gonzales.conllu',
#  'archivos-conllu\\ud-annotatrix-(318)-Rosa Gonzales.conllu',
#  'archivos-conllu\\ud-annotatrix-(341)-Rosa Gonzales.conllu',
#  'archivos-conllu\\ud-annotatrix-(363)-Rosa Gonzales.conllu',
#  'archivos-conllu\\ud-annotatrix-(407)-Rosa Gonzales.conllu',
#  'archivos-conllu\\ud-annotatrix-(490)-Rosa Gonzales.conllu',
#  'archivos-conllu\\ud-annotatrix-(508)-Rosa Gonzales.conllu',
#  'archivos-conllu\\ud-annotatrix-(515)-Rosa Gonzales.conllu',
#  'archivos-conllu\\ud-claudia-1.conllu',
#  'archivos-conllu\\ud-claudia-2.conllu',
#  'archivos-conllu\\ud-claudia-3.conllu',
#  'archivos-conllu\\ud-luisa-s370.conllu',
#  'archivos-conllu\\ud-luisa-s445.conllu',
#  'archivos-conllu\\ud-luisa-s476.conllu',
#  'archivos-conllu\\ud-mariana-333.conllu',
#  'archivos-conllu\\ud-mariana-335.conllu',
#  'archivos-conllu\\ud-mariana-460.conllu',
#  'archivos-conllu\\ud-rosa-1.conllu',
#  'archivos-conllu\\ud-rosa-2.conllu',
#  'archivos-conllu\\ud-rosa-3.conllu',
#  'archivos-conllu\\ud-sabina-1.conllu',
#  'archivos-conllu\\ud-sabina-2.conllu',
#  'archivos-conllu\\ud-sabina-3.conllu']

# %%
kakataibo = []

# %%
from conllu import parse

for file in conllu_archivos:
    try:
        data_k = open('archivos-conllu/'+file.split('\\')[1] , "r", encoding="utf-8")
        print(data_k)
        data = data_k.read()
        kakataibo += parse(data)
        print(data_k,data)
    except Exception as inst:
        print(file)
        pass
# Out:
# <_io.TextIOWrapper name='archivos-conllu/1005(1) - Sabina (v).conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/1005(1) - Sabina (v).conllu' mode='r' encoding='utf-8'> 1	patron	_	NOUN	_	_	6	obl	_	boss
# 2	=bëtan	_	PART	_	_	1	case	_	=COM
# 3	ka	_	PART	_	_	6	aux:sgen	_	NAR
# 4	=a	_	PART	_	_	6	nsubj	_	:3
# 5	balata	_	NOUN	_	_	6	obj	_	rubber.latex
# 6	a-akë-x-ín	_	VERB	_	_	0	root	_	do-REM.PST-3-PROX
# 7	.	_	PUNCT	_	_	6	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/1005(6) - Sabina -- ud-sabina-3.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/1005(6) - Sabina -- ud-sabina-3.conllu' mode='r' encoding='utf-8'> 1	maru-kin	_	VERB	_	_	3	advcl	_	sell-s/a>a:se
# 2	no-n	_	ADJ	_	_	3	nsubj:free	_	non.indigenous-erg
# 3	buan-akë-x-ín	_	VERB	_	_	0	root	_	take-rem.pas-3-non.prox
# 4	.	_	PUNCT	_	_	3	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/174-ud-annotatrix-corpus.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/174-ud-annotatrix-corpus.conllu' mode='r' encoding='utf-8'> 1	Juan	_	PROPN	_	_	7	nsubj	_	Juan
# 2	ka	_	PART	_	_	7	nsubj	_	NAR:3
# 3	=mënë	_	PART	_	_	7	nsubj	_	=MIR
# 4	mi	_	PRON	_	_	6	nmod	_	2SG
# 5	=n	_	PART	_	_	4	case	_	=GEN
# 6	kuriki	_	NOUN	_	_	7	aux:sgen	_	money:ABS
# 7	mëkama-iéé	_	VERB	_	_	0	root	_	steal-3.accusatory
# 8	.	_	PUNCT	_	_	7	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/175-1-ud-annotatrix-corpus.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/175-1-ud-annotatrix-corpus.conllu' mode='r' encoding='utf-8'> 1	Nukën	_	PRON	_	_	2	nmod	_	1pl:gen
# 2	chaiti	_	NOUN	_	_	6	nsubj:free	_	ancestor:abs
# 3	ka	_	PART	_	_	6	aux:sgen	_	nar
# 4	=is	_	PART	_	_	6	aux:ev	_	=rep
# 5	=a	_	PART	_	_	6	nsubj	_	=3
# 6	tsó-akë-x-a	_	VERB	_	_	0	root	_	live-rem.pst-3-non.prox
# 7	norte	_	NOUN	_	_	6	obl	_	North
# 8	=nu	_	PART	_	_	7	case	_	=loc
# 9	.	_	PUNCT	_	_	6	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/175-2-ud-annotatrix-corpus.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/175-2-ud-annotatrix-corpus.conllu' mode='r' encoding='utf-8'> 1	Norte	_	NOUN	_	_	16	obl	_	North
# 2	=nu	_	PART	_	_	1	case	_	=loc
# 3	tsó-xun	_	VERB	_	_	16	advcl	_	live-S/A>A:SE
# 4	ka	_	PART	_	_	16	aux:sgen	_	NAR
# 5	=is	_	PART	_	_	16	aux:ev	_	=REP
# 6	=a	_	PART	_	_	16	nsubj	_	=3
# 7	nukën	_	PRON	_	_	8	nmod	_	1pl.gen
# 8	chaiti-baë	_	NOUN	_	_	16	nsubj:free	_	ancestor-COL
# 9	=n	_	PART	_	_	8	case	_	=ERG
# 10	uni	_	NOUN	_	_	16	obl	_	people
# 11	=ñu	_	PART	_	_	10	case	_	=PROP
# 12	=ma	_	PART	_	_	10	nmod	_	=NEG
# 13	no	_	ADJ	_	_	16	obl	_	foreign
# 14	=ñu	_	PART	_	_	13	case	_	=PROP
# 15	=ma	_	PART	_	_	13	nmod	_	=NEG
# 16	'a-akë-x-a	_	VERB	_	_	0	root	_	do-REM.PST-3-NON.PROX
# 17	.	_	PUNCT	_	_	16	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/178-ud-annotatrix-corpus.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/178-ud-annotatrix-corpus.conllu' mode='r' encoding='utf-8'> 1	Nukën	_	PRON	_	_	2	nmod	_	1PL.GEN
# 2	chaiti	_	NOUN	_	_	7	nsubj:free	_	ancestor
# 3	=n	_	PART	_	_	2	case	_	=ERG
# 4	ka	_	PART	_	_	7	aux:sgen	_	NAR:3
# 5	=a	_	PART	_	_	7	nsubj	_	_
# 6	bana	_	NOUN	_	_	7	obl	_	tale:ABS
# 7	ñui-xun-kian	_	VERB	_	_	0	root	_	say-BEN-REM.PST.HAB.3
# 8	.	_	PUNCT	_	_	7	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/180-ud-annotatrix-corpus.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/180-ud-annotatrix-corpus.conllu' mode='r' encoding='utf-8'> 1	'Ë	_	PRON	_	_	4	nsubj	_	1SG:P
# 2	ka	_	PART	_	_	4	aux:sgen	_	NAR
# 3	'atsa	_	NOUN	_	_	4	obl	_	manioc:ABS
# 4	'inan	_	VERB	_	_	0	root	_	give:IMP
# 5	.	_	PUNCT	_	_	4	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/189-a-ud-annotatrix-corpus.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/189-a-ud-annotatrix-corpus.conllu' mode='r' encoding='utf-8'> 1	Nukën	_	PRON	_	_	2	nmod	_	1PL.GEN
# 2	chaiti	_	NOUN	_	_	9	nsubj:free	_	ancestor
# 3	=n	_	PART	_	_	2	case	_	=ERG
# 4	ka	_	PART	_	_	9	aux:gen	_	NAR
# 5	=is	_	PART	_	_	9	aux:ev	_	=REP
# 6	=a	_	PART	_	_	9	nsubj	_	=3
# 7	'ó	_	NOUN	_	_	8	nmod	_	tapir
# 8	nami	_	NOUN	_	_	9	obl	_	meat:ABS
# 9	pi-akë-x-a	_	VERB	_	_	0	root	_	eat-REM.PST-3-NON.PROX
# 10	.	_	PUNCT	_	_	9	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/189a-ud-annotatrix-corpus.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/189a-ud-annotatrix-corpus.conllu' mode='r' encoding='utf-8'> 1	Nukën	_	PRON	_	_	2	nmod	_	1PL.GEN
# 2	chaiti	_	NOUN	_	_	9	nsubj:free	_	ancestor
# 3	=n	_	PART	_	_	2	case	_	=ERG
# 4	ka	_	PART	_	_	9	aux:gen	_	NAR
# 5	=is	_	PART	_	_	9	aux:ev	_	=REP
# 6	=a	_	PART	_	_	9	nsubj	_	=3
# 7	'ó	_	NOUN	_	_	8	nmod	_	tapir
# 8	nami	_	NOUN	_	_	9	obl	_	meat:ABS
# 9	pi-akë-x-a	_	VERB	_	_	0	root	_	eat-REM.PST-3-NON.PROX
# 10	.	_	PUNCT	_	_	9	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/199-ud-annotatrix-corpus.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/199-ud-annotatrix-corpus.conllu' mode='r' encoding='utf-8'> # sent_id = _
# # text = Achushi uni chaxkë =bëtan ka =na 'ë =n xubu' a-ti 'ain .
# 1	Achushi	_	NUM	_	_	2	nummod	_	one
# 2	uni	_	NOUN	_	_	10	obl	_	man
# 3	chaxkë	_	ADJ	_	_	2	amod	_	big
# 4	=bëtan	_	PART	_	_	3	case	_	=COM:A
# 5	ka	_	PART	_	_	10	aux:sgen	_	NAR
# 6	=na	_	PART	_	_	10	nsubj	_	=1SG
# 7	'ë	_	PRON	_	_	10	nsubj:free	_	1SG
# 8	=n	_	PART	_	_	7	case	_	=GEN
# 9	xubu'	_	NOUN	_	_	10	obl	_	house:ABS
# 10	a-ti	_	VERB	_	_	0	root	_	do-NMLZ
# 11	'ain	_	AUX	_	_	10	aux	_	be:1/2
# 12	.	_	PUNCT	_	_	10	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/200-ud-annotatrix-corpus.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/200-ud-annotatrix-corpus.conllu' mode='r' encoding='utf-8'> 1	Uni	_	NOUN	_	_	9	nsubj:free	_	man
# 2	=n	_	PART	_	_	1	case	_	=ERG
# 3	ka	_	PART	_	_	9	aux:sgen	_	NAR:3
# 4	=a	_	PART	_	_	9	nsubj	_	_
# 5	baka	_	NOUN	_	_	9	obl	_	river
# 6	=nu	_	PART	_	_	5	case	_	=LOC
# 7	=xun	_	PART	_	_	1	case	_	=PA.A
# 8	chaxu	_	NOUN	_	_	9	obj	_	deer:ABS
# 9	'a-a-x-a	_	VERB	_	_	0	root	_	kill-PFV-3-NON.PROX
# 10	.	_	PUNCT	_	_	9	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/203-ud-annotatrix-corpus.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/203-ud-annotatrix-corpus.conllu' mode='r' encoding='utf-8'> 1	Munu	_	ADV	_	_	5	advmod	_	slowly
# 2	=ishi	_	PART	_	_	1	advmod	_	=only
# 3	ka	_	PART	_	_	5	aux:sgen	_	NAR
# 4	=mina	_	PART	_	_	5	nsubj	_	=2
# 5	pi-ti	_	VERB	_	_	0	root	_	eat-NOMLZ
# 6	'ain	_	AUX	_	_	5	aux	_	be:1/2
# 7	.	_	PUNCT	_	_	6	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/211-ud-annotatrix-corpus.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/211-ud-annotatrix-corpus.conllu' mode='r' encoding='utf-8'> 1	Aguaytia	_	PRON	_	_	6	obl	_	Aguaytía
# 2	=nu	_	PART	_	_	1	case	_	=DIR
# 3	ka	_	PART	_	_	6	aux:sgen	_	NAR
# 4	=na	_	PART	_	_	6	nsubj	_	=1SG
# 5	imëshi	_	NOUN	_	_	6	advmod	_	tomorrow
# 6	kwan-ti	_	VERB	_	_	0	root	_	go-NOMLZ
# 7	ain	_	AUX	_	_	6	aux	_	be:1/2
# 8	.	_	PUNCT	_	_	6	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/222a-ud-annotatrix-corpus.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/222a-ud-annotatrix-corpus.conllu' mode='r' encoding='utf-8'> 1	Roberto	_	PROPN	_	_	5	nsubj:free	_	Roberto
# 2	ka	_	PART	_	_	5	aux:sgen	_	NAR
# 3	=a	_	PART	_	_	5	nsubj	_	_
# 4	më-uxu	_	NOUN	_	_	5	nmod	_	hand-white
# 5	'ikën	_	VERB	_	_	0	root	_	be:3
# 6	.	_	PUNCT	_	_	5	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/222b-ud-annotatrix-corpus.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/222b-ud-annotatrix-corpus.conllu' mode='r' encoding='utf-8'> 1	Roberto	_	PROPN	_	_	7	nsubj:free	_	Roberto
# 2	ka	_	PART	_	_	7	aux:sgen	_	NAR:3
# 3	=a	_	PART	_	_	7	nsubj	_	_
# 4	mëkën	_	NOUN	_	_	7	obl	_	hand
# 5	=nu	_	PART	_	_	4	case	_	=LOC
# 6	më-uxu	_	NOUN	_	_	7	nmod	_	hand-white
# 7	'ikën	_	VERB	_	_	0	root	_	be:3
# 8	.	_	PUNCT	_	_	7	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/225-ud-annotatrix-corpus.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/225-ud-annotatrix-corpus.conllu' mode='r' encoding='utf-8'> 1	Ta-tani-katsi	_	VERB	_	_	2	parataxis	_	foot-tie-pretending
# 2	ki-xun	_	_	VERB	_	3	advcl	_	say:INTR-S/A>A:SE
# 3	rakan-bian-a-n	_	VERB	_	_	0	root	_	lay.down-going:TRAN-PFV-1/2
# 4	.	_	PUNCT	_	_	3	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/226-ud-annotatrix-corpus.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/226-ud-annotatrix-corpus.conllu' mode='r' encoding='utf-8'> 1	Tënka-këbë	_	VERB	_	_	8	advcl	_	cut-when:DS/A/P:INTR
# 2	ka	_	PART	_	_	8	aux:sgen	_	NAR
# 3	=is	_	PART	_	_	8	aux:ev	_	REP
# 4	=a	_	PART	_	_	8	nsubj	_	3
# 5	uni	_	NOUN	_	_	8	nsubj:free	_	person:ABS
# 6	ëëëëëë	_	INTJ	_	_	8	parataxis	_	ëëëëë
# 7	ki-i	_	VERB	_	_	8	advcl	_	say:INTR-S/A>S:SE
# 8	bë-man-mët-akë-xín	_	VERB	_	_	0	root	_	eyes-touch-REFL-REM.PST-3-PROX
# 9	.	_	PUNCT	_	_	8	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/232-ud-annotatrix-corpus.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/232-ud-annotatrix-corpus.conllu' mode='r' encoding='utf-8'> 1	Ë	_	PRON	_	_	7	nsubj:free	_	1SG
# 2	=x	_	PART	_	_	1	case	_	=S
# 3	ka	_	PART	_	_	7	aux:sgen	_	NAR
# 4	=na	_	PART	_	_	7	nsubj	_	=1SG
# 5	xubu	_	NOUN	_	_	7	obl	_	house
# 6	=nu	_	PART	_	_	5	case	_	=LOC
# 7	atsin-i-n	_	VERB	_	_	0	root	_	enter-IPFV-1/2
# 8	.	_	PUNCT	_	_	7	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/248 - 343 - Sabina (v).conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/248 - 343 - Sabina (v).conllu' mode='r' encoding='utf-8'> 1	y	_	CCONJ	_	_	8	conj	8:conj	and
# 2	a	_	SCONJ	_	_	3	det	3:det	that
# 3	kaibu	_	NOUN	_	_	_	_	_	relative:ABS
# 4	=ribi	_	PART	_	_	3	advmod	3:advmod	=also
# 5	abat-a	_	NOUN	_	_	3	advmod	3:advmod	escape-NOMLZ
# 6	ka	_	PART	_	_	8	aux:sgen	8:aux:sgen	NAR
# 7	=a	_	PART	_	_	8	nsubj	8:nsubj	:3
# 8	ikën	_	VERB	_	_	0	root	0:root	be:3
# 9	bëtsi	_	NOUN	_	_	8	advmod	8:advmod	other
# 10	Palcaso	_	PROPN	_	_	11	nmod	11:nmod	Palcaso river
# 11	rëbúmi	_	ADP	_	_	8	advmod	8:advmod	beyond
# 12	.	_	PUNCT	_	_	8	punct	8:punct	_
#
# 1	nukën	_	DET	_	_	2	nmod	2:nmod	1PL.GEN
# 2	papa	_	NOUN	_	_	4	nmod	4:nmod	father
# 3	=n	_	PART	_	_	2	case	2:case	=GEN
# 4	bana	_	NOUN	_	_	7	nsubj	7:nsubj	tale:ABS
# 5	=ishi	_	PART	_	_	4	advmod	4:advmod	=only
# 6	a-i	_	VERB	_	_	7	advcl	7:advcl	do-S/A>S:SE
# 7	tsót-i-n	_	VERB	_	_	12	parataxis	12:parataxis	live-IPFV-1/2
# 8	a	_	PRON	_	_	12	obj	12:obj	that
# 9	=ishi	_	PART	_	_	8	advmod	8:advmod	=only
# 10	ka	_	PART	_	_	12	aux:sgen	12:aux:sgen	NAR
# 11	=na	_	PART	_	_	12	nsubj	12:nsubj	=1SG
# 12	ka-i-n	_	VERB	_	_	0	root	0:root	say-IPFV-1/2
# 13	.	_	PUNCT	_	_	12	punct	12:punct	_
# <_io.TextIOWrapper name='archivos-conllu/315.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/315.conllu' mode='r' encoding='utf-8'> 1	Xanu	Xanu	_	NOUN	_	6	nsubj:free	_	_
# 2	 =n	 =n	_	PART	_	1	case	_	_
# 3	ka	ka	_	AUX	_	6	aux:sgen	_	_
# 4	=is	=is	_	AUX	_	6	aux:evid	_	_
# 5	=a	=a	_	DET	_	6	nsubj:bound	_	_
# 6	buankian	buankian	_	VERB	_	0	root	_	_
# 7	ain	ain	_	DET	_	8	nmod	_	_
# 8	bënë	bënë	_	NOUN	_	6	obj	_	_
# 9	“	“	_	PUNCT	_	6	punct	_	_
# 10	unirá	unirá	_	NOUN	_	11	nsubj:free	_	_
# 11	ka	ka	_	AUX	_	6	parataxis	_	_
# 12	”	”	_	PUNCT	_	6	punct	_	_
# 13	.	.	_	PUNCT	_	6	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/316.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/316.conllu' mode='r' encoding='utf-8'> 1	“	_	PUNCT	_	_	15	punct	_	_
# 2	Min	_	DET	_	_	3	nmod	_	_
# 3	bënë	_	NOUN	_	_	4	obj	_	_
# 4	‘atankëxun	_	ADV	_	_	10	advcl	_	_
# 5	ka	_	AUX	_	_	10	aux:sgen	_	_
# 6	‘ëribi	_	NOUN	_	_	10	obj	_	_
# 7	min	_	DET	_	_	8	nmod	_	_
# 8	maëxratsukun	_	NOUN	_	_	10	obl	_	_
# 9	‘ë	_	PRON	_	_	10	obj	_	_
# 10	‘a	_	VERB	_	_	15	parataxis	_	_
# 11	”	_	PUNCT	_	_	15	punct	_	_
# 12	ka	_	AUX	_	_	15	aux:sgen	_	_
# 13	=is	_	AUX	_	_	15	aux:ev	_	_
# 14	=a	_	DET	_	_	15	nsubj:bound	_	_
# 15	kakëshín	_	VERB	_	_	0	root	_	_
# 16	.	_	PUNCT	_	_	15	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/319.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/319.conllu' mode='r' encoding='utf-8'> 1	Usa	_	ADV	_	_	6	advmod	_	_
# 2	=bi	_	PART	_	_	6	aux:sgen	_	_
# 3	ka	_	AUX	_	_	_	_	_	_
# 4	‘isenaka	_	NOUN	_	_	6	nsubj:bound	_	_
# 5	=n	_	PART	_	_	4	case	_	_
# 6	rataxtamainun	_	VERB	_	_	0	root	_	_
# 7	chëkiai	_	ADV	_	_	_	_	_	_
# 8	.	_	PUNCT	_	_	6	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/320.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/320.conllu' mode='r' encoding='utf-8'> 1	Usai	_	ADV	_	_	5	advmod	_	_
# 2	ka	_	AUX	_	_	5	aux:sgen	_	_
# 3	=a	_	PART	_	_	5	nsubj:bound	_	_
# 4	ëo	_	ADJ	_	_	_	_	_	_
# 5	kamëokëxa	_	VERB	_	_	0	root	_	_
# 6	nu	_	PRON	_	_	8	nmod	_	_
# 7	=n	_	PART	_	_	6	case	_	_
# 8	‘anibu	_	NOUN	_	_	5	obj	_	_
# 9	nukën	_	PRON	_	_	10	nmod	_	_
# 10	chaitibaë	_	NOUN	_	_	5	nmod	_	_
# 11	=n	_	PART	_	_	10	case	_	_
# 12	nukën	_	PRON	_	_	13	nmod	_	_
# 13	xutabaë	_	NOUN	_	_	5	nmod	_	_
# 14	=n	_	PART	_	_	13	case	_	_
# 15	.	_	PUNCT	_	_	5	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/330.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/330.conllu' mode='r' encoding='utf-8'> 1	‘Ë	_	NOUN	_	_	11	nsubj:free	_	_
# 2	=n	_	PART	_	_	1	case	_	_
# 3	ka	_	AUX	_	_	10	aux:sgen	_	_
# 4	=na	_	PART	_	_	10	nsubj:bound	_	_
# 5	ënë	_	PRON	_	_	8	det	_	_
# 6	an	_	PART	_	_	8	compound	_	_
# 7	taë	_	PART	_	_	8	compound	_	_
# 8	tëbiskati	_	NOUN	_	_	_	_	_	_
# 9	bu	_	VERB	_	_	0	root	_	_
# 10	=a	_	DET	_	_	_	_	_	_
# 11	=n	_	PART	_	_	_	_	_	_
# 12	.	_	PUNCT	_	_	9	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/331.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/331.conllu' mode='r' encoding='utf-8'> 1	An	_	PART	_	_	3	compound	_	_
# 2	taë	_	PART	_	_	3	compound	_	_
# 3	tëbiskati	_	NOUN	_	_	7	nsubj:free	_	_
# 4	ka	_	AUX	_	_	7	aux:sgen	_	_
# 5	=n	_	PART	_	_	7	nsubj	_	_
# 6	‘aisama	_	ADJ	_	_	7	amod	_	_
# 7	‘ikën	_	VERB	_	_	0	root	_	_
# 8	.	_	PUNCT	_	_	7	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/332.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/332.conllu' mode='r' encoding='utf-8'> 1	Tsatsa	_	NOUN	_	_	4	obj	_	_
# 2	ënë	_	PRON	_	_	1	det	_	_
# 3	ka	_	AUX	_	_	4	aux:sgen	_	_
# 4	bëruan	_	VERB	_	_	0	root	_	_
# 5	!	_	PUNCT	_	_	4	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/333-ud-annotatrix-corpus.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/333-ud-annotatrix-corpus.conllu' mode='r' encoding='utf-8'> 1	atian	_	ADV	_	_	11	discourse	_	then
# 2	casi	_	ADV	_	_	3	advmod	_	almost
# 3	kamabi	_	DET	_	_	4	nummod	_	every
# 4	nëtë	_	NOUN	_	_	11	advmod	_	day
# 5	=n	_	PART	_	_	4	case	_	=temp
# 6	ka	_	PART	_	_	11	aux:sgen	_	nar
# 7	=is	_	PART	_	_	11	aux:evi	_	=rep
# 8	=a	_	PART	_	_	11	nsubj:bound	_	=3
# 9	a	_	DET	_	_	10	det	_	that
# 10	uni	_	NOUN	_	_	11	nsubj	_	person:abs
# 11	kwan-akë-x-ín	_	VERB	_	_	0	root	_	go-rem.pst-3-prox
# 12	.	_	PUNCT	_	_	11	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/334.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/334.conllu' mode='r' encoding='utf-8'> 1	Upí	_	ADJ	_	_	2	amod	_	_
# 2	ñu	_	NOUN	_	_	5	obj	_	_
# 3	ka	_	AUX	_	_	5	aux:sgen	_	_
# 4	=na	_	PART	_	_	5	nsubj:bound	_	_
# 5	kwëënin	_	VERB	_	_	0	root	_	_
# 6	.	_	PUNCT	_	_	5	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/335-ud-annotatrix-corpus.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/335-ud-annotatrix-corpus.conllu' mode='r' encoding='utf-8'> 1	ka	_	PART	_	_	11	aux:sgen	11:aux:sgen	nar
# 2	=nanuna	_	PART	_	_	11	nsubj:bound	11:nsubj:bound	=1pl
# 3	toxama	_	NOUN	_	_	5	obj	5:obj	tree.sp.
# 4	upí	_	ADJ	_	_	3	amod	3:amod	beautiful:abs
# 5	bits-tankëxun	_	VERB	_	_	11	advcl	11:advcl	pick.up-s/a>a:pe
# 6	taish	_	NOUN	_	_	8	obj	8:obj	tree.sp.
# 7	a	_	DET	_	_	6	det	6:det	3sg:p
# 8	bits-tankëxun	_	VERB	_	_	11	advcl	11:advcl	buy-s/a>a:pe
# 9	ka	_	PART	_	_	11	aux:sgen	11:aux:sgen	nar
# 10	=nanuna	_	PART	_	_	11	nsubj:bound	11:nsubj:bound	=1pl
# 11	‘aru-i-n	_	VERB	_	_	0	root	0:root	cook-ipfv-½
# 12	.	_	PUNCT	_	_	11	punct	11:punct	_
# <_io.TextIOWrapper name='archivos-conllu/337.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/337.conllu' mode='r' encoding='utf-8'> 1	Ka	_	PRON	_	_	5	nsubj:free	_	_
# 2	=n	_	PART	_	_	1	nsubj	_	_
# 3	‘itsa	_	ADJ	_	_	4	nummod	_	_
# 4	ñu	_	NOUN	_	_	_	_	_	_
# 5	xarákë	_	VERB	_	_	4	appos	_	_
# 6	.	_	PUNCT	_	_	5	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/338.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/338.conllu' mode='r' encoding='utf-8'> 1	Ësaokin	_	ADV	_	_	5	advcl	_	_
# 2	mane	_	NOUN	_	_	5	nsubj	_	_
# 3	‘itsa	_	ADJ	_	_	2	nummod	_	_
# 4	toinkë	_	VERB	_	_	2	appos	_	_
# 5	‘ixunmabi	_	VERB	_	_	0	root	_	_
# 6	.	_	PUNCT	_	_	5	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/339.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/339.conllu' mode='r' encoding='utf-8'> 1	Pui	_	NOUN	_	_	3	obl	_	_
# 2	=n	_	PART	_	_	1	case	_	_
# 3	‘axankëbë	_	VERB	_	_	9	advcl	_	_
# 4	ka	_	AUX	_	_	9	aux:sgen	_	_
# 5	=is	_	AUX	_	_	9	aux:evid	_	_
# 6	=a	_	DET	_	_	9	nsubj:bound	_	_
# 7	a	_	DET	_	_	_	_	_	_
# 8	kaxu	_	ADV	_	_	7	case	_	_
# 9	kwankëxa	_	VERB	_	_	0	root	_	_
# 10	uni	_	NOUN	_	_	_	_	_	_
# 11	achushi	_	ADJ	_	_	10	nummod	_	_
# 12	.	_	PUNCT	_	_	_	_	_	_
#
# <_io.TextIOWrapper name='archivos-conllu/340.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/340.conllu' mode='r' encoding='utf-8'> 1	Achushi	_	ADJ	_	_	2	nmod	_	_
# 2	uni	_	NOUN	_	_	11	nsubj:free	_	_
# 3	=n	_	PART	_	_	2	case	_	_
# 4	ka	_	AUX	_	_	11	aux:sgen	_	_
# 5	=is	_	AUX	_	_	11	aux:evid	_	_
# 6	=a	_	DET	_	_	11	nsubj:bound	_	_
# 7	kamabi	_	ADJ	_	_	8	nummod	_	_
# 8	nëtë	_	NOUN	_	_	11	obl	_	_
# 9	=n	_	PART	_	_	8	case	_	_
# 10	tanu	_	NOUN	_	_	11	obj	_	_
# 11	buankëxa	_	VERB	_	_	_	_	_	_
# 12	.	_	PUNCT	_	_	11	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/348 - Sabina (v).conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/348 - Sabina (v).conllu' mode='r' encoding='utf-8'> 1	rët-tankëxun	_	VERB	_	_	8	advcl	_	kill-S/A:A:PE
# 2	ka	_	PART	_	_	8	aux:sgen	_	NAR
# 3	=is	_	PART	_	_	8	aux:ev	_	=REP
# 4	=a	_	PART	_	_	8	nsubj	_	=3
# 5	xanu	_	NOUN	_	_	8	nsubj:free	_	woman
# 6	=n	_	PART	_	_	5	case	_	=ERG
# 7	chaxu	_	NOUN	_	_	8	obj	_	deer:ABS
# 8	rakan-akë-x-in	_	VERB	_	_	0	root	_	lay.down-REM.PST-3-PROX
# 9	.	_	PUNCT	_	_	8	punct	_	_
#
# <_io.TextIOWrapper name='archivos-conllu/357 - Sabina (v).conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/357 - Sabina (v).conllu' mode='r' encoding='utf-8'> 1	ka	_	NOUN	_	_	2	aux:sgen	_	NAR
# 2	xui	_	VERB	_	_	10	parataxis	_	grill:IMP
# 3	ka-xun	_	VERB	_	_	10	advcl	_	say-S/A>A:SE
# 4	ka	_	PART	_	_	10	aux:sgen	_	NAR
# 5	=is	_	PART	_	_	10	aux:ev	_	=REP
# 6	=a	_	PART	_	_	10	nsubj	_	=3
# 7	charu	_	NOUN	_	_	10	obj	_	crab:ABS
# 8	ain	_	PRON	_	_	9	nmod	_	3SG:GEN
# 9	xanu	_	NOUN	_	_	10	iobj	_	woman:ABS
# 10	inan-akë-x-a	_	VERB	_	_	0	root	_	give-REM.PST-3-NON.PROX
# 11	.	_	PUNCT	_	_	10	punct	_	_
#
# <_io.TextIOWrapper name='archivos-conllu/361 - Sabina (v).conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/361 - Sabina (v).conllu' mode='r' encoding='utf-8'> 1	a-kin	_	VERB	_	_	5	advcl	_	do-S/A>A:SE
# 2	=ma	_	PART	_	_	1	advmod	_	=NEG
# 3	ka	_	PART	_	_	5	aux:sgen	_	NAR
# 4	=nanuna	_	PART	_	_	5	nsubj	_	=1PL
# 5	a-i-n	_	VERB	_	_	0	root	_	do-IPFV-1/1
# 6	atsa	_	NOUN	_	_	5	obl	_	manioc
# 7	=këñun	_	PART	_	_	6	case	_	=COMP:P
# 8	xëki	_	NOUN	_	_	5	obj	_	corn:ABS
# 9	.	_	PUNCT	_	_	5	punct	_	_
#
# <_io.TextIOWrapper name='archivos-conllu/366 - Sabina (v).conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/366 - Sabina (v).conllu' mode='r' encoding='utf-8'> 1	cha	_	ADJ	_	_	2	amod	_	big
# 2	bai	_	NOUN	_	_	5	obj	_	path:ABS
# 3	ka	_	PART	_	_	5	aux:sgen	_	NAR
# 4	=a	_	PART	_	_	5	nsubj	_	=3
# 5	a-akë-x-a	_	VERB	_	_	0	root	_	do-REM.PST-3
# 6	desde	_	ADP	_	_	7	case	_	from
# 7	Tingo	_	PROPN	_	_	8	compound	_	Tingo
# 8	María	_	PROPN	_	_	5	obl	_	María
# 9	anu-xun	_	ADV	_	_	5	advmod	_	there-PA.A
# 10	hasta	_	ADP	_	_	11	case	_	until
# 11	Pucallpa	_	PROPN	_	_	5	obl	_	Pucallpa
# 12	=nu	_	PART	_	_	11	case	_	=LOC
# 13	.	_	PUNCT	_	_	5	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/369 - Sabina (v).conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/369 - Sabina (v).conllu' mode='r' encoding='utf-8'> 1	hotel	_	NOUN	_	_	8	obl	_	hotel
# 2	=miki	_	PART	_	_	1	case	_	=IMPR.DIR
# 3	ka	_	PART	_	_	8	aux:sgen	_	NAR
# 4	=a	_	PART	_	_	8	nsubj	_	:3
# 5	e	_	PRON	_	_	7	nmod	_	1SG
# 6	=n	_	PART	_	_	5	case	_	=GEN
# 7	xukën	_	NOUN	_	_	8	nsubj:free	_	brother:ABS
# 8	u-i-a	_	VERB	_	_	0	root	_	come-IPFV-NON.PROX
# 9	.	_	PUNCT	_	_	8	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/379 - Sabina (v).conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/379 - Sabina (v).conllu' mode='r' encoding='utf-8'> 1	xubu	_	NOUN	_	_	5	obj	_	houses
# 2	=kama	_	PART	_	_	1	nmod	_	=PL:ABS
# 3	ka	_	PART	_	_	5	aux:sgen	_	NAR
# 4	=a	_	PART	_	_	5	nsubj	_	:3
# 5	is-akë-x-a	_	VERB	_	_	0	root	_	see-REM.PST-3-NON.PROX
# 6	.	_	PUNCT	_	_	5	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/388 - Sabina (v)--ud-sabina-2.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/388 - Sabina (v)--ud-sabina-2.conllu' mode='r' encoding='utf-8'> 1	nukën	_	PRON	_	_	2	nmod	_	our
# 2	papaokë	_	NOUN	_	_	10	nsubj:free	_	ancestor
# 3	=kama	_	PART	_	_	2	nummod	_	=PL
# 4	ka	_	PART	_	_	10	aux:sgen	_	NAR
# 5	=a	_	PART	_	_	10	nsubj	_	:3
# 6	uni	_	NOUN	_	_	7	amod	_	man
# 7	chaxkë	_	ADJ	_	_	10	nmod	_	big
# 8	siná	_	ADJ	_	_	9	amod	_	brave
# 9	uni	_	NOUN	_	_	10	nmod	_	man
# 10	i-akë-x-a	_	VERB	_	_	0	root	_	be-REM.PST-3-NON.PROX
# 11	.	_	PUNCT	_	_	10	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/389 - Sabina (v).conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/389 - Sabina (v).conllu' mode='r' encoding='utf-8'> 1	anu	_	ADV	_	_	4	advmod	_	heroes
# 2	ka	_	PART	_	_	4	aux	_	NAR
# 3	=a	_	PART	_	_	4	nsubj	_	:3
# 4	i-akë-x-a	_	VERB	_	_	0	root	_	be-REM.PST-3-NON.PROX
# 5	a	_	SCONJ	_	_	6	det	_	that
# 6	uni	_	NOUN	_	_	4	nsubj:free	_	person
# 7	=kama	_	PART	_	_	6	nmod	_	=PL
# 8	ë	_	PRON	_	_	10	nmod	_	1SG
# 9	=n	_	PART	_	_	8	case	_	=GEN
# 10	papaokë	_	NOUN	_	_	6	appos	_	ancestor
# 11	.	_	PUNCT	_	_	4	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/390 - Sabina (v).conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/390 - Sabina (v).conllu' mode='r' encoding='utf-8'> 1	después	_	ADV	_	_	5	advmod	_	after
# 2	ka	_	PART	_	_	5	aux:sgen	_	NAR
# 3	=nanuna	_	PART	_	_	5	nsubj	_	=PL
# 4	bëtsi	_	NOUN	_	_	5	obj	_	other:ABS
# 5	a-ti	_	VERB	_	_	0	root	_	do-NOMLZ
# 6	ain	_	AUX	_	_	5	aux	_	be:1/2
# 7	bëtsi	_	DET	_	_	8	amod	_	other
# 8	historia	_	NOUN	_	_	5	obj	_	story:ABS
# 9	bëtsi	_	DET	_	_	10	amod	_	other
# 10	bana	_	NOUN	_	_	8	appos	_	tale:ABS
# 11	.	_	PUNCT	_	_	5	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/391 - Sabina (v).conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/391 - Sabina (v).conllu' mode='r' encoding='utf-8'> 1	a-tankëxun	_	VERB	_	_	8	advcl	8:advcl	do-S/A>A:PE
# 2	ka	_	PART	_	_	8	aux:sgen	8:aux:sgen	NAR
# 3	=na	_	PART	_	_	8	nsubj	8:nsubj	=1SG
# 4	itsa	_	DET	_	_	5	nummod	5:nummod	a.lot
# 5	katsin	_	NOUN	_	_	8	obj	8:obj	banana.sp:ABS
# 6	itsa	_	DET	_	_	7	nummod	7:nummod	a.lot
# 7	xinkun	_	NOUN	_	_	5	appos	5:appos	banana.sp:ABS
# 8	a-ti	_	VERB	_	_	0	root	0:root	do-NOMLZ
# 9	ain	_	AUX	_	_	8	aux	8:aux	be:1/2
# 10	.	_	PUNCT	_	_	8	punct	8:punct	_
# <_io.TextIOWrapper name='archivos-conllu/393 - Sabina (v).conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/393 - Sabina (v).conllu' mode='r' encoding='utf-8'> 1	ainbi	_	CCONJ	_	_	11	advcl	_	but:DS/A/P
# 2	ka	_	PART	_	_	11	aux:sgen	_	NAR
# 3	=a	_	PART	_	_	11	nsubj	_	:3
# 4	bëná	_	ADJ	_	_	5	amod	_	young
# 5	uni	_	NOUN	_	_	11	nsubj:free	_	person
# 6	=n	_	PART	_	_	5	case	_	=ERG
# 7	pia	_	NOUN	_	_	8	nmod	_	arrow:ABS
# 8	toin-ti	_	NOUN	_	_	11	obj	_	grab-NOMLZ
# 9	kanti	_	NOUN	_	_	10	nmod	_	bow
# 10	toin-ti	_	NOUN	_	_	8	appos	_	hold-NOMLZ
# 11	rabin-i-a	_	VERB	_	_	0	root	_	feel.embarrased-IPFV-NON.PROX
# 12	.	_	PUNCT	_	_	11	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/395 - Sabina (v).conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/395 - Sabina (v).conllu' mode='r' encoding='utf-8'> 1	upit-o-kin	_	ADJ	_	_	3	advcl	_	good-FACT-S/A>A:SE
# 2	nui-xun	_	_	NOUN	_	3	advcl	_	love-S/A>A:SE
# 3	nits-kin-kin	_	VERB	_	_	0	root	_	walk-APPL-HAB:REM.PST:3
# 4	.	_	PUNCT	_	_	3	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/397 - Sabina (v).conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/397 - Sabina (v).conllu' mode='r' encoding='utf-8'> 1	a	_	PRON	_	_	8	obl	_	that
# 2	=kupí	_	PART	_	_	1	case	_	-REAS
# 3	ka	_	PART	_	_	8	aux:sgen	_	NAR
# 4	=a	_	PART	_	_	8	nsubj	_	:3
# 5	nu	_	PRON	_	_	7	nmod	_	we
# 6	=n	_	PART	_	_	5	case	_	=GEN
# 7	me	_	NOUN	_	_	8	nsubj:free	_	land:ABS
# 8	chukúma	_	ADJ	_	_	9	amod	_	small
# 9	ikën	_	VERB	_	_	0	root	_	be:3
# 10	.	_	PUNCT	_	_	9	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/401 - Sabina (v)--ud-sabina-1.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/401 - Sabina (v)--ud-sabina-1.conllu' mode='r' encoding='utf-8'> 1	Emilio	_	NOUN	_	_	9	nsubj	_	Emilio:abs
# 2	ka	_	PART	_	_	9	aux:spgen	_	nar:3
# 3	=a	_	PART	_	_	9	nsubj	_	_
# 4	mas	_	ADV	_	_	6	goeswith	_	more
# 5	xuá	_	ADJ	_	_	9	cop	_	fat
# 6	ki	_	CCONJ	_	_	7	case	_	than
# 7	Roberto	_	NOUN	_	_	9	obl	_	Roberto
# 8	=ma	_	PART	_	_	9	advmod	_	=neg
# 9	‘ikën	_	VERB	_	_	0	root	_	be:3
# 10	.	_	PUNCT	_	_	9	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/405.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/405.conllu' mode='r' encoding='utf-8'> 1	Bëxuñurá	_	NOUN	_	_	2	nsubj	_	_
# 2	‘ikë	_	VERB	_	_	14	advcl	_	_
# 3	=bi	_	ADV	_	_	2	advmod	_	_
# 4	ka	_	AUX	_	_	14	aux:sgen	_	_
# 5	=is	_	AUX	_	_	14	aux:evid	_	_
# 6	=a	_	DET	_	_	14	nsubj:bound	_	_
# 7	xanu	_	NOUN	_	_	14	nsubj:free	_	_
# 8	=n	_	PART	_	_	7	case	_	_
# 9	ain	_	AUX	_	_	10	nmod	_	_
# 10	bënë	_	NOUN	_	_	13	obj	_	_
# 11	‘akë	_	VERB	_	_	13	obl	_	_
# 12	=sa	_	PART	_	_	11	case	_	_
# 13	okin	_	ADV	_	_	14	advcl	_	_
# 14	maso	_	VERB	_	_	0	root	_	_
# 15	=ma	_	ADV	_	_	14	advmod	_	_
# 16	‘ikën	_	VERB	_	_	14	aux	_	_
# 17	.	_	PUNCT	_	_	14	punct	_	_
#
# <_io.TextIOWrapper name='archivos-conllu/408 - Sabina (v).conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/408 - Sabina (v).conllu' mode='r' encoding='utf-8'> 1	uni-tín	_	ADJ	_	_	2	nmod	2:nmod	man-same.size
# 2	chuna	_	NOUN	_	_	8	nsubj:free	8:nsubj:free	spider.monkey
# 3	a	_	PRON	_	_	2	det	2:det	3SG
# 4	=n	_	PART	_	_	2	case	2:case	=A
# 5	ka	_	PART	_	_	8	aux:sgen	8:aux:sgen	NAR
# 6	=a	_	PART	_	_	8	nsubj	8:nsubj	:3
# 7	ë	_	PRON	_	_	8	obj	8:obj	1SG:P
# 8	ratu-a-x-a	_	VERB	_	_	0	root	0:root	scare-PFV-3-NON.PROX
# 9	.	_	PUNCT	_	_	8	punct	8:punct	_
# <_io.TextIOWrapper name='archivos-conllu/460-ud-annotatrix-corpus.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/460-ud-annotatrix-corpus.conllu' mode='r' encoding='utf-8'> 1	paën-xun	_	VERB	_	_	7	advcl	_	get.drunk-s/a>a
# 2	ka	_	PART	_	_	7	aux:sgen	_	nar
# 3	=na	_	PART	_	_	7	nsubj:bound	_	1sg
# 4	‘ë	_	PRON	_	_	7	nsubj:free	_	1sg
# 5	=n	_	PART	_	_	4	case	_	a
# 6	‘atsa	_	NOUN	_	_	7	nsubj:free	_	manioc:abs
# 7	kwëën-i-n	_	VERB	_	_	0	root	_	want-ipfv-½
# 8	.	_	PUNCT	_	_	7	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/471.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/471.conllu' mode='r' encoding='utf-8'> 1	“	_	PUNCT	_	_	17	punct	_	_
# 2	Anun	_	PRON	_	_	3	nmod	_	_
# 3	ma	_	NOUN	_	_	12	obj	_	_
# 4	shi	_	VERB	_	_	17	parataxis	_	_
# 5	ki	_	PRON	_	_	3	nmod	_	_
# 6	nun	_	ADV	_	_	4	advcl	_	_
# 7	ka	_	AUX	_	_	12	aux:sgen	_	_
# 8	‘ë	_	PRON	_	_	9	nmod	_	_
# 9	nanë	_	NOUN	_	_	12	obj	_	_
# 10	itsirá	_	NOUN	_	_	12	obj	_	_
# 11	‘ë	_	PRON	_	_	10	nmod	_	_
# 12	nipáxun	_	VERB	_	_	17	parataxis	_	_
# 13	”	_	PUNCT	_	_	17	punct	_	_
# 14	ka	_	AUX	_	_	17	aux:sgen	_	_
# 15	=is	_	AUX	_	_	17	aux:ev	_	_
# 16	=a	_	DET	_	_	17	nsubj:bound	_	_
# 17	kakëshín	_	VERB	_	_	0	root	_	_
# 18	.	_	PUNCT	_	_	17	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/509.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/509.conllu' mode='r' encoding='utf-8'> 1	Chaxu	_	NOUN	_	_	_	_	_	_
# 2	an	_	DET	_	_	1	det	_	_
# 3	=n	_	PART	_	_	1	case	_	_
# 4	churukukwainkin	_	NOUN	_	_	12	nsubj	_	_
# 5	ka	_	AUX	_	_	12	aux:sgen	_	_
# 6	=is	_	AUX	_	_	12	aux:evid	_	_
# 7	=a	_	DET	_	_	12	nsubj:bound	_	_
# 8	xanu	_	NOUN	_	_	12	obj	_	_
# 9	xënirá	_	ADJ	_	_	8	amod	_	_
# 10	chaxu	_	NOUN	_	_	12	nsubj:free	_	_
# 11	=n	_	PART	_	_	10	case	_	_
# 12	makwëxakëshín	_	VERB	_	_	0	root	_	_
# 13	.	_	PUNCT	_	_	12	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/517.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/517.conllu' mode='r' encoding='utf-8'> 1	‘Ë	_	PRON	_	_	8	nmod	_	_
# 2	=n	_	PART	_	_	1	case	_	_
# 3	ka	_	AUX	_	_	8	aux:sgen	_	_
# 4	=na	_	PART	_	_	8	nsubj:bound	_	_
# 5	a	_	DET	_	_	7	nsubj:bound	_	_
# 6	bana	_	NOUN	_	_	7	nsubj	_	_
# 7	ñuiti	_	VERB	_	_	0	root	_	_
# 8	kwëëni	_	ADV	_	_	7	advcl	_	_
# 9	=ma	_	PART	_	_	8	advmod	_	_
# 10	.	_	PUNCT	_	_	7	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/518.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/518.conllu' mode='r' encoding='utf-8'> 1	Ë	_	PRON	_	_	7	nmod	_	_
# 2	=n	_	PART	_	_	1	case	_	_
# 3	ka	_	AUX	_	_	7	aux:sgen	_	_
# 4	=na	_	PART	_	_	7	nsubj:bound	_	_
# 5	a	_	DET	_	_	7	nsubj:bound	_	_
# 6	bana	_	NOUN	_	_	7	nsubj	_	_
# 7	ñuiti	_	VERB	_	_	0	root	_	_
# 8	‘ain	_	AUX	_	_	7	aux:sgen	_	_
# 9	.	_	PUNCT	_	_	7	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/799.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/799.conllu' mode='r' encoding='utf-8'> 1	‘Itankëxun	_	ADV	_	_	5	advcl	_	_
# 2	ka	_	AUX	_	_	5	aux:sgen	_	_
# 3	=is	_	AUX	_	_	5	aux:evid	_	_
# 4	=a	_	DET	_	_	5	nsubj:bound	_	_
# 5	kakëxa	_	VERB	_	_	0	root	_	_
# 6	ain	_	AUX	_	_	7	nmod	_	_
# 7	tita	_	NOUN	_	_	5	obj	_	_
# 8	ñuxanrá	_	ADJ	_	_	7	amod	_	_
# 9	“	_	PUNCT	_	_	5	punct	_	_
# 10	tita	_	NOUN	_	_	23	discourse	_	_
# 11	=n	_	PART	_	_	10	case	_	_
# 12	,	_	PUNCT	_	_	_	_	_	_
# 13	anu	_	DET	_	_	16	obj	_	_
# 14	uni	_	NOUN	_	_	16	advmod	_	_
# 15	xëni	_	ADJ	_	_	14	amod	_	_
# 16	‘ati	_	VERB	_	_	21	ccomp	_	_
# 17	ë	_	PRON	_	_	20	nmod	_	_
# 18	=n	_	PART	_	_	17	case	_	_
# 19	kupë	_	NOUN	_	_	_	_	_	_
# 20	atsa	_	PART	_	_	19	compound	_	_
# 21	bitstanmainun	_	VERB	_	_	23	advcl	_	_
# 22	ka	_	AUX	_	_	23	aux:sgen	_	_
# 23	bëruan	_	VERB	_	_	5	parataxis	_	_
# 24	,	_	PUNCT	_	_	5	punct	_	_
# 25	tita	_	NOUN	_	_	23	discourse	_	_
# 26	=n	_	PART	_	_	25	case	_	_
# 27	”	_	PUNCT	_	_	5	punct	_	_
# 28	.	_	PUNCT	_	_	5	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/976-ud-annotatrix-corpus.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/976-ud-annotatrix-corpus.conllu' mode='r' encoding='utf-8'> 1	nukën	_	PRON	_	_	2	det	_	1pl:gen
# 2	chaiti	_	NOUN	_	_	7	nsubj:free	_	ancestor:abs
# 3	ka	_	PART	_	_	6	aux:sgen	_	nar
# 4	=is	_	PART	_	_	6	aux:evi	_	=rep
# 5	=a	_	PART	_	_	6	nsubj:bound	_	=3
# 6	ënu	_	ADV	_	_	7	advcl	_	here
# 7	tsót-a	_	NOUN	_	_	16	ccomp	_	live-nomlz
# 8	=ma	_	PART	_	_	7	advcl	_	=neg
# 9	‘ikën	_	VERB	_	_	_	_	_	be:3
# 10	sino	_	CCONJ	_	_	_	_	_	but
# 11	nukën	_	NOUN	_	_	_	_	_	1pl.gen
# 12	chaiti	_	NOUN	_	_	_	_	_	ancestor:abs
# 13	ka	_	PART	_	_	_	_	_	nar
# 14	=is	_	PART	_	_	_	_	_	=rep
# 15	=a	_	PART	_	_	_	_	_	=3
# 16	tsót-akë-x-a	_	VERB	_	_	0	root	_	live-rem.pst-3-non.prox
# 17	rima	_	NOUN	_	_	_	_	_	Lima
# 18	kaxu	_	ADV	_	_	_	_	_	behind
# 19	norte	_	NOUN	_	_	_	_	_	North
# 20	=nu	_	PART	_	_	_	_	_	=loc
# 21	.	_	PUNCT	_	_	16	punct	_	_
#
# 1	norte	_	_	_	_	_	_	_	North
# 2	=nu	_	_	_	_	_	_	_	=loc
# 3	ka	_	_	_	_	_	_	_	nar
# 4	=is	_	_	_	_	_	_	_	=rep
# 5	=a	_	_	_	_	_	_	_	=3
# 6	nukën	_	_	_	_	_	_	_	1pl:gen
# 7	chaiti	_	_	_	_	_	_	_	ancestor:abs
# 8	tsót-akë-x-a	_	VERB	_	_	0	root	_	live-rem.pst-3-non.prox
# 9	.	_	_	_	_	_	_	_	_
# <_io.TextIOWrapper name='archivos-conllu/977a - Sabina (v).conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/977a - Sabina (v).conllu' mode='r' encoding='utf-8'>
#
# 1	xëa-kë	_	NOUN	_	_	6	nsubj:free	6:nsubj:free	drink-NOMLZ
# 2	a	_	DET	_	_	1	det	1:det	that
# 3	=x	_	PART	_	_	1	case	1:case	=S
# 4	ka	_	PART	_	_	6	aux:sgen	6:aux:sgen	NAR
# 5	=a	_	PART	_	_	6	nsubj	6:nsubj	:3
# 6	ikën	_	VERB	_	_	0	root	0:root	be:3
# 7	shipibo	_	PROPN	_	_	8	nmod	8:nmod	Shipibo
# 8	bana	_	NOUN	_	_	6	nmod	6:nmod	word:ABS
# 9	.	_	PUNCT	_	_	6	punct	6:punct	_
# <_io.TextIOWrapper name='archivos-conllu/977b - Sabina (v).conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/977b - Sabina (v).conllu' mode='r' encoding='utf-8'> 1	nu	_	PRON	_	_	3	nmod	3:nmod	1PL
# 2	=n	_	PART	_	_	1	case	1:case	=GEN
# 3	bana	_	NOUN	_	_	6	nmod	6:nmod	word:ABS
# 4	ka	_	PART	_	_	6	aux:sgen	6:aux:sgen	NAR
# 5	=a	_	PART	_	_	6	nsubj	6:nsubj	:3
# 6	iken	_	VERB	_	_	0	root	0:root	be:3
# 7	kwáxka-kë	_	NOUN	_	_	6	nsubj:free	6:nsubj:free	drink-NOMLZ
# 8	.	_	PUNCT	_	_	6	punct	6:punct	_
# <_io.TextIOWrapper name='archivos-conllu/s201.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/s201.conllu' mode='r' encoding='utf-8'> 1	Xanu-xun	xanu	NOUN	_	_	5	adv	_	woman
# 2	ka		_	PART	_	_	5	aux:sgen	_	_
# 3	=a		ka	PART	_	_	5	nsubj:bound	_	nar:3
# 4	‘atapa		‘atapa	NOUN	_	_	5	obj	_	chicken:abs
# 5	‘a-a-x-a	‘a	VERB	_	_	0	root	_	kill-pfv-3-non.prox
# 6	.		_	PUNCT	_	_	5	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/s202.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/s202.conllu' mode='r' encoding='utf-8'> 1	Uni	uni	NOUN	_	_	9	nsubj:free	_	man
# 2	achushi	achushi	DET	_	_	1	xmod	_	one
# 3	=n	n	PART	_	_	1	case	_	=ergative
# 4	=pain	pain	PART	_	_	9	adv	_	=first
# 5	ka	_	PART	_	_	9	aux:sgen	_	_
# 6	=a	ka	PART	_	_	9	nsubj:bound	_	nar:3
# 7	ënë	ënë	DET	_	_	8	det	_	this
# 8	‘ó	‘ó	NOUN	_	_	9	obj	_	tapir:abs
# 9	‘a-a-x-a	‘a	VERB	_	_	0	root	_	kill-pfv-3-non.prox
# 10	.	_	PUNCT	_	_	9	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/s206.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/s206.conllu' mode='r' encoding='utf-8'> 1	Achushi	achushi	DET	_	_	3	nummod	_	one
# 2	=ishi	ishi	PART	_	_	1	advmod	_	=only
# 3	ñu	ñu	NOUN	_	_	7	obj	_	thing:abs
# 4	ka	_	PART	_	_	7	aux:sgen	_	_
# 5	=a	ka	PART	_	_	7	nsubj:bound	_	nar:3
# 6	‘ë	‘ë	PRON	_	_	7	obj	_	1sg:p
# 7	‘inan	'inan	VERB	_	_	0	root	_	give:imp
# 8	.	_	PUNCT	_	_	7	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/s210.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/s210.conllu' mode='r' encoding='utf-8'> 1	Imëishi	imëishi	ADV	_	_	6	advmod	_	tomorrow
# 2	ka	ka	PART	_	_	6	aux:sgen	_	narrative
# 3	=na	na	PART	_	_	6	nsubj:bound	_	=1sg
# 4	Aguaytia	Aguaytia	NOUN	_	_	6	obl	_	Aguaytia
# 5	=nu	nu	PART	_	_	4	case	_	=directional
# 6	kwan-ti	kwanti	VERB	_	_	0	root	_	go-nomlz
# 7	‘ain	‘i	AUX	_	_	6	aux	_	be:1/2
# 8	.	_	PUNCT	_	_	6	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/s233.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/s233.conllu' mode='r' encoding='utf-8'> 1	Ë	ë	PRON	_	_	8	nsubj:free	_	1sg
# 2	=n	n	PART	_	_	1	case	_	=a
# 3	ka	ka	PART	_	_	8	aux:sgen	_	narrative
# 4	=na	na	PART	_	_	8	nsubj:bound	_	=1sg
# 5	xubu	xubu	NOUN	_	_	8	obl	_	house
# 6	=nu	nu	PART	_	_	5	case	_	=locative
# 7	i	i	NOUN	_	_	8	obj	_	wood:abs
# 8	atsin-mi-i-n	atsin	VERB	_	_	0	root	_	enter-caus-ipfv-1/2
# 9	.	_	PUNCT	_	_	8	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/s234.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/s234.conllu' mode='r' encoding='utf-8'> 1	‘Ë	‘ë	PRON	_	_	7	nsubj:free	_	1sg
# 2	=x	x	PART	_	_	1	case	_	=s
# 3	ka	ka	PART	_	_	7	aux:sgen	_	narrative
# 4	=na	na	PART	_	_	7	nsubj:bound	_	=1sg
# 5	kini	kini	NOUN	_	_	7	obl	_	hole
# 6	=nu	nu	PART	_	_	5	case	_	=locative
# 7	më-atsin-mët-i-n	atsin	VERB	_	_	0	root	_	hand-enter-refl-ipfv-1/2
# 8	.	_	PUNCT	_	_	7	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/s243.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/s243.conllu' mode='r' encoding='utf-8'> 1	Uinbi	uinbi	PRON	_	_	7	nsubj:free	_	nobody:a
# 2	ka	_	PART	_	_	7	aux:sgen	_	_
# 3	=a	ka	PART	_	_	7	nsubj:bound	_	nar:3
# 4	‘ë	‘ë	PRON	_	_	6	nmod	_	1sg
# 5	=n	n	PART	_	_	4	case	_	=genitive
# 6	piti	piti	NOUN	_	_	7	obj	_	food:abs
# 7	pi-ti	piti	VERB	_	_	0	root	_	eat-nomlz
# 8	=ma	ma	PART	_	_	7	neg	_	=negative
# 9	‘ikën	‘i	AUX	_	_	7	aux	_	be:3
# 10	.	_	PUNCT	_	_	7	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/s264(1).conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/s264(1).conllu' mode='r' encoding='utf-8'> 1	Achushi	achushi	ADJ	_	_	2	nummod	_	one
# 2	kini	kini	NOUN	_	_	_	_	_	hole
# 3	=ñu	ñu	PART	_	_	2	case	_	=propietive
# 4	ka	_	PART	_	_	10	aux:sgen	_	_
# 5	=a	ka	PART	_	_	10	nsubj:bound	_	nar:3
# 6	mi	mi	PRON	_	_	8	nmod	_	2sg
# 7	=n	n	PART	_	_	6	case	_	=genitive
# 8	xo	_	NOUN	_	_	9	amod	_	_
# 9	rabé̈okë	xo vrabé̈okë	NOUN	_	_	_	_	_	pants
# 10	‘ikën	‘i	VERB	_	_	0	root	_	be:3
# 11	.	_	PUNCT	_	_	10	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/s264(2).conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/s264(2).conllu' mode='r' encoding='utf-8'> 1	Mi	mi	PRON	_	_	3	nmod	_	2sg
# 2	=n	n	PART	_	_	1	case	_	=genitive
# 3	nunti	nunti	NOUN	_	_	6	nsubj:free	_	canoe:abs
# 4	ka	_	PART	_	_	6	aux:sgen	_	_
# 5	=a	ka	PART	_	_	6	nsubj:bound	_	nar:3
# 6	kini-i-ín	kini	VERB	_	_	0	root	_	become.hole-ipfv-prox_
# 7	.	_	PUNCT	_	_	6	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/s265(2).conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/s265(2).conllu' mode='r' encoding='utf-8'> 1	Mi	mi	PRON	_	_	3	nmod	_	2sg
# 2	=n	n	PART	_	_	1	case	_	=genitive
# 3	naë	naë	NOUN	_	_	6	nsubj:free	_	garden:abs
# 4	ka	_	PART	_	_	6	aux:sgen	_	_
# 5	=a	ka	PART	_	_	6	nsubj:bound	_	nar:3
# 6	matat-i-ín	matat	VERB	_	_	0	root	_	become.hill-ipfv-prox
# 7	.	_	PUNCT	_	_	6	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/s271(a).conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/s271(a).conllu' mode='r' encoding='utf-8'> 1	Mi	mi	PRON	_	_	3	nmod	_	2sg
# 2	=n	n	PART	_	_	1	case	_	=genitive
# 3	linterna	linterna	NOUN	_	_	6	nsubj:free	_	torch:abs
# 4	ka	ka	PART	_	_	6	aux:sgen	_	narrative
# 5	=mina	mina	PART	_	_	6	nsubj:bound	_	=2
# 6	tirit-o-a-n	tirit	VERB	_	_	0	root	_	become.shining-fact-pfv-2
# 7	.	_	PUNCT	_	_	6	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/s286(3).conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/s286(3).conllu' mode='r' encoding='utf-8'> 1	A	a	DET	_	_	2	det	_	that
# 2	xubu	xubu	NOUN	_	_	7	obl	_	house
# 3	=nu	nu	PART	_	_	2	case	_	=locative
# 4	ka	ka	PART	_	_	7	aux:sgen	_	narrative
# 5	=na	na	PART	_	_	7	nsubj:bound	_	=1sg
# 6	imé̈	imé̈	ADV	_	_	7	advmod	_	at.night
# 7	kwan-ti	kwanti	VERB	_	_	0	root	_	go-nomlz
# 8	‘ain	‘i	AUX	_	_	7	aux	_	be:1/2
# 9	.	_	PUNCT	_	_	7	punct	_	_
#
# <_io.TextIOWrapper name='archivos-conllu/s299.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/s299.conllu' mode='r' encoding='utf-8'> 1	‘Ë	‘Ë	PRON	_	_	3	nmod	_	1sg
# 2	=n	n	PART	_	_	1	case	_	=genitive
# 3	xubu	xubu	NOUN	_	_	5	nsubj	_	house:abs
# 4	‘aisama	‘aisama	ADJ	_	_	5	amod	_	bad
# 5	‘i-këbëtan	‘i	VERB	_	_	_	_	_	be-ds/a/p:se:tran
# 6	ka	ka	PART	_	_	12	aux:sgen	_	narrative
# 7	=na	na	PART	_	_	12	nsubj:bound	_	=1sg
# 8	bëtsi	bëtsi	ADJ	_	_	9	amod	_	other
# 9	xubu	xubu	NOUN	_	_	12	obj	_	house:abs
# 10	‘ë	‘ë	PRON	_	_	12	nsubj:free	_	1sg
# 11	=n	n	PART	_	_	10	case	_	=a
# 12	‘a-akë-n	‘a	VERB	_	_	0	root	_	do-rem.pst-1/2
# 13	.	_	PUNCT	_	_	12	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/s301.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/s301.conllu' mode='r' encoding='utf-8'> 1	Kënë	kënë	NOUN	_	_	2	nsubj	_	wall:abs
# 2	xaiki-këbë	xaibi	VERB	_	_	6	advcl	_	shake-ds/a/p:se:intr
# 3	ka	_	PART	_	_	6	aux:sgen	_	_
# 4	=a	ka	PART	_	_	6	nsubj:bound	_	nar:3
# 5	xubu	xubu	NOUN	_	_	6	nsubj:free	_	house:abs
# 6	nipakët-a-x-a	nipakët	VERB	_	_	0	root	_	fall.down-ipfv-non.prox
# 7	.	_	PUNCT	_	_	6	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/s302.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/s302.conllu' mode='r' encoding='utf-8'> 1	Emilionë	Emilionë	NOUN	_	_	4	nsubj	_	Emilio
# 2	=n	n	PART	_	_	1	case	_	=ergative
# 3	kënë	kënë	NOUN	_	_	4	obj	_	wall:abs
# 4	xaika-këx	xaika	VERB	_	_	8	advcl	_	shake:tran-p>s:pe:tran
# 5	ka	_	PART	_	_	8	aux:sgen	_	_
# 6	=a	ka	PART	_	_	8	nsubj:bound	_	nar:3
# 7	xubu	xubu	NOUN	_	_	8	nsubj:free	_	house:abs
# 8	nipakët-a-x-a	nipakët	VERB	_	_	0	root	_	fall.down-ipfv-3-non.prox
# 9	.	_	PUNCT	_	_	8	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/s310.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/s310.conllu' mode='r' encoding='utf-8'> 1	‘Ë	‘ë	PRON	_	_	3	nmod	_	1sg
# 2	=n	n	PART	_	_	1	case	_	=genitive
# 3	xubu	xubu	NOUN	_	_	8	obl	_	house
# 4	=nu	nu	PART	_	_	3	case	_	=locative
# 5	ka	ka	PART	_	_	8	aux:sgen	_	narrative
# 6	=na	na	PART	_	_	8	nsubj:bound	_	=1sg
# 7	‘aisama	‘aisama	ADJ	_	_	8	amod	_	bad
# 8	‘ain	‘i	VERB	_	_	0	root	_	be:1/2
# 9	.	_	PUNCT	_	_	8	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/s370.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/s370.conllu' mode='r' encoding='utf-8'> 1	Hotel	hotel	NOUN	_	_	8	obl	_	hotel
# 2	=uki	u(ki)	PART	_	_	1	case	_	=indirect direction
# 3	ka	_	PART	_	_	8	aux:sgen	_	_
# 4	=a	ka	PART	_	_	8	nsubj:bound	_	nar:3
# 5	‘ë	‘ë	PRON	_	_	7	nmod	_	1sg
# 6	=n	n	PART	_	_	5	case	_	=genitive
# 7	xukën	xukën	NOUN	_	_	8	nsubj:free	_	brother:abs
# 8	u-i-a	u	VERB	_	_	0	root	_	come-ipvf-non.prox
# 9	.	_	PUNCT	_	_	8	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/s445.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/s445.conllu' mode='r' encoding='utf-8'> 1	‘Ë	‘ë	PRON	_	_	5	nsubj:free	_	1sg
# 2	=x	x	PART	_	_	1	case	_	=intransitive subject
# 3	ka	ka	PART	_	_	5	aux:sgen	_	indicative
# 4	=na	na	PART	_	_	5	nsubj:bound	_	=1sg
# 5	rakwët-i-n	rakwët	VERB	_	_	0	root	_	be.affraid.of-ipfv-1/2
# 6	‘inu	‘inu	NOUN	_	_	8	nsubj:free	_	jaguar
# 7	=n	n	PART	_	_	6	case	_	=ergative
# 8	pi-ti	piti	NOUN	_	_	5	obl	_	eat-nomlz
# 9	rabanan	rabanan	ADP	_	_	8	case	_	because.of
# 10	.	_	PUNCT	_	_	8	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/ud-annotatrix-(204)-Rosa Gonzales.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/ud-annotatrix-(204)-Rosa Gonzales.conllu' mode='r' encoding='utf-8'> 1	Roberto	Roberto	PROPN	_	_	8	nsubj:free	_	Roberto
# 2	=nën	n	PART	_	_	1	case	_	Ergative
# 3	ka	ka	PART	_	_	8	aux:sgen	_	narrative
# 4	=a	a	PART	_	_	8	nsubj:bound	_	3
# 5	ënë	ënë	DET	_	_	7	det	_	this
# 6	‘ó	'o	NOUN	_	_	7	nmod	_	tapir
# 7	name	nami	NOUN	_	_	8	obj	_	meat
# 8	pipania	pi-pan	VERB	_	_	0	root	_	eat-first
# 9	.	_	PUNCT	_	_	8	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/ud-annotatrix-(209)-Rosa Gonzales.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/ud-annotatrix-(209)-Rosa Gonzales.conllu' mode='r' encoding='utf-8'> 1	Uni	uni	NOUN	_	_	10	obl	_	man
# 2	chaxkë´	chaxkë´	ADJ	_	_	1	amod	_	big
# 3	achushi	achushi	NUM	_	_	1	nummod	_	one
# 4	=bëtan	bëtan	PART	_	_	1	case	_	comitative
# 5	ka	ka	PART	_	_	10	aux:sgen	_	narrative
# 6	=na	na	PART	_	_	10	nsubj:bound	_	1sg
# 7	'ë	'ë	PRON	_	_	9	nmod	_	1sg
# 8	=n	n	PART	_	_	7	case	_	genitive
# 9	xubu	xubu	NOUN	_	_	10	obj	_	house
# 10	'ati	'a	VERB	_	_	0	root	_	do
# 11	'ain	'ain	AUX	_	_	10	aux	_	be
# 12	.	_	PUNCT	_	_	10	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/ud-annotatrix-(214)-Rosa Gonzales.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/ud-annotatrix-(214)-Rosa Gonzales.conllu' mode='r' encoding='utf-8'> 1	uni	uni	NOUN	_	_	10	nsubj:free	_	man
# 2	=n	n	PART	_	_	1	case	_	ergative
# 3	ka	ka	PART	_	_	10	aux:sgen	_	narrative
# 4	=a	a	PART	_	_	10	nsubj	_	3
# 5	baka	baka	NOUN	_	_	10	obl	_	river
# 6	=nu	nu	PART	_	_	5	case	_	locative
# 7	=xun	xun	PART	_	_	1	case	_	Participant agreement.Agent
# 8	=bi	bi	PART	_	_	5	advmod	_	same
# 9	chaxu	chaxu	NOUN	_	_	10	obj	_	deer
# 10	'aaxa	'a	VERB	_	_	0	root	_	kill
# 11	.	_	PUNCT	_	_	10	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/ud-annotatrix-(227)-Rosa Gonzales.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/ud-annotatrix-(227)-Rosa Gonzales.conllu' mode='r' encoding='utf-8'> 1	Parunuti	parunuti	NOUN	_	_	6	nsubj:free	_	earring
# 2	a	a	DET	_	_	1	det	_	that
# 3	=x	x	PART	_	_	1	case	_	s.
# 4	ka	ka	PART	_	_	6	aux:sgen	_	narrative
# 5	=a	a	PART	_	_	6	nsubj:bound	_	3
# 6	pabëntamëti	pa.bëntan	VERB	_	_	0	root	_	ear.hang
# 7	'ikën	'ikën	AUX	_	_	6	aux	_	be
# 8	.	_	PUNCT	_	_	6	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/ud-annotatrix-(228)-Rosa Gonzales.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/ud-annotatrix-(228)-Rosa Gonzales.conllu' mode='r' encoding='utf-8'> 1	Parunuti	parunuti	NOUN	_	_	8	nsubj:free	_	earring
# 2	a	a	DET	_	_	1	det	_	that
# 3	=x	x	PART	_	_	1	case	_	s.
# 4	ka	ka	PART	_	_	8	aux:sgen	_	narrative
# 5	=a	a	PART	_	_	8	nsubj:bound	_	3
# 6	pabí	pabí	NOUN	_	_	8	obl	_	ear
# 7	=nu	nu	PART	_	_	6	case	_	locative
# 8	bëntamëti	bëntan	VERB	_	_	0	root	_	hang
# 9	'ikën	'ikën	AUX	_	_	8	aux	_	be
# 10	.	_	PUNCT	_	_	8	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/ud-annotatrix-(241)-Rosa Gonzales.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/ud-annotatrix-(241)-Rosa Gonzales.conllu' mode='r' encoding='utf-8'> 1	Uinbirës	uinbirës	PRON	_	_	7	nsubj:free	_	anyone
# 2	ka	ka	PART	_	_	7	aux:sgen	_	narrative
# 3	=a	a	PART	_	_	7	nsubj:bound	_	3
# 4	'ë	'ë	PRON	_	_	6	nmod	_	1
# 5	=n	n	PART	_	_	4	case	_	genetive
# 6	piti	piti	NOUN	_	_	7	obj	_	food
# 7	piti	pi	VERB	_	_	0	root	_	eat
# 8	'ikën	'ikën	AUX	_	_	7	aux	_	be
# 9	.	_	PUNCT	_	_	7	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/ud-annotatrix-(247)-Rosa Gonzales.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/ud-annotatrix-(247)-Rosa Gonzales.conllu' mode='r' encoding='utf-8'> 1	Tanu	tanu	NOUN	_	_	2	obj	_	palm.grub
# 2	rërëkanux	rërëka	VERB	_	_	3	advcl	_	spill
# 3	tsóbuakëxa	tsót-but	VERB	_	_	0	root	_	live-down
# 4	bai	bai	NOUN	_	_	3	obl	_	path
# 5	‘ipasu	'ipasu	ADP	_	_	4	case	_	at.side.of
# 6	.	_	PUNCT	_	_	3	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/ud-annotatrix-(255)-Rosa Gonzales.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/ud-annotatrix-(255)-Rosa Gonzales.conllu' mode='r' encoding='utf-8'> 1	Comodiezaños	como diez años	ADV	_	_	2	advmod	_	como diez años
# 2	aish	aish	VERB	_	_	7	advcl	_	be
# 3	ka	ka	PART	_	_	7	aux:sgen	_	narrative
# 4	=na	=na	PART	_	_	7	nsubj:bound	_	1sg
# 5	'ë	'ë	PRON	_	_	_	_	_	1sg
# 6	=x	x	PART	_	_	5	case	_	s
# 7	tsókën	tsót	VERB	_	_	0	root	_	live
# 8	SantaRosa	Santa Rosa	NOUN	_	_	7	obl	_	Santa Rosa
# 9	tsipúmi	 tsipumi	ADP	_	_	8	case	_	below
# 10	.	_	PUNCT	_	_	7	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/ud-annotatrix-(263)-Rosa Gonzales.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/ud-annotatrix-(263)-Rosa Gonzales.conllu' mode='r' encoding='utf-8'> 1	Nukën	nukën	PRON	_	_	2	nmod	_	1pl.gen
# 2	'ibu	'ibu	NOUN	_	_	9	nsubj:free	_	owner:abs
# 3	ka	ka	PART	_	_	9	aux:sgen	_	narrative
# 4	=is	is	PART	_	_	9	aux:evid	_	reportative
# 5	=a	a	PART	_	_	9	nsubj:bound	_	3
# 6	nai	nai	NOUN	_	_	9	obl	_	sky
# 7	=nu	nu	PART	_	_	6	case	_	locative
# 8	=ax	ax	PART	_	_	2	case	_	agreement.s
# 9	uakëxa	u	VERB	_	_	0	root	_	come
# 10	.	_	PUNCT	_	_	9	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/ud-annotatrix-(270)-Rosa Gonzales.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/ud-annotatrix-(270)-Rosa Gonzales.conllu' mode='r' encoding='utf-8'> 1	Bari	bari	NOUN	_	_	7	nsubj:free	_	sun
# 2	=n	n	PART	_	_	1	case	_	ergative
# 3	ka	ka	PART	_	_	7	aux:sgen	_	narrative
# 4	=a	a	PART	_	_	7	nsubj:bound	_	3
# 5	a	a	DET	_	_	6	det	_	that
# 6	këntí	këntí	NOUN	_	_	7	obj	_	pot
# 7	ichútmiaxa	ichút	VERB	_	_	0	root	_	be.bright
# 8	.	_	PUNCT	_	_	7	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/ud-annotatrix-(285)-Rosa Gonzales.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/ud-annotatrix-(285)-Rosa Gonzales.conllu' mode='r' encoding='utf-8'> 1	A	a	DET	_	_	2	det	_	that
# 2	uni	uni	NOUN	_	_	9	nsubj:free	_	man
# 3	=n	n	PART	_	_	2	case	_	ergative
# 4	ka	ka	PART	_	_	9	aux:sgen	_	narrative
# 5	=a	a	PART	_	_	9	nsubj:bound	_	3
# 6	uri	uri	ADV	_	_	9	advmod	_	far
# 7	achushi	achushi	NUM	_	_	8	nummod	_	one
# 8	xaë	xaë	NOUN	_	_	9	obj	_	turtle
# 9	mëraxa	mëra	VERB	_	_	0	root	_	find
# 10	.	_	PUNCT	_	_	9	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/ud-annotatrix-(318)-Rosa Gonzales.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/ud-annotatrix-(318)-Rosa Gonzales.conllu' mode='r' encoding='utf-8'> 1	Anuxun	anu	ADV	_	_	11	advmod	_	there
# 2	nukën	nukën	PRON	_	_	3	nmod	_	1pl.gen
# 3	bake	bakë	NOUN	_	_	11	obj	_	son
# 4	bëchikë	bëchikë	NOUN	_	_	3	compound	_	son
# 5	nukën	nukën	PRON	_	_	6	nmod	_	1pl.gen
# 6	ini	ini	NOUN	_	_	11	obj	_	daughter
# 7	bëchikë	bëchikë	NOUN	_	_	6	compound	_	daughter
# 8	'óina	'ó	NOUN	_	_	10	obj	_	tapir
# 9	chunena	chuna	NOUN	_	_	10	obj	_	monkey
# 10	pitankëxun	pi	VERB	_	_	11	advcl	_	eat
# 11	kaniotin	kaniot	VERB	_	_	0	root	_	raise
# 12	.	_	PUNCT	_	_	11	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/ud-annotatrix-(341)-Rosa Gonzales.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/ud-annotatrix-(341)-Rosa Gonzales.conllu' mode='r' encoding='utf-8'> 1	Kana	kana	NOUN	_	_	2	nmod	_	macaw
# 2	rani	rani	NOUN	_	_	10	obj	_	feather
# 3	xon	xon	NOUN	_	_	4	nmod	_	red.macaw
# 4	rani	rani	NOUN	_	_	10	obj	_	feather
# 5	ka	ka	PART	_	_	10	aux:sgen	_	narrative
# 6	=nanuna	(na)nuna	PART	_	_	10	nsubj:bound	_	1pl
# 7	ain	ain	PRON	_	_	8	nmod	_	his
# 8	tsipu	tsipun	NOUN	_	_	10	obl	_	end (of an object)
# 9	=nu	nu	PART	_	_	8	case	_	locative
# 10	bëtanitin	bëtanit	VERB	_	_	0	root	_	tie
# 11	.	_	PUNCT	_	_	10	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/ud-annotatrix-(363)-Rosa Gonzales.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/ud-annotatrix-(363)-Rosa Gonzales.conllu' mode='r' encoding='utf-8'> 1	Ain	ain	PRON	_	_	2	nmod	_	3sg:gen
# 2	monument	monumento	NOUN	_	_	8	nsubj:free	_	statue
# 3	=sapi	sapi	PART	_	_	8	aux:dub	_	dubitative
# 4	ka	ka	PART	_	_	8	aux:sgen	_	narrative
# 5	=a	a	PART	_	_	8	nsubj:bound	_	3
# 6	Pucallpa	Pucallpa	NOUN	_	_	8	obl	_	Pucallpa
# 7	=nu	nu	PART	_	_	6	case	_	locative
# 8	'ikën	'ikën	VERB	_	_	0	root	_	be
# 9	.	_	PUNCT	_	_	8	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/ud-annotatrix-(407)-Rosa Gonzales.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/ud-annotatrix-(407)-Rosa Gonzales.conllu' mode='r' encoding='utf-8'> 1	Chuna	chuna	NOUN	_	_	8	nsubj:free	_	spider.monkey
# 2	unitín	uni	NOUN	_	_	1	nmod	_	man
# 3	a	a	PRON	_	_	1	appos	_	3sg
# 4	=n	n	PART	_	_	3	case	_	A
# 5	ka	ka	PART	_	_	8	aux:sgen	_	narrative
# 6	=a	a	PART	_	_	8	nsubj:bound	_	3
# 7	'ë	'ë	PRON	_	_	8	obj	_	1sg:P
# 8	ratuaxa	ratu	VERB	_	_	0	root	_	scare
# 9	.	_	PUNCT	_	_	8	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/ud-annotatrix-(490)-Rosa Gonzales.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/ud-annotatrix-(490)-Rosa Gonzales.conllu' mode='r' encoding='utf-8'> 1	'Aishbi	'aishbi	VERB	_	_	5	advmod	_	but
# 2	ka	ka	PART	_	_	5	aux:sgen	_	narrative
# 3	=is	is	PART	_	_	5	aux:evid	_	reportative
# 4	=a	a	PART	_	_	5	nsubj:bound	_	3
# 5	'iakëxa	'i	VERB	_	_	0	root	_	be
# 6	a	a	DET	_	_	7	det	_	that
# 7	uni	uni	NOUN	_	_	5	nsubj:free	_	person
# 8	chumíbukë	chumin-but	ADJ	_	_	7	amod	_	thin-advance.process
# 9	bamati	bama	VERB	_	_	5	advmod	_	die
# 10	ura	ura	ADV	_	_	9	advmod	_	far
# 11	=ma	ma	ADV	_	_	10	advmod	_	negative
# 12	.	_	PUNCT	_	_	5	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/ud-annotatrix-(508)-Rosa Gonzales.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/ud-annotatrix-(508)-Rosa Gonzales.conllu' mode='r' encoding='utf-8'> 1	kwainkin	kwain	VERB	_	_	13	advcl	_	move.over
# 2	=shi	ishi	PART	_	_	1	advmod	_	only
# 3	ka	ka	PART	_	_	13	aux:sgen	_	narrative
# 4	=is	is	PART	_	_	13	aux:evid	_	reportative
# 5	=a	a	PART	_	_	13	nsubj:bound	_	3
# 6	ain	ain	PRON	_	_	7	nmod	_	3sg
# 7	tita	tita	NOUN	_	_	13	obj	_	mother
# 8	ñuxanrá	ñuxan	NOUN	_	_	7	amod	_	old.woman
# 9	ain	ain	PRON	_	_	10	nmod	_	3sg:gen
# 10	maë	maë	NOUN	_	_	11	obj	_	house
# 11	matsunkubuinia	matsun	VERB	_	_	13	advcl	_	sweep
# 12	=bi	bi	PART	_	_	11	advmod	_	same
# 13	rëakëxa	rët	VERB	_	_	0	root	_	beat
# 14	.	_	PUNCT	_	_	13	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/ud-annotatrix-(515)-Rosa Gonzales.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/ud-annotatrix-(515)-Rosa Gonzales.conllu' mode='r' encoding='utf-8'> 1	Ë	Ë	ADV	_	_	8	obl	_	here
# 2	=nu	nu	PART	_	_	1	case	_	locative
# 3	achushi	achushi	NUM	_	_	7	nummod	_	one
# 4	bëráma	bëráma	ADJ	_	_	7	amod	_	old
# 5	nu	nu	PRON	_	_	7	amod	_	1pl
# 6	=n	n	PART	_	_	5	case	_	genitive
# 7	‘anibu	‘anibu	NOUN	_	_	8	nsubj:free	_	ancestor
# 8	‘ia	be	NOUN	_	_	11	ccomp	_	be-NOMLZ
# 9	ka	ka	PART	_	_	11	aux:sgen	_	narrative
# 10	=na	na	PART	_	_	11	nsubj:bound	_	1sg
# 11	ñuikasin	ñui	VERB	_	_	0	root	_	tell
# 12	.	_	PUNCT	_	_	11	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/ud-claudia-1.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/ud-claudia-1.conllu' mode='r' encoding='utf-8'> 1	Xanu	Xanu	_	NOUN	_	6	nsubj:free	_	_
# 2	 =n	 =n	_	PART	_	1	case	_	_
# 3	ka	ka	_	AUX	_	6	aux:sgen	_	_
# 4	=is	=is	_	AUX	_	6	aux:evid	_	_
# 5	=a	=a	_	DET	_	6	nsubj:bound	_	_
# 6	buankian	buankian	_	VERB	_	0	root	_	_
# 7	ain	ain	_	DET	_	8	nmod	_	_
# 8	bënë	bënë	_	NOUN	_	6	obj	_	_
# 9	“	“	_	PUNCT	_	6	punct	_	_
# 10	unirá	unirá	_	NOUN	_	11	nsubj:free	_	_
# 11	ka	ka	_	AUX	_	6	parataxis	_	_
# 12	”	”	_	PUNCT	_	6	punct	_	_
# 13	.	.	_	PUNCT	_	6	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/ud-claudia-2.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/ud-claudia-2.conllu' mode='r' encoding='utf-8'> 1	“	_	PUNCT	_	_	15	punct	_	_
# 2	Min	_	DET	_	_	3	nmod	_	_
# 3	bënë	_	NOUN	_	_	4	obj	_	_
# 4	‘atankëxun	_	ADV	_	_	10	advcl	_	_
# 5	ka	_	AUX	_	_	10	aux:sgen	_	_
# 6	‘ëribi	_	NOUN	_	_	10	obj	_	_
# 7	min	_	DET	_	_	8	nmod	_	_
# 8	maëxratsukun	_	NOUN	_	_	10	obl	_	_
# 9	‘ë	_	PRON	_	_	10	obj	_	_
# 10	‘a	_	VERB	_	_	15	parataxis	_	_
# 11	”	_	PUNCT	_	_	15	punct	_	_
# 12	ka	_	AUX	_	_	15	aux:sgen	_	_
# 13	=is	_	AUX	_	_	15	aux:ev	_	_
# 14	=a	_	DET	_	_	15	nsubj:bound	_	_
# 15	kakëshín	_	VERB	_	_	0	root	_	_
# 16	.	_	PUNCT	_	_	15	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/ud-claudia-3.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/ud-claudia-3.conllu' mode='r' encoding='utf-8'> 1	“	_	PUNCT	_	_	17	punct	_	_
# 2	Anun	_	PRON	_	_	3	nmod	_	_
# 3	ma	_	NOUN	_	_	12	obj	_	_
# 4	shi	_	VERB	_	_	17	parataxis	_	_
# 5	ki	_	PRON	_	_	3	nmod	_	_
# 6	nun	_	ADV	_	_	4	advcl	_	_
# 7	ka	_	AUX	_	_	12	aux:sgen	_	_
# 8	‘ë	_	PRON	_	_	9	nmod	_	_
# 9	nanë	_	NOUN	_	_	12	obj	_	_
# 10	itsirá	_	NOUN	_	_	12	obj	_	_
# 11	‘ë	_	PRON	_	_	10	nmod	_	_
# 12	nipáxun	_	VERB	_	_	17	parataxis	_	_
# 13	”	_	PUNCT	_	_	17	punct	_	_
# 14	ka	_	AUX	_	_	17	aux:sgen	_	_
# 15	=is	_	AUX	_	_	17	aux:ev	_	_
# 16	=a	_	DET	_	_	17	nsubj:bound	_	_
# 17	kakëshín	_	VERB	_	_	0	root	_	_
# 18	.	_	PUNCT	_	_	17	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/ud-luisa-s370.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/ud-luisa-s370.conllu' mode='r' encoding='utf-8'> 1	Hotel	hotel	NOUN	_	_	8	obl	_	hotel
# 2	=uki	u(ki)	PART	_	_	1	case	_	=indirect direction
# 3	ka	_	PART	_	_	8	aux:sgen	_	_
# 4	=a	ka	PART	_	_	8	nsubj:bound	_	nar:3
# 5	‘ë	‘ë	PRON	_	_	7	nmod	_	1sg
# 6	=n	n	PART	_	_	5	case	_	=genitive
# 7	xukën	xukën	NOUN	_	_	8	nsubj:free	_	brother:abs
# 8	u-i-a	u	VERB	_	_	0	root	_	come-ipvf-non.prox
# 9	.	_	PUNCT	_	_	8	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/ud-luisa-s445.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/ud-luisa-s445.conllu' mode='r' encoding='utf-8'> 1	‘Ë	‘ë	PRON	_	_	5	nsubj:free	_	1sg
# 2	=x	x	PART	_	_	1	case	_	=intransitive subject
# 3	ka	ka	PART	_	_	5	aux:sgen	_	indicative
# 4	=na	na	PART	_	_	5	nsubj:bound	_	=1sg
# 5	rakwët-i-n	rakwët	VERB	_	_	0	root	_	be.affraid.of-ipfv-1/2
# 6	‘inu	‘inu	NOUN	_	_	8	nsubj:free	_	jaguar
# 7	=n	n	PART	_	_	6	case	_	=ergative
# 8	pi-ti	piti	NOUN	_	_	5	obl	_	eat-nomlz
# 9	rabanan	rabanan	ADP	_	_	8	case	_	because.of
# 10	.	_	PUNCT	_	_	8	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/ud-luisa-s476.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/ud-luisa-s476.conllu' mode='r' encoding='utf-8'> 1	Bëru-ax	bëru	VERB	_	_	11	advcl	_	stay-s/a>s
# 2	ka	_	PART	_	_	11	aux:sgen	_	stay-ds:pe
# 3	=is	_	PART	_	_	11	aux:evi	_	_
# 4	=a	kaisa	PART	_	_	11	nsubj:bound	_	nar=rep=3
# 5	bëru-an	bëru	VERB	_	_	11	advcl	_	_
# 6	ka	_	PART	_	_	11	aux:sgen	_	_
# 7	=is	_	PART	_	_	11	aux:evi	_	_
# 8	=a	kaisa	PART	_	_	11	nsubj:bound	_	nar=rep=3
# 9	ukairi	_	NOUN	_	_	11	obj	_	ladder
# 10	a	_	DET	_	_	9	appos	_	that:p
# 11	tënka-pat-akë-x-ín	_	VERB	_	_	0	root	_	cut.making.noise-down:tran-rem.pst-3-prox
# 12	u-but-kin	u	VERB	_	_	11	advcl	_	come-down:intr-s/a>a:se
# 13	is	_	PART	_	_	11	aux:evi	_	_
# 14	=a	isa	PART	_	_	11	nsubj:bound	_	rep=3
# 15	rët-uku-but-an	rët	VERB	_	_	11	advcl	_	cut-iter:one.direction-down:intr-ds/a/p:pe
# 16	.	_	PUNCT	_	_	11	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/ud-mariana-333.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/ud-mariana-333.conllu' mode='r' encoding='utf-8'> 1	atian	_	ADV	_	_	11	discourse	_	then
# 2	casi	_	ADV	_	_	3	advmod	_	almost
# 3	kamabi	_	DET	_	_	4	nummod	_	every
# 4	nëtë	_	NOUN	_	_	11	advmod	_	day
# 5	=n	_	PART	_	_	4	case	_	=temp
# 6	ka	_	PART	_	_	11	aux:sgen	_	nar
# 7	=is	_	PART	_	_	11	aux:evi	_	=rep
# 8	=a	_	PART	_	_	11	nsubj:bound	_	=3
# 9	a	_	DET	_	_	10	det	_	that
# 10	uni	_	NOUN	_	_	11	nsubj	_	person:abs
# 11	kwan-akë-x-ín	_	VERB	_	_	0	root	_	go-rem.pst-3-prox
# 12	.	_	PUNCT	_	_	11	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/ud-mariana-335.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/ud-mariana-335.conllu' mode='r' encoding='utf-8'> 1	ka	_	PART	_	_	11	aux:sgen	11:aux:sgen	nar
# 2	=nanuna	_	PART	_	_	11	nsubj:bound	11:nsubj:bound	=1pl
# 3	toxama	_	NOUN	_	_	5	obj	5:obj	tree.sp.
# 4	upí	_	ADJ	_	_	3	amod	3:amod	beautiful:abs
# 5	bits-tankëxun	_	VERB	_	_	11	advcl	11:advcl	pick.up-s/a>a:pe
# 6	taish	_	NOUN	_	_	8	obj	8:obj	tree.sp.
# 7	a	_	DET	_	_	6	det	6:det	3sg:p
# 8	bits-tankëxun	_	VERB	_	_	11	advcl	11:advcl	buy-s/a>a:pe
# 9	ka	_	PART	_	_	11	aux:sgen	11:aux:sgen	nar
# 10	=nanuna	_	PART	_	_	11	nsubj:bound	11:nsubj:bound	=1pl
# 11	‘aru-i-n	_	VERB	_	_	0	root	0:root	cook-ipfv-½
# 12	.	_	PUNCT	_	_	11	punct	11:punct	_
# <_io.TextIOWrapper name='archivos-conllu/ud-mariana-460.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/ud-mariana-460.conllu' mode='r' encoding='utf-8'> 1	paën-xun	_	VERB	_	_	7	advcl	_	get.drunk-s/a>a
# 2	ka	_	PART	_	_	7	aux:sgen	_	nar
# 3	=na	_	PART	_	_	7	nsubj:bound	_	1sg
# 4	‘ë	_	NOUN	_	_	7	nsubj:free	_	1sg
# 5	=n	_	PART	_	_	4	case	_	a
# 6	‘atsa	_	NOUN	_	_	7	nsubj:free	_	manioc:abs
# 7	kwëën-i-n	_	VERB	_	_	0	root	_	want-ipfv-½
# 8	.	_	PUNCT	_	_	7	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/ud-rosa-1.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/ud-rosa-1.conllu' mode='r' encoding='utf-8'> 1	Ë	Ë	ADV	_	_	8	obl	_	here
# 2	=nu	nu	PART	_	_	1	case	_	locative
# 3	achushi	achushi	NUM	_	_	7	nummod	_	one
# 4	bëráma	bëráma	ADJ	_	_	7	amod	_	old
# 5	nu	nu	PRON	_	_	7	amod	_	1pl
# 6	=n	n	PART	_	_	5	case	_	genitive
# 7	‘anibu	‘anibu	NOUN	_	_	8	nsubj:free	_	ancestor
# 8	‘ia	be	NOUN	_	_	11	ccomp	_	be-NOMLZ
# 9	ka	ka	PART	_	_	11	aux:sgen	_	narrative
# 10	=na	na	PART	_	_	11	nsubj:bound	_	1sg
# 11	ñuikasin	ñui	VERB	_	_	0	root	_	tell
# 12	.	_	PUNCT	_	_	11	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/ud-rosa-2.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/ud-rosa-2.conllu' mode='r' encoding='utf-8'> 1	Tanu	tanu	NOUN	_	_	2	obj	_	palm.grub
# 2	rërëkanux	rërëka	verb/adv?	_	_	3	advcl	_	spill
# 3	tsóbuakëxa	tsót-but	VERB	_	_	0	root	_	live-down
# 4	bai	bai	NOUN	_	_	3	obl	_	path
# 5	‘ipasu	'ipasu	ADP	_	_	4	case	_	at.side.of
# 6	.	_	PUNCT	_	_	3	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/ud-rosa-3.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/ud-rosa-3.conllu' mode='r' encoding='utf-8'> 1	Roberto	Roberto	PROPN	_	_	8	nsubj:free	_	Roberto
# 2	=nën	n	PART	_	_	1	case	_	Ergative
# 3	ka	ka	PART	_	_	8	aux:sgen	_	narrative
# 4	=a	a	PART	_	_	8	nsubj:bound	_	3
# 5	ënë	ënë	DET	_	_	7	det	_	this
# 6	‘ó	'o	NOUN	_	_	7	nmod	_	tapir
# 7	name	nami	NOUN	_	_	8	obj	_	meat
# 8	pipania	pi-pan	VERB	_	_	0	root	_	eat-first
# 9	.	_	PUNCT	_	_	8	punct	_	_
# <_io.TextIOWrapper name='archivos-conllu/ud-sabina-1.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/ud-sabina-1.conllu' mode='r' encoding='utf-8'> 1	Emilio	_	NOUN	_	_	9	nsubj:free	_	Emilio:abs
# 2	ka	_	PART	_	_	9	aux:sgen	_	nar:3
# 3	=a	_	PART	_	_	9	nsubj:bound	_	_
# 4	mas	_	ADV	_	_	6	goeswith	_	more
# 5	xuá	_	ADJ	_	_	9	cop	_	fat
# 6	ki	_	CCONJ	_	_	7	case	_	than
# 7	Roberto	_	NOUN	_	_	9	obl	_	Roberto
# 8	=ma	_	PART	_	_	9	advmod	_	=neg
# 9	‘ikën	_	VERB	_	_	0	root	_	be:3
# 10	.	_	PUNCT	_	_	9	punct	_	_
#
# <_io.TextIOWrapper name='archivos-conllu/ud-sabina-2.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/ud-sabina-2.conllu' mode='r' encoding='utf-8'> 1	nukën	_	DET	_	_	2	nmod	_	our
# 2	papaokë	_	NOUN	_	_	10	nsubj:free	_	ancestor
# 3	=kama	_	PART	_	_	2	nmod	_	=pl
# 4	ka	_	PART	_	_	10	aux:sgen	_	nar
# 5	=a	_	PART	_	_	10	nsubj:bound	_	_
# 6	uni	_	NOUN	_	_	10	cop	_	man
# 7	chaxké	_	ADJ	_	_	6	amod	_	big
# 8	siná	_	ADJ	_	_	9	amod	_	brave
# 9	uni	_	NOUN	_	_	10	cop	_	man
# 10	‘i-akë-x-a	_	VERB	_	_	0	root	_	be-rem.pst-3-non.prox
# 11	.	_	PUNCT	_	_	10	punct	_	_
#
# <_io.TextIOWrapper name='archivos-conllu/ud-sabina-3.conllu' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='archivos-conllu/ud-sabina-3.conllu' mode='r' encoding='utf-8'> 1	maru-kin	_	VERB	_	_	3	advcl	_	sell-s/a>a:se
# 2	no-n	_	ADJ	_	_	3	nsubj:free	_	non.indigenous-erg
# 3	buan-akë-x-ín	_	VERB	_	_	0	root	_	take-rem.pas-3-non.prox
# 4	.	_	PUNCT	_	_	3	punct	_	_

# %%
len(kakataibo)
# Out:
# 111

# %%
## lista de objetos TokenList

kakataibo
# Out:
# [TokenList<patron, =bëtan, ka, =a, balata, a-akë-x-ín, .>,
#  TokenList<maru-kin, no-n, buan-akë-x-ín, .>,
#  TokenList<Juan, ka, =mënë, mi, =n, kuriki, mëkama-iéé, .>,
#  TokenList<Nukën, chaiti, ka, =is, =a, tsó-akë-x-a, norte, =nu, .>,
#  TokenList<Norte, =nu, tsó-xun, ka, =is, =a, nukën, chaiti-baë, =n, uni, =ñu, =ma, no, =ñu, =ma, 'a-akë-x-a, .>,
#  TokenList<Nukën, chaiti, =n, ka, =a, bana, ñui-xun-kian, .>,
#  TokenList<'Ë, ka, 'atsa, 'inan, .>,
#  TokenList<Nukën, chaiti, =n, ka, =is, =a, 'ó, nami, pi-akë-x-a, .>,
#  TokenList<Nukën, chaiti, =n, ka, =is, =a, 'ó, nami, pi-akë-x-a, .>,
#  TokenList<Achushi, uni, chaxkë, =bëtan, ka, =na, 'ë, =n, xubu', a-ti, 'ain, .>,
#  TokenList<Uni, =n, ka, =a, baka, =nu, =xun, chaxu, 'a-a-x-a, .>,
#  TokenList<Munu, =ishi, ka, =mina, pi-ti, 'ain, .>,
#  TokenList<Aguaytia, =nu, ka, =na, imëshi, kwan-ti, ain, .>,
#  TokenList<Roberto, ka, =a, më-uxu, 'ikën, .>,
#  TokenList<Roberto, ka, =a, mëkën, =nu, më-uxu, 'ikën, .>,
#  TokenList<Ta-tani-katsi, ki-xun, rakan-bian-a-n, .>,
#  TokenList<Tënka-këbë, ka, =is, =a, uni, ëëëëëë, ki-i, bë-man-mët-akë-xín, .>,
#  TokenList<Ë, =x, ka, =na, xubu, =nu, atsin-i-n, .>,
#  TokenList<y, a, kaibu, =ribi, abat-a, ka, =a, ikën, bëtsi, Palcaso, rëbúmi, .>,
#  TokenList<nukën, papa, =n, bana, =ishi, a-i, tsót-i-n, a, =ishi, ka, =na, ka-i-n, .>,
#  TokenList<Xanu,  =n, ka, =is, =a, buankian, ain, bënë, “, unirá, ka, ”, .>,
#  TokenList<“, Min, bënë, ‘atankëxun, ka, ‘ëribi, min, maëxratsukun, ‘ë, ‘a, ”, ka, =is, =a, kakëshín, .>,
#  TokenList<Usa, =bi, ka, ‘isenaka, =n, rataxtamainun, chëkiai, .>,
#  TokenList<Usai, ka, =a, ëo, kamëokëxa, nu, =n, ‘anibu, nukën, chaitibaë, =n, nukën, xutabaë, =n, .>,
#  TokenList<‘Ë, =n, ka, =na, ënë, an, taë, tëbiskati, bu, =a, =n, .>,
#  TokenList<An, taë, tëbiskati, ka, =n, ‘aisama, ‘ikën, .>,
#  TokenList<Tsatsa, ënë, ka, bëruan, !>,
#  TokenList<atian, casi, kamabi, nëtë, =n, ka, =is, =a, a, uni, kwan-akë-x-ín, .>,
#  TokenList<Upí, ñu, ka, =na, kwëënin, .>,
#  TokenList<ka, =nanuna, toxama, upí, bits-tankëxun, taish, a, bits-tankëxun, ka, =nanuna, ‘aru-i-n, .>,
#  TokenList<Ka, =n, ‘itsa, ñu, xarákë, .>,
#  TokenList<Ësaokin, mane, ‘itsa, toinkë, ‘ixunmabi, .>,
#  TokenList<Pui, =n, ‘axankëbë, ka, =is, =a, a, kaxu, kwankëxa, uni, achushi, .>,
#  TokenList<Achushi, uni, =n, ka, =is, =a, kamabi, nëtë, =n, tanu, buankëxa, .>,
#  TokenList<rët-tankëxun, ka, =is, =a, xanu, =n, chaxu, rakan-akë-x-in, .>,
#  TokenList<ka, xui, ka-xun, ka, =is, =a, charu, ain, xanu, inan-akë-x-a, .>,
#  TokenList<a-kin, =ma, ka, =nanuna, a-i-n, atsa, =këñun, xëki, .>,
#  TokenList<cha, bai, ka, =a, a-akë-x-a, desde, Tingo, María, anu-xun, hasta, Pucallpa, =nu, .>,
#  TokenList<hotel, =miki, ka, =a, e, =n, xukën, u-i-a, .>,
#  TokenList<xubu, =kama, ka, =a, is-akë-x-a, .>,
#  TokenList<nukën, papaokë, =kama, ka, =a, uni, chaxkë, siná, uni, i-akë-x-a, .>,
#  TokenList<anu, ka, =a, i-akë-x-a, a, uni, =kama, ë, =n, papaokë, .>,
#  TokenList<después, ka, =nanuna, bëtsi, a-ti, ain, bëtsi, historia, bëtsi, bana, .>,
#  TokenList<a-tankëxun, ka, =na, itsa, katsin, itsa, xinkun, a-ti, ain, .>,
#  TokenList<ainbi, ka, =a, bëná, uni, =n, pia, toin-ti, kanti, toin-ti, rabin-i-a, .>,
#  TokenList<upit-o-kin, nui-xun, nits-kin-kin, .>,
#  TokenList<a, =kupí, ka, =a, nu, =n, me, chukúma, ikën, .>,
#  TokenList<Emilio, ka, =a, mas, xuá, ki, Roberto, =ma, ‘ikën, .>,
#  TokenList<Bëxuñurá, ‘ikë, =bi, ka, =is, =a, xanu, =n, ain, bënë, ‘akë, =sa, okin, maso, =ma, ‘ikën, .>,
#  TokenList<uni-tín, chuna, a, =n, ka, =a, ë, ratu-a-x-a, .>,
#  TokenList<paën-xun, ka, =na, ‘ë, =n, ‘atsa, kwëën-i-n, .>,
#  TokenList<“, Anun, ma, shi, ki, nun, ka, ‘ë, nanë, itsirá, ‘ë, nipáxun, ”, ka, =is, =a, kakëshín, .>,
#  TokenList<Chaxu, an, =n, churukukwainkin, ka, =is, =a, xanu, xënirá, chaxu, =n, makwëxakëshín, .>,
#  TokenList<‘Ë, =n, ka, =na, a, bana, ñuiti, kwëëni, =ma, .>,
#  TokenList<Ë, =n, ka, =na, a, bana, ñuiti, ‘ain, .>,
#  TokenList<‘Itankëxun, ka, =is, =a, kakëxa, ain, tita, ñuxanrá, “, tita, =n, ,, anu, uni, xëni, ‘ati, ë, =n, kupë, atsa, bitstanmainun, ka, bëruan, ,, tita, =n, ”, .>,
#  TokenList<nukën, chaiti, ka, =is, =a, ënu, tsót-a, =ma, ‘ikën, sino, nukën, chaiti, ka, =is, =a, tsót-akë-x-a, rima, kaxu, norte, =nu, .>,
#  TokenList<norte, =nu, ka, =is, =a, nukën, chaiti, tsót-akë-x-a, .>,
#  TokenList<xëa-kë, a, =x, ka, =a, ikën, shipibo, bana, .>,
#  TokenList<nu, =n, bana, ka, =a, iken, kwáxka-kë, .>,
#  TokenList<Xanu-xun, ka, =a, ‘atapa, ‘a-a-x-a, .>,
#  TokenList<Uni, achushi, =n, =pain, ka, =a, ënë, ‘ó, ‘a-a-x-a, .>,
#  TokenList<Achushi, =ishi, ñu, ka, =a, ‘ë, ‘inan, .>,
#  TokenList<Imëishi, ka, =na, Aguaytia, =nu, kwan-ti, ‘ain, .>,
#  TokenList<Ë, =n, ka, =na, xubu, =nu, i, atsin-mi-i-n, .>,
#  TokenList<‘Ë, =x, ka, =na, kini, =nu, më-atsin-mët-i-n, .>,
#  TokenList<Uinbi, ka, =a, ‘ë, =n, piti, pi-ti, =ma, ‘ikën, .>,
#  TokenList<Achushi, kini, =ñu, ka, =a, mi, =n, xo, rabé̈okë, ‘ikën, .>,
#  TokenList<Mi, =n, nunti, ka, =a, kini-i-ín, .>,
#  TokenList<Mi, =n, naë, ka, =a, matat-i-ín, .>,
#  TokenList<Mi, =n, linterna, ka, =mina, tirit-o-a-n, .>,
#  TokenList<A, xubu, =nu, ka, =na, imé̈, kwan-ti, ‘ain, .>,
#  TokenList<‘Ë, =n, xubu, ‘aisama, ‘i-këbëtan, ka, =na, bëtsi, xubu, ‘ë, =n, ‘a-akë-n, .>,
#  TokenList<Kënë, xaiki-këbë, ka, =a, xubu, nipakët-a-x-a, .>,
#  TokenList<Emilionë, =n, kënë, xaika-këx, ka, =a, xubu, nipakët-a-x-a, .>,
#  TokenList<‘Ë, =n, xubu, =nu, ka, =na, ‘aisama, ‘ain, .>,
#  TokenList<Hotel, =uki, ka, =a, ‘ë, =n, xukën, u-i-a, .>,
#  TokenList<‘Ë, =x, ka, =na, rakwët-i-n, ‘inu, =n, pi-ti, rabanan, .>,
#  TokenList<Roberto, =nën, ka, =a, ënë, ‘ó, name, pipania, .>,
#  TokenList<Uni, chaxkë´, achushi, =bëtan, ka, =na, 'ë, =n, xubu, 'ati, 'ain, .>,
#  TokenList<uni, =n, ka, =a, baka, =nu, =xun, =bi, chaxu, 'aaxa, .>,
#  TokenList<Parunuti, a, =x, ka, =a, pabëntamëti, 'ikën, .>,
#  TokenList<Parunuti, a, =x, ka, =a, pabí, =nu, bëntamëti, 'ikën, .>,
#  TokenList<Uinbirës, ka, =a, 'ë, =n, piti, piti, 'ikën, .>,
#  TokenList<Tanu, rërëkanux, tsóbuakëxa, bai, ‘ipasu, .>,
#  TokenList<Comodiezaños, aish, ka, =na, 'ë, =x, tsókën, SantaRosa, tsipúmi, .>,
#  TokenList<Nukën, 'ibu, ka, =is, =a, nai, =nu, =ax, uakëxa, .>,
#  TokenList<Bari, =n, ka, =a, a, këntí, ichútmiaxa, .>,
#  TokenList<A, uni, =n, ka, =a, uri, achushi, xaë, mëraxa, .>,
#  TokenList<Anuxun, nukën, bake, bëchikë, nukën, ini, bëchikë, 'óina, chunena, pitankëxun, kaniotin, .>,
#  TokenList<Kana, rani, xon, rani, ka, =nanuna, ain, tsipu, =nu, bëtanitin, .>,
#  TokenList<Ain, monument, =sapi, ka, =a, Pucallpa, =nu, 'ikën, .>,
#  TokenList<Chuna, unitín, a, =n, ka, =a, 'ë, ratuaxa, .>,
#  TokenList<'Aishbi, ka, =is, =a, 'iakëxa, a, uni, chumíbukë, bamati, ura, =ma, .>,
#  TokenList<kwainkin, =shi, ka, =is, =a, ain, tita, ñuxanrá, ain, maë, matsunkubuinia, =bi, rëakëxa, .>,
#  TokenList<Ë, =nu, achushi, bëráma, nu, =n, ‘anibu, ‘ia, ka, =na, ñuikasin, .>,
#  TokenList<Xanu,  =n, ka, =is, =a, buankian, ain, bënë, “, unirá, ka, ”, .>,
#  TokenList<“, Min, bënë, ‘atankëxun, ka, ‘ëribi, min, maëxratsukun, ‘ë, ‘a, ”, ka, =is, =a, kakëshín, .>,
#  TokenList<“, Anun, ma, shi, ki, nun, ka, ‘ë, nanë, itsirá, ‘ë, nipáxun, ”, ka, =is, =a, kakëshín, .>,
#  TokenList<Hotel, =uki, ka, =a, ‘ë, =n, xukën, u-i-a, .>,
#  TokenList<‘Ë, =x, ka, =na, rakwët-i-n, ‘inu, =n, pi-ti, rabanan, .>,
#  TokenList<Bëru-ax, ka, =is, =a, bëru-an, ka, =is, =a, ukairi, a, tënka-pat-akë-x-ín, u-but-kin, is, =a, rët-uku-but-an, .>,
#  TokenList<atian, casi, kamabi, nëtë, =n, ka, =is, =a, a, uni, kwan-akë-x-ín, .>,
#  TokenList<ka, =nanuna, toxama, upí, bits-tankëxun, taish, a, bits-tankëxun, ka, =nanuna, ‘aru-i-n, .>,
#  TokenList<paën-xun, ka, =na, ‘ë, =n, ‘atsa, kwëën-i-n, .>,
#  TokenList<Ë, =nu, achushi, bëráma, nu, =n, ‘anibu, ‘ia, ka, =na, ñuikasin, .>,
#  TokenList<Tanu, rërëkanux, tsóbuakëxa, bai, ‘ipasu, .>,
#  TokenList<Roberto, =nën, ka, =a, ënë, ‘ó, name, pipania, .>,
#  TokenList<Emilio, ka, =a, mas, xuá, ki, Roberto, =ma, ‘ikën, .>,
#  TokenList<nukën, papaokë, =kama, ka, =a, uni, chaxké, siná, uni, ‘i-akë-x-a, .>,
#  TokenList<maru-kin, no-n, buan-akë-x-ín, .>]

# %% [markdown]
# ## Ejercicios con el corpus :)

# %% [markdown]
# Para una **oración**, identifique todos los **tokens** y los **types**.

# %%
## función que calcula la frecuencia de types para una oración

## INPUT: lista de diccionarios
## OUTPUT: diccionario type:frecuencia del type
def frecuencia_types(sent):
    
    ## tokens
    puntuacion = ['.',',']
    tokens = []
    for d in sent:
        form = d['form']
        if form not in puntuacion:
            tokens+=[form.lower()]
            
    ## types
    types = []
    for palabra in tokens:
        if palabra not in types:
            types+=[palabra]
            
    D_type_frec = {}
    
    ## diccionario de frecuencia, con ceros al principio
    for word_type in types:
        D_type_frec[word_type]=0
    ## recorremos la lista tokens buscando los types, y cuando aparecen sumamos 1
    for token in tokens:
        D_type_frec[token]+=1
        
    return D_type_frec

# %%
frecuencia_types(kakataibo[6])
# Out:
# {'nukën': 1,
#  'chaiti': 1,
#  '=n': 1,
#  'ka': 1,
#  '=is': 1,
#  '=a': 1,
#  "'ó": 1,
#  'nami': 1,
#  'pi-akë-x-a': 1}

# %%
from collections import Counter

## función que usa la librería collections

## INPUT: lista de diccionarios
## OUTPUT: diccionario type:frecuencia del type
def frecuencia_types_counter(sent):
    
    ## tokens
    puntuacion = ['.',',']
    tokens = []
    for d in sent:
        form = d['form']
        if form not in puntuacion:
            tokens+=[form.lower()]
            
    D_type_frec = dict(Counter(tokens))
        
    return D_type_frec

# %%
frecuencia_types_counter(kakataibo[12])
# Out:
# {'roberto': 1, 'ka': 1, '=a': 1, 'mëkën': 1, '=nu': 1, 'më-uxu': 1, "'ikën": 1}

# %%
## INPUT: lista de diccionarios
## INPUT: entero k -> número de types más frecuentes
## OUTPUT: diccionario type:frecuencia del type
def types_mas_frecuentes(sent,k):
    
    ## tokens
    puntuacion = ['.',',']
    tokens = []
    for d in sent:
        form = d['form']
        if form not in puntuacion:
            tokens+=[form.lower()]
            
    D_type_frec = Counter(tokens)
        
    return D_type_frec.most_common(k)

# %%
types_mas_frecuentes(kakataibo[0],4)
# Out:
# [('juan', 1), ('ka', 1), ('=mënë', 1), ('mi', 1)]

# %%
## ¿Cómo podemos generalizar esto para todo el mini-corpus?

lista_diccionarios_corpus = []

for sentence in kakataibo:
    for d in sentence:
        lista_diccionarios_corpus+=[d]

# %%
dict_frec_types = frecuencia_types(lista_diccionarios_corpus)

# %%
dict_frec_types
# Out:
# {'juan': 1,
#  'ka': 88,
#  '=mënë': 1,
#  'mi': 5,
#  '=n': 51,
#  'kuriki': 1,
#  'mëkama-iéé': 1,
#  'nukën': 11,
#  'chaiti': 4,
#  '=is': 22,
#  '=a': 52,
#  'tsó-akë-x-a': 1,
#  'norte': 2,
#  '=nu': 18,
#  'tsó-xun': 1,
#  'chaiti-baë': 1,
#  'uni': 15,
#  '=ñu': 3,
#  '=ma': 7,
#  'no': 1,
#  "'a-akë-x-a": 1,
#  'bana': 3,
#  'ñui-xun-kian': 1,
#  "'ë": 6,
#  "'atsa": 1,
#  "'inan": 1,
#  "'ó": 2,
#  'nami': 2,
#  'pi-akë-x-a': 2,
#  'achushi': 10,
#  'chaxkë': 1,
#  '=bëtan': 2,
#  '=na': 20,
#  "xubu'": 1,
#  'a-ti': 1,
#  "'ain": 3,
#  'baka': 2,
#  '=xun': 2,
#  'chaxu': 4,
#  "'a-a-x-a": 1,
#  'munu': 1,
#  '=ishi': 2,
#  '=mina': 2,
#  'pi-ti': 4,
#  'aguaytia': 2,
#  'imëshi': 1,
#  'kwan-ti': 3,
#  'ain': 10,
#  'roberto': 5,
#  'më-uxu': 2,
#  "'ikën": 6,
#  'mëkën': 1,
#  'ta-tani-katsi': 1,
#  'ki-xun': 1,
#  'rakan-bian-a-n': 1,
#  'tënka-këbë': 1,
#  'ëëëëëë': 1,
#  'ki-i': 1,
#  'bë-man-mët-akë-xín': 1,
#  'ë': 6,
#  '=x': 7,
#  'xubu': 9,
#  'atsin-i-n': 1,
#  'xanu': 4,
#  ' =n': 2,
#  'buankian': 2,
#  'bënë': 4,
#  '“': 7,
#  'unirá': 2,
#  '”': 7,
#  'min': 4,
#  '‘atankëxun': 2,
#  '‘ëribi': 2,
#  'maëxratsukun': 2,
#  '‘ë': 6,
#  '‘a': 2,
#  'kakëshín': 4,
#  'usa': 1,
#  '=bi': 4,
#  '‘isenaka': 1,
#  'rataxtamainun': 1,
#  'chëkiai': 1,
#  'usai': 1,
#  'ëo': 1,
#  'kamëokëxa': 1,
#  'nu': 3,
#  '‘anibu': 3,
#  'chaitibaë': 1,
#  'xutabaë': 1,
#  '‘ë': 13,
#  'ënë': 5,
#  'an': 3,
#  'taë': 2,
#  'tëbiskati': 2,
#  'bu': 1,
#  '‘aisama': 3,
#  '‘ikën': 5,
#  'tsatsa': 1,
#  'bëruan': 2,
#  '!': 1,
#  'upí': 2,
#  'ñu': 3,
#  'kwëënin': 1,
#  '‘itsa': 2,
#  'xarákë': 1,
#  'ësaokin': 1,
#  'mane': 1,
#  'toinkë': 1,
#  '‘ixunmabi': 1,
#  'puin': 1,
#  '‘axankëbë': 2,
#  'kaisa': 1,
#  '[': 1,
#  '...': 1,
#  'pui': 1,
#  'a': 13,
#  'kaxu': 1,
#  'kwankëxa': 1,
#  '_': 24,
#  'kamabi': 2,
#  'nëtë': 2,
#  'tanu': 3,
#  'buankëxa': 1,
#  'bëxuñurá': 1,
#  '‘ikë': 1,
#  'bënë': 1,
#  '‘akë': 1,
#  '=sa': 1,
#  'okin': 1,
#  'maso': 1,
#  'anun': 2,
#  'ma': 2,
#  'shi': 2,
#  'ki': 3,
#  'nun': 2,
#  'nanë': 2,
#  'itsirá': 2,
#  'nipáxun': 2,
#  'churukukwainkin': 1,
#  'xënirá': 1,
#  'makwëxakëshín': 1,
#  'ñuiti': 2,
#  'kwëëni': 1,
#  '‘ain': 4,
#  '‘itankëxun': 1,
#  'kakëxa': 1,
#  'tita': 4,
#  'ñuxanrá': 2,
#  'anu': 1,
#  'xëni': 1,
#  '‘ati': 1,
#  'kupë': 1,
#  'atsa': 1,
#  'bitstanmainun': 1,
#  'xanu-xun': 1,
#  '‘atapa': 1,
#  '‘a-a-x-a': 1,
#  '=pain': 1,
#  '‘ó': 3,
#  '‘a-a-x-a‘a': 1,
#  '‘inan': 1,
#  'imëishi': 1,
#  'i': 1,
#  'atsin-mi-i-n': 1,
#  'kini': 2,
#  'më-atsin-mët-i-n': 1,
#  'uinbi': 1,
#  'piti': 3,
#  'xo': 1,
#  'rabé̈okë': 1,
#  'nunti': 1,
#  'kini-i-ín': 1,
#  'naë': 1,
#  'matat-i-ín': 1,
#  'linterna': 1,
#  'tirit-o-a-n': 1,
#  'imé̈': 1,
#  '‘i-këbëtan': 1,
#  'bëtsi': 1,
#  '‘a-akë-n': 1,
#  'kënë': 2,
#  'xaiki-këbë': 1,
#  'nipakët-a-x-a': 2,
#  'emilionë': 1,
#  'xaika-këx': 1,
#  'hotel': 2,
#  '=uki': 2,
#  'xukën': 2,
#  'u-i-a': 2,
#  'rakwët-i-n': 2,
#  '‘inu': 2,
#  'rabanan': 2,
#  '=nën': 2,
#  'name': 2,
#  'pipania': 2,
#  'chaxkë´': 1,
#  "'ati": 1,
#  "'aaxa": 1,
#  'parunuti': 2,
#  'pabëntamëti': 1,
#  'pabí': 1,
#  'bëntamëti': 1,
#  'uinbirës': 1,
#  'rërëkanux': 2,
#  'tsóbuakëxa': 2,
#  'bai': 2,
#  '‘ipasu': 2,
#  'comodiezaños': 1,
#  'aish': 1,
#  'tsókën': 1,
#  'santarosa': 1,
#  'tsipúmi': 1,
#  "'ibu": 1,
#  'nai': 1,
#  '=ax': 1,
#  'uakëxa': 1,
#  'bari': 1,
#  'këntí': 1,
#  'ichútmiaxa': 1,
#  'uri': 1,
#  'xaë': 1,
#  'mëraxa': 1,
#  'anuxun': 1,
#  'bake': 1,
#  'bëchikë': 2,
#  'ini': 1,
#  "'óina": 1,
#  'chunena': 1,
#  'pitankëxun': 1,
#  'kaniotin': 1,
#  'kana': 2,
#  'rani': 3,
#  'xon': 2,
#  'ranikananuna': 1,
#  'tsipunu': 1,
#  'bëtanitin': 2,
#  '=nanuna': 3,
#  'tsipu': 1,
#  'monument': 1,
#  '=sapi': 1,
#  'pucallpa': 1,
#  'chuna': 1,
#  'unitín': 1,
#  'ratuaxa': 1,
#  "'aishbi": 1,
#  "'iakëxa": 1,
#  'chumíbukë': 1,
#  'bamati': 1,
#  'ura': 1,
#  'kwainkin': 1,
#  '=shi': 1,
#  'maë': 1,
#  'matsunkubuinia': 1,
#  'rëakëxa': 1,
#  'bëráma': 2,
#  '‘ia': 2,
#  'ñuikasin': 2,
#  'bëru-ax': 1,
#  'bëru-an': 1,
#  'ukairi': 1,
#  'tënka-pat-akë-x-ín': 1,
#  'u-but-kin': 1,
#  'is': 1,
#  'rët-uku-but-an': 1,
#  'atian': 1,
#  'casi': 1,
#  'kwan-akë-x-ín': 1,
#  'toxama': 1,
#  'bits-tankëxun': 2,
#  'taish': 1,
#  '‘aru-i-n': 1,
#  'paën-xun': 1,
#  '‘atsa': 1,
#  'kwëën-i-n': 1,
#  'emilio': 1,
#  'mas': 1,
#  'xuá': 1,
#  'papaokë': 1,
#  '=kama': 1,
#  'chaxké': 1,
#  'siná': 1,
#  '‘i-akë-x-a': 1,
#  'maru-kin': 1,
#  'no-n': 1,
#  'buan-akë-x-ín': 1}

# %%
num_types = len(dict_frec_types)

# %%
num_types
# Out:
# 285

# %%
num_tokens = sum(dict_frec_types.values())

# %%
num_tokens
# Out:
# 808

# %%
types_frec = types_mas_frecuentes(lista_diccionarios_corpus,len(lista_diccionarios_corpus))

# %%
types_frec
# Out:
# [('ka', 88),
#  ('=a', 52),
#  ('=n', 51),
#  ('_', 24),
#  ('=is', 22),
#  ('=na', 20),
#  ('=nu', 18),
#  ('uni', 15),
#  ('‘ë', 13),
#  ('a', 13),
#  ('nukën', 11),
#  ('achushi', 10),
#  ('ain', 10),
#  ('xubu', 9),
#  ('=ma', 7),
#  ('=x', 7),
#  ('“', 7),
#  ('”', 7),
#  ("'ë", 6),
#  ("'ikën", 6),
#  ('ë', 6),
#  ('‘ë', 6),
#  ('mi', 5),
#  ('roberto', 5),
#  ('ënë', 5),
#  ('‘ikën', 5),
#  ('chaiti', 4),
#  ('chaxu', 4),
#  ('pi-ti', 4),
#  ('xanu', 4),
#  ('bënë', 4),
#  ('min', 4),
#  ('kakëshín', 4),
#  ('=bi', 4),
#  ('‘ain', 4),
#  ('tita', 4),
#  ('=ñu', 3),
#  ('bana', 3),
#  ("'ain", 3),
#  ('kwan-ti', 3),
#  ('nu', 3),
#  ('‘anibu', 3),
#  ('an', 3),
#  ('‘aisama', 3),
#  ('ñu', 3),
#  ('tanu', 3),
#  ('ki', 3),
#  ('‘ó', 3),
#  ('piti', 3),
#  ('rani', 3),
#  ('=nanuna', 3),
#  ('norte', 2),
#  ("'ó", 2),
#  ('nami', 2),
#  ('pi-akë-x-a', 2),
#  ('=bëtan', 2),
#  ('baka', 2),
#  ('=xun', 2),
#  ('=ishi', 2),
#  ('=mina', 2),
#  ('aguaytia', 2),
#  ('më-uxu', 2),
#  (' =n', 2),
#  ('buankian', 2),
#  ('unirá', 2),
#  ('‘atankëxun', 2),
#  ('‘ëribi', 2),
#  ('maëxratsukun', 2),
#  ('‘a', 2),
#  ('taë', 2),
#  ('tëbiskati', 2),
#  ('bëruan', 2),
#  ('upí', 2),
#  ('‘itsa', 2),
#  ('‘axankëbë', 2),
#  ('kamabi', 2),
#  ('nëtë', 2),
#  ('anun', 2),
#  ('ma', 2),
#  ('shi', 2),
#  ('nun', 2),
#  ('nanë', 2),
#  ('itsirá', 2),
#  ('nipáxun', 2),
#  ('ñuiti', 2),
#  ('ñuxanrá', 2),
#  ('kini', 2),
#  ('kënë', 2),
#  ('nipakët-a-x-a', 2),
#  ('hotel', 2),
#  ('=uki', 2),
#  ('xukën', 2),
#  ('u-i-a', 2),
#  ('rakwët-i-n', 2),
#  ('‘inu', 2),
#  ('rabanan', 2),
#  ('=nën', 2),
#  ('name', 2),
#  ('pipania', 2),
#  ('parunuti', 2),
#  ('rërëkanux', 2),
#  ('tsóbuakëxa', 2),
#  ('bai', 2),
#  ('‘ipasu', 2),
#  ('bëchikë', 2),
#  ('kana', 2),
#  ('xon', 2),
#  ('bëtanitin', 2),
#  ('bëráma', 2),
#  ('‘ia', 2),
#  ('ñuikasin', 2),
#  ('bits-tankëxun', 2),
#  ('juan', 1),
#  ('=mënë', 1),
#  ('kuriki', 1),
#  ('mëkama-iéé', 1),
#  ('tsó-akë-x-a', 1),
#  ('tsó-xun', 1),
#  ('chaiti-baë', 1),
#  ('no', 1),
#  ("'a-akë-x-a", 1),
#  ('ñui-xun-kian', 1),
#  ("'atsa", 1),
#  ("'inan", 1),
#  ('chaxkë', 1),
#  ("xubu'", 1),
#  ('a-ti', 1),
#  ("'a-a-x-a", 1),
#  ('munu', 1),
#  ('imëshi', 1),
#  ('mëkën', 1),
#  ('ta-tani-katsi', 1),
#  ('ki-xun', 1),
#  ('rakan-bian-a-n', 1),
#  ('tënka-këbë', 1),
#  ('ëëëëëë', 1),
#  ('ki-i', 1),
#  ('bë-man-mët-akë-xín', 1),
#  ('atsin-i-n', 1),
#  ('usa', 1),
#  ('‘isenaka', 1),
#  ('rataxtamainun', 1),
#  ('chëkiai', 1),
#  ('usai', 1),
#  ('ëo', 1),
#  ('kamëokëxa', 1),
#  ('chaitibaë', 1),
#  ('xutabaë', 1),
#  ('bu', 1),
#  ('tsatsa', 1),
#  ('!', 1),
#  ('kwëënin', 1),
#  ('xarákë', 1),
#  ('ësaokin', 1),
#  ('mane', 1),
#  ('toinkë', 1),
#  ('‘ixunmabi', 1),
#  ('puin', 1),
#  ('kaisa', 1),
#  ('[', 1),
#  ('...', 1),
#  ('pui', 1),
#  ('kaxu', 1),
#  ('kwankëxa', 1),
#  ('buankëxa', 1),
#  ('bëxuñurá', 1),
#  ('‘ikë', 1),
#  ('bënë', 1),
#  ('‘akë', 1),
#  ('=sa', 1),
#  ('okin', 1),
#  ('maso', 1),
#  ('churukukwainkin', 1),
#  ('xënirá', 1),
#  ('makwëxakëshín', 1),
#  ('kwëëni', 1),
#  ('‘itankëxun', 1),
#  ('kakëxa', 1),
#  ('anu', 1),
#  ('xëni', 1),
#  ('‘ati', 1),
#  ('kupë', 1),
#  ('atsa', 1),
#  ('bitstanmainun', 1),
#  ('xanu-xun', 1),
#  ('‘atapa', 1),
#  ('‘a-a-x-a', 1),
#  ('=pain', 1),
#  ('‘a-a-x-a‘a', 1),
#  ('‘inan', 1),
#  ('imëishi', 1),
#  ('i', 1),
#  ('atsin-mi-i-n', 1),
#  ('më-atsin-mët-i-n', 1),
#  ('uinbi', 1),
#  ('xo', 1),
#  ('rabé̈okë', 1),
#  ('nunti', 1),
#  ('kini-i-ín', 1),
#  ('naë', 1),
#  ('matat-i-ín', 1),
#  ('linterna', 1),
#  ('tirit-o-a-n', 1),
#  ('imé̈', 1),
#  ('‘i-këbëtan', 1),
#  ('bëtsi', 1),
#  ('‘a-akë-n', 1),
#  ('xaiki-këbë', 1),
#  ('emilionë', 1),
#  ('xaika-këx', 1),
#  ('chaxkë´', 1),
#  ("'ati", 1),
#  ("'aaxa", 1),
#  ('pabëntamëti', 1),
#  ('pabí', 1),
#  ('bëntamëti', 1),
#  ('uinbirës', 1),
#  ('comodiezaños', 1),
#  ('aish', 1),
#  ('tsókën', 1),
#  ('santarosa', 1),
#  ('tsipúmi', 1),
#  ("'ibu", 1),
#  ('nai', 1),
#  ('=ax', 1),
#  ('uakëxa', 1),
#  ('bari', 1),
#  ('këntí', 1),
#  ('ichútmiaxa', 1),
#  ('uri', 1),
#  ('xaë', 1),
#  ('mëraxa', 1),
#  ('anuxun', 1),
#  ('bake', 1),
#  ('ini', 1),
#  ("'óina", 1),
#  ('chunena', 1),
#  ('pitankëxun', 1),
#  ('kaniotin', 1),
#  ('ranikananuna', 1),
#  ('tsipunu', 1),
#  ('tsipu', 1),
#  ('monument', 1),
#  ('=sapi', 1),
#  ('pucallpa', 1),
#  ('chuna', 1),
#  ('unitín', 1),
#  ('ratuaxa', 1),
#  ("'aishbi", 1),
#  ("'iakëxa", 1),
#  ('chumíbukë', 1),
#  ('bamati', 1),
#  ('ura', 1),
#  ('kwainkin', 1),
#  ('=shi', 1),
#  ('maë', 1),
#  ('matsunkubuinia', 1),
#  ('rëakëxa', 1),
#  ('bëru-ax', 1),
#  ('bëru-an', 1),
#  ('ukairi', 1),
#  ('tënka-pat-akë-x-ín', 1),
#  ('u-but-kin', 1),
#  ('is', 1),
#  ('rët-uku-but-an', 1),
#  ('atian', 1),
#  ('casi', 1),
#  ('kwan-akë-x-ín', 1),
#  ('toxama', 1),
#  ('taish', 1),
#  ('‘aru-i-n', 1),
#  ('paën-xun', 1),
#  ('‘atsa', 1),
#  ('kwëën-i-n', 1),
#  ('emilio', 1),
#  ('mas', 1),
#  ('xuá', 1),
#  ('papaokë', 1),
#  ('=kama', 1),
#  ('chaxké', 1),
#  ('siná', 1),
#  ('‘i-akë-x-a', 1),
#  ('maru-kin', 1),
#  ('no-n', 1),
#  ('buan-akë-x-ín', 1)]

# %%
X = list(range(len(types_frec)))
Y = []

for item in types_frec:
    Y += [item[1]]

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(dpi=800)

plt.title('Ránking de frecuencias corpus Kakataibo',fontsize=12)

ax.plot(X,Y,marker='o',color='gold',markersize=3,markeredgewidth=0.5,markeredgecolor='k',alpha=0.75,linewidth=1,fillstyle='full')

for i in range(3):
    ax.annotate(types_frec[i][0], (X[i], Y[i]), fontsize=7)
    
#plt.grid(False)
#plt.legend(loc='best',fontsize=7)
plt.xlabel(r'ránking (frecuencia decreciente)',fontsize=10)
plt.ylabel(r'frecuencia de types',fontsize=10)
plt.rcParams.update({'font.size': 10})
plt.savefig('K.jpg', format='jpg', transparent=True, bbox_inches='tight',dpi=800)
plt.show()

# %% [markdown]
# Calcule para cada type la cantidad $-\log (p_t)$, donde $p_t$ es la frecuencia normalizada del type $t$ ¿Qué puede observar?

# %%
dict_probabilidades = {}

for key in dict_frec_types:
    dict_probabilidades[key]=dict_frec_types[key]/num_tokens

# %%
import math

# %%
dict_sorpresa = {}

for key in dict_frec_types:
    dict_sorpresa[key]=-math.log(dict_probabilidades[key])

# %%
types = [item[0] for item in types_frec]

# %%
entropia_kakataibo = 0

for key in types:
    entropia_kakataibo += dict_probabilidades[key]*dict_sorpresa[key]

# %%
X = []
Y = []

for key in types:
    X += [dict_probabilidades[key]]
    Y += [dict_sorpresa[key]]
    print(key,dict_frec_types[key],dict_probabilidades[key],dict_sorpresa[key])
# Out:
# ka 52 0.11279826464208242 2.182154324415221
# =a 33 0.07158351409978309 2.6368904815301684
# =n 25 0.05422993492407809 2.9145222181284476
# =na 13 0.028199566160520606 3.568448685535112
# =nu 12 0.026030368763557483 3.6484913932086482
# ‘ë 11 0.02386117136659436 3.735502770198278
# a 10 0.021691973969631236 3.8308129500026027
# =is 9 0.019522776572668113 3.936173465660429
# uni 8 0.01735357917570499 4.053956501316812
# xubu 8 0.01735357917570499 4.053956501316812
# achushi 7 0.015184381778741865 4.187487893941335
# =x 6 0.013015184381778741 4.341638573768593
# ain 6 0.013015184381778741 4.341638573768593
# mi 4 0.008676789587852495 4.747103681876758
# 'ë 4 0.008676789587852495 4.747103681876758
# 'ikën 4 0.008676789587852495 4.747103681876758
# nukën 4 0.008676789587852495 4.747103681876758
# ënë 3 0.006507592190889371 5.034785754328539
# ‘ó 3 0.006507592190889371 5.034785754328539
# ‘ain 3 0.006507592190889371 5.034785754328539
# ë 3 0.006507592190889371 5.034785754328539
# piti 3 0.006507592190889371 5.034785754328539
# pi-ti 3 0.006507592190889371 5.034785754328539
# =ma 3 0.006507592190889371 5.034785754328539
# ‘ikën 3 0.006507592190889371 5.034785754328539
# roberto 3 0.006507592190889371 5.034785754328539
# rani 3 0.006507592190889371 5.034785754328539
# =nanuna 3 0.006507592190889371 5.034785754328539
# “ 3 0.006507592190889371 5.034785754328539
# ” 3 0.006507592190889371 5.034785754328539
# ‘ë 3 0.006507592190889371 5.034785754328539
# kwan-ti 2 0.004338394793926247 5.440250862436703
# kini 2 0.004338394793926247 5.440250862436703
# ‘aisama 2 0.004338394793926247 5.440250862436703
# kënë 2 0.004338394793926247 5.440250862436703
# nipakët-a-x-a 2 0.004338394793926247 5.440250862436703
# hotel 2 0.004338394793926247 5.440250862436703
# =uki 2 0.004338394793926247 5.440250862436703
# xukën 2 0.004338394793926247 5.440250862436703
# u-i-a 2 0.004338394793926247 5.440250862436703
# rakwët-i-n 2 0.004338394793926247 5.440250862436703
# ‘inu 2 0.004338394793926247 5.440250862436703
# rabanan 2 0.004338394793926247 5.440250862436703
# =nën 2 0.004338394793926247 5.440250862436703
# name 2 0.004338394793926247 5.440250862436703
# pipania 2 0.004338394793926247 5.440250862436703
# =bi 2 0.004338394793926247 5.440250862436703
# parunuti 2 0.004338394793926247 5.440250862436703
# tanu 2 0.004338394793926247 5.440250862436703
# rërëkanux 2 0.004338394793926247 5.440250862436703
# tsóbuakëxa 2 0.004338394793926247 5.440250862436703
# bai 2 0.004338394793926247 5.440250862436703
# ‘ipasu 2 0.004338394793926247 5.440250862436703
# bëchikë 2 0.004338394793926247 5.440250862436703
# kana 2 0.004338394793926247 5.440250862436703
# xon 2 0.004338394793926247 5.440250862436703
# bëtanitin 2 0.004338394793926247 5.440250862436703
# bëráma 2 0.004338394793926247 5.440250862436703
# nu 2 0.004338394793926247 5.440250862436703
# ‘anibu 2 0.004338394793926247 5.440250862436703
# ‘ia 2 0.004338394793926247 5.440250862436703
# ñuikasin 2 0.004338394793926247 5.440250862436703
# bënë 2 0.004338394793926247 5.440250862436703
# min 2 0.004338394793926247 5.440250862436703
# kakëshín 2 0.004338394793926247 5.440250862436703
# ki 2 0.004338394793926247 5.440250862436703
# bits-tankëxun 2 0.004338394793926247 5.440250862436703
# xanu-xun 1 0.0021691973969631237 6.133398042996649
# ‘atapa 1 0.0021691973969631237 6.133398042996649
# ‘a-a-x-a 1 0.0021691973969631237 6.133398042996649
# =pain 1 0.0021691973969631237 6.133398042996649
# ‘a-a-x-a‘a 1 0.0021691973969631237 6.133398042996649
# =ishi 1 0.0021691973969631237 6.133398042996649
# ñu 1 0.0021691973969631237 6.133398042996649
# ‘inan 1 0.0021691973969631237 6.133398042996649
# imëishi 1 0.0021691973969631237 6.133398042996649
# aguaytia 1 0.0021691973969631237 6.133398042996649
# i 1 0.0021691973969631237 6.133398042996649
# atsin-mi-i-n 1 0.0021691973969631237 6.133398042996649
# më-atsin-mët-i-n 1 0.0021691973969631237 6.133398042996649
# uinbi 1 0.0021691973969631237 6.133398042996649
# =ñu 1 0.0021691973969631237 6.133398042996649
# xo 1 0.0021691973969631237 6.133398042996649
# rabé̈okë 1 0.0021691973969631237 6.133398042996649
# nunti 1 0.0021691973969631237 6.133398042996649
# kini-i-ín 1 0.0021691973969631237 6.133398042996649
# naë 1 0.0021691973969631237 6.133398042996649
# matat-i-ín 1 0.0021691973969631237 6.133398042996649
# linterna 1 0.0021691973969631237 6.133398042996649
# =mina 1 0.0021691973969631237 6.133398042996649
# tirit-o-a-n 1 0.0021691973969631237 6.133398042996649
# imé̈ 1 0.0021691973969631237 6.133398042996649
# ‘i-këbëtan 1 0.0021691973969631237 6.133398042996649
# bëtsi 1 0.0021691973969631237 6.133398042996649
# ‘a-akë-n 1 0.0021691973969631237 6.133398042996649
# xaiki-këbë 1 0.0021691973969631237 6.133398042996649
# emilionë 1 0.0021691973969631237 6.133398042996649
# xaika-këx 1 0.0021691973969631237 6.133398042996649
# chaxkë´ 1 0.0021691973969631237 6.133398042996649
# =bëtan 1 0.0021691973969631237 6.133398042996649
# 'ati 1 0.0021691973969631237 6.133398042996649
# 'ain 1 0.0021691973969631237 6.133398042996649
# baka 1 0.0021691973969631237 6.133398042996649
# =xun 1 0.0021691973969631237 6.133398042996649
# chaxu 1 0.0021691973969631237 6.133398042996649
# 'aaxa 1 0.0021691973969631237 6.133398042996649
# pabëntamëti 1 0.0021691973969631237 6.133398042996649
# pabí 1 0.0021691973969631237 6.133398042996649
# bëntamëti 1 0.0021691973969631237 6.133398042996649
# uinbirës 1 0.0021691973969631237 6.133398042996649
# comodiezaños 1 0.0021691973969631237 6.133398042996649
# aish 1 0.0021691973969631237 6.133398042996649
# tsókën 1 0.0021691973969631237 6.133398042996649
# santarosa 1 0.0021691973969631237 6.133398042996649
# tsipúmi 1 0.0021691973969631237 6.133398042996649
# 'ibu 1 0.0021691973969631237 6.133398042996649
# nai 1 0.0021691973969631237 6.133398042996649
# =ax 1 0.0021691973969631237 6.133398042996649
# uakëxa 1 0.0021691973969631237 6.133398042996649
# bari 1 0.0021691973969631237 6.133398042996649
# këntí 1 0.0021691973969631237 6.133398042996649
# ichútmiaxa 1 0.0021691973969631237 6.133398042996649
# uri 1 0.0021691973969631237 6.133398042996649
# xaë 1 0.0021691973969631237 6.133398042996649
# mëraxa 1 0.0021691973969631237 6.133398042996649
# anuxun 1 0.0021691973969631237 6.133398042996649
# bake 1 0.0021691973969631237 6.133398042996649
# ini 1 0.0021691973969631237 6.133398042996649
# 'óina 1 0.0021691973969631237 6.133398042996649
# chunena 1 0.0021691973969631237 6.133398042996649
# pitankëxun 1 0.0021691973969631237 6.133398042996649
# kaniotin 1 0.0021691973969631237 6.133398042996649
# ranikananuna 1 0.0021691973969631237 6.133398042996649
# tsipunu 1 0.0021691973969631237 6.133398042996649
# tsipu 1 0.0021691973969631237 6.133398042996649
# monument 1 0.0021691973969631237 6.133398042996649
# =sapi 1 0.0021691973969631237 6.133398042996649
# pucallpa 1 0.0021691973969631237 6.133398042996649
# chuna 1 0.0021691973969631237 6.133398042996649
# unitín 1 0.0021691973969631237 6.133398042996649
# ratuaxa 1 0.0021691973969631237 6.133398042996649
# 'aishbi 1 0.0021691973969631237 6.133398042996649
# 'iakëxa 1 0.0021691973969631237 6.133398042996649
# chumíbukë 1 0.0021691973969631237 6.133398042996649
# bamati 1 0.0021691973969631237 6.133398042996649
# ura 1 0.0021691973969631237 6.133398042996649
# kwainkin 1 0.0021691973969631237 6.133398042996649
# =shi 1 0.0021691973969631237 6.133398042996649
# tita 1 0.0021691973969631237 6.133398042996649
# ñuxanrá 1 0.0021691973969631237 6.133398042996649
# maë 1 0.0021691973969631237 6.133398042996649
# matsunkubuinia 1 0.0021691973969631237 6.133398042996649
# rëakëxa 1 0.0021691973969631237 6.133398042996649
# xanu 1 0.0021691973969631237 6.133398042996649
#  =n 1 0.0021691973969631237 6.133398042996649
# buankian 1 0.0021691973969631237 6.133398042996649
# unirá 1 0.0021691973969631237 6.133398042996649
# ‘atankëxun 1 0.0021691973969631237 6.133398042996649
# ‘ëribi 1 0.0021691973969631237 6.133398042996649
# maëxratsukun 1 0.0021691973969631237 6.133398042996649
# ‘a 1 0.0021691973969631237 6.133398042996649
# anun 1 0.0021691973969631237 6.133398042996649
# ma 1 0.0021691973969631237 6.133398042996649
# shi 1 0.0021691973969631237 6.133398042996649
# nun 1 0.0021691973969631237 6.133398042996649
# nanë 1 0.0021691973969631237 6.133398042996649
# itsirá 1 0.0021691973969631237 6.133398042996649
# nipáxun 1 0.0021691973969631237 6.133398042996649
# bëru-ax 1 0.0021691973969631237 6.133398042996649
# bëru-an 1 0.0021691973969631237 6.133398042996649
# ukairi 1 0.0021691973969631237 6.133398042996649
# tënka-pat-akë-x-ín 1 0.0021691973969631237 6.133398042996649
# u-but-kin 1 0.0021691973969631237 6.133398042996649
# is 1 0.0021691973969631237 6.133398042996649
# rët-uku-but-an 1 0.0021691973969631237 6.133398042996649
# atian 1 0.0021691973969631237 6.133398042996649
# casi 1 0.0021691973969631237 6.133398042996649
# kamabi 1 0.0021691973969631237 6.133398042996649
# nëtë 1 0.0021691973969631237 6.133398042996649
# kwan-akë-x-ín 1 0.0021691973969631237 6.133398042996649
# toxama 1 0.0021691973969631237 6.133398042996649
# upí 1 0.0021691973969631237 6.133398042996649
# taish 1 0.0021691973969631237 6.133398042996649
# ‘aru-i-n 1 0.0021691973969631237 6.133398042996649
# paën-xun 1 0.0021691973969631237 6.133398042996649
# ‘atsa 1 0.0021691973969631237 6.133398042996649
# kwëën-i-n 1 0.0021691973969631237 6.133398042996649
# emilio 1 0.0021691973969631237 6.133398042996649
# mas 1 0.0021691973969631237 6.133398042996649
# xuá 1 0.0021691973969631237 6.133398042996649
# papaokë 1 0.0021691973969631237 6.133398042996649
# =kama 1 0.0021691973969631237 6.133398042996649
# chaxké 1 0.0021691973969631237 6.133398042996649
# siná 1 0.0021691973969631237 6.133398042996649
# ‘i-akë-x-a 1 0.0021691973969631237 6.133398042996649
# maru-kin 1 0.0021691973969631237 6.133398042996649
# no-n 1 0.0021691973969631237 6.133398042996649
# buan-akë-x-ín 1 0.0021691973969631237 6.133398042996649

# %%
fig, ax = plt.subplots(dpi=800)

plt.title('Probabilidad versus sorpresa corpus Kakataibo',fontsize=12)

ax.plot(X,Y,marker='D',color='fuchsia',markersize=3,markeredgewidth=0.5,markeredgecolor='k',alpha=0.75,linewidth=1,fillstyle='full')
    
#plt.grid(False)
#plt.legend(loc='best',fontsize=7)
plt.xlabel(r'probabilidad',fontsize=10)
plt.ylabel(r'sorpresa',fontsize=10)
plt.rcParams.update({'font.size': 10})
plt.savefig('PvsS.jpg', format='jpg', transparent=True, bbox_inches='tight',dpi=800)
plt.show()

# %%
entropia_kakataibo
# Out:
# 4.570958059632577

# %% [markdown]
# Construya un **diccionario {frecuencia:lista de types con esa frecuencia}** para cada frecuencia del corpus.

# %%
len(dict_frec_types)
# Out:
# 198

# %%
sum(dict_frec_types.values())
# Out:
# 461

# %%
frecuencias = list(set(dict_frec_types.values()))

# %%
frecuencias
# Out:
# [1, 33, 3, 2, 4, 6, 7, 8, 9, 10, 11, 12, 13, 52, 25]

# %%
D_frecuencias_lista = {}

for f in frecuencias:
    D_frecuencias_lista[f]=[]

# %%
for palabra in dict_frec_types.keys():
    frec = dict_frec_types[palabra]
    D_frecuencias_lista[frec]+=[palabra]

# %%
D_frecuencias_lista[3]
# Out:
# ['ënë',
#  '‘ó',
#  '‘ain',
#  'ë',
#  'piti',
#  'pi-ti',
#  '=ma',
#  '‘ikën',
#  'roberto',
#  'rani',
#  '=nanuna',
#  '“',
#  '”',
#  '‘ë']

# %% [markdown]
# Construya un **diccionario {frecuencia:número de veces que aparece esa frecuencia}** para cada frecuencia del corpus.

# %%
D_frec_numero = {}

for key in D_frecuencias_lista.keys():
    D_frec_numero[key]=len(D_frecuencias_lista[key])

# %%
D_frec_numero
# Out:
# {1: 131,
#  33: 1,
#  3: 14,
#  2: 36,
#  4: 4,
#  6: 2,
#  7: 1,
#  8: 2,
#  9: 1,
#  10: 1,
#  11: 1,
#  12: 1,
#  13: 1,
#  52: 1,
#  25: 1}

# %%
X = list(D_frec_numero.keys())
Y = list(D_frec_numero.values())

# %%
sum(X)
# Out:
# 196

# %%
fig, ax = plt.subplots(dpi=800)

plt.title('Frecuencia de aparición vs. número de types corpus Kakataibo',fontsize=9)
ax.plot(X,Y,marker='o',color='gold',markersize=3,markeredgewidth=0.5,markeredgecolor='k',alpha=0.75,linewidth=1,fillstyle='full')

#plt.grid(False)
#plt.legend(loc='best',fontsize=7)
plt.xlabel(r'frecuencia',fontsize=10)
plt.ylabel(r'número de types',fontsize=10)
plt.rcParams.update({'font.size': 10})
plt.savefig('frec_num.jpg', format='jpg', transparent=True, bbox_inches='tight',dpi=800)
plt.show()

# %% [markdown]
# Suponga que el número de tokens es $n$. Si las palabras sucesivas están numeradas desde la palabra 1, luego 2, hasta la palabra $n$, la **distancia** entre dos palabras en posiciones $i$ y $j$ se define como $|i-j|$.

# %% [markdown]
# Para una oración, calcule las distancias entre **cada token** y la **raiz (head)**. Identifique primero la posición de **head**.

# %%
oracion = kakataibo[6]

# %%
oracion
# Out:
# TokenList<Uinbi, ka, =a, ‘ë, =n, piti, pi-ti, =ma, ‘ikën, .>

# %%
token = oracion[6]

# %%
token
# Out:
# {'id': 7,
#  'form': 'pi-ti',
#  'lemma': 'piti',
#  'upos': 'NOUN',
#  'xpos': None,
#  'feats': None,
#  'head': None,
#  'deprel': '_',
#  'deps': None,
#  'misc': {'eat-nomlz': ''}}

# %%
def head_oracion(oracion):
    
    for token in oracion:
        if token['head']==0 or token['head']==None:
            head_id = token['id']
            
    return head_id

# %%
head_id = head_oracion(oracion)

# %%
import numpy as np

distancias_head = []

for token in oracion:
    distancia = np.abs(token['id']-head_id)
    distancias_head+=[distancia]

# %%
distancias_head
# Out:
# [6, 5, 4, 3, 2, 1, 0, 1, 2, 3]

# %%
import numpy as np

def distancias_head(oracion):
    
    head_id = head_oracion(oracion)
    distancias_head = []

    for token in oracion:
        distancia = np.abs(token['id']-head_id)
        distancias_head+=[distancia]
    return np.mean(distancias_head),np.max(distancias_head)

# %%
distancias_head(oracion)
# Out:
# (2.7, 6)

# %%
for token in oracion:
    print(token['form'],token['id'],token['head'])
# Out:
# Uinbi 1 7
# ka 2 7
# =a 3 7
# ‘ë 4 6
# =n 5 4
# piti 6 7
# pi-ti 7 None
# =ma 8 7
# ‘ikën 9 7
# . 10 9

# %%
import numpy as np
largos = []

for d in kakataibo[0]:
    largos += [np.abs(d['id']-d['head'])]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_35560/3304513170.py in <module>
#       3
#       4 for d in kakataibo[0]:
# ----> 5     largos += [np.abs(d['id']-d['head'])]
#
# TypeError: unsupported operand type(s) for -: 'int' and 'NoneType'

# %%
np.mean(largos)
# Out:
# 4.0

# %% [markdown]
# Calcule el **largo de dependencias** **promedio**, **máximo** y **mínimo**.

# %% [markdown]
# [Paper :)](liu-dependencies-2017.pdf)

# %% [markdown]
# [otro paper :)](W19-7911.pdf)

# %% [markdown]
# Desordene **aleatoriamente las dependencias de las oraciones.** Use

# %%
import random

A = [1,2,3]

A_random = random.sample(A,len(A))

# %%
A_random
# Out:
# [2, 1, 3]

# %% [markdown]
# Cree 100 versiones aleatorias de las dependencias de una oración. Guárdelas en una lista.
